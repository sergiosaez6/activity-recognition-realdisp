# %% [markdown]
# # CNN

# %%
import tensorflow.keras as keras

# %%
# Módulos necesarios. Asegurarse de poder importarlos.
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from pylab import rcParams
from scipy import stats
from sklearn import metrics
import seaborn as sns
from sklearn import preprocessing
import os as os
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
from time import time

# Config the matplotlib backend as plotting inline in IPython
# %matplotlib inline

# %%
import sys
print(sys.executable)
print(sys.version)
print(sys.version_info)
tf.__version__
# Out:
# /usr/bin/python
# 3.6.8 (default, Aug 20 2019, 17:12:48)
# [GCC 8.3.0]
# sys.version_info(major=3, minor=6, micro=8, releaselevel='final', serial=0)
# '1.14.0'

# %%
keras.__version__
# Out:
# '2.2.4-tf'

# %% [markdown]
# # 12-FOLD

# %%
subjects = ['01', '02', '03', '05', '08', '09', '10', '11', '13', '14', '16', '17']
global activities
activities = [9,10,11,12,13,19,20,21,24,25,31]

# %%
# Ajustado a los datos
n_time_steps = 128
n_classes = 11 # Nº de clases (el 0 está eliminado)
n_channels = 1 # Nº de canales
n_columns = 20

# Podríamos variarlo
batch_size = 128 # Tamaño del batch
learning_rate = 1e-3 # Learning rate (por defecto es 0.001)
epochs = 100 # Épocas

# %%
class LearningRateDecay:
    def plot(self, epochs, title="Learning Rate Schedule"):
        # compute the set of learning rates for each corresponding
        # epoch
        lrs = [self(i) for i in epochs]
 
        # the learning rate schedule
        plt.style.use("ggplot")
        plt.figure()
        plt.plot(epochs, lrs)
        plt.title(title)
        plt.xlabel("Epoch #")
        plt.ylabel("Learning Rate")
class StepDecay(LearningRateDecay):
    def __init__(self, initAlpha=0.01, factor=0.25, dropEvery=10):
        # store the base initial learning rate, drop factor, and
        # epochs to drop every
        self.initAlpha = initAlpha
        self.factor = factor
        self.dropEvery = dropEvery
 
    def __call__(self, epoch):
        # compute the learning rate for the current epoch
        exp = np.floor((1 + epoch) / self.dropEvery)
        alpha = self.initAlpha * (self.factor ** exp)
        if(alpha<1e-9):
            alpha=1e-9

        # return the learning rate
        return float(alpha) 

schedule = StepDecay(initAlpha=learning_rate, factor=0.4, dropEvery=10)

reduce_lr = keras.callbacks.LearningRateScheduler(schedule, verbose = 1)
callbacks_list = [reduce_lr]

# %%
#Visualize training evolution
def plot_curves(model, acc, loss, val_acc, val_loss, subject_test):
    #########################################################################################
    # LOSS plot
    plt.figure(figsize=(12,8))
    plt.plot(model.history.history[loss], label='Training loss')
    plt.xlabel('Epochs', fontsize=15)
    plt.ylabel('Loss', fontsize=15)
    plt.tick_params(labelsize=10)
    plt.legend(loc=1,prop={'size': 10})
    plt.title('Loss in trainnig', fontsize=20)
    fig = plt.gcf()
    plt.show()
    
    fig.savefig('./000_1_RAW_SP/loss_train_000_1_RAW_SP_KFOLD_'+subject_test+'.pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./000_1_RAW_SP/loss_train_000_1_RAW_SP_KFOLD_'+subject_test+'svg', bbox_inches='tight',format='svg')
    
    #########################################################################################
    # ACC plot
    plt.figure(figsize=(12,8))
    plt.plot(model.history.history[acc], label='Training accuracy')
    plt.xlabel('Epochs', fontsize=15)
    plt.ylabel('Accuracy', fontsize=15)
    plt.tick_params(labelsize=10)
    plt.legend(loc=1,prop={'size': 10})
    plt.title('Accuracy in training', fontsize=20)
    fig = plt.gcf()
    plt.show()

    fig.savefig('./000_1_RAW_SP/acc_train_000_1_RAW_SP_KFOLD_'+subject_test+'pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./000_1_RAW_SP/acc_train_000_1_RAW_SP_KFOLD_'+subject_test+'svg', bbox_inches='tight',format='svg')
    
    #########################################################################################
    # ACC+LOSS plot
    plt.figure(figsize=(14,10))
    plt_loss = host_subplot(111, axes_class=AA.Axes)
    plt.subplots_adjust(right=0.75)

    plt_acc = plt_loss.twinx()
    plt_acc.axis["right"].toggle(all=True)
    
    plt_loss.set_xlim(0, len(model.history.history[loss]))
    plt_loss.set_ylim(0, max(model.history.history[loss]))
    plt_loss.set_xlabel('Epochs')
    plt_loss.set_ylabel('Loss')
    plt_acc.set_ylabel('Accuracy')
                        
    plt_loss.axis['left'].label.set_fontsize(15)
    plt_loss.axis['bottom'].label.set_fontsize(15)
    plt_acc.axis['right'].label.set_fontsize(15)
    
    plt_loss.plot(model.history.history[loss], c='tab:blue', ls='--', label='Training loss')
    plt_acc.plot(model.history.history[acc], c='tab:orange',ls='--', label='Training accuracy')
    
    plt.tick_params(labelsize=10)
    plt.title('Training performance', fontsize=20)
    plt_acc.set_ylim(0, 1)
    plt_loss.legend(loc=1, prop={'size': 10})
    
    fig = plt.gcf()
    plt.show()

    fig.savefig('./000_1_RAW_SP/all_train_000_1_RAW_SP_KFOLD_'+subject_test+'pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./000_1_RAW_SP/all_train_000_1_RAW_SP_KFOLD_'+subject_test+'svg', bbox_inches='tight',format='svg')

# %%
def plot_confusion_matrix(y_true, y_pred, subject_test, classes,
                          cmap=plt.cm.Blues):

    # Compute confusion matrix
    cm = metrics.confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(20, 20))
    sns.heatmap(cm, xticklabels=classes, yticklabels=classes, square = True, robust = True, annot=True, cmap='YlOrBr')
    plt.title('CONFUSION MATRIX')
    plt.ylabel('TRUE ACTIVITY')
    plt.xlabel('PREDICTION')
    
    locs, labels = plt.xticks()
    plt.xticks(locs, labels, rotation='vertical')
    locs, labels = plt.yticks()
    plt.yticks(locs, labels, rotation='horizontal')

    # Guardamos la imagen en formato vectorial
    plt.draw()
    plt.savefig('./000_1_RAW_SP/matriz_confusion_'+subject_test+'.svg', bbox_inches='tight',format='svg')
    plt.show()

# %%
accuracies = []
for i in range(12):
    print('##################################################################################################################################')
    print('#####################################################  K-FOLD %d  ################################################################'%(i+1))
    
    subject_test = subjects[i]
    subjects_train = [s for s in subjects if s not in subject_test]
    print('Training subjects: ' + str(subjects_train))
    print('Test subject: ' + str(subject_test))
    
    ##  GENERACIÓN DATASET
    tr_seg = np.concatenate((np.load('./raw/subject_'+subjects_train[0]+'_seg.npy'),np.load('./raw/subject_'+subjects_train[1]+'_seg.npy'),np.load('./raw/subject_'+subjects_train[2]+'_seg.npy'),np.load('./raw/subject_'+subjects_train[3]+'_seg.npy'),
                             np.load('./raw/subject_'+subjects_train[4]+'_seg.npy'),np.load('./raw/subject_'+subjects_train[5]+'_seg.npy'),np.load('./raw/subject_'+subjects_train[6]+'_seg.npy'),np.load('./raw/subject_'+subjects_train[7]+'_seg.npy'),
                             np.load('./raw/subject_'+subjects_train[8]+'_seg.npy'),np.load('./raw/subject_'+subjects_train[9]+'_seg.npy'),np.load('./raw/subject_'+subjects_train[10]+'_seg.npy')))
    tr_lab = np.concatenate((np.load('./raw/subject_'+subjects_train[0]+'_lab.npy'),np.load('./raw/subject_'+subjects_train[1]+'_lab.npy'),np.load('./raw/subject_'+subjects_train[2]+'_lab.npy'),np.load('./raw/subject_'+subjects_train[3]+'_lab.npy'),
                             np.load('./raw/subject_'+subjects_train[4]+'_lab.npy'),np.load('./raw/subject_'+subjects_train[5]+'_lab.npy'),np.load('./raw/subject_'+subjects_train[6]+'_lab.npy'),np.load('./raw/subject_'+subjects_train[7]+'_lab.npy'),
                             np.load('./raw/subject_'+subjects_train[8]+'_lab.npy'),np.load('./raw/subject_'+subjects_train[9]+'_lab.npy'),np.load('./raw/subject_'+subjects_train[10]+'_lab.npy')))


    ts_seg = np.load('./raw/subject_'+subject_test+'_seg.npy')
    ts_lab = np.load('./raw/subject_'+subject_test+'_lab.npy')
    
    limit = 20
    tr_seg = tr_seg[:,:,:,:limit]
    ts_seg = ts_seg[:,:,:,:limit]
    ####################################################################################################################
    ## SHUFFLE DE DATOS
    np.random.seed(235)
    tr_seg = np.reshape(tr_seg[np.random.shuffle(np.arange(0,tr_seg.shape[0]))], (11*98,1,128,limit))
    tr_lab = np.reshape(tr_lab[np.random.shuffle(np.arange(0,tr_seg.shape[0]))], (11*98,11))

    np.random.seed(235)
    ts_seg = np.reshape(ts_seg[np.random.shuffle(np.arange(0,ts_seg.shape[0]))], (98,1,128,limit))
    ts_lab = np.reshape(ts_lab[np.random.shuffle(np.arange(0,ts_seg.shape[0]))], (98,11))
    
    print('Train dataset: ')
    print(tr_seg.shape, tr_lab.shape)
    print('Test dataset: ')
    print(ts_seg.shape, ts_lab.shape)
    ####################################################################################################################
    ## VISTA DE DFT-2D
    plt.figure(figsize=(30,30))
    plt.imshow(np.log(np.abs(np.fft.fftshift(tr_seg[0,0,:,20:40].T))**2))
    plt.show()
    print('Activity: ',activities[np.argmax(tr_lab[0])])

    plt.figure(figsize=(30,30))
    plt.imshow(np.log(np.fft.fftshift(tr_seg[10,0,:,20:40].T)**2))
    plt.show()
    print('Activity: ',activities[np.argmax(tr_lab[10])])
    ####################################################################################################################
    ## RED
    quat_input = keras.Input(shape=(n_channels, n_time_steps, n_columns), name='input_layer')

    # Some convolutional layers
    conv_1 = keras.layers.Conv2D(16, kernel_size=4,padding='same',activation='relu', data_format = 'channels_first')(quat_input)
    max_1 = keras.layers.MaxPooling2D(pool_size=2, strides=2, padding='same', data_format = 'channels_first')(conv_1)
    bn_1 = keras.layers.BatchNormalization(axis=1)(max_1)
    conv_2 = keras.layers.Conv2D(32,kernel_size=4, padding='same',activation='relu', data_format = 'channels_first')(bn_1)
    max_2 = keras.layers.MaxPooling2D(pool_size=2, strides=2, padding='same', data_format = 'channels_first')(conv_2)

    # Flatten the output of the convolutional layers
    conv_flat = keras.layers.Flatten()(max_2)

    # Output layers: separate outputs for the weather and the ground labels
    multiclass_output = keras.layers.Dense(n_classes, activation='softmax',name='activity_class')(conv_flat)
    
    # Creamos la estrcutura que contendrá a nuestro modelo
    model = keras.Model(inputs=quat_input, outputs=[multiclass_output],name='cnn')

    # Compilamos el modelo
    model.compile(optimizer=keras.optimizers.Adam(lr=learning_rate),
                  loss='categorical_crossentropy', metrics=['categorical_accuracy'])
    
    print(model.summary())
    ####################################################################################################################
    ## TRAIN
    history = model.fit(tr_seg,
                        tr_lab,
                        epochs = epochs,
                        steps_per_epoch = None,
                        verbose = 1,
                        batch_size = batch_size,
                        callbacks = callbacks_list)
    model.save('./000_1_RAW_SP/CNN_'+subject_test+'.h5')
    
    #Visualize training evolution
    plot_curves(model, 'categorical_accuracy', 'loss', 'val_categorical_accuracy', 'val_loss', subject_test)
    ####################################################################################################################
    ## TEST
    predictions = model.predict(ts_seg, batch_size = batch_size, verbose = 1)
    
    print(predictions.shape)
    
    y_pred = np.argmax(predictions,axis=-1)
    y_pred = np.expand_dims(y_pred,axis=-1)
    print(y_pred[:100].T)
    
    y_true = np.argmax(ts_lab,axis=-1)
    y_true = np.expand_dims(y_true,axis=-1)
    print(y_true.shape)
    print(y_true[:100].T)
    
    evaluation = model.evaluate(ts_seg, ts_lab, batch_size=batch_size, verbose=1)
    accuracies.append(evaluation[1])
    
    fo = open('./000_1_RAW_SP/accuracy_'+subject_test+'.txt', "w")
    fo.seek(0,2)
    fo.write(str(evaluation))
    fo.close()
    
    ####################################################################################################################
    ## CONFUSION MATRIX
    y_true_flat = np.ndarray.flatten(y_true)
    y_pred_flat = np.ndarray.flatten(y_pred)
    
    plot_confusion_matrix(y_true_flat, y_pred_flat, subject_test, classes=activities)
    
    del subject_test, subjects_train, limit, tr_seg, tr_lab, ts_seg, ts_lab, model, history, y_pred, y_true, predictions, evaluation, y_true_flat, y_pred_flat
# Out:
# ##################################################################################################################################
# #####################################################  K-FOLD 1  ################################################################
# Training subjects: ['02', '03', '05', '08', '09', '10', '11', '13', '14', '16', '17']
# Test subject: 01
# Train dataset:
# (1078, 1, 128, 20) (1078, 11)
# Test dataset:
# (98, 1, 128, 20) (98, 11)
# /usr/local/lib/python3.6/dist-packages/matplotlib/image.py:857: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=-0.5, top=-0.5
#   self.axes.set_ylim((ymin, ymax), auto=None)
# Activity:  10
# Activity:  10
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 20)]      0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 16, 128, 20)       272
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 64, 10)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 16, 64, 10)        64
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 64, 10)        8224
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 5)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 5120)              0
# _________________________________________________________________
# activity_class (Dense)       (None, 11)                56331
# =================================================================
# Total params: 64,891
# Trainable params: 64,859
# Non-trainable params: 32
# _________________________________________________________________
# None
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/100
# 1078/1078 [==============================] - 2s 2ms/sample - loss: 2.4978 - categorical_accuracy: 0.2486
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/100
# 1078/1078 [==============================] - 0s 142us/sample - loss: 1.1338 - categorical_accuracy: 0.6104
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.6166 - categorical_accuracy: 0.7978
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.3134 - categorical_accuracy: 0.9212
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.1590 - categorical_accuracy: 0.9703
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/100
# 1078/1078 [==============================] - 0s 85us/sample - loss: 0.0796 - categorical_accuracy: 0.9944
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0493 - categorical_accuracy: 0.9981
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0378 - categorical_accuracy: 0.9981
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/100
# 1078/1078 [==============================] - 0s 85us/sample - loss: 0.0272 - categorical_accuracy: 0.9991
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 10/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0196 - categorical_accuracy: 1.0000
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 11/100
# 1078/1078 [==============================] - 0s 87us/sample - loss: 0.0184 - categorical_accuracy: 1.0000
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 12/100
# 1078/1078 [==============================] - 0s 85us/sample - loss: 0.0167 - categorical_accuracy: 1.0000
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 13/100
# 1078/1078 [==============================] - 0s 87us/sample - loss: 0.0152 - categorical_accuracy: 1.0000
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 14/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0139 - categorical_accuracy: 1.0000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 15/100
# 1078/1078 [==============================] - 0s 87us/sample - loss: 0.0129 - categorical_accuracy: 1.0000
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 16/100
# 1078/1078 [==============================] - 0s 85us/sample - loss: 0.0121 - categorical_accuracy: 1.0000
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 17/100
# 1078/1078 [==============================] - 0s 85us/sample - loss: 0.0118 - categorical_accuracy: 1.0000
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 18/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0107 - categorical_accuracy: 1.0000
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 19/100
# 1078/1078 [==============================] - 0s 85us/sample - loss: 0.0100 - categorical_accuracy: 1.0000
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 20/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0096 - categorical_accuracy: 1.0000
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 21/100
# 1078/1078 [==============================] - 0s 87us/sample - loss: 0.0093 - categorical_accuracy: 1.0000
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 22/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0090 - categorical_accuracy: 1.0000
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 23/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0090 - categorical_accuracy: 1.0000
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 24/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0086 - categorical_accuracy: 1.0000
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 25/100
# 1078/1078 [==============================] - 0s 87us/sample - loss: 0.0083 - categorical_accuracy: 1.0000
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 26/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0082 - categorical_accuracy: 1.0000
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 27/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0078 - categorical_accuracy: 1.0000
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 28/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0078 - categorical_accuracy: 1.0000
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 29/100
# 1078/1078 [==============================] - 0s 87us/sample - loss: 0.0075 - categorical_accuracy: 1.0000
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 30/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0074 - categorical_accuracy: 1.0000
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 31/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0073 - categorical_accuracy: 1.0000
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 32/100
# 1078/1078 [==============================] - 0s 85us/sample - loss: 0.0073 - categorical_accuracy: 1.0000
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 33/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0072 - categorical_accuracy: 1.0000
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 34/100
# 1078/1078 [==============================] - 0s 85us/sample - loss: 0.0072 - categorical_accuracy: 1.0000
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 35/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0070 - categorical_accuracy: 1.0000
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 36/100
# 1078/1078 [==============================] - 0s 85us/sample - loss: 0.0069 - categorical_accuracy: 1.0000
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 37/100
# 1078/1078 [==============================] - 0s 85us/sample - loss: 0.0069 - categorical_accuracy: 1.0000
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 38/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0068 - categorical_accuracy: 1.0000
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 39/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0067 - categorical_accuracy: 1.0000
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 40/100
# 1078/1078 [==============================] - 0s 85us/sample - loss: 0.0066 - categorical_accuracy: 1.0000
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 41/100
# 1078/1078 [==============================] - 0s 85us/sample - loss: 0.0067 - categorical_accuracy: 1.0000
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 42/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0065 - categorical_accuracy: 1.0000
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 43/100
# 1078/1078 [==============================] - 0s 84us/sample - loss: 0.0066 - categorical_accuracy: 1.0000
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 44/100
# 1078/1078 [==============================] - 0s 84us/sample - loss: 0.0067 - categorical_accuracy: 1.0000
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 45/100
# 1078/1078 [==============================] - 0s 87us/sample - loss: 0.0065 - categorical_accuracy: 1.0000
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 46/100
# 1078/1078 [==============================] - 0s 85us/sample - loss: 0.0066 - categorical_accuracy: 1.0000
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 47/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0065 - categorical_accuracy: 1.0000
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 48/100
# 1078/1078 [==============================] - 0s 85us/sample - loss: 0.0064 - categorical_accuracy: 1.0000
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 49/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0064 - categorical_accuracy: 1.0000
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 50/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0065 - categorical_accuracy: 1.0000
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 51/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0064 - categorical_accuracy: 1.0000
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 52/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0065 - categorical_accuracy: 1.0000
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 53/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0063 - categorical_accuracy: 1.0000
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 54/100
# 1078/1078 [==============================] - 0s 85us/sample - loss: 0.0064 - categorical_accuracy: 1.0000
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 55/100
# 1078/1078 [==============================] - 0s 87us/sample - loss: 0.0065 - categorical_accuracy: 1.0000
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 56/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0064 - categorical_accuracy: 1.0000
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 57/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0064 - categorical_accuracy: 1.0000
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 58/100
# 1078/1078 [==============================] - 0s 85us/sample - loss: 0.0063 - categorical_accuracy: 1.0000
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 59/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0063 - categorical_accuracy: 1.0000
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 60/100
# 1078/1078 [==============================] - 0s 85us/sample - loss: 0.0062 - categorical_accuracy: 1.0000
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 61/100
# 1078/1078 [==============================] - 0s 85us/sample - loss: 0.0062 - categorical_accuracy: 1.0000
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 62/100
# 1078/1078 [==============================] - 0s 85us/sample - loss: 0.0063 - categorical_accuracy: 1.0000
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 63/100
# 1078/1078 [==============================] - 0s 84us/sample - loss: 0.0062 - categorical_accuracy: 1.0000
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 64/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0063 - categorical_accuracy: 1.0000
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 65/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0063 - categorical_accuracy: 1.0000
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 66/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0063 - categorical_accuracy: 1.0000
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 67/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0063 - categorical_accuracy: 1.0000
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 68/100
# 1078/1078 [==============================] - 0s 85us/sample - loss: 0.0063 - categorical_accuracy: 1.0000
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 69/100
# 1078/1078 [==============================] - 0s 87us/sample - loss: 0.0064 - categorical_accuracy: 1.0000
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 70/100
# 1078/1078 [==============================] - 0s 87us/sample - loss: 0.0062 - categorical_accuracy: 1.0000
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 71/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0063 - categorical_accuracy: 1.0000
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 72/100
# 1078/1078 [==============================] - 0s 85us/sample - loss: 0.0062 - categorical_accuracy: 1.0000
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 73/100
# 1078/1078 [==============================] - 0s 87us/sample - loss: 0.0062 - categorical_accuracy: 1.0000
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 74/100
# 1078/1078 [==============================] - 0s 89us/sample - loss: 0.0064 - categorical_accuracy: 1.0000
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 75/100
# 1078/1078 [==============================] - 0s 87us/sample - loss: 0.0062 - categorical_accuracy: 1.0000
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 76/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0063 - categorical_accuracy: 1.0000
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 77/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0063 - categorical_accuracy: 1.0000
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 78/100
# 1078/1078 [==============================] - 0s 85us/sample - loss: 0.0061 - categorical_accuracy: 1.0000
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 79/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0062 - categorical_accuracy: 1.0000
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 80/100
# 1078/1078 [==============================] - 0s 87us/sample - loss: 0.0062 - categorical_accuracy: 1.0000
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 81/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0062 - categorical_accuracy: 1.0000
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 82/100
# 1078/1078 [==============================] - 0s 85us/sample - loss: 0.0062 - categorical_accuracy: 1.0000
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 83/100
# 1078/1078 [==============================] - 0s 85us/sample - loss: 0.0063 - categorical_accuracy: 1.0000
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 84/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0063 - categorical_accuracy: 1.0000
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 85/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0062 - categorical_accuracy: 1.0000
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 86/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0062 - categorical_accuracy: 1.0000
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 87/100
# 1078/1078 [==============================] - 0s 87us/sample - loss: 0.0062 - categorical_accuracy: 1.0000
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 88/100
# 1078/1078 [==============================] - 0s 85us/sample - loss: 0.0062 - categorical_accuracy: 1.0000
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 89/100
# 1078/1078 [==============================] - 0s 87us/sample - loss: 0.0063 - categorical_accuracy: 1.0000
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 90/100
# 1078/1078 [==============================] - 0s 96us/sample - loss: 0.0061 - categorical_accuracy: 1.0000
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 91/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0062 - categorical_accuracy: 1.0000
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 92/100
# 1078/1078 [==============================] - 0s 84us/sample - loss: 0.0063 - categorical_accuracy: 1.0000
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 93/100
# 1078/1078 [==============================] - 0s 87us/sample - loss: 0.0061 - categorical_accuracy: 1.0000
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 94/100
# 1078/1078 [==============================] - 0s 87us/sample - loss: 0.0062 - categorical_accuracy: 1.0000
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 95/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0061 - categorical_accuracy: 1.0000
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 96/100
# 1078/1078 [==============================] - 0s 85us/sample - loss: 0.0062 - categorical_accuracy: 1.0000
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 97/100
# 1078/1078 [==============================] - 0s 89us/sample - loss: 0.0063 - categorical_accuracy: 1.0000
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 98/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0062 - categorical_accuracy: 1.0000
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 99/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0061 - categorical_accuracy: 1.0000
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 1.0485760000000006e-07.
# Epoch 100/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0062 - categorical_accuracy: 1.0000
# 98/98 [==============================] - 0s 921us/sample
# (98, 11)
# [[ 2  7  8  1  0 10  7  8  3  7 10  0  1  8  3 10  2  2  8  1 10 10 10  1
#    8  3 10  1  0 10  0  3  0 10  1 10  3  1 10  2  1  2  2  1 10  8  1 10
#    8 10  8  0  0  8  1  2  8  8 10  8 10 10  1  7  3 10  3 10 10 10 10  1
#    1  8 10  8  3 10  8  7  2  8  1  1  1  8  2 10  1  7  7 10  7  0  3  0
#    8  7]]
# (98, 1)
# [[ 2  7  9  4  0  5  7  8  3  7 10  0  4  9  3  6  2  2  8  1 10  5 10  4
#    8  3  6  1  0  5  0  3  0 10  1  6  3  4  5  2  4  2  2  4  5  8  1  5
#    8  5  9  0  0  8  1  2  9  8  6  9  6 10  1  7  3  6  3 10  6 10  6  1
#    1  8  5  9  3  6  9  7  2  9  4  4  4  8  2  5  1  7  7 10  7  0  3  0
#    9  7]]
# 98/98 [==============================] - 0s 994us/sample - loss: 1.4827 - categorical_accuracy: 0.6327
# ##################################################################################################################################
# #####################################################  K-FOLD 2  ################################################################
# Training subjects: ['01', '03', '05', '08', '09', '10', '11', '13', '14', '16', '17']
# Test subject: 02
# Train dataset:
# (1078, 1, 128, 20) (1078, 11)
# Test dataset:
# (98, 1, 128, 20) (98, 11)
# /usr/local/lib/python3.6/dist-packages/matplotlib/image.py:857: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=-0.5, top=-0.5
#   self.axes.set_ylim((ymin, ymax), auto=None)
# Activity:  11
# Activity:  31
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 20)]      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 128, 20)       272
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 64, 10)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 64, 10)        64
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 64, 10)        8224
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 32, 32, 5)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 5120)              0
# _________________________________________________________________
# activity_class (Dense)       (None, 11)                56331
# =================================================================
# Total params: 64,891
# Trainable params: 64,859
# Non-trainable params: 32
# _________________________________________________________________
# None
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/100
# 1078/1078 [==============================] - 0s 222us/sample - loss: 2.5484 - categorical_accuracy: 0.2514
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 1.0686 - categorical_accuracy: 0.6419
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.5083 - categorical_accuracy: 0.8785
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.2175 - categorical_accuracy: 0.9722
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/100
# 1078/1078 [==============================] - 0s 91us/sample - loss: 0.1195 - categorical_accuracy: 0.9787
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0633 - categorical_accuracy: 0.9963
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0406 - categorical_accuracy: 0.9991
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0280 - categorical_accuracy: 1.0000
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/100
# 1078/1078 [==============================] - 0s 87us/sample - loss: 0.0185 - categorical_accuracy: 1.0000
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 10/100
# 1078/1078 [==============================] - 0s 91us/sample - loss: 0.0155 - categorical_accuracy: 1.0000
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 11/100
# 1078/1078 [==============================] - 0s 89us/sample - loss: 0.0145 - categorical_accuracy: 1.0000
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 12/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0131 - categorical_accuracy: 1.0000
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 13/100
# 1078/1078 [==============================] - 0s 95us/sample - loss: 0.0122 - categorical_accuracy: 1.0000
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 14/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0114 - categorical_accuracy: 1.0000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 15/100
# 1078/1078 [==============================] - 0s 89us/sample - loss: 0.0108 - categorical_accuracy: 1.0000
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 16/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0102 - categorical_accuracy: 1.0000
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 17/100
# 1078/1078 [==============================] - 0s 91us/sample - loss: 0.0098 - categorical_accuracy: 1.0000
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 18/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0091 - categorical_accuracy: 1.0000
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 19/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0087 - categorical_accuracy: 1.0000
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 20/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0083 - categorical_accuracy: 1.0000
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 21/100
# 1078/1078 [==============================] - 0s 89us/sample - loss: 0.0080 - categorical_accuracy: 1.0000
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 22/100
# 1078/1078 [==============================] - 0s 89us/sample - loss: 0.0078 - categorical_accuracy: 1.0000
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 23/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0078 - categorical_accuracy: 1.0000
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 24/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0075 - categorical_accuracy: 1.0000
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 25/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0073 - categorical_accuracy: 1.0000
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 26/100
# 1078/1078 [==============================] - 0s 89us/sample - loss: 0.0072 - categorical_accuracy: 1.0000
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 27/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0069 - categorical_accuracy: 1.0000
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 28/100
# 1078/1078 [==============================] - 0s 87us/sample - loss: 0.0069 - categorical_accuracy: 1.0000
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 29/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0067 - categorical_accuracy: 1.0000
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 30/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0065 - categorical_accuracy: 1.0000
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 31/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0065 - categorical_accuracy: 1.0000
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 32/100
# 1078/1078 [==============================] - 0s 87us/sample - loss: 0.0065 - categorical_accuracy: 1.0000
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 33/100
# 1078/1078 [==============================] - 0s 91us/sample - loss: 0.0064 - categorical_accuracy: 1.0000
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 34/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0063 - categorical_accuracy: 1.0000
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 35/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0063 - categorical_accuracy: 1.0000
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 36/100
# 1078/1078 [==============================] - 0s 89us/sample - loss: 0.0062 - categorical_accuracy: 1.0000
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 37/100
# 1078/1078 [==============================] - 0s 93us/sample - loss: 0.0062 - categorical_accuracy: 1.0000
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 38/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0061 - categorical_accuracy: 1.0000
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 39/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0060 - categorical_accuracy: 1.0000
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 40/100
# 1078/1078 [==============================] - 0s 89us/sample - loss: 0.0060 - categorical_accuracy: 1.0000
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 41/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0061 - categorical_accuracy: 1.0000
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 42/100
# 1078/1078 [==============================] - 0s 87us/sample - loss: 0.0059 - categorical_accuracy: 1.0000
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 43/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0058 - categorical_accuracy: 1.0000
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 44/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0060 - categorical_accuracy: 1.0000
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 45/100
# 1078/1078 [==============================] - 0s 89us/sample - loss: 0.0059 - categorical_accuracy: 1.0000
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 46/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0058 - categorical_accuracy: 1.0000
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 47/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0058 - categorical_accuracy: 1.0000
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 48/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0058 - categorical_accuracy: 1.0000
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 49/100
# 1078/1078 [==============================] - 0s 91us/sample - loss: 0.0058 - categorical_accuracy: 1.0000
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 50/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0058 - categorical_accuracy: 1.0000
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 51/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0057 - categorical_accuracy: 1.0000
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 52/100
# 1078/1078 [==============================] - 0s 89us/sample - loss: 0.0058 - categorical_accuracy: 1.0000
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 53/100
# 1078/1078 [==============================] - 0s 89us/sample - loss: 0.0058 - categorical_accuracy: 1.0000
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 54/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0057 - categorical_accuracy: 1.0000
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 55/100
# 1078/1078 [==============================] - 0s 89us/sample - loss: 0.0058 - categorical_accuracy: 1.0000
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 56/100
# 1078/1078 [==============================] - 0s 87us/sample - loss: 0.0057 - categorical_accuracy: 1.0000
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 57/100
# 1078/1078 [==============================] - 0s 93us/sample - loss: 0.0058 - categorical_accuracy: 1.0000
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 58/100
# 1078/1078 [==============================] - 0s 87us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 59/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0057 - categorical_accuracy: 1.0000
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 60/100
# 1078/1078 [==============================] - 0s 89us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 61/100
# 1078/1078 [==============================] - 0s 91us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 62/100
# 1078/1078 [==============================] - 0s 89us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 63/100
# 1078/1078 [==============================] - 0s 89us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 64/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 65/100
# 1078/1078 [==============================] - 0s 89us/sample - loss: 0.0057 - categorical_accuracy: 1.0000
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 66/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 67/100
# 1078/1078 [==============================] - 0s 89us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 68/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 69/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0057 - categorical_accuracy: 1.0000
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 70/100
# 1078/1078 [==============================] - 0s 86us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 71/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0057 - categorical_accuracy: 1.0000
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 72/100
# 1078/1078 [==============================] - 0s 87us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 73/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 74/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 75/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 76/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0058 - categorical_accuracy: 1.0000
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 77/100
# 1078/1078 [==============================] - 0s 94us/sample - loss: 0.0057 - categorical_accuracy: 1.0000
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 78/100
# 1078/1078 [==============================] - 0s 87us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 79/100
# 1078/1078 [==============================] - 0s 89us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 80/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 81/100
# 1078/1078 [==============================] - 0s 89us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 82/100
# 1078/1078 [==============================] - 0s 91us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 83/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 84/100
# 1078/1078 [==============================] - 0s 87us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 85/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 86/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 87/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 88/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0057 - categorical_accuracy: 1.0000
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 89/100
# 1078/1078 [==============================] - 0s 89us/sample - loss: 0.0057 - categorical_accuracy: 1.0000
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 90/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 91/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 92/100
# 1078/1078 [==============================] - 0s 87us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 93/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 94/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 95/100
# 1078/1078 [==============================] - 0s 89us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 96/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 97/100
# 1078/1078 [==============================] - 0s 91us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 98/100
# 1078/1078 [==============================] - 0s 89us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 99/100
# 1078/1078 [==============================] - 0s 89us/sample - loss: 0.0055 - categorical_accuracy: 1.0000
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 1.0485760000000006e-07.
# Epoch 100/100
# 1078/1078 [==============================] - 0s 87us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
# 98/98 [==============================] - 0s 428us/sample
# (98, 11)
# [[ 1  4  5  2  2 10  7  0  8  6  1  5  9  4  5  2  4  9  4  9  4  0  8  1
#    0  2  1  8  3  9  6  7  6  9  8  3  8  7  4 10  0 10  5  4  4  0  7  6
#    7 10  5  3  7  9 10  8  0  2  1  3  0  9  6  0  8  9 10  4  5  6  5  6
#    5  7  3  8  4  4  3  3  8  3  3  2  2  6  2 10  0  6  9  7  2  4  6  5
#    7  4]]
# (98, 1)
# [[ 1  4  5  2  2 10  7  0  8  6  1  5  9  4  5  2  4  9  1  9  4  0  8  1
#    0  2  1  8  3  9  6  7  6  9  8  3  8  7  1 10  0 10  5  4  4  0  7  6
#    7 10  5  3  7  9 10  8  0  2  1  3  0  9  6  0  8  9 10  1  5  6  5  6
#    5  7  3  8  1  4  3  3  8  3  3  2  2  6  2 10  0 10  9  7  2  4  6  5
#    7  4]]
# 98/98 [==============================] - 0s 621us/sample - loss: 0.1036 - categorical_accuracy: 0.9490
# ##################################################################################################################################
# #####################################################  K-FOLD 3  ################################################################
# Training subjects: ['01', '02', '05', '08', '09', '10', '11', '13', '14', '16', '17']
# Test subject: 03
# Train dataset:
# (1078, 1, 128, 20) (1078, 11)
# Test dataset:
# (98, 1, 128, 20) (98, 11)
# /usr/local/lib/python3.6/dist-packages/matplotlib/image.py:857: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=-0.5, top=-0.5
#   self.axes.set_ylim((ymin, ymax), auto=None)
# Activity:  11
# Activity:  31
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 20)]      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 128, 20)       272
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 64, 10)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 64, 10)        64
# _________________________________________________________________
# ...
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 27/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0070 - categorical_accuracy: 1.0000
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 28/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0070 - categorical_accuracy: 1.0000
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 29/100
# 1078/1078 [==============================] - 0s 92us/sample - loss: 0.0073 - categorical_accuracy: 1.0000
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 30/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0066 - categorical_accuracy: 1.0000
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 31/100
# 1078/1078 [==============================] - 0s 92us/sample - loss: 0.0064 - categorical_accuracy: 1.0000
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 32/100
# 1078/1078 [==============================] - 0s 89us/sample - loss: 0.0067 - categorical_accuracy: 1.0000
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 33/100
# 1078/1078 [==============================] - 0s 91us/sample - loss: 0.0065 - categorical_accuracy: 1.0000
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 34/100
# 1078/1078 [==============================] - 0s 91us/sample - loss: 0.0063 - categorical_accuracy: 1.0000
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 35/100
# 1078/1078 [==============================] - 0s 91us/sample - loss: 0.0062 - categorical_accuracy: 1.0000
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 36/100
# 1078/1078 [==============================] - 0s 92us/sample - loss: 0.0062 - categorical_accuracy: 1.0000
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 37/100
# 1078/1078 [==============================] - 0s 91us/sample - loss: 0.0063 - categorical_accuracy: 1.0000
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 38/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0060 - categorical_accuracy: 1.0000
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 39/100
# 1078/1078 [==============================] - 0s 92us/sample - loss: 0.0060 - categorical_accuracy: 1.0000
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 40/100
# 1078/1078 [==============================] - 0s 92us/sample - loss: 0.0061 - categorical_accuracy: 1.0000
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 41/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0060 - categorical_accuracy: 1.0000
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 42/100
# 1078/1078 [==============================] - 0s 91us/sample - loss: 0.0059 - categorical_accuracy: 1.0000
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 43/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0058 - categorical_accuracy: 1.0000
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 44/100
# 1078/1078 [==============================] - 0s 91us/sample - loss: 0.0058 - categorical_accuracy: 1.0000
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 45/100
# 1078/1078 [==============================] - 0s 91us/sample - loss: 0.0059 - categorical_accuracy: 1.0000
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 46/100
# 1078/1078 [==============================] - 0s 99us/sample - loss: 0.0057 - categorical_accuracy: 1.0000
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 47/100
# 1078/1078 [==============================] - 0s 92us/sample - loss: 0.0058 - categorical_accuracy: 1.0000
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 48/100
# 1078/1078 [==============================] - 0s 92us/sample - loss: 0.0059 - categorical_accuracy: 1.0000
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 49/100
# 1078/1078 [==============================] - 0s 94us/sample - loss: 0.0058 - categorical_accuracy: 1.0000
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 50/100
# 1078/1078 [==============================] - 0s 91us/sample - loss: 0.0057 - categorical_accuracy: 1.0000
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 51/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0063 - categorical_accuracy: 1.0000
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 52/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0057 - categorical_accuracy: 1.0000
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 53/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 54/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0057 - categorical_accuracy: 1.0000
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 55/100
# 1078/1078 [==============================] - 0s 91us/sample - loss: 0.0058 - categorical_accuracy: 1.0000
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 56/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0058 - categorical_accuracy: 1.0000
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 57/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 58/100
# 1078/1078 [==============================] - 0s 92us/sample - loss: 0.0057 - categorical_accuracy: 1.0000
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 59/100
# 1078/1078 [==============================] - 0s 92us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 60/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0055 - categorical_accuracy: 1.0000
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 61/100
# 1078/1078 [==============================] - 0s 91us/sample - loss: 0.0058 - categorical_accuracy: 1.0000
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 62/100
# 1078/1078 [==============================] - 0s 91us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 63/100
# 1078/1078 [==============================] - 0s 91us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 64/100
# 1078/1078 [==============================] - 0s 91us/sample - loss: 0.0058 - categorical_accuracy: 1.0000
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 65/100
# 1078/1078 [==============================] - 0s 92us/sample - loss: 0.0055 - categorical_accuracy: 1.0000
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 66/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0057 - categorical_accuracy: 1.0000
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 67/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0059 - categorical_accuracy: 1.0000
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 68/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 69/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 70/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 71/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0057 - categorical_accuracy: 1.0000
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 72/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0057 - categorical_accuracy: 1.0000
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 73/100
# 1078/1078 [==============================] - 0s 91us/sample - loss: 0.0057 - categorical_accuracy: 1.0000
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 74/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0059 - categorical_accuracy: 1.0000
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 75/100
# 1078/1078 [==============================] - 0s 95us/sample - loss: 0.0055 - categorical_accuracy: 1.0000
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 76/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0055 - categorical_accuracy: 1.0000
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 77/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0057 - categorical_accuracy: 1.0000
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 78/100
# 1078/1078 [==============================] - 0s 91us/sample - loss: 0.0055 - categorical_accuracy: 1.0000
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 79/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 80/100
# 1078/1078 [==============================] - 0s 91us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 81/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0055 - categorical_accuracy: 1.0000
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 82/100
# 1078/1078 [==============================] - 0s 91us/sample - loss: 0.0054 - categorical_accuracy: 1.0000
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 83/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0055 - categorical_accuracy: 1.0000
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 84/100
# 1078/1078 [==============================] - 0s 93us/sample - loss: 0.0054 - categorical_accuracy: 1.0000
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 85/100
# 1078/1078 [==============================] - 0s 92us/sample - loss: 0.0055 - categorical_accuracy: 1.0000
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 86/100
# 1078/1078 [==============================] - 0s 91us/sample - loss: 0.0055 - categorical_accuracy: 1.0000
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 87/100
# 1078/1078 [==============================] - 0s 95us/sample - loss: 0.0054 - categorical_accuracy: 1.0000
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 88/100
# 1078/1078 [==============================] - 0s 92us/sample - loss: 0.0057 - categorical_accuracy: 1.0000
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 89/100
# 1078/1078 [==============================] - 0s 91us/sample - loss: 0.0055 - categorical_accuracy: 1.0000
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 90/100
# 1078/1078 [==============================] - 0s 91us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 91/100
# 1078/1078 [==============================] - 0s 88us/sample - loss: 0.0057 - categorical_accuracy: 1.0000
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 92/100
# 1078/1078 [==============================] - 0s 91us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 93/100
# 1078/1078 [==============================] - 0s 89us/sample - loss: 0.0055 - categorical_accuracy: 1.0000
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 94/100
# 1078/1078 [==============================] - 0s 96us/sample - loss: 0.0058 - categorical_accuracy: 1.0000
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 95/100
# 1078/1078 [==============================] - 0s 91us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 96/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0056 - categorical_accuracy: 1.0000
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 97/100
# 1078/1078 [==============================] - 0s 94us/sample - loss: 0.0055 - categorical_accuracy: 1.0000
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 98/100
# 1078/1078 [==============================] - 0s 92us/sample - loss: 0.0057 - categorical_accuracy: 1.0000
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 99/100
# 1078/1078 [==============================] - 0s 91us/sample - loss: 0.0055 - categorical_accuracy: 1.0000
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 1.0485760000000006e-07.
# Epoch 100/100
# 1078/1078 [==============================] - 0s 90us/sample - loss: 0.0057 - categorical_accuracy: 1.0000
# 98/98 [==============================] - 0s 1ms/sample
# (98, 11)
# [[ 1  1 10  8  4  8  6  7  4  8  6  2  3  8  4  7  3  4  1  6  6  8  8  1
#    2  7  7  8  6  8  6  1  3  2  4  7  0  8  6  0  7  1  7  8  8  8  3  7
#    7  6  6  8  9  1  1  7  3  1  3  7  7  2  1  1 10  8  4  7  0  4  3  8
#    8  1  3 10 10 10  2  1  2  6  4  8  2  7  2  0  2  8  7  8  6  8  6  1
#    3  4]]
# (98, 1)
# [[ 1  1 10  9  4  9  6  5  4  8  6  2  3  8  4  5  3  4  1  6 10  9  8  1
#    2  5  5  9 10  9  6  1  3  2  4  5  0  9 10  0  5  0  7  8  8  8  3  7
#    7  6  6  9  7  0  1  5  3  0  3  7  7  2  1  1 10  8  4  7  0  4  3  8
#    9  1  3 10 10 10  2  0  2  6  4  7  2  5  2  0  2  7  5  8  6  9  6  0
#    3  4]]
# 98/98 [==============================] - 0s 1ms/sample - loss: 0.8555 - categorical_accuracy: 0.7041

# %% [markdown]
# # Accuracy

# %%
sum = 0
for acc in accuracies:
    sum += acc
print('Accuracy of K-Fold: ' + str(sum/12))
# Out:
# Accuracy of K-Fold: 0.7806122551361719
