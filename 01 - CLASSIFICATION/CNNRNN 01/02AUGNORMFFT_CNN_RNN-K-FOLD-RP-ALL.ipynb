# %% [markdown]
# # CNN

# %%
import tensorflow.keras as keras

# %%
# Módulos necesarios. Asegurarse de poder importarlos.
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from pylab import rcParams
from scipy import stats
from sklearn import metrics
import seaborn as sns
from sklearn import preprocessing
import os as os
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
from time import time

# Config the matplotlib backend as plotting inline in IPython
# %matplotlib inline

# %%
import sys
print(sys.executable)
print(sys.version)
print(sys.version_info)
tf.__version__
# Out:
# /usr/bin/python
# 3.6.8 (default, Aug 20 2019, 17:12:48)
# [GCC 8.3.0]
# sys.version_info(major=3, minor=6, micro=8, releaselevel='final', serial=0)
# '1.14.0'

# %%
keras.__version__
# Out:
# '2.2.4-tf'

# %% [markdown]
# # 10-FOLD

# %%
subjects = ['01', '02', '03', '05', '08', '09', '10', '11', '13', '14', '16', '17']
global activities
activities = [9,10,11,12,13,19,20,21,24,25,31]

# %%
# Ajustado a los datos
n_time_steps = 128
n_classes = 11 # Nº de clases (el 0 está eliminado)
n_channels = 1 # Nº de canales
n_columns = 40

# Podríamos variarlo
batch_size = 128 # Tamaño del batch
learning_rate = 1e-3 # Learning rate (por defecto es 0.001)
epochs = 100 # Épocas

# %%
class LearningRateDecay:
    def plot(self, epochs, title="Learning Rate Schedule"):
        # compute the set of learning rates for each correRPonding
        # epoch
        lrs = [self(i) for i in epochs]
 
        # the learning rate schedule
        plt.style.use("ggplot")
        plt.figure()
        plt.plot(epochs, lrs)
        plt.title(title)
        plt.xlabel("Epoch #")
        plt.ylabel("Learning Rate")
class StepDecay(LearningRateDecay):
    def __init__(self, initAlpha=0.01, factor=0.25, dropEvery=10):
        # store the base initial learning rate, drop factor, and
        # epochs to drop every
        self.initAlpha = initAlpha
        self.factor = factor
        self.dropEvery = dropEvery
 
    def __call__(self, epoch):
        # compute the learning rate for the current epoch
        exp = np.floor((1 + epoch) / self.dropEvery)
        alpha = self.initAlpha * (self.factor ** exp)
        if(alpha<1e-9):
            alpha=1e-9

        # return the learning rate
        return float(alpha) 

schedule = StepDecay(initAlpha=learning_rate, factor=0.4, dropEvery=10)

reduce_lr = keras.callbacks.LearningRateScheduler(schedule, verbose = 1)
callbacks_list = [reduce_lr]

# %%
#Visualize training evolution
def plot_curves(model, acc, loss, val_acc, val_loss, kfold):
    #########################################################################################
    # LOSS plot
    plt.figure(figsize=(12,8))
    plt.plot(model.history.history[loss], label='Training loss')
    plt.xlabel('Epochs', fontsize=15)
    plt.ylabel('Loss', fontsize=15)
    plt.tick_params(labelsize=10)
    plt.legend(loc=1,prop={'size': 10})
    plt.title('Loss in trainnig', fontsize=20)
    fig = plt.gcf()
    plt.show()
    
    fig.savefig('./02AUGNORMFFT_RP_KFOLD_models/loss_train_02AUGNORMFFT_RP_KFOLD_'+kfold+'.pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./02AUGNORMFFT_RP_KFOLD_models/loss_train_02AUGNORMFFT_RP_KFOLD_'+kfold+'svg', bbox_inches='tight',format='svg')
    
    #########################################################################################
    # ACC plot
    plt.figure(figsize=(12,8))
    plt.plot(model.history.history[acc], label='Training accuracy')
    plt.xlabel('Epochs', fontsize=15)
    plt.ylabel('Accuracy', fontsize=15)
    plt.tick_params(labelsize=10)
    plt.legend(loc=1,prop={'size': 10})
    plt.title('Accuracy in training', fontsize=20)
    fig = plt.gcf()
    plt.show()

    fig.savefig('./02AUGNORMFFT_RP_KFOLD_models/acc_train_02AUGNORMFFT_RP_KFOLD_'+kfold+'pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./02AUGNORMFFT_RP_KFOLD_models/acc_train_02AUGNORMFFT_RP_KFOLD_'+kfold+'svg', bbox_inches='tight',format='svg')
    
    #########################################################################################
    # ACC+LOSS plot
    plt.figure(figsize=(14,10))
    plt_loss = host_subplot(111, axes_class=AA.Axes)
    plt.subplots_adjust(right=0.75)

    plt_acc = plt_loss.twinx()
    plt_acc.axis["right"].toggle(all=True)
    
    plt_loss.set_xlim(0, len(model.history.history[loss]))
    plt_loss.set_ylim(0, max(model.history.history[loss]))
    plt_loss.set_xlabel('Epochs')
    plt_loss.set_ylabel('Loss')
    plt_acc.set_ylabel('Accuracy')
                        
    plt_loss.axis['left'].label.set_fontsize(15)
    plt_loss.axis['bottom'].label.set_fontsize(15)
    plt_acc.axis['right'].label.set_fontsize(15)
    
    plt_loss.plot(model.history.history[loss], c='tab:blue', ls='--', label='Training loss')
    plt_acc.plot(model.history.history[acc], c='tab:orange',ls='--', label='Training accuracy')
    
    plt.tick_params(labelsize=10)
    plt.title('Training performance', fontsize=20)
    plt_acc.set_ylim(0, 1)
    plt_loss.legend(loc=1, prop={'size': 10})
    
    fig = plt.gcf()
    plt.show()

    fig.savefig('./02AUGNORMFFT_RP_KFOLD_models/all_train_02AUGNORMFFT_RP_KFOLD_'+kfold+'pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./02AUGNORMFFT_RP_KFOLD_models/all_train_02AUGNORMFFT_RP_KFOLD_'+kfold+'svg', bbox_inches='tight',format='svg')

# %%
def plot_confusion_matrix(y_true, y_pred, kfold, classes,
                          cmap=plt.cm.Blues):

    # Compute confusion matrix
    cm = metrics.confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(20, 20))
    sns.heatmap(cm, xticklabels=classes, yticklabels=classes, square = True, robust = True, annot=True, cmap='YlOrBr')
    plt.title('CONFUSION MATRIX')
    plt.ylabel('TRUE ACTIVITY')
    plt.xlabel('PREDICTION')
    
    locs, labels = plt.xticks()
    plt.xticks(locs, labels, rotation='vertical')
    locs, labels = plt.yticks()
    plt.yticks(locs, labels, rotation='horizontal')

    # Guardamos la imagen en formato vectorial
    plt.draw()
    plt.savefig('./02AUGNORMFFT_RP_KFOLD_models/matriz_confusion_'+kfold+'.svg', bbox_inches='tight',format='svg')
    plt.show()

# %%
global size
size = 26125

# %%
from sklearn.model_selection import KFold
S = np.arange(0,size)
kf = KFold(n_splits=10)
kf.get_n_splits(S)

print(kf)  

S_train = []
S_test = []

for train_index, test_index in kf.split(S):
    print("TRAIN:", train_index, "TEST:", test_index)
    print(S[train_index])
    print(S[test_index])
    S_train.append(S[train_index])
    S_test.append(S[test_index])
# Out:
# KFold(n_splits=10, random_state=None, shuffle=False)
# TRAIN: [ 2613  2614  2615 ... 26122 26123 26124] TEST: [   0    1    2 ... 2610 2611 2612]
# [ 2613  2614  2615 ... 26122 26123 26124]
# [   0    1    2 ... 2610 2611 2612]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [2613 2614 2615 ... 5223 5224 5225]
# [    0     1     2 ... 26122 26123 26124]
# [2613 2614 2615 ... 5223 5224 5225]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [5226 5227 5228 ... 7836 7837 7838]
# [    0     1     2 ... 26122 26123 26124]
# [5226 5227 5228 ... 7836 7837 7838]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [ 7839  7840  7841 ... 10449 10450 10451]
# [    0     1     2 ... 26122 26123 26124]
# [ 7839  7840  7841 ... 10449 10450 10451]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [10452 10453 10454 ... 13062 13063 13064]
# [    0     1     2 ... 26122 26123 26124]
# [10452 10453 10454 ... 13062 13063 13064]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [13065 13066 13067 ... 15674 15675 15676]
# [    0     1     2 ... 26122 26123 26124]
# [13065 13066 13067 ... 15674 15675 15676]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [15677 15678 15679 ... 18286 18287 18288]
# [    0     1     2 ... 26122 26123 26124]
# [15677 15678 15679 ... 18286 18287 18288]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [18289 18290 18291 ... 20898 20899 20900]
# [    0     1     2 ... 26122 26123 26124]
# [18289 18290 18291 ... 20898 20899 20900]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [20901 20902 20903 ... 23510 23511 23512]
# [    0     1     2 ... 26122 26123 26124]
# [20901 20902 20903 ... 23510 23511 23512]
# TRAIN: [    0     1     2 ... 23510 23511 23512] TEST: [23513 23514 23515 ... 26122 26123 26124]
# [    0     1     2 ... 23510 23511 23512]
# [23513 23514 23515 ... 26122 26123 26124]

# %%
accuracies = []
for i in range(10):
    if(i<10):
        kfold='0'+str(i)
    else:
        kfold=str(i)
    print('##################################################################################################################################')
    print('#####################################################  K-FOLD %d  ################################################################'%(i+1))
    
    subjects = ['01', '02', '03', '05', '08', '09', '10', '11', '13', '14', '16', '17']
    
    ##  GENERACIÓN DATASET
    tr_seg = np.concatenate((np.load('./augment_norm/subject_'+subjects[0]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects[1]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects[2]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects[3]+'_seg.npy'),
                             np.load('./augment_norm/subject_'+subjects[4]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects[5]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects[6]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects[7]+'_seg.npy'),
                             np.load('./augment_norm/subject_'+subjects[8]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects[9]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects[10]+'_seg.npy')))

    tr_lab = np.concatenate((np.load('./augment_norm/subject_'+subjects[0]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects[1]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects[2]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects[3]+'_lab.npy'),
                             np.load('./augment_norm/subject_'+subjects[4]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects[5]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects[6]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects[7]+'_lab.npy'),
                             np.load('./augment_norm/subject_'+subjects[8]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects[9]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects[10]+'_lab.npy')))
    
    limit = 40
    tr_seg = tr_seg[:,:,:,:limit]
    ####################################################################################################################
    ## SHUFFLE DE DATOS
    np.random.seed(235)
    tr_seg = np.reshape(tr_seg[np.random.shuffle(np.arange(0,tr_seg.shape[0]))], (size,1,128,limit))
    tr_lab = np.reshape(tr_lab[np.random.shuffle(np.arange(0,tr_seg.shape[0]))], (size,11))
    
    ts_seg = tr_seg[S_test[i]]
    ts_lab = tr_lab[S_test[i]]
    
    tr_seg = tr_seg[S_train[i]]
    tr_lab = tr_lab[S_train[i]]
    
    print('Train dataset: ')
    print(tr_seg.shape, tr_lab.shape)
    print('Test dataset: ')
    print(ts_seg.shape, ts_lab.shape)
    ####################################################################################################################
    ## VISTA DE DFT-2D
    plt.figure(figsize=(30,30))
    plt.imshow(np.log(np.abs(np.fft.fftshift(tr_seg[0,0,:,20:40].T))**2))
    plt.show()
    print('Activity: ',activities[np.argmax(tr_lab[0])])

    plt.figure(figsize=(30,30))
    plt.imshow(np.log(np.fft.fftshift(tr_seg[10,0,:,20:40].T)**2))
    plt.show()
    print('Activity: ',activities[np.argmax(tr_lab[10])])
    ####################################################################################################################
   ## RED
    quat_input = keras.Input(shape=(n_channels, n_time_steps, n_columns), name='input_layer')
    
    # Some convolutional layers
    conv_1 = keras.layers.Conv2D(32, kernel_size=4,padding='same',activation='relu', data_format = 'channels_first')(quat_input)
    max_1 = keras.layers.MaxPooling2D(pool_size=2, strides=2, padding='same', data_format = 'channels_first')(conv_1)
    bn_1 = keras.layers.BatchNormalization(axis=1)(max_1)
    conv_2 = keras.layers.Conv2D(64,kernel_size=4, padding='same',activation='relu', data_format = 'channels_first')(bn_1)
    max_2 = keras.layers.MaxPooling2D(pool_size=4, strides=4, padding='same', data_format = 'channels_first')(conv_2)
    bn_2 = keras.layers.BatchNormalization(axis=1)(max_2)
    conv_3 = keras.layers.Conv2D(32,kernel_size=4, padding='same',activation='relu', data_format = 'channels_first')(bn_2)
    max_3 = keras.layers.MaxPooling2D(pool_size=2, strides=2, padding='same', data_format = 'channels_first')(conv_3)
    bn_3 = keras.layers.BatchNormalization(axis=1)(max_3)

    # Flatten the output of the convolutional layers
    dr_2 = keras.layers.Dropout(0.5)(bn_3)

    units = 64

    res_1 = keras.layers.Reshape((12,units))(dr_2)

    gru_1 = keras.layers.GRU(units, activation='tanh', return_sequences=False, reset_after = False)(res_1)

    # Output layers: separate outputs for the weather and the ground labels
    multiclass_output = keras.layers.Dense(n_classes, activation='softmax',name='activity_class')(gru_1)

    # Creamos la estrcutura que contendrá a nuestro modelo
    model = keras.Model(inputs=quat_input, outputs=[multiclass_output],name='cnn')

    # Compilamos el modelo
    model.compile(optimizer=keras.optimizers.Adam(lr=learning_rate),
                  loss='categorical_crossentropy', metrics=['categorical_accuracy'])
    
    print(model.summary())
    ####################################################################################################################
    ## TRAIN
    history = model.fit(tr_seg,
                        tr_lab,
                        epochs = epochs,
                        steps_per_epoch = None,
                        verbose = 1,
                        batch_size = batch_size,
                        callbacks = callbacks_list)
    model.save('./02AUGNORMFFT_RP_KFOLD_models/CNN_'+kfold+'.h5')
    
    #Visualize training evolution
    plot_curves(model, 'categorical_accuracy', 'loss', 'val_categorical_accuracy', 'val_loss', kfold)
    ####################################################################################################################
    ## TEST
    predictions = model.predict(ts_seg, batch_size = batch_size, verbose = 1)
    
    print(predictions.shape)
    
    y_pred = np.argmax(predictions,axis=-1)
    y_pred = np.expand_dims(y_pred,axis=-1)
    print(y_pred[:100].T)
    
    y_true = np.argmax(ts_lab,axis=-1)
    y_true = np.expand_dims(y_true,axis=-1)
    print(y_true.shape)
    print(y_true[:100].T)
    
    evaluation = model.evaluate(ts_seg, ts_lab, batch_size=batch_size, verbose=1)
    accuracies.append(evaluation[1])
    
    fo = open('./02AUGNORMFFT_RP_KFOLD_models/accuracy_'+kfold+'.txt', "w")
    fo.seek(0,2)
    fo.write(str(evaluation))
    fo.close()
    
    ####################################################################################################################
    ## CONFUSION MATRIX
    y_true_flat = np.ndarray.flatten(y_true)
    y_pred_flat = np.ndarray.flatten(y_pred)
    
    plot_confusion_matrix(y_true_flat, y_pred_flat, kfold, classes=activities)
    
    del kfold, limit, tr_seg, tr_lab, ts_seg, ts_lab, model, history, y_pred, y_true, predictions, evaluation, y_true_flat, y_pred_flat
# Out:
# ##################################################################################################################################
# #####################################################  K-FOLD 8  ################################################################
# Train dataset:
# (23513, 1, 128, 40) (23513, 11)
# Test dataset:
# (2612, 1, 128, 40) (2612, 11)
# Activity:  13
# Activity:  25
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 40)]      0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 32, 128, 40)       544
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 64, 20)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 64, 20)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 20)        32832
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 16, 5)         0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 16, 5)         256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 16, 5)         32800
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 8, 3)          0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 8, 3)          128
# _________________________________________________________________
# dropout (Dropout)            (None, 32, 8, 3)          0
# _________________________________________________________________
# reshape (Reshape)            (None, 12, 64)            0
# _________________________________________________________________
# gru (GRU)                    (None, 64)                24768
# _________________________________________________________________
# activity_class (Dense)       (None, 11)                715
# =================================================================
# Total params: 92,171
# Trainable params: 91,915
# Non-trainable params: 256
# _________________________________________________________________
# None
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/100
# 23513/23513 [==============================] - 18s 771us/sample - loss: 0.7144 - categorical_accuracy: 0.7908
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 0.0468 - categorical_accuracy: 0.9930
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/100
# 23513/23513 [==============================] - 10s 431us/sample - loss: 0.0190 - categorical_accuracy: 0.9962
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 0.0227 - categorical_accuracy: 0.9939
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/100
# 23513/23513 [==============================] - 10s 429us/sample - loss: 0.0123 - categorical_accuracy: 0.9974
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 0.0074 - categorical_accuracy: 0.9983
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 0.0159 - categorical_accuracy: 0.9957
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 0.0087 - categorical_accuracy: 0.9977
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 0.0054 - categorical_accuracy: 0.9986
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 10/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 0.0016 - categorical_accuracy: 0.9997
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 11/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 7.9052e-04 - categorical_accuracy: 1.0000
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 12/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 6.0373e-04 - categorical_accuracy: 1.0000
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 13/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 8.8410e-04 - categorical_accuracy: 0.9999
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 14/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 6.1501e-04 - categorical_accuracy: 1.0000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 15/100
# 23513/23513 [==============================] - 10s 431us/sample - loss: 4.5528e-04 - categorical_accuracy: 1.0000
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 16/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 5.2954e-04 - categorical_accuracy: 1.0000
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 17/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 7.8973e-04 - categorical_accuracy: 0.9998
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 18/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 9.8054e-04 - categorical_accuracy: 0.9998
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 19/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 0.0016 - categorical_accuracy: 0.9994
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 20/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 8.5157e-04 - categorical_accuracy: 0.9998
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 21/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 5.8427e-04 - categorical_accuracy: 1.0000
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 22/100
# 23513/23513 [==============================] - 10s 428us/sample - loss: 3.7674e-04 - categorical_accuracy: 1.0000
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 23/100
# 23513/23513 [==============================] - 10s 429us/sample - loss: 6.5171e-04 - categorical_accuracy: 0.9998
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 24/100
# 23513/23513 [==============================] - 10s 429us/sample - loss: 3.7568e-04 - categorical_accuracy: 0.9999
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 25/100
# 23513/23513 [==============================] - 10s 429us/sample - loss: 4.7869e-04 - categorical_accuracy: 0.9999
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 26/100
# 23513/23513 [==============================] - 10s 429us/sample - loss: 2.9843e-04 - categorical_accuracy: 1.0000
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 27/100
# 23513/23513 [==============================] - 10s 429us/sample - loss: 4.6209e-04 - categorical_accuracy: 0.9999
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 28/100
# 23513/23513 [==============================] - 10s 429us/sample - loss: 3.3919e-04 - categorical_accuracy: 0.9999
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 29/100
# 23513/23513 [==============================] - 10s 428us/sample - loss: 2.8510e-04 - categorical_accuracy: 1.0000
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 30/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 1.7997e-04 - categorical_accuracy: 1.0000
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 31/100
# 23513/23513 [==============================] - 10s 429us/sample - loss: 2.8898e-04 - categorical_accuracy: 1.0000
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 32/100
# 23513/23513 [==============================] - 10s 431us/sample - loss: 1.7790e-04 - categorical_accuracy: 1.0000
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 33/100
# 23513/23513 [==============================] - 10s 431us/sample - loss: 2.9474e-04 - categorical_accuracy: 1.0000
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 34/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 2.5749e-04 - categorical_accuracy: 1.0000
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 35/100
# 23513/23513 [==============================] - 10s 429us/sample - loss: 1.7404e-04 - categorical_accuracy: 1.0000
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 36/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 1.4785e-04 - categorical_accuracy: 1.0000
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 37/100
# 23513/23513 [==============================] - 10s 429us/sample - loss: 1.7118e-04 - categorical_accuracy: 1.0000
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 38/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 1.2910e-04 - categorical_accuracy: 1.0000
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 39/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 1.8751e-04 - categorical_accuracy: 1.0000
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 40/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 1.6231e-04 - categorical_accuracy: 1.0000
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 41/100
# 23513/23513 [==============================] - 10s 431us/sample - loss: 1.4449e-04 - categorical_accuracy: 1.0000
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 42/100
# 23513/23513 [==============================] - 10s 431us/sample - loss: 1.9951e-04 - categorical_accuracy: 1.0000
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 43/100
# 23513/23513 [==============================] - 10s 431us/sample - loss: 1.1108e-04 - categorical_accuracy: 1.0000
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 44/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 1.6128e-04 - categorical_accuracy: 1.0000
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 45/100
# 23513/23513 [==============================] - 10s 429us/sample - loss: 1.0748e-04 - categorical_accuracy: 1.0000
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 46/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 1.1173e-04 - categorical_accuracy: 1.0000
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 47/100
# 23513/23513 [==============================] - 10s 428us/sample - loss: 1.0901e-04 - categorical_accuracy: 1.0000
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 48/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 1.0603e-04 - categorical_accuracy: 1.0000
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 49/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 1.0754e-04 - categorical_accuracy: 1.0000
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 50/100
# 23513/23513 [==============================] - 10s 431us/sample - loss: 1.2961e-04 - categorical_accuracy: 1.0000
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 51/100
# 23513/23513 [==============================] - 10s 429us/sample - loss: 1.6225e-04 - categorical_accuracy: 1.0000
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 52/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 9.1284e-05 - categorical_accuracy: 1.0000
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 53/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 1.0300e-04 - categorical_accuracy: 1.0000
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 54/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 1.2353e-04 - categorical_accuracy: 1.0000
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 55/100
# 23513/23513 [==============================] - 10s 432us/sample - loss: 1.0452e-04 - categorical_accuracy: 1.0000
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 56/100
# 23513/23513 [==============================] - 10s 431us/sample - loss: 1.0634e-04 - categorical_accuracy: 1.0000
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 57/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 1.3898e-04 - categorical_accuracy: 1.0000
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 58/100
# 23513/23513 [==============================] - 10s 429us/sample - loss: 1.0102e-04 - categorical_accuracy: 1.0000
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 59/100
# 23513/23513 [==============================] - 10s 429us/sample - loss: 1.0740e-04 - categorical_accuracy: 1.0000
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 60/100
# 23513/23513 [==============================] - 10s 431us/sample - loss: 8.8703e-05 - categorical_accuracy: 1.0000
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 61/100
# 23513/23513 [==============================] - 10s 431us/sample - loss: 9.0573e-05 - categorical_accuracy: 1.0000
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 62/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 8.9786e-05 - categorical_accuracy: 1.0000
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 63/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 8.5545e-05 - categorical_accuracy: 1.0000
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 64/100
# 23513/23513 [==============================] - 10s 429us/sample - loss: 1.1285e-04 - categorical_accuracy: 1.0000
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 65/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 8.7057e-05 - categorical_accuracy: 1.0000
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 66/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 8.0918e-05 - categorical_accuracy: 1.0000
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 67/100
# 23513/23513 [==============================] - 10s 431us/sample - loss: 7.9384e-05 - categorical_accuracy: 1.0000
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 68/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 8.5220e-05 - categorical_accuracy: 1.0000
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 69/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 1.1471e-04 - categorical_accuracy: 1.0000
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 70/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 9.6271e-05 - categorical_accuracy: 1.0000
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 71/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 8.2507e-05 - categorical_accuracy: 1.0000
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 72/100
# 23513/23513 [==============================] - 10s 431us/sample - loss: 8.4757e-05 - categorical_accuracy: 1.0000
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 73/100
# 23513/23513 [==============================] - 10s 431us/sample - loss: 7.8717e-05 - categorical_accuracy: 1.0000
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 74/100
# 23513/23513 [==============================] - 10s 432us/sample - loss: 8.5667e-05 - categorical_accuracy: 1.0000
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 75/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 8.2091e-05 - categorical_accuracy: 1.0000
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 76/100
# 23513/23513 [==============================] - 10s 429us/sample - loss: 1.0496e-04 - categorical_accuracy: 1.0000
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 77/100
# 23513/23513 [==============================] - 10s 431us/sample - loss: 8.8349e-05 - categorical_accuracy: 1.0000
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 78/100
# 23513/23513 [==============================] - 10s 429us/sample - loss: 8.5551e-05 - categorical_accuracy: 1.0000
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 79/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 8.6385e-05 - categorical_accuracy: 1.0000
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 80/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 8.5871e-05 - categorical_accuracy: 1.0000
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 81/100
# 23513/23513 [==============================] - 10s 429us/sample - loss: 8.5434e-05 - categorical_accuracy: 1.0000
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 82/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 8.5477e-05 - categorical_accuracy: 1.0000
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 83/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 8.4865e-05 - categorical_accuracy: 1.0000
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 84/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 8.5088e-05 - categorical_accuracy: 1.0000
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 85/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 8.4366e-05 - categorical_accuracy: 1.0000
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 86/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 8.0247e-05 - categorical_accuracy: 1.0000
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 87/100
# 23513/23513 [==============================] - 10s 431us/sample - loss: 9.1091e-05 - categorical_accuracy: 1.0000
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 88/100
# 23513/23513 [==============================] - 10s 431us/sample - loss: 1.0121e-04 - categorical_accuracy: 1.0000
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 89/100
# 23513/23513 [==============================] - 10s 431us/sample - loss: 9.2690e-05 - categorical_accuracy: 1.0000
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 90/100
# 23513/23513 [==============================] - 10s 429us/sample - loss: 7.7060e-05 - categorical_accuracy: 1.0000
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 91/100
# 23513/23513 [==============================] - 10s 429us/sample - loss: 1.1280e-04 - categorical_accuracy: 1.0000
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 92/100
# 23513/23513 [==============================] - 10s 429us/sample - loss: 8.0051e-05 - categorical_accuracy: 1.0000
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 93/100
# 23513/23513 [==============================] - 10s 429us/sample - loss: 8.3860e-05 - categorical_accuracy: 1.0000
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 94/100
# 23513/23513 [==============================] - 10s 429us/sample - loss: 8.5026e-05 - categorical_accuracy: 1.0000
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 95/100
# 23513/23513 [==============================] - 10s 431us/sample - loss: 8.9637e-05 - categorical_accuracy: 1.0000
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 96/100
# 23513/23513 [==============================] - 10s 431us/sample - loss: 9.6535e-05 - categorical_accuracy: 1.0000
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 97/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 9.4341e-05 - categorical_accuracy: 1.0000
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 98/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 8.8021e-05 - categorical_accuracy: 1.0000
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 99/100
# 23513/23513 [==============================] - 10s 430us/sample - loss: 1.2687e-04 - categorical_accuracy: 1.0000
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 1.0485760000000006e-07.
# Epoch 100/100
# 23513/23513 [==============================] - 10s 431us/sample - loss: 8.9429e-05 - categorical_accuracy: 1.0000
# 2612/2612 [==============================] - 1s 252us/sample
# (2612, 11)
# [[ 7  2  4  5  8  4  4  9 10  7  4  4  3  0  8  9  2  7  8  1  2  5  0  5
#    0  1  5  6  5  3  6  1  2  7 10  1  5  0  7  9  6  6  8  5  6  7  6  4
#    4  2  1  3  5  0  8  2  9 10  9  5  5  1 10  7  2  7  7  9  0  1  4  6
#    8  6  4  3  4  2  6  8  2  4 10  4 10 10 10  0  4  1  5 10  4  0 10  5
#    3  6 10  2]]
# (2612, 1)
# [[ 7  2  4  5  8  4  4  9 10  7  4  4  3  0  8  9  2  7  8  1  2  5  0  5
#    0  1  5  6  5  3  6  1  2  7 10  1  5  0  7  9  6  6  8  5  6  7  6  4
#    4  2  1  3  5  0  8  2  9 10  9  5  5  1 10  7  2  7  7  9  0  1  4  6
#    8  6  4  3  4  2  6  8  2  4 10  4 10 10 10  0  4  1  5 10  4  0 10  5
#    3  6 10  2]]
# 2612/2612 [==============================] - 1s 268us/sample - loss: 2.7573e-05 - categorical_accuracy: 1.0000
# ##################################################################################################################################
# #####################################################  K-FOLD 9  ################################################################
# Train dataset:
# (23513, 1, 128, 40) (23513, 11)
# Test dataset:
# (2612, 1, 128, 40) (2612, 11)
# Activity:  13
# Activity:  25
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 40)]      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 128, 40)       544
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 32, 64, 20)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32, 64, 20)        128
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 64, 64, 20)        32832
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 64, 16, 5)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64, 16, 5)         256
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 16, 5)         32800
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 32, 8, 3)          0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32, 8, 3)          128
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 8, 3)          0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 12, 64)            0
# _________________________________________________________________
# gru_1 (GRU)                  (None, 64)                24768
# _________________________________________________________________
# activity_class (Dense)       (None, 11)                715
# =================================================================
# Total params: 92,171
# Trainable params: 91,915
# Non-trainable params: 256
# _________________________________________________________________
# None
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/100
# 23513/23513 [==============================] - 12s 496us/sample - loss: 0.7192 - categorical_accuracy: 0.7874
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 0.0456 - categorical_accuracy: 0.9923
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/100
# 23513/23513 [==============================] - 10s 432us/sample - loss: 0.0144 - categorical_accuracy: 0.9979
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/100
# 23513/23513 [==============================] - 10s 434us/sample - loss: 0.0250 - categorical_accuracy: 0.9933
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/100
# 23513/23513 [==============================] - 10s 435us/sample - loss: 0.0130 - categorical_accuracy: 0.9969
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/100
# 23513/23513 [==============================] - 10s 435us/sample - loss: 0.0038 - categorical_accuracy: 0.9993
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 0.0113 - categorical_accuracy: 0.9967
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/100
# 23513/23513 [==============================] - 10s 432us/sample - loss: 0.0088 - categorical_accuracy: 0.9975
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 0.0031 - categorical_accuracy: 0.9994
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 10/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 0.0017 - categorical_accuracy: 0.9998
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 11/100
# 23513/23513 [==============================] - 10s 432us/sample - loss: 7.0975e-04 - categorical_accuracy: 1.0000
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 12/100
# 23513/23513 [==============================] - 10s 434us/sample - loss: 9.3004e-04 - categorical_accuracy: 0.9998
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 13/100
# 23513/23513 [==============================] - 10s 434us/sample - loss: 0.0017 - categorical_accuracy: 0.9996
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 14/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 4.7687e-04 - categorical_accuracy: 1.0000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 15/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 7.5195e-04 - categorical_accuracy: 1.0000
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 16/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 4.0022e-04 - categorical_accuracy: 1.0000
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 17/100
# 23513/23513 [==============================] - 10s 434us/sample - loss: 3.5768e-04 - categorical_accuracy: 1.0000
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 18/100
# 23513/23513 [==============================] - 10s 434us/sample - loss: 5.7023e-04 - categorical_accuracy: 0.9999
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 19/100
# 23513/23513 [==============================] - 10s 432us/sample - loss: 0.0074 - categorical_accuracy: 0.9977
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 20/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 0.0025 - categorical_accuracy: 0.9994
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 21/100
# 23513/23513 [==============================] - 10s 434us/sample - loss: 9.1524e-04 - categorical_accuracy: 0.9998
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 22/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 7.4405e-04 - categorical_accuracy: 0.9999
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 23/100
# 23513/23513 [==============================] - 10s 434us/sample - loss: 6.4618e-04 - categorical_accuracy: 0.9999
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 24/100
# 23513/23513 [==============================] - 10s 434us/sample - loss: 6.8020e-04 - categorical_accuracy: 0.9999
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 25/100
# 23513/23513 [==============================] - 10s 434us/sample - loss: 4.5769e-04 - categorical_accuracy: 0.9999
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 26/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 5.6332e-04 - categorical_accuracy: 0.9999
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 27/100
# 23513/23513 [==============================] - 10s 434us/sample - loss: 3.4373e-04 - categorical_accuracy: 1.0000
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 28/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 2.5974e-04 - categorical_accuracy: 1.0000
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 29/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 2.5168e-04 - categorical_accuracy: 1.0000
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 30/100
# 23513/23513 [==============================] - 10s 432us/sample - loss: 2.4183e-04 - categorical_accuracy: 1.0000
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 31/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 2.1139e-04 - categorical_accuracy: 1.0000
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 32/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 1.9750e-04 - categorical_accuracy: 1.0000
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 33/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 2.3861e-04 - categorical_accuracy: 1.0000
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 34/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 3.6269e-04 - categorical_accuracy: 0.9999
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 35/100
# 23513/23513 [==============================] - 10s 434us/sample - loss: 3.7247e-04 - categorical_accuracy: 1.0000
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 36/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 1.8567e-04 - categorical_accuracy: 1.0000
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 37/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 2.6917e-04 - categorical_accuracy: 1.0000
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 38/100
# 23513/23513 [==============================] - 10s 432us/sample - loss: 3.0287e-04 - categorical_accuracy: 1.0000
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 39/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 3.0061e-04 - categorical_accuracy: 0.9999
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 40/100
# 23513/23513 [==============================] - 10s 434us/sample - loss: 1.5028e-04 - categorical_accuracy: 1.0000
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 41/100
# 23513/23513 [==============================] - 10s 432us/sample - loss: 1.4132e-04 - categorical_accuracy: 1.0000
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 42/100
# 23513/23513 [==============================] - 10s 434us/sample - loss: 1.3778e-04 - categorical_accuracy: 1.0000
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 43/100
# 23513/23513 [==============================] - 10s 432us/sample - loss: 1.5341e-04 - categorical_accuracy: 1.0000
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 44/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 1.7026e-04 - categorical_accuracy: 1.0000
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 45/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 1.5237e-04 - categorical_accuracy: 1.0000
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 46/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 1.3099e-04 - categorical_accuracy: 1.0000
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 47/100
# 23513/23513 [==============================] - 10s 434us/sample - loss: 1.2736e-04 - categorical_accuracy: 1.0000
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 48/100
# 23513/23513 [==============================] - 10s 435us/sample - loss: 1.8040e-04 - categorical_accuracy: 1.0000
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 49/100
# 23513/23513 [==============================] - 10s 434us/sample - loss: 2.7506e-04 - categorical_accuracy: 0.9999
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 50/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 1.4755e-04 - categorical_accuracy: 1.0000
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 51/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 1.3507e-04 - categorical_accuracy: 1.0000
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 52/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 2.2872e-04 - categorical_accuracy: 1.0000
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 53/100
# 23513/23513 [==============================] - 10s 434us/sample - loss: 3.9300e-04 - categorical_accuracy: 1.0000
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 54/100
# 23513/23513 [==============================] - 10s 432us/sample - loss: 1.2874e-04 - categorical_accuracy: 1.0000
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 55/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 1.3280e-04 - categorical_accuracy: 1.0000
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 56/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 1.9532e-04 - categorical_accuracy: 1.0000
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 57/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 1.3231e-04 - categorical_accuracy: 1.0000
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 58/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 1.1731e-04 - categorical_accuracy: 1.0000
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 59/100
# 23513/23513 [==============================] - 10s 434us/sample - loss: 1.0589e-04 - categorical_accuracy: 1.0000
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 60/100
# 23513/23513 [==============================] - 10s 432us/sample - loss: 1.1374e-04 - categorical_accuracy: 1.0000
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 61/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 1.0628e-04 - categorical_accuracy: 1.0000
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 62/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 1.1051e-04 - categorical_accuracy: 1.0000
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 63/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 1.0582e-04 - categorical_accuracy: 1.0000
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 64/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 1.3022e-04 - categorical_accuracy: 1.0000
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 65/100
# 23513/23513 [==============================] - 10s 434us/sample - loss: 1.5042e-04 - categorical_accuracy: 1.0000
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 66/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 1.1004e-04 - categorical_accuracy: 1.0000
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 67/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 1.6487e-04 - categorical_accuracy: 1.0000
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 68/100
# 23513/23513 [==============================] - 10s 434us/sample - loss: 1.3182e-04 - categorical_accuracy: 1.0000
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 69/100
# 23513/23513 [==============================] - 10s 431us/sample - loss: 1.1365e-04 - categorical_accuracy: 1.0000
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 70/100
# 23513/23513 [==============================] - 10s 434us/sample - loss: 1.0235e-04 - categorical_accuracy: 1.0000
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 71/100
# 23513/23513 [==============================] - 10s 434us/sample - loss: 9.4985e-05 - categorical_accuracy: 1.0000
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 72/100
# 23513/23513 [==============================] - 10s 434us/sample - loss: 1.2539e-04 - categorical_accuracy: 1.0000
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 73/100
# 23513/23513 [==============================] - 10s 434us/sample - loss: 1.0621e-04 - categorical_accuracy: 1.0000
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 74/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 9.1784e-05 - categorical_accuracy: 1.0000
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 75/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 1.8605e-04 - categorical_accuracy: 1.0000
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 76/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 1.0854e-04 - categorical_accuracy: 1.0000
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 77/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 1.3503e-04 - categorical_accuracy: 1.0000
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 78/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 1.5114e-04 - categorical_accuracy: 1.0000
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 79/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 9.2511e-05 - categorical_accuracy: 1.0000
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 80/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 1.0278e-04 - categorical_accuracy: 1.0000
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 81/100
# 23513/23513 [==============================] - 10s 434us/sample - loss: 9.9456e-05 - categorical_accuracy: 1.0000
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 82/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 1.1964e-04 - categorical_accuracy: 1.0000
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 83/100
# 23513/23513 [==============================] - 10s 434us/sample - loss: 9.8077e-05 - categorical_accuracy: 1.0000
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 84/100
# 23513/23513 [==============================] - 10s 431us/sample - loss: 9.1976e-05 - categorical_accuracy: 1.0000
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 85/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 1.0800e-04 - categorical_accuracy: 1.0000
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 86/100
# 23513/23513 [==============================] - 10s 435us/sample - loss: 1.1255e-04 - categorical_accuracy: 1.0000
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 87/100
# 23513/23513 [==============================] - 10s 432us/sample - loss: 1.0750e-04 - categorical_accuracy: 1.0000
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 88/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 1.5775e-04 - categorical_accuracy: 1.0000
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 89/100
# 23513/23513 [==============================] - 10s 432us/sample - loss: 1.0331e-04 - categorical_accuracy: 1.0000
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 90/100
# 23513/23513 [==============================] - 10s 432us/sample - loss: 9.3180e-05 - categorical_accuracy: 1.0000
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 91/100
# 23513/23513 [==============================] - 10s 432us/sample - loss: 9.4625e-05 - categorical_accuracy: 1.0000
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 92/100
# 23513/23513 [==============================] - 10s 434us/sample - loss: 1.0326e-04 - categorical_accuracy: 1.0000
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 93/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 1.2519e-04 - categorical_accuracy: 1.0000
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 94/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 1.0957e-04 - categorical_accuracy: 1.0000
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 95/100
# 23513/23513 [==============================] - 10s 433us/sample - loss: 1.1662e-04 - categorical_accuracy: 1.0000
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 96/100
# 23513/23513 [==============================] - 10s 432us/sample - loss: 9.7028e-05 - categorical_accuracy: 1.0000
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 97/100
# 23513/23513 [==============================] - 10s 434us/sample - loss: 9.5766e-05 - categorical_accuracy: 1.0000
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 98/100
# ...
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 30/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 1.3629e-04 - categorical_accuracy: 1.0000
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 31/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 1.4418e-04 - categorical_accuracy: 1.0000
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 32/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 2.0123e-04 - categorical_accuracy: 1.0000
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 33/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 1.8856e-04 - categorical_accuracy: 1.0000
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 34/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 1.3717e-04 - categorical_accuracy: 1.0000
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 35/100
# 23513/23513 [==============================] - 10s 441us/sample - loss: 1.2028e-04 - categorical_accuracy: 1.0000
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 36/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 1.4603e-04 - categorical_accuracy: 1.0000
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 37/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 1.3784e-04 - categorical_accuracy: 1.0000
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 38/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 2.5070e-04 - categorical_accuracy: 1.0000
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 39/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 1.2832e-04 - categorical_accuracy: 1.0000
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 40/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 2.7121e-04 - categorical_accuracy: 1.0000
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 41/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 1.1348e-04 - categorical_accuracy: 1.0000
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 42/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 1.3489e-04 - categorical_accuracy: 1.0000
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 43/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 1.1805e-04 - categorical_accuracy: 1.0000
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 44/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 1.0336e-04 - categorical_accuracy: 1.0000
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 45/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 1.1378e-04 - categorical_accuracy: 1.0000
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 46/100
# 23513/23513 [==============================] - 10s 441us/sample - loss: 1.0459e-04 - categorical_accuracy: 1.0000
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 47/100
# 23513/23513 [==============================] - 10s 440us/sample - loss: 1.0458e-04 - categorical_accuracy: 1.0000
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 48/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 1.0406e-04 - categorical_accuracy: 1.0000
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 49/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 9.5805e-05 - categorical_accuracy: 1.0000
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 50/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 9.2787e-05 - categorical_accuracy: 1.0000
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 51/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 9.9365e-05 - categorical_accuracy: 1.0000
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 52/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 8.5618e-05 - categorical_accuracy: 1.0000
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 53/100
# 23513/23513 [==============================] - 10s 440us/sample - loss: 8.7320e-05 - categorical_accuracy: 1.0000
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 54/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 8.0829e-05 - categorical_accuracy: 1.0000
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 55/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 9.2284e-05 - categorical_accuracy: 1.0000
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 56/100
# 23513/23513 [==============================] - 10s 440us/sample - loss: 8.7091e-05 - categorical_accuracy: 1.0000
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 57/100
# 23513/23513 [==============================] - 10s 440us/sample - loss: 1.0985e-04 - categorical_accuracy: 1.0000
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 58/100
# 23513/23513 [==============================] - 10s 440us/sample - loss: 8.5506e-05 - categorical_accuracy: 1.0000
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 59/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 8.4114e-05 - categorical_accuracy: 1.0000
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 60/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 7.7614e-05 - categorical_accuracy: 1.0000
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 61/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 7.6610e-05 - categorical_accuracy: 1.0000
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 62/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 7.7450e-05 - categorical_accuracy: 1.0000
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 63/100
# 23513/23513 [==============================] - 10s 438us/sample - loss: 8.1064e-05 - categorical_accuracy: 1.0000
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 64/100
# 23513/23513 [==============================] - 10s 440us/sample - loss: 7.4750e-05 - categorical_accuracy: 1.0000
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 65/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 8.7537e-05 - categorical_accuracy: 1.0000
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 66/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 7.7783e-05 - categorical_accuracy: 1.0000
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 67/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 7.7357e-05 - categorical_accuracy: 1.0000
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 68/100
# 23513/23513 [==============================] - 10s 440us/sample - loss: 1.0087e-04 - categorical_accuracy: 1.0000
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 69/100
# 23513/23513 [==============================] - 10s 440us/sample - loss: 7.2840e-05 - categorical_accuracy: 1.0000
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 70/100
# 23513/23513 [==============================] - 10s 440us/sample - loss: 7.3187e-05 - categorical_accuracy: 1.0000
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 71/100
# 23513/23513 [==============================] - 10s 440us/sample - loss: 9.1581e-05 - categorical_accuracy: 1.0000
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 72/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 8.2043e-05 - categorical_accuracy: 1.0000
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 73/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 7.2153e-05 - categorical_accuracy: 1.0000
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 74/100
# 23513/23513 [==============================] - 10s 440us/sample - loss: 7.4600e-05 - categorical_accuracy: 1.0000
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 75/100
# 23513/23513 [==============================] - 10s 440us/sample - loss: 6.6482e-05 - categorical_accuracy: 1.0000
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 76/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 6.9894e-05 - categorical_accuracy: 1.0000
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 77/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 9.2979e-05 - categorical_accuracy: 1.0000
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 78/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 1.3247e-04 - categorical_accuracy: 1.0000
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 79/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 6.5639e-05 - categorical_accuracy: 1.0000
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 80/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 6.7203e-05 - categorical_accuracy: 1.0000
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 81/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 6.5667e-05 - categorical_accuracy: 1.0000
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 82/100
# 23513/23513 [==============================] - 10s 440us/sample - loss: 6.9429e-05 - categorical_accuracy: 1.0000
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 83/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 7.3025e-05 - categorical_accuracy: 1.0000
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 84/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 7.1713e-05 - categorical_accuracy: 1.0000
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 85/100
# 23513/23513 [==============================] - 10s 440us/sample - loss: 6.7511e-05 - categorical_accuracy: 1.0000
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 86/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 7.0219e-05 - categorical_accuracy: 1.0000
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 87/100
# 23513/23513 [==============================] - 10s 441us/sample - loss: 6.8701e-05 - categorical_accuracy: 1.0000
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 88/100
# 23513/23513 [==============================] - 10s 440us/sample - loss: 7.4294e-05 - categorical_accuracy: 1.0000
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 89/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 7.9325e-05 - categorical_accuracy: 1.0000
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 90/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 7.8005e-05 - categorical_accuracy: 1.0000
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 91/100
# 23513/23513 [==============================] - 10s 438us/sample - loss: 7.0730e-05 - categorical_accuracy: 1.0000
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 92/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 6.5362e-05 - categorical_accuracy: 1.0000
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 93/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 6.6151e-05 - categorical_accuracy: 1.0000
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 94/100
# 23513/23513 [==============================] - 10s 440us/sample - loss: 7.0242e-05 - categorical_accuracy: 1.0000
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 95/100
# 23513/23513 [==============================] - 10s 440us/sample - loss: 7.0394e-05 - categorical_accuracy: 1.0000
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 96/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 6.6377e-05 - categorical_accuracy: 1.0000
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 97/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 6.9690e-05 - categorical_accuracy: 1.0000
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 98/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 8.5442e-05 - categorical_accuracy: 1.0000
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 99/100
# 23513/23513 [==============================] - 10s 440us/sample - loss: 8.4162e-05 - categorical_accuracy: 1.0000
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 1.0485760000000006e-07.
# Epoch 100/100
# 23513/23513 [==============================] - 10s 439us/sample - loss: 7.0026e-05 - categorical_accuracy: 1.0000
# 2612/2612 [==============================] - 1s 250us/sample
# (2612, 11)
# [[ 6  1  3  9  4 10  5  1  4  1  1  8  0 10  3  9  1  8  9  6  1  2  8  1
#    6  0  8  2  2 10  1  4  1  4  2  8  5  4  9  5  1 10  5  8  4  7  4  3
#    6  8  2  4  7  8  1  5  1 10  7  7  0  8  7  9  7  3  4  6  4  4  3  7
#    3  9  0  9  5  8  2  1  2 10 10  1  3  6  9 10 10  1  0  9  8 10 10  2
#   10  2  8  6]]
# (2612, 1)
# [[ 6  1  3  9  4 10  5  1  4  1  1  8  0 10  3  9  1  8  9  6  1  2  8  1
#    6  0  8  2  2 10  1  4  1  4  2  8  5  4  9  5  1 10  5  8  4  7  4  3
#    6  8  2  4  7  8  1  5  1 10  7  7  0  8  7  9  7  3  4  6  4  4  3  7
#    3  9  0  9  5  8  2  1  2 10 10  1  3  6  9 10 10  1  0  9  8 10 10  2
#   10  2  8  6]]
# 2612/2612 [==============================] - 1s 263us/sample - loss: 0.0177 - categorical_accuracy: 0.9954

# %% [markdown]
# # Accuracy

# %%
sum = 0
for acc in accuracies:
    sum += acc
print('Accuracy of K-Fold: ' + str(sum/10))
# Out:
# Accuracy of K-Fold: 0.29954057931900024
