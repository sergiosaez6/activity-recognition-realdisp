# %% [markdown]
# # CNN

# %%
import tensorflow.keras as keras

# %%
# Módulos necesarios. Asegurarse de poder importarlos.
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from pylab import rcParams
from scipy import stats
from sklearn import metrics
import seaborn as sns
from sklearn import preprocessing
import os as os
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
from time import time

# Config the matplotlib backend as plotting inline in IPython
# %matplotlib inline

# %%
import sys
print(sys.executable)
print(sys.version)
print(sys.version_info)
tf.__version__
# Out:
# /usr/bin/python
# 3.6.8 (default, Aug 20 2019, 17:12:48)
# [GCC 8.3.0]
# sys.version_info(major=3, minor=6, micro=8, releaselevel='final', serial=0)
# '1.14.0'

# %%
keras.__version__
# Out:
# '2.2.4-tf'

# %% [markdown]
# # 10-FOLD

# %%
subjects = ['01', '02', '03', '05', '08', '09', '10', '11', '13', '14', '16', '17']
global activities
activities = [9,10,11,12,13,19,20,21,24,25,31]

# %%
# Ajustado a los datos
n_time_steps = 128
n_classes = 11 # Nº de clases (el 0 está eliminado)
n_channels = 1 # Nº de canales
n_columns = 40

# Podríamos variarlo
batch_size = 128 # Tamaño del batch
learning_rate = 1e-3 # Learning rate (por defecto es 0.001)
epochs = 100 # Épocas

# %%
class LearningRateDecay:
    def plot(self, epochs, title="Learning Rate Schedule"):
        # compute the set of learning rates for each correRPonding
        # epoch
        lrs = [self(i) for i in epochs]
 
        # the learning rate schedule
        plt.style.use("ggplot")
        plt.figure()
        plt.plot(epochs, lrs)
        plt.title(title)
        plt.xlabel("Epoch #")
        plt.ylabel("Learning Rate")
class StepDecay(LearningRateDecay):
    def __init__(self, initAlpha=0.01, factor=0.25, dropEvery=10):
        # store the base initial learning rate, drop factor, and
        # epochs to drop every
        self.initAlpha = initAlpha
        self.factor = factor
        self.dropEvery = dropEvery
 
    def __call__(self, epoch):
        # compute the learning rate for the current epoch
        exp = np.floor((1 + epoch) / self.dropEvery)
        alpha = self.initAlpha * (self.factor ** exp)
        if(alpha<1e-9):
            alpha=1e-9

        # return the learning rate
        return float(alpha) 

schedule = StepDecay(initAlpha=learning_rate, factor=0.4, dropEvery=10)

reduce_lr = keras.callbacks.LearningRateScheduler(schedule, verbose = 1)
callbacks_list = [reduce_lr]

# %%
#Visualize training evolution
def plot_curves(model, acc, loss, val_acc, val_loss, kfold):
    #########################################################################################
    # LOSS plot
    plt.figure(figsize=(12,8))
    plt.plot(model.history.history[loss], label='Training loss')
    plt.xlabel('Epochs', fontsize=15)
    plt.ylabel('Loss', fontsize=15)
    plt.tick_params(labelsize=10)
    plt.legend(loc=1,prop={'size': 10})
    plt.title('Loss in trainnig', fontsize=20)
    fig = plt.gcf()
    plt.show()
    
    fig.savefig('./03AUGFFT_RP_KFOLD_models/loss_train_03AUGFFT_RP_KFOLD_'+kfold+'.pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./03AUGFFT_RP_KFOLD_models/loss_train_03AUGFFT_RP_KFOLD_'+kfold+'svg', bbox_inches='tight',format='svg')
    
    #########################################################################################
    # ACC plot
    plt.figure(figsize=(12,8))
    plt.plot(model.history.history[acc], label='Training accuracy')
    plt.xlabel('Epochs', fontsize=15)
    plt.ylabel('Accuracy', fontsize=15)
    plt.tick_params(labelsize=10)
    plt.legend(loc=1,prop={'size': 10})
    plt.title('Accuracy in training', fontsize=20)
    fig = plt.gcf()
    plt.show()

    fig.savefig('./03AUGFFT_RP_KFOLD_models/acc_train_03AUGFFT_RP_KFOLD_'+kfold+'pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./03AUGFFT_RP_KFOLD_models/acc_train_03AUGFFT_RP_KFOLD_'+kfold+'svg', bbox_inches='tight',format='svg')
    
    #########################################################################################
    # ACC+LOSS plot
    plt.figure(figsize=(14,10))
    plt_loss = host_subplot(111, axes_class=AA.Axes)
    plt.subplots_adjust(right=0.75)

    plt_acc = plt_loss.twinx()
    plt_acc.axis["right"].toggle(all=True)
    
    plt_loss.set_xlim(0, len(model.history.history[loss]))
    plt_loss.set_ylim(0, max(model.history.history[loss]))
    plt_loss.set_xlabel('Epochs')
    plt_loss.set_ylabel('Loss')
    plt_acc.set_ylabel('Accuracy')
                        
    plt_loss.axis['left'].label.set_fontsize(15)
    plt_loss.axis['bottom'].label.set_fontsize(15)
    plt_acc.axis['right'].label.set_fontsize(15)
    
    plt_loss.plot(model.history.history[loss], c='tab:blue', ls='--', label='Training loss')
    plt_acc.plot(model.history.history[acc], c='tab:orange',ls='--', label='Training accuracy')
    
    plt.tick_params(labelsize=10)
    plt.title('Training performance', fontsize=20)
    plt_acc.set_ylim(0, 1)
    plt_loss.legend(loc=1, prop={'size': 10})
    
    fig = plt.gcf()
    plt.show()

    fig.savefig('./03AUGFFT_RP_KFOLD_models/all_train_03AUGFFT_RP_KFOLD_'+kfold+'pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./03AUGFFT_RP_KFOLD_models/all_train_03AUGFFT_RP_KFOLD_'+kfold+'svg', bbox_inches='tight',format='svg')

# %%
def plot_confusion_matrix(y_true, y_pred, kfold, classes,
                          cmap=plt.cm.Blues):

    # Compute confusion matrix
    cm = metrics.confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(20, 20))
    sns.heatmap(cm, xticklabels=classes, yticklabels=classes, square = True, robust = True, annot=True, cmap='YlOrBr')
    plt.title('CONFUSION MATRIX')
    plt.ylabel('TRUE ACTIVITY')
    plt.xlabel('PREDICTION')
    
    locs, labels = plt.xticks()
    plt.xticks(locs, labels, rotation='vertical')
    locs, labels = plt.yticks()
    plt.yticks(locs, labels, rotation='horizontal')

    # Guardamos la imagen en formato vectorial
    plt.draw()
    plt.savefig('./03AUGFFT_RP_KFOLD_models/matriz_confusion_'+kfold+'.svg', bbox_inches='tight',format='svg')
    plt.show()

# %%
global size
size = 26125

# %%
from sklearn.model_selection import KFold
S = np.arange(0,size)
kf = KFold(n_splits=10)
kf.get_n_splits(S)

print(kf)  

S_train = []
S_test = []

for train_index, test_index in kf.split(S):
    print("TRAIN:", train_index, "TEST:", test_index)
    print(S[train_index])
    print(S[test_index])
    S_train.append(S[train_index])
    S_test.append(S[test_index])
# Out:
# KFold(n_splits=10, random_state=None, shuffle=False)
# TRAIN: [ 2613  2614  2615 ... 26122 26123 26124] TEST: [   0    1    2 ... 2610 2611 2612]
# [ 2613  2614  2615 ... 26122 26123 26124]
# [   0    1    2 ... 2610 2611 2612]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [2613 2614 2615 ... 5223 5224 5225]
# [    0     1     2 ... 26122 26123 26124]
# [2613 2614 2615 ... 5223 5224 5225]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [5226 5227 5228 ... 7836 7837 7838]
# [    0     1     2 ... 26122 26123 26124]
# [5226 5227 5228 ... 7836 7837 7838]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [ 7839  7840  7841 ... 10449 10450 10451]
# [    0     1     2 ... 26122 26123 26124]
# [ 7839  7840  7841 ... 10449 10450 10451]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [10452 10453 10454 ... 13062 13063 13064]
# [    0     1     2 ... 26122 26123 26124]
# [10452 10453 10454 ... 13062 13063 13064]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [13065 13066 13067 ... 15674 15675 15676]
# [    0     1     2 ... 26122 26123 26124]
# [13065 13066 13067 ... 15674 15675 15676]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [15677 15678 15679 ... 18286 18287 18288]
# [    0     1     2 ... 26122 26123 26124]
# [15677 15678 15679 ... 18286 18287 18288]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [18289 18290 18291 ... 20898 20899 20900]
# [    0     1     2 ... 26122 26123 26124]
# [18289 18290 18291 ... 20898 20899 20900]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [20901 20902 20903 ... 23510 23511 23512]
# [    0     1     2 ... 26122 26123 26124]
# [20901 20902 20903 ... 23510 23511 23512]
# TRAIN: [    0     1     2 ... 23510 23511 23512] TEST: [23513 23514 23515 ... 26122 26123 26124]
# [    0     1     2 ... 23510 23511 23512]
# [23513 23514 23515 ... 26122 26123 26124]

# %%
accuracies = []
for i in range(10):
    if(i<10):
        kfold='0'+str(i)
    else:
        kfold=str(i)
    print('##################################################################################################################################')
    print('#####################################################  K-FOLD %d  ################################################################'%(i+1))
    
    subjects = ['01', '02', '03', '05', '08', '09', '10', '11', '13', '14', '16', '17']
    
    ##  GENERACIÓN DATASET
    tr_seg = np.concatenate((np.load('./augment_2/subject_'+subjects[0]+'_seg.npy'),np.load('./augment_2/subject_'+subjects[1]+'_seg.npy'),np.load('./augment_2/subject_'+subjects[2]+'_seg.npy'),np.load('./augment_2/subject_'+subjects[3]+'_seg.npy'),
                             np.load('./augment_2/subject_'+subjects[4]+'_seg.npy'),np.load('./augment_2/subject_'+subjects[5]+'_seg.npy'),np.load('./augment_2/subject_'+subjects[6]+'_seg.npy'),np.load('./augment_2/subject_'+subjects[7]+'_seg.npy'),
                             np.load('./augment_2/subject_'+subjects[8]+'_seg.npy'),np.load('./augment_2/subject_'+subjects[9]+'_seg.npy'),np.load('./augment_2/subject_'+subjects[10]+'_seg.npy')))

    tr_lab = np.concatenate((np.load('./augment_2/subject_'+subjects[0]+'_lab.npy'),np.load('./augment_2/subject_'+subjects[1]+'_lab.npy'),np.load('./augment_2/subject_'+subjects[2]+'_lab.npy'),np.load('./augment_2/subject_'+subjects[3]+'_lab.npy'),
                             np.load('./augment_2/subject_'+subjects[4]+'_lab.npy'),np.load('./augment_2/subject_'+subjects[5]+'_lab.npy'),np.load('./augment_2/subject_'+subjects[6]+'_lab.npy'),np.load('./augment_2/subject_'+subjects[7]+'_lab.npy'),
                             np.load('./augment_2/subject_'+subjects[8]+'_lab.npy'),np.load('./augment_2/subject_'+subjects[9]+'_lab.npy'),np.load('./augment_2/subject_'+subjects[10]+'_lab.npy')))
    
    limit = 40
    tr_seg = tr_seg[:,:,:,:limit]
    ####################################################################################################################
    ## SHUFFLE DE DATOS
    np.random.seed(235)
    tr_seg = np.reshape(tr_seg[np.random.shuffle(np.arange(0,tr_seg.shape[0]))], (size,1,128,limit))
    tr_lab = np.reshape(tr_lab[np.random.shuffle(np.arange(0,tr_seg.shape[0]))], (size,11))
    
    ts_seg = tr_seg[S_test[i]]
    ts_lab = tr_lab[S_test[i]]
    
    tr_seg = tr_seg[S_train[i]]
    tr_lab = tr_lab[S_train[i]]
    
    print('Train dataset: ')
    print(tr_seg.shape, tr_lab.shape)
    print('Test dataset: ')
    print(ts_seg.shape, ts_lab.shape)
    ####################################################################################################################
    ## VISTA DE DFT-2D
    plt.figure(figsize=(30,30))
    plt.imshow(np.log(np.abs(np.fft.fftshift(tr_seg[0,0,:,20:40].T))**2))
    plt.show()
    print('Activity: ',activities[np.argmax(tr_lab[0])])

    plt.figure(figsize=(30,30))
    plt.imshow(np.log(np.fft.fftshift(tr_seg[10,0,:,20:40].T)**2))
    plt.show()
    print('Activity: ',activities[np.argmax(tr_lab[10])])
    ####################################################################################################################
    ## RED
    quat_input = keras.Input(shape=(n_channels, n_time_steps, n_columns), name='input_layer')
    
    # Some convolutional layers
    conv_1 = keras.layers.Conv2D(32, kernel_size=4,padding='same',activation='relu', data_format = 'channels_first')(quat_input)
    max_1 = keras.layers.MaxPooling2D(pool_size=2, strides=2, padding='same', data_format = 'channels_first')(conv_1)
    bn_1 = keras.layers.BatchNormalization(axis=1)(max_1)
    conv_2 = keras.layers.Conv2D(64,kernel_size=4, padding='same',activation='relu', data_format = 'channels_first')(bn_1)
    max_2 = keras.layers.MaxPooling2D(pool_size=4, strides=4, padding='same', data_format = 'channels_first')(conv_2)
    bn_2 = keras.layers.BatchNormalization(axis=1)(max_2)
    conv_3 = keras.layers.Conv2D(32,kernel_size=4, padding='same',activation='relu', data_format = 'channels_first')(bn_2)
    max_3 = keras.layers.MaxPooling2D(pool_size=2, strides=2, padding='same', data_format = 'channels_first')(conv_3)
    bn_3 = keras.layers.BatchNormalization(axis=1)(max_3)

    # Flatten the output of the convolutional layers
    dr_2 = keras.layers.Dropout(0.5)(bn_3)

    units = 96

    res_1 = keras.layers.Reshape((8,units))(dr_2)

    gru_1 = keras.layers.GRU(units, activation='tanh', return_sequences=False, reset_after = False)(res_1)

    # Output layers: separate outputs for the weather and the ground labels
    multiclass_output = keras.layers.Dense(n_classes, activation='softmax',name='activity_class')(gru_1)

    # Creamos la estrcutura que contendrá a nuestro modelo
    model = keras.Model(inputs=quat_input, outputs=[multiclass_output],name='cnn')

    # Compilamos el modelo
    model.compile(optimizer=keras.optimizers.Adam(lr=learning_rate),
                  loss='categorical_crossentropy', metrics=['categorical_accuracy'])
    
    print(model.summary())
    ####################################################################################################################
    ## TRAIN
    history = model.fit(tr_seg,
                        tr_lab,
                        epochs = epochs,
                        steps_per_epoch = None,
                        verbose = 1,
                        batch_size = batch_size,
                        callbacks = callbacks_list)
    model.save('./03AUGFFT_RP_KFOLD_models/CNN_'+kfold+'.h5')
    
    #Visualize training evolution
    plot_curves(model, 'categorical_accuracy', 'loss', 'val_categorical_accuracy', 'val_loss', kfold)
    ####################################################################################################################
    ## TEST
    predictions = model.predict(ts_seg, batch_size = batch_size, verbose = 1)
    
    print(predictions.shape)
    
    y_pred = np.argmax(predictions,axis=-1)
    y_pred = np.expand_dims(y_pred,axis=-1)
    print(y_pred[:100].T)
    
    y_true = np.argmax(ts_lab,axis=-1)
    y_true = np.expand_dims(y_true,axis=-1)
    print(y_true.shape)
    print(y_true[:100].T)
    
    evaluation = model.evaluate(ts_seg, ts_lab, batch_size=batch_size, verbose=1)
    accuracies.append(evaluation[1])
    
    fo = open('./03AUGFFT_RP_KFOLD_models/accuracy_'+kfold+'.txt', "w")
    fo.seek(0,2)
    fo.write(str(evaluation))
    fo.close()
    
    ####################################################################################################################
    ## CONFUSION MATRIX
    y_true_flat = np.ndarray.flatten(y_true)
    y_pred_flat = np.ndarray.flatten(y_pred)
    
    plot_confusion_matrix(y_true_flat, y_pred_flat, kfold, classes=activities)
    
    del kfold, limit, tr_seg, tr_lab, ts_seg, ts_lab, model, history, y_pred, y_true, predictions, evaluation, y_true_flat, y_pred_flat
# Out:
# ##################################################################################################################################
# #####################################################  K-FOLD 1  ################################################################
# Train dataset:
# (23512, 1, 128, 40) (23512, 11)
# Test dataset:
# (2613, 1, 128, 40) (2613, 11)
# Activity:  9
# Activity:  24
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 40)]      0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 32, 128, 40)       544
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 64, 20)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 64, 20)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 20)        32832
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 16, 5)         0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 16, 5)         256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 16, 5)         32800
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 8, 3)          0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 8, 3)          128
# _________________________________________________________________
# dropout (Dropout)            (None, 32, 8, 3)          0
# _________________________________________________________________
# reshape (Reshape)            (None, 8, 96)             0
# _________________________________________________________________
# gru (GRU)                    (None, 96)                55584
# _________________________________________________________________
# activity_class (Dense)       (None, 11)                1067
# =================================================================
# Total params: 123,339
# Trainable params: 123,083
# Non-trainable params: 256
# _________________________________________________________________
# None
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/100
# 23512/23512 [==============================] - 17s 705us/sample - loss: 0.6199 - categorical_accuracy: 0.8036
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/100
# 23512/23512 [==============================] - 9s 388us/sample - loss: 0.0192 - categorical_accuracy: 0.9970
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/100
# 23512/23512 [==============================] - 9s 378us/sample - loss: 0.0173 - categorical_accuracy: 0.9958
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/100
# 23512/23512 [==============================] - 9s 378us/sample - loss: 0.0115 - categorical_accuracy: 0.9972
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/100
# 23512/23512 [==============================] - 9s 381us/sample - loss: 0.0093 - categorical_accuracy: 0.9974
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/100
# 23512/23512 [==============================] - 9s 382us/sample - loss: 0.0105 - categorical_accuracy: 0.9967
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/100
# 23512/23512 [==============================] - 9s 379us/sample - loss: 0.0051 - categorical_accuracy: 0.9986
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/100
# 23512/23512 [==============================] - 9s 380us/sample - loss: 0.0080 - categorical_accuracy: 0.9978
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/100
# 23512/23512 [==============================] - 9s 381us/sample - loss: 0.0027 - categorical_accuracy: 0.9993
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 10/100
# 23512/23512 [==============================] - 9s 379us/sample - loss: 4.0650e-04 - categorical_accuracy: 1.0000
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 11/100
# 23512/23512 [==============================] - 9s 379us/sample - loss: 3.1427e-04 - categorical_accuracy: 1.0000
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 12/100
# 23512/23512 [==============================] - 9s 379us/sample - loss: 2.8628e-04 - categorical_accuracy: 1.0000
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 13/100
# 23512/23512 [==============================] - 9s 381us/sample - loss: 2.0842e-04 - categorical_accuracy: 1.0000
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 14/100
# 23512/23512 [==============================] - 9s 379us/sample - loss: 2.4529e-04 - categorical_accuracy: 1.0000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 15/100
# 23512/23512 [==============================] - 9s 378us/sample - loss: 1.9839e-04 - categorical_accuracy: 1.0000
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 16/100
# 23512/23512 [==============================] - 9s 378us/sample - loss: 1.6276e-04 - categorical_accuracy: 1.0000
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 17/100
# 23512/23512 [==============================] - 9s 379us/sample - loss: 1.5590e-04 - categorical_accuracy: 1.0000
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 18/100
# 23512/23512 [==============================] - 9s 379us/sample - loss: 2.0573e-04 - categorical_accuracy: 1.0000
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 19/100
# 23512/23512 [==============================] - 9s 379us/sample - loss: 1.2743e-04 - categorical_accuracy: 1.0000
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 20/100
# 23512/23512 [==============================] - 9s 379us/sample - loss: 1.1494e-04 - categorical_accuracy: 1.0000
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 21/100
# 23512/23512 [==============================] - 9s 378us/sample - loss: 1.1676e-04 - categorical_accuracy: 1.0000
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 22/100
# 23512/23512 [==============================] - 9s 378us/sample - loss: 4.3730e-04 - categorical_accuracy: 0.9999
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 23/100
# 23512/23512 [==============================] - 9s 379us/sample - loss: 1.4769e-04 - categorical_accuracy: 1.0000
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 24/100
# 23512/23512 [==============================] - 9s 379us/sample - loss: 1.5375e-04 - categorical_accuracy: 1.0000
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 25/100
# 23512/23512 [==============================] - 9s 379us/sample - loss: 3.3761e-04 - categorical_accuracy: 0.9999
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 26/100
# 23512/23512 [==============================] - 9s 378us/sample - loss: 4.6941e-04 - categorical_accuracy: 1.0000
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 27/100
# 23512/23512 [==============================] - 9s 377us/sample - loss: 8.8946e-05 - categorical_accuracy: 1.0000
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 28/100
# 23512/23512 [==============================] - 9s 377us/sample - loss: 8.5409e-05 - categorical_accuracy: 1.0000
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 29/100
# 23512/23512 [==============================] - 9s 377us/sample - loss: 9.1920e-05 - categorical_accuracy: 1.0000
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 30/100
# 23512/23512 [==============================] - 9s 378us/sample - loss: 6.9705e-05 - categorical_accuracy: 1.0000
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 31/100
# 23512/23512 [==============================] - 9s 377us/sample - loss: 7.1017e-05 - categorical_accuracy: 1.0000
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 32/100
# 23512/23512 [==============================] - 9s 374us/sample - loss: 2.4737e-04 - categorical_accuracy: 1.0000
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 33/100
# 23512/23512 [==============================] - 9s 374us/sample - loss: 8.8905e-05 - categorical_accuracy: 1.0000
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 34/100
# 23512/23512 [==============================] - 9s 376us/sample - loss: 7.2410e-05 - categorical_accuracy: 1.0000
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 35/100
# 23512/23512 [==============================] - 9s 380us/sample - loss: 7.0034e-05 - categorical_accuracy: 1.0000
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 36/100
# 23512/23512 [==============================] - 9s 380us/sample - loss: 7.2657e-05 - categorical_accuracy: 1.0000
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 37/100
# 23512/23512 [==============================] - 9s 380us/sample - loss: 6.1775e-05 - categorical_accuracy: 1.0000
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 38/100
# 23512/23512 [==============================] - 9s 381us/sample - loss: 6.0156e-05 - categorical_accuracy: 1.0000
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 39/100
# 23512/23512 [==============================] - 9s 379us/sample - loss: 5.6144e-05 - categorical_accuracy: 1.0000
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 40/100
# 23512/23512 [==============================] - 9s 380us/sample - loss: 6.0302e-05 - categorical_accuracy: 1.0000
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 41/100
# 23512/23512 [==============================] - 9s 380us/sample - loss: 5.2544e-05 - categorical_accuracy: 1.0000
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 42/100
#  2176/23512 [=>............................] - ETA: 8s - loss: 5.2520e-05 - categorical_accuracy: 1.0000
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 23512/23512 [==============================] - 9s 378us/sample - loss: 5.2111e-05 - categorical_accuracy: 1.0000
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 72/100
# 23512/23512 [==============================] - 9s 375us/sample - loss: 4.0692e-05 - categorical_accuracy: 1.0000
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 73/100
# 23512/23512 [==============================] - 9s 378us/sample - loss: 3.5732e-05 - categorical_accuracy: 1.0000
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 74/100
# 23512/23512 [==============================] - 9s 377us/sample - loss: 3.5891e-05 - categorical_accuracy: 1.0000
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 75/100
# 23512/23512 [==============================] - 9s 379us/sample - loss: 3.7738e-05 - categorical_accuracy: 1.0000
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 76/100
# 23512/23512 [==============================] - 9s 377us/sample - loss: 3.7182e-05 - categorical_accuracy: 1.0000
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 77/100
# 23512/23512 [==============================] - 9s 377us/sample - loss: 3.3803e-05 - categorical_accuracy: 1.0000
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 78/100
# 23512/23512 [==============================] - 9s 377us/sample - loss: 3.4580e-05 - categorical_accuracy: 1.0000
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 79/100
# 23512/23512 [==============================] - 9s 379us/sample - loss: 3.7656e-05 - categorical_accuracy: 1.0000
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 80/100
# 23512/23512 [==============================] - 9s 377us/sample - loss: 3.4874e-05 - categorical_accuracy: 1.0000
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 81/100
# 23512/23512 [==============================] - 9s 377us/sample - loss: 3.3231e-05 - categorical_accuracy: 1.0000
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 82/100
# 23512/23512 [==============================] - 9s 377us/sample - loss: 3.3288e-05 - categorical_accuracy: 1.0000
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 83/100
# 23512/23512 [==============================] - 9s 377us/sample - loss: 3.4531e-05 - categorical_accuracy: 1.0000
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 84/100
# 23512/23512 [==============================] - 9s 380us/sample - loss: 3.4621e-05 - categorical_accuracy: 1.0000
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 85/100
# 23512/23512 [==============================] - 9s 376us/sample - loss: 4.7870e-05 - categorical_accuracy: 1.0000
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 86/100
# 23512/23512 [==============================] - 9s 377us/sample - loss: 3.3946e-05 - categorical_accuracy: 1.0000
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 87/100
# 23512/23512 [==============================] - 9s 378us/sample - loss: 3.7193e-05 - categorical_accuracy: 1.0000
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 88/100
# 23512/23512 [==============================] - 9s 378us/sample - loss: 3.3529e-05 - categorical_accuracy: 1.0000
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 89/100
# 23512/23512 [==============================] - 9s 378us/sample - loss: 4.4841e-05 - categorical_accuracy: 1.0000
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 90/100
# 23512/23512 [==============================] - 9s 377us/sample - loss: 3.4178e-05 - categorical_accuracy: 1.0000
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 91/100
# 23512/23512 [==============================] - 9s 377us/sample - loss: 4.0639e-05 - categorical_accuracy: 1.0000
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 92/100
# 23512/23512 [==============================] - 9s 378us/sample - loss: 3.5452e-05 - categorical_accuracy: 1.0000
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 93/100
# 23512/23512 [==============================] - 9s 378us/sample - loss: 4.1695e-05 - categorical_accuracy: 1.0000
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 94/100
# 23512/23512 [==============================] - 9s 377us/sample - loss: 3.4764e-05 - categorical_accuracy: 1.0000
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 95/100
# 23512/23512 [==============================] - 9s 378us/sample - loss: 3.4561e-05 - categorical_accuracy: 1.0000
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 96/100
# 23512/23512 [==============================] - 9s 377us/sample - loss: 3.4190e-05 - categorical_accuracy: 1.0000
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 97/100
# 23512/23512 [==============================] - 9s 378us/sample - loss: 3.9117e-05 - categorical_accuracy: 1.0000
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 98/100
# 23512/23512 [==============================] - 9s 379us/sample - loss: 3.7741e-05 - categorical_accuracy: 1.0000
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 99/100
# 23512/23512 [==============================] - 9s 377us/sample - loss: 3.5101e-05 - categorical_accuracy: 1.0000
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 1.0485760000000006e-07.
# Epoch 100/100
# 23512/23512 [==============================] - 9s 378us/sample - loss: 3.2736e-05 - categorical_accuracy: 1.0000
# 2613/2613 [==============================] - 1s 232us/sample
# (2613, 11)
# [[ 5  1  2  8  6  6  0  4  9  8  2  5  4  1  7  3 10  7  9  9  7  5  0  5
#    4  0  8  7  9  3  1  5  0  9  5  9  2  8  6  5  5  9  8  0  1  2  8  5
#    7  8 10  6  4  4  3 10  4  5  5  2  4  0  5  3  3  9  1  2 10 10  2  0
#    7  0 10  9  8  9  4  0  4  8  0  2  2  0  4 10  9  3  2  3  7 10  5  7
#    2  5  9  9]]
# (2613, 1)
# [[ 6  1  2  8  6  6  0  4  9  8  2  6  4  1  7  3 10  7  9  9  7  6  0  6
#    3  0  8  7  9  3  1  6  0  9  5  9  2  8  6  5  6  9  8  0  1  2  8  5
#    7  8 10  6  4  4  3 10  4  6  5  2  1  0  5  3  3  9  1  2 10 10  2  0
#    7  0 10  9  8  9  4  0  4  8  0  2  2  0  4 10  9  3  2  1  7 10  5  7
#    2  5  9  9]]
# 2613/2613 [==============================] - 1s 247us/sample - loss: 0.6778 - categorical_accuracy: 0.9101
# ##################################################################################################################################
# #####################################################  K-FOLD 2  ################################################################
# Train dataset:
# (23512, 1, 128, 40) (23512, 11)
# Test dataset:
# (2613, 1, 128, 40) (2613, 11)
# Activity:  20
# Activity:  11
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 40)]      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 128, 40)       544
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 32, 64, 20)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32, 64, 20)        128
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 64, 64, 20)        32832
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 64, 16, 5)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64, 16, 5)         256
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 16, 5)         32800
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 32, 8, 3)          0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32, 8, 3)          128
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 8, 3)          0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 8, 96)             0
# _________________________________________________________________
# gru_1 (GRU)                  (None, 96)                55584
# _________________________________________________________________
# activity_class (Dense)       (None, 11)                1067
# =================================================================
# Total params: 123,339
# Trainable params: 123,083
# Non-trainable params: 256
# _________________________________________________________________
# None
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/100
# 20480/23512 [=========================>....] - ETA: 1s - loss: 0.6032 - categorical_accuracy: 0.8184
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 23512/23512 [==============================] - 9s 388us/sample - loss: 8.7022e-05 - categorical_accuracy: 1.0000
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 32/100
# 23512/23512 [==============================] - 9s 388us/sample - loss: 8.7118e-05 - categorical_accuracy: 1.0000
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 33/100
# 23512/23512 [==============================] - 9s 388us/sample - loss: 7.3253e-05 - categorical_accuracy: 1.0000
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 34/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 6.9862e-05 - categorical_accuracy: 1.0000
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 35/100
# 23512/23512 [==============================] - 9s 389us/sample - loss: 1.1704e-04 - categorical_accuracy: 1.0000
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 36/100
# 23512/23512 [==============================] - 9s 388us/sample - loss: 6.3083e-05 - categorical_accuracy: 1.0000
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 37/100
# 23512/23512 [==============================] - 9s 388us/sample - loss: 6.3348e-05 - categorical_accuracy: 1.0000
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 38/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 5.8099e-05 - categorical_accuracy: 1.0000
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 39/100
# 23512/23512 [==============================] - 9s 388us/sample - loss: 5.5650e-05 - categorical_accuracy: 1.0000
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 40/100
# 23512/23512 [==============================] - 9s 388us/sample - loss: 8.0229e-05 - categorical_accuracy: 1.0000
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 41/100
# 23512/23512 [==============================] - 9s 388us/sample - loss: 6.1433e-05 - categorical_accuracy: 1.0000
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 42/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 5.2024e-05 - categorical_accuracy: 1.0000
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 43/100
# 23512/23512 [==============================] - 9s 388us/sample - loss: 4.8217e-05 - categorical_accuracy: 1.0000
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 44/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 6.0930e-05 - categorical_accuracy: 1.0000
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 45/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 5.3644e-05 - categorical_accuracy: 1.0000
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 46/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 4.9533e-05 - categorical_accuracy: 1.0000
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 47/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 4.4990e-05 - categorical_accuracy: 1.0000
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 48/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 4.8214e-05 - categorical_accuracy: 1.0000
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 49/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 4.5961e-05 - categorical_accuracy: 1.0000
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 50/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 4.7033e-05 - categorical_accuracy: 1.0000
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 51/100
# 23512/23512 [==============================] - 9s 388us/sample - loss: 4.4252e-05 - categorical_accuracy: 1.0000
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 52/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 4.0257e-05 - categorical_accuracy: 1.0000
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 53/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 7.0816e-05 - categorical_accuracy: 1.0000
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 54/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 1.0417e-04 - categorical_accuracy: 1.0000
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 55/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 3.9826e-05 - categorical_accuracy: 1.0000
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 56/100
# 22784/23512 [============================>.] - ETA: 0s - loss: 3.9178e-05 - categorical_accuracy: 1.0000
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 23512/23512 [==============================] - 9s 389us/sample - loss: 1.8734e-04 - categorical_accuracy: 1.0000
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 82/100
# 23512/23512 [==============================] - 9s 388us/sample - loss: 4.2457e-05 - categorical_accuracy: 1.0000
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 83/100
# 23512/23512 [==============================] - 9s 389us/sample - loss: 3.7853e-05 - categorical_accuracy: 1.0000
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 84/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 6.1141e-05 - categorical_accuracy: 1.0000
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 85/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 4.9000e-05 - categorical_accuracy: 1.0000
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 86/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 3.3828e-05 - categorical_accuracy: 1.0000
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 87/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 3.9397e-05 - categorical_accuracy: 1.0000
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 88/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 3.2369e-05 - categorical_accuracy: 1.0000
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 89/100
# 23512/23512 [==============================] - 9s 388us/sample - loss: 3.5446e-05 - categorical_accuracy: 1.0000
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 90/100
# 23512/23512 [==============================] - 9s 388us/sample - loss: 3.1616e-05 - categorical_accuracy: 1.0000
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 91/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 3.2778e-05 - categorical_accuracy: 1.0000
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 92/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 3.1674e-05 - categorical_accuracy: 1.0000
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 93/100
# 23512/23512 [==============================] - 9s 388us/sample - loss: 3.3785e-05 - categorical_accuracy: 1.0000
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 94/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 3.6351e-05 - categorical_accuracy: 1.0000
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 95/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 3.2745e-05 - categorical_accuracy: 1.0000
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 96/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 3.2073e-05 - categorical_accuracy: 1.0000
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 97/100
# 23512/23512 [==============================] - 9s 388us/sample - loss: 3.4030e-05 - categorical_accuracy: 1.0000
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 98/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 3.7140e-05 - categorical_accuracy: 1.0000
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 99/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 3.2080e-05 - categorical_accuracy: 1.0000
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 1.0485760000000006e-07.
# Epoch 100/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 3.1779e-05 - categorical_accuracy: 1.0000
# 2613/2613 [==============================] - 1s 222us/sample
# (2613, 11)
# [[ 0  4  0  3  5 10  1  3  9  2  8  7  5  9  9  0  5  5  8  3  8  0  2  1
#   10  1  5  6  4  5  8  2  8  9  7  4  0  9  4  7 10  7  4 10 10  5 10  4
#    3  7  6  9  1  4  6  8  1  4  3  6 10  9  2  2  2  3  5  1  2  3  2  9
#   10  2  3  4  1  8  9  2  5  2  9  5  8  0  6  1  0  7  2  6  6  0  3 10
#    1  8  7  1]]
# (2613, 1)
# [[ 0  4  0  3  5 10  1  3  9  2  8  7  5  9  9  0  5  5  8  3  8  0  2  1
#   10  1  5  6  4  5  8  2  8  9  7  4  0  9  4  7 10  7  4 10 10  5 10  4
#    3  7  6  9  1  4  6  8  1  4  3  6 10  9  2  2  2  3  5  1  2  3  2  9
#   10  2  3  4  1  8  9  2  5  2  9  5  8  0  6  1  0  7  2  6  6  0  3 10
#    1  8  7  1]]
# 2613/2613 [==============================] - 1s 238us/sample - loss: 3.4522e-05 - categorical_accuracy: 1.0000
# ##################################################################################################################################
# #####################################################  K-FOLD 3  ################################################################
# Train dataset:
# (23512, 1, 128, 40) (23512, 11)
# Test dataset:
# (2613, 1, 128, 40) (2613, 11)
# Activity:  20
# Activity:  11
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 40)]      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 128, 40)       544
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 32, 64, 20)        0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 32, 64, 20)        128
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 64, 64, 20)        32832
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 64, 16, 5)         0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 64, 16, 5)         256
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 32, 16, 5)         32800
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 32, 8, 3)          0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32, 8, 3)          128
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32, 8, 3)          0
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 8, 96)             0
# _________________________________________________________________
# gru_2 (GRU)                  (None, 96)                55584
# _________________________________________________________________
# activity_class (Dense)       (None, 11)                1067
# =================================================================
# Total params: 123,339
# Trainable params: 123,083
# Non-trainable params: 256
# _________________________________________________________________
# None
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/100
# 23512/23512 [==============================] - 10s 419us/sample - loss: 0.5633 - categorical_accuracy: 0.8236
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/100
# 23512/23512 [==============================] - 9s 385us/sample - loss: 0.0327 - categorical_accuracy: 0.9918
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/100
# 23512/23512 [==============================] - 9s 383us/sample - loss: 0.0154 - categorical_accuracy: 0.9963
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/100
# 23512/23512 [==============================] - 9s 383us/sample - loss: 0.0109 - categorical_accuracy: 0.9970
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/100
# 23512/23512 [==============================] - 9s 384us/sample - loss: 0.0129 - categorical_accuracy: 0.9963
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/100
# 23512/23512 [==============================] - 9s 383us/sample - loss: 0.0053 - categorical_accuracy: 0.9985
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/100
# 11392/23512 [=============>................] - ETA: 4s - loss: 0.0014 - categorical_accuracy: 0.9998
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 23512/23512 [==============================] - 9s 383us/sample - loss: 8.4003e-05 - categorical_accuracy: 1.0000
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 42/100
# 23512/23512 [==============================] - 9s 385us/sample - loss: 5.2465e-05 - categorical_accuracy: 1.0000
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 43/100
# 23512/23512 [==============================] - 9s 383us/sample - loss: 5.5939e-05 - categorical_accuracy: 1.0000
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 44/100
# 23512/23512 [==============================] - 9s 384us/sample - loss: 4.9757e-05 - categorical_accuracy: 1.0000
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 45/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 4.8118e-05 - categorical_accuracy: 1.0000
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 46/100
# 23512/23512 [==============================] - 9s 384us/sample - loss: 5.9345e-05 - categorical_accuracy: 1.0000
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 47/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 4.9978e-05 - categorical_accuracy: 1.0000
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 48/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 4.6114e-05 - categorical_accuracy: 1.0000
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 49/100
# 23512/23512 [==============================] - 9s 385us/sample - loss: 4.6455e-05 - categorical_accuracy: 1.0000
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 50/100
# 23512/23512 [==============================] - 9s 385us/sample - loss: 4.3018e-05 - categorical_accuracy: 1.0000
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 51/100
# 23512/23512 [==============================] - 9s 384us/sample - loss: 4.1490e-05 - categorical_accuracy: 1.0000
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 52/100
# 23512/23512 [==============================] - 9s 385us/sample - loss: 3.9415e-05 - categorical_accuracy: 1.0000
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 53/100
# 23512/23512 [==============================] - 9s 385us/sample - loss: 4.3024e-05 - categorical_accuracy: 1.0000
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 54/100
# 23512/23512 [==============================] - 9s 384us/sample - loss: 3.9807e-05 - categorical_accuracy: 1.0000
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 55/100
# 23512/23512 [==============================] - 9s 385us/sample - loss: 3.8120e-05 - categorical_accuracy: 1.0000
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 56/100
# 23512/23512 [==============================] - 9s 385us/sample - loss: 3.9439e-05 - categorical_accuracy: 1.0000
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 57/100
# 23512/23512 [==============================] - 9s 385us/sample - loss: 5.5302e-05 - categorical_accuracy: 1.0000
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 58/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 3.7847e-05 - categorical_accuracy: 1.0000
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 59/100
# 23512/23512 [==============================] - 9s 385us/sample - loss: 3.9229e-05 - categorical_accuracy: 1.0000
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 60/100
# 23512/23512 [==============================] - 9s 385us/sample - loss: 3.6369e-05 - categorical_accuracy: 1.0000
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 61/100
# 23512/23512 [==============================] - 9s 384us/sample - loss: 4.5459e-05 - categorical_accuracy: 1.0000
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 62/100
# 23512/23512 [==============================] - 9s 385us/sample - loss: 3.9051e-05 - categorical_accuracy: 1.0000
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 63/100
# 23512/23512 [==============================] - 9s 385us/sample - loss: 3.8381e-05 - categorical_accuracy: 1.0000
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 64/100
# 23512/23512 [==============================] - 9s 385us/sample - loss: 3.7021e-05 - categorical_accuracy: 1.0000
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 65/100
# 23512/23512 [==============================] - 9s 384us/sample - loss: 3.8798e-05 - categorical_accuracy: 1.0000
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 66/100
# 23512/23512 [==============================] - 9s 383us/sample - loss: 3.5981e-05 - categorical_accuracy: 1.0000
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 67/100
# 23512/23512 [==============================] - 9s 384us/sample - loss: 3.4387e-05 - categorical_accuracy: 1.0000
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 68/100
# 21632/23512 [==========================>...] - ETA: 0s - loss: 3.6022e-05 - categorical_accuracy: 1.0000
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 23512/23512 [==============================] - 9s 385us/sample - loss: 2.8836e-05 - categorical_accuracy: 1.0000
# 2613/2613 [==============================] - 1s 232us/sample
# (2613, 11)
# [[10  6  1 10  0 10  4  3  2  9  8  4  5  5  5  0  6  6  0  4  3  9  3  7
#    0  1  4  5 10  5  9  1  1  9  4  6  1  3  0 10  4  6  3 10  7  1  9  1
#   10  0  1  2  1  5  9  4  9  5  4  9  3  7  7 10  0  7  2 10  0  7  0  2
#    1  6  7  1  9  6  6  4  3  4  7  9 10  8  2  0  8  7  6  8  5  1  6  5
#    4  0  3  4]]
# (2613, 1)
# [[10  6  1 10  0 10  4  3  2  9  8  4  5  5  5  0  6  6  0  4  3  9  3  7
#    0  1  4  5 10  5  9  1  1  9  4  6  1  3  0 10  4  6  3 10  7  1  9  1
#   10  0  1  2  1  5  9  4  9  5  4  9  3  7  7 10  0  7  2 10  0  7  0  2
#    1  6  7  1  9  6  6  4  3  4  7  9 10  8  2  0  8  7  6  8  5  1  6  5
#    4  0  3  4]]
# 2613/2613 [==============================] - 1s 239us/sample - loss: 1.2964e-05 - categorical_accuracy: 1.0000
# ##################################################################################################################################
# #####################################################  K-FOLD 4  ################################################################
# Train dataset:
# (23512, 1, 128, 40) (23512, 11)
# Test dataset:
# (2613, 1, 128, 40) (2613, 11)
# Activity:  20
# Activity:  11
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 40)]      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 32, 128, 40)       544
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 32, 64, 20)        0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 32, 64, 20)        128
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 64, 64, 20)        32832
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 64, 16, 5)         0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 64, 16, 5)         256
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 32, 16, 5)         32800
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 32, 8, 3)          0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 32, 8, 3)          128
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32, 8, 3)          0
# _________________________________________________________________
# reshape_3 (Reshape)          (None, 8, 96)             0
# _________________________________________________________________
# gru_3 (GRU)                  (None, 96)                55584
# _________________________________________________________________
# activity_class (Dense)       (None, 11)                1067
# =================================================================
# Total params: 123,339
# Trainable params: 123,083
# Non-trainable params: 256
# _________________________________________________________________
# None
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/100
# 23512/23512 [==============================] - 10s 423us/sample - loss: 0.5409 - categorical_accuracy: 0.8319
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 0.0209 - categorical_accuracy: 0.9969
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 0.0257 - categorical_accuracy: 0.9925
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 0.0033 - categorical_accuracy: 0.9996
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 0.0010 - categorical_accuracy: 0.9999
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 0.0266 - categorical_accuracy: 0.9911
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 0.0099 - categorical_accuracy: 0.9972
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 0.0020 - categorical_accuracy: 0.9996
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 7.9939e-04 - categorical_accuracy: 0.9999
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 10/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 4.2439e-04 - categorical_accuracy: 1.0000
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 11/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 3.3467e-04 - categorical_accuracy: 1.0000
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 12/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 4.9395e-04 - categorical_accuracy: 0.9999
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 13/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 3.3606e-04 - categorical_accuracy: 1.0000
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 14/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 2.2807e-04 - categorical_accuracy: 1.0000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 15/100
# 23512/23512 [==============================] - 9s 385us/sample - loss: 0.0017 - categorical_accuracy: 0.9994
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 16/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 3.6508e-04 - categorical_accuracy: 1.0000
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 17/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 1.9936e-04 - categorical_accuracy: 1.0000
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 18/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 1.7244e-04 - categorical_accuracy: 1.0000
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 19/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 5.9919e-04 - categorical_accuracy: 0.9998
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 20/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 2.0060e-04 - categorical_accuracy: 1.0000
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 21/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 2.3551e-04 - categorical_accuracy: 1.0000
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 22/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 6.9554e-04 - categorical_accuracy: 0.9998
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 23/100
# 23512/23512 [==============================] - 9s 385us/sample - loss: 1.8193e-04 - categorical_accuracy: 1.0000
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 24/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 1.4555e-04 - categorical_accuracy: 1.0000
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 25/100
# 23512/23512 [==============================] - 9s 385us/sample - loss: 1.0916e-04 - categorical_accuracy: 1.0000
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 26/100
# 23512/23512 [==============================] - 9s 385us/sample - loss: 1.1998e-04 - categorical_accuracy: 1.0000
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 27/100
#  7424/23512 [========>.....................] - ETA: 6s - loss: 1.0723e-04 - categorical_accuracy: 1.0000
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 23512/23512 [==============================] - 9s 384us/sample - loss: 4.7366e-05 - categorical_accuracy: 1.0000
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 48/100
# 23512/23512 [==============================] - 9s 385us/sample - loss: 5.4516e-05 - categorical_accuracy: 1.0000
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 49/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 4.4605e-05 - categorical_accuracy: 1.0000
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 50/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 4.7542e-05 - categorical_accuracy: 1.0000
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 51/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 4.7198e-05 - categorical_accuracy: 1.0000
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 52/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 4.2022e-05 - categorical_accuracy: 1.0000
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 53/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 4.5002e-05 - categorical_accuracy: 1.0000
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 54/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 4.2331e-05 - categorical_accuracy: 1.0000
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 55/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 4.2571e-05 - categorical_accuracy: 1.0000
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 56/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 4.0452e-05 - categorical_accuracy: 1.0000
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 57/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 4.0538e-05 - categorical_accuracy: 1.0000
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 58/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 4.7883e-05 - categorical_accuracy: 1.0000
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 59/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 3.9908e-05 - categorical_accuracy: 1.0000
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 60/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 3.7744e-05 - categorical_accuracy: 1.0000
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 61/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 4.3022e-05 - categorical_accuracy: 1.0000
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 62/100
# 23512/23512 [==============================] - 9s 388us/sample - loss: 4.5825e-05 - categorical_accuracy: 1.0000
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 63/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 3.8724e-05 - categorical_accuracy: 1.0000
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 64/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 3.7747e-05 - categorical_accuracy: 1.0000
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 65/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 3.8214e-05 - categorical_accuracy: 1.0000
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 66/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 4.3889e-05 - categorical_accuracy: 1.0000
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 67/100
# 23512/23512 [==============================] - 9s 385us/sample - loss: 3.4813e-05 - categorical_accuracy: 1.0000
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 68/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 3.5829e-05 - categorical_accuracy: 1.0000
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 69/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 3.8942e-05 - categorical_accuracy: 1.0000
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 70/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 3.6697e-05 - categorical_accuracy: 1.0000
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 71/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 3.4031e-05 - categorical_accuracy: 1.0000
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 72/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 3.5760e-05 - categorical_accuracy: 1.0000
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 73/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 3.4727e-05 - categorical_accuracy: 1.0000
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 74/100
# 23512/23512 [==============================] - 9s 385us/sample - loss: 3.5899e-05 - categorical_accuracy: 1.0000
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 75/100
# 23512/23512 [==============================] - 9s 385us/sample - loss: 3.5985e-05 - categorical_accuracy: 1.0000
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 76/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 3.4885e-05 - categorical_accuracy: 1.0000
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 77/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 3.5252e-05 - categorical_accuracy: 1.0000
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 78/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 3.2531e-05 - categorical_accuracy: 1.0000
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 79/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 3.2567e-05 - categorical_accuracy: 1.0000
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 80/100
# 23512/23512 [==============================] - 9s 386us/sample - loss: 3.1642e-05 - categorical_accuracy: 1.0000
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 81/100
# 23512/23512 [==============================] - 9s 387us/sample - loss: 3.3037e-05 - categorical_accuracy: 1.0000
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 82/100
# 15616/23512 [==================>...........] - ETA: 3s - loss: 3.1948e-05 - categorical_accuracy: 1.0000

# %% [markdown]
# # Accuracy

# %%
sum = 0
for acc in accuracies:
    sum += acc
print('Accuracy of K-Fold: ' + str(sum/10))
# Out:
# Accuracy of K-Fold: 0.9900493860244751
