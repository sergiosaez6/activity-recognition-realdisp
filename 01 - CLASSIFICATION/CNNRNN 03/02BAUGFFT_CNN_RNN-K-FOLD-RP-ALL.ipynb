# %% [markdown]
# # CNN

# %%
import tensorflow.keras as keras

# %%
# Módulos necesarios. Asegurarse de poder importarlos.
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from pylab import rcParams
from scipy import stats
from sklearn import metrics
import seaborn as sns
from sklearn import preprocessing
import os as os
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
from time import time

# Config the matplotlib backend as plotting inline in IPython
# %matplotlib inline

# %%
import sys
print(sys.executable)
print(sys.version)
print(sys.version_info)
tf.__version__
# Out:
# /usr/bin/python
# 3.6.8 (default, Aug 20 2019, 17:12:48)
# [GCC 8.3.0]
# sys.version_info(major=3, minor=6, micro=8, releaselevel='final', serial=0)
# '1.14.0'

# %%
keras.__version__
# Out:
# '2.2.4-tf'

# %% [markdown]
# # 10-FOLD

# %%
subjects = ['01', '02', '03', '05', '08', '09', '10', '11', '13', '14', '16', '17']
global activities
activities = [9,10,11,12,13,19,20,21,24,25,31]

# %%
# Ajustado a los datos
n_time_steps = 128
n_classes = 11 # Nº de clases (el 0 está eliminado)
n_channels = 1 # Nº de canales
n_columns = 40

# Podríamos variarlo
batch_size = 128 # Tamaño del batch
learning_rate = 1e-3 # Learning rate (por defecto es 0.001)
epochs = 100 # Épocas

# %%
class LearningRateDecay:
    def plot(self, epochs, title="Learning Rate Schedule"):
        # compute the set of learning rates for each correRPonding
        # epoch
        lrs = [self(i) for i in epochs]
 
        # the learning rate schedule
        plt.style.use("ggplot")
        plt.figure()
        plt.plot(epochs, lrs)
        plt.title(title)
        plt.xlabel("Epoch #")
        plt.ylabel("Learning Rate")
class StepDecay(LearningRateDecay):
    def __init__(self, initAlpha=0.01, factor=0.25, dropEvery=10):
        # store the base initial learning rate, drop factor, and
        # epochs to drop every
        self.initAlpha = initAlpha
        self.factor = factor
        self.dropEvery = dropEvery
 
    def __call__(self, epoch):
        # compute the learning rate for the current epoch
        exp = np.floor((1 + epoch) / self.dropEvery)
        alpha = self.initAlpha * (self.factor ** exp)
        if(alpha<1e-9):
            alpha=1e-9

        # return the learning rate
        return float(alpha) 

schedule = StepDecay(initAlpha=learning_rate, factor=0.4, dropEvery=10)

reduce_lr = keras.callbacks.LearningRateScheduler(schedule, verbose = 1)
callbacks_list = [reduce_lr]

# %%
#Visualize training evolution
def plot_curves(model, acc, loss, val_acc, val_loss, kfold):
    #########################################################################################
    # LOSS plot
    plt.figure(figsize=(12,8))
    plt.plot(model.history.history[loss], label='Training loss')
    plt.xlabel('Epochs', fontsize=15)
    plt.ylabel('Loss', fontsize=15)
    plt.tick_params(labelsize=10)
    plt.legend(loc=1,prop={'size': 10})
    plt.title('Loss in trainnig', fontsize=20)
    fig = plt.gcf()
    plt.show()
    
    fig.savefig('./02BAUGFFT_RP_KFOLD_models/loss_train_02BAUGFFT_RP_KFOLD_'+kfold+'.pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./02BAUGFFT_RP_KFOLD_models/loss_train_02BAUGFFT_RP_KFOLD_'+kfold+'svg', bbox_inches='tight',format='svg')
    
    #########################################################################################
    # ACC plot
    plt.figure(figsize=(12,8))
    plt.plot(model.history.history[acc], label='Training accuracy')
    plt.xlabel('Epochs', fontsize=15)
    plt.ylabel('Accuracy', fontsize=15)
    plt.tick_params(labelsize=10)
    plt.legend(loc=1,prop={'size': 10})
    plt.title('Accuracy in training', fontsize=20)
    fig = plt.gcf()
    plt.show()

    fig.savefig('./02BAUGFFT_RP_KFOLD_models/acc_train_02BAUGFFT_RP_KFOLD_'+kfold+'pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./02BAUGFFT_RP_KFOLD_models/acc_train_02BAUGFFT_RP_KFOLD_'+kfold+'svg', bbox_inches='tight',format='svg')
    
    #########################################################################################
    # ACC+LOSS plot
    plt.figure(figsize=(14,10))
    plt_loss = host_subplot(111, axes_class=AA.Axes)
    plt.subplots_adjust(right=0.75)

    plt_acc = plt_loss.twinx()
    plt_acc.axis["right"].toggle(all=True)
    
    plt_loss.set_xlim(0, len(model.history.history[loss]))
    plt_loss.set_ylim(0, max(model.history.history[loss]))
    plt_loss.set_xlabel('Epochs')
    plt_loss.set_ylabel('Loss')
    plt_acc.set_ylabel('Accuracy')
                        
    plt_loss.axis['left'].label.set_fontsize(15)
    plt_loss.axis['bottom'].label.set_fontsize(15)
    plt_acc.axis['right'].label.set_fontsize(15)
    
    plt_loss.plot(model.history.history[loss], c='tab:blue', ls='--', label='Training loss')
    plt_acc.plot(model.history.history[acc], c='tab:orange',ls='--', label='Training accuracy')
    
    plt.tick_params(labelsize=10)
    plt.title('Training performance', fontsize=20)
    plt_acc.set_ylim(0, 1)
    plt_loss.legend(loc=1, prop={'size': 10})
    
    fig = plt.gcf()
    plt.show()

    fig.savefig('./02BAUGFFT_RP_KFOLD_models/all_train_02BAUGFFT_RP_KFOLD_'+kfold+'pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./02BAUGFFT_RP_KFOLD_models/all_train_02BAUGFFT_RP_KFOLD_'+kfold+'svg', bbox_inches='tight',format='svg')

# %%
def plot_confusion_matrix(y_true, y_pred, kfold, classes,
                          cmap=plt.cm.Blues):

    # Compute confusion matrix
    cm = metrics.confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(20, 20))
    sns.heatmap(cm, xticklabels=classes, yticklabels=classes, square = True, robust = True, annot=True, cmap='YlOrBr')
    plt.title('CONFUSION MATRIX')
    plt.ylabel('TRUE ACTIVITY')
    plt.xlabel('PREDICTION')
    
    locs, labels = plt.xticks()
    plt.xticks(locs, labels, rotation='vertical')
    locs, labels = plt.yticks()
    plt.yticks(locs, labels, rotation='horizontal')

    # Guardamos la imagen en formato vectorial
    plt.draw()
    plt.savefig('./02BAUGFFT_RP_KFOLD_models/matriz_confusion_'+kfold+'.svg', bbox_inches='tight',format='svg')
    plt.show()

# %%
global size
size = 26125

# %%
from sklearn.model_selection import KFold
S = np.arange(0,size)
kf = KFold(n_splits=10)
kf.get_n_splits(S)

print(kf)  

S_train = []
S_test = []

for train_index, test_index in kf.split(S):
    print("TRAIN:", train_index, "TEST:", test_index)
    print(S[train_index])
    print(S[test_index])
    S_train.append(S[train_index])
    S_test.append(S[test_index])
# Out:
# KFold(n_splits=10, random_state=None, shuffle=False)
# TRAIN: [ 2613  2614  2615 ... 26122 26123 26124] TEST: [   0    1    2 ... 2610 2611 2612]
# [ 2613  2614  2615 ... 26122 26123 26124]
# [   0    1    2 ... 2610 2611 2612]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [2613 2614 2615 ... 5223 5224 5225]
# [    0     1     2 ... 26122 26123 26124]
# [2613 2614 2615 ... 5223 5224 5225]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [5226 5227 5228 ... 7836 7837 7838]
# [    0     1     2 ... 26122 26123 26124]
# [5226 5227 5228 ... 7836 7837 7838]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [ 7839  7840  7841 ... 10449 10450 10451]
# [    0     1     2 ... 26122 26123 26124]
# [ 7839  7840  7841 ... 10449 10450 10451]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [10452 10453 10454 ... 13062 13063 13064]
# [    0     1     2 ... 26122 26123 26124]
# [10452 10453 10454 ... 13062 13063 13064]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [13065 13066 13067 ... 15674 15675 15676]
# [    0     1     2 ... 26122 26123 26124]
# [13065 13066 13067 ... 15674 15675 15676]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [15677 15678 15679 ... 18286 18287 18288]
# [    0     1     2 ... 26122 26123 26124]
# [15677 15678 15679 ... 18286 18287 18288]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [18289 18290 18291 ... 20898 20899 20900]
# [    0     1     2 ... 26122 26123 26124]
# [18289 18290 18291 ... 20898 20899 20900]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [20901 20902 20903 ... 23510 23511 23512]
# [    0     1     2 ... 26122 26123 26124]
# [20901 20902 20903 ... 23510 23511 23512]
# TRAIN: [    0     1     2 ... 23510 23511 23512] TEST: [23513 23514 23515 ... 26122 26123 26124]
# [    0     1     2 ... 23510 23511 23512]
# [23513 23514 23515 ... 26122 26123 26124]

# %%
accuracies = []
for i in range(10):
    if(i<10):
        kfold='0'+str(i)
    else:
        kfold=str(i)
    print('##################################################################################################################################')
    print('#####################################################  K-FOLD %d  ################################################################'%(i+1))
    
    subjects = ['01', '02', '03', '05', '08', '09', '10', '11', '13', '14', '16', '17']
    
    ##  GENERACIÓN DATASET
    tr_seg = np.concatenate((np.load('./augment_2/subject_'+subjects[0]+'_seg.npy'),np.load('./augment_2/subject_'+subjects[1]+'_seg.npy'),np.load('./augment_2/subject_'+subjects[2]+'_seg.npy'),np.load('./augment_2/subject_'+subjects[3]+'_seg.npy'),
                             np.load('./augment_2/subject_'+subjects[4]+'_seg.npy'),np.load('./augment_2/subject_'+subjects[5]+'_seg.npy'),np.load('./augment_2/subject_'+subjects[6]+'_seg.npy'),np.load('./augment_2/subject_'+subjects[7]+'_seg.npy'),
                             np.load('./augment_2/subject_'+subjects[8]+'_seg.npy'),np.load('./augment_2/subject_'+subjects[9]+'_seg.npy'),np.load('./augment_2/subject_'+subjects[10]+'_seg.npy')))

    tr_lab = np.concatenate((np.load('./augment_2/subject_'+subjects[0]+'_lab.npy'),np.load('./augment_2/subject_'+subjects[1]+'_lab.npy'),np.load('./augment_2/subject_'+subjects[2]+'_lab.npy'),np.load('./augment_2/subject_'+subjects[3]+'_lab.npy'),
                             np.load('./augment_2/subject_'+subjects[4]+'_lab.npy'),np.load('./augment_2/subject_'+subjects[5]+'_lab.npy'),np.load('./augment_2/subject_'+subjects[6]+'_lab.npy'),np.load('./augment_2/subject_'+subjects[7]+'_lab.npy'),
                             np.load('./augment_2/subject_'+subjects[8]+'_lab.npy'),np.load('./augment_2/subject_'+subjects[9]+'_lab.npy'),np.load('./augment_2/subject_'+subjects[10]+'_lab.npy')))
    
    limit = 40
    tr_seg = tr_seg[:,:,:,:limit]
    ####################################################################################################################
    ## SHUFFLE DE DATOS
    np.random.seed(235)
    tr_seg = np.reshape(tr_seg[np.random.shuffle(np.arange(0,tr_seg.shape[0]))], (size,1,128,limit))
    tr_lab = np.reshape(tr_lab[np.random.shuffle(np.arange(0,tr_seg.shape[0]))], (size,11))
    
    ts_seg = tr_seg[S_test[i]]
    ts_lab = tr_lab[S_test[i]]
    
    tr_seg = tr_seg[S_train[i]]
    tr_lab = tr_lab[S_train[i]]
    
    print('Train dataset: ')
    print(tr_seg.shape, tr_lab.shape)
    print('Test dataset: ')
    print(ts_seg.shape, ts_lab.shape)
    ####################################################################################################################
    ## VISTA DE DFT-2D
    plt.figure(figsize=(30,30))
    plt.imshow(np.log(np.abs(np.fft.fftshift(tr_seg[0,0,:,20:40].T))**2))
    plt.show()
    print('Activity: ',activities[np.argmax(tr_lab[0])])

    plt.figure(figsize=(30,30))
    plt.imshow(np.log(np.fft.fftshift(tr_seg[10,0,:,20:40].T)**2))
    plt.show()
    print('Activity: ',activities[np.argmax(tr_lab[10])])
    ####################################################################################################################
    ## RED
    quat_input = keras.Input(shape=(n_channels, n_time_steps, n_columns), name='input_layer')

    # Some convolutional layers
    conv_1 = keras.layers.Conv2D(64, kernel_size=4,padding='same',activation='relu', data_format = 'channels_first')(quat_input)
    max_1 = keras.layers.MaxPooling2D(pool_size=2, strides=2, padding='same', data_format = 'channels_first')(conv_1)
    bn_1 = keras.layers.BatchNormalization(axis=1)(max_1)
    conv_2 = keras.layers.Conv2D(64,kernel_size=4, padding='same',activation='relu', data_format = 'channels_first')(bn_1)
    max_2 = keras.layers.MaxPooling2D(pool_size=4, strides=4, padding='same', data_format = 'channels_first')(conv_2)
    bn_2 = keras.layers.BatchNormalization(axis=1)(max_2)
    conv_3 = keras.layers.Conv2D(64,kernel_size=4, padding='same',activation='relu', data_format = 'channels_first')(bn_2)
    max_3 = keras.layers.MaxPooling2D(pool_size=4, strides=4, padding='same', data_format = 'channels_first')(conv_3)
    bn_3 = keras.layers.BatchNormalization(axis=1)(max_3)

    # Flatten the output of the convolutional layers
    #conv_flat = keras.layers.Flatten()(max_3)
    dr_1 = keras.layers.Dropout(0.5)(bn_3)

    units = 64

    res_1 = keras.layers.Reshape((8,units))(dr_1)

    gru_1 = keras.layers.GRU(units, activation='tanh', return_sequences=False, reset_after = False)(res_1)
    
    # Output layers: separate outputs for the weather and the ground labels
    multiclass_output = keras.layers.Dense(n_classes, activation='softmax',name='activity_class')(gru_1)
    
    # Creamos la estrcutura que contendrá a nuestro modelo
    model = keras.Model(inputs=quat_input, outputs=[multiclass_output],name='cnn')

    # Compilamos el modelo
    model.compile(optimizer=keras.optimizers.Adam(lr=learning_rate),
                  loss='categorical_crossentropy', metrics=['categorical_accuracy'])
    
    print(model.summary())
    ####################################################################################################################
    ## TRAIN
    history = model.fit(tr_seg,
                        tr_lab,
                        epochs = epochs,
                        steps_per_epoch = None,
                        verbose = 1,
                        batch_size = batch_size,
                        callbacks = callbacks_list)
    model.save('./02BAUGFFT_RP_KFOLD_models/CNN_'+kfold+'.h5')
    
    #Visualize training evolution
    plot_curves(model, 'categorical_accuracy', 'loss', 'val_categorical_accuracy', 'val_loss', kfold)
    ####################################################################################################################
    ## TEST
    predictions = model.predict(ts_seg, batch_size = batch_size, verbose = 1)
    
    print(predictions.shape)
    
    y_pred = np.argmax(predictions,axis=-1)
    y_pred = np.expand_dims(y_pred,axis=-1)
    print(y_pred[:100].T)
    
    y_true = np.argmax(ts_lab,axis=-1)
    y_true = np.expand_dims(y_true,axis=-1)
    print(y_true.shape)
    print(y_true[:100].T)
    
    evaluation = model.evaluate(ts_seg, ts_lab, batch_size=batch_size, verbose=1)
    accuracies.append(evaluation[1])
    
    fo = open('./02BAUGFFT_RP_KFOLD_models/accuracy_'+kfold+'.txt', "w")
    fo.seek(0,2)
    fo.write(str(evaluation))
    fo.close()
    
    ####################################################################################################################
    ## CONFUSION MATRIX
    y_true_flat = np.ndarray.flatten(y_true)
    y_pred_flat = np.ndarray.flatten(y_pred)
    
    plot_confusion_matrix(y_true_flat, y_pred_flat, kfold, classes=activities)
    
    del kfold, limit, tr_seg, tr_lab, ts_seg, ts_lab, model, history, y_pred, y_true, predictions, evaluation, y_true_flat, y_pred_flat
# Out:
# ##################################################################################################################################
# #####################################################  K-FOLD 1  ################################################################
# Train dataset:
# (23512, 1, 128, 40) (23512, 11)
# Test dataset:
# (2613, 1, 128, 40) (2613, 11)
# Activity:  9
# Activity:  24
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 40)]      0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 128, 40)       1088
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 20)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 20)        256
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 20)        65600
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 16, 5)         0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 16, 5)         256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 16, 5)         65600
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 64, 4, 2)          0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64, 4, 2)          256
# _________________________________________________________________
# dropout (Dropout)            (None, 64, 4, 2)          0
# _________________________________________________________________
# reshape (Reshape)            (None, 8, 64)             0
# _________________________________________________________________
# gru (GRU)                    (None, 64)                24768
# _________________________________________________________________
# activity_class (Dense)       (None, 11)                715
# =================================================================
# Total params: 158,539
# Trainable params: 158,155
# Non-trainable params: 384
# _________________________________________________________________
# None
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/100
# 23512/23512 [==============================] - 20s 864us/sample - loss: 0.6307 - categorical_accuracy: 0.8252
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/100
# 23512/23512 [==============================] - 13s 563us/sample - loss: 0.0268 - categorical_accuracy: 0.9969
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/100
# 23512/23512 [==============================] - 13s 546us/sample - loss: 0.0120 - categorical_accuracy: 0.9980
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/100
# 23512/23512 [==============================] - 13s 546us/sample - loss: 0.0128 - categorical_accuracy: 0.9971
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 0.0057 - categorical_accuracy: 0.9990
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 0.0103 - categorical_accuracy: 0.9972
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/100
# 23512/23512 [==============================] - 13s 548us/sample - loss: 0.0141 - categorical_accuracy: 0.9957
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 8.1748e-04 - categorical_accuracy: 1.0000
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 8.3149e-04 - categorical_accuracy: 0.9999
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 10/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 6.0145e-04 - categorical_accuracy: 1.0000
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 11/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 4.8645e-04 - categorical_accuracy: 1.0000
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 12/100
# 23512/23512 [==============================] - 13s 546us/sample - loss: 4.4723e-04 - categorical_accuracy: 1.0000
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 13/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 4.2127e-04 - categorical_accuracy: 1.0000
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 14/100
# 23512/23512 [==============================] - 13s 546us/sample - loss: 0.0010 - categorical_accuracy: 0.9999
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 15/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 3.1159e-04 - categorical_accuracy: 1.0000
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 16/100
# 23512/23512 [==============================] - 13s 545us/sample - loss: 3.4012e-04 - categorical_accuracy: 1.0000
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 17/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 3.3316e-04 - categorical_accuracy: 1.0000
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 18/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 2.4602e-04 - categorical_accuracy: 1.0000
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 19/100
# 23512/23512 [==============================] - 13s 546us/sample - loss: 2.0979e-04 - categorical_accuracy: 1.0000
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 20/100
# 23512/23512 [==============================] - 13s 546us/sample - loss: 2.5454e-04 - categorical_accuracy: 1.0000
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 21/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 2.1186e-04 - categorical_accuracy: 1.0000
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 22/100
# 23512/23512 [==============================] - 13s 546us/sample - loss: 1.6244e-04 - categorical_accuracy: 1.0000
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 23/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 1.6361e-04 - categorical_accuracy: 1.0000
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 24/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 1.4962e-04 - categorical_accuracy: 1.0000
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 25/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 1.4659e-04 - categorical_accuracy: 1.0000
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 26/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 1.4099e-04 - categorical_accuracy: 1.0000
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 27/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 1.2576e-04 - categorical_accuracy: 1.0000
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 28/100
# 23512/23512 [==============================] - 13s 546us/sample - loss: 1.2699e-04 - categorical_accuracy: 1.0000
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 29/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 1.1704e-04 - categorical_accuracy: 1.0000
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 30/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 1.1039e-04 - categorical_accuracy: 1.0000
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 31/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 1.0787e-04 - categorical_accuracy: 1.0000
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 32/100
# 23512/23512 [==============================] - 13s 546us/sample - loss: 1.2527e-04 - categorical_accuracy: 1.0000
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 33/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 1.1217e-04 - categorical_accuracy: 1.0000
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 34/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 1.0449e-04 - categorical_accuracy: 1.0000
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 35/100
# 23512/23512 [==============================] - 13s 548us/sample - loss: 9.8001e-05 - categorical_accuracy: 1.0000
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 36/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 1.0002e-04 - categorical_accuracy: 1.0000
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 37/100
# 23512/23512 [==============================] - 13s 546us/sample - loss: 9.2067e-05 - categorical_accuracy: 1.0000
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 38/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 8.9364e-05 - categorical_accuracy: 1.0000
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 39/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 8.5068e-05 - categorical_accuracy: 1.0000
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 40/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 8.5757e-05 - categorical_accuracy: 1.0000
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 41/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 8.1329e-05 - categorical_accuracy: 1.0000
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 42/100
# 23512/23512 [==============================] - 13s 546us/sample - loss: 7.9343e-05 - categorical_accuracy: 1.0000
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 43/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 8.0535e-05 - categorical_accuracy: 1.0000
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 44/100
# 23512/23512 [==============================] - 13s 548us/sample - loss: 1.0865e-04 - categorical_accuracy: 1.0000
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 45/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 8.3748e-05 - categorical_accuracy: 1.0000
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 46/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 8.3821e-05 - categorical_accuracy: 1.0000
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 47/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 7.6943e-05 - categorical_accuracy: 1.0000
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 48/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 7.3399e-05 - categorical_accuracy: 1.0000
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 49/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 7.2494e-05 - categorical_accuracy: 1.0000
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 50/100
# 23512/23512 [==============================] - 13s 546us/sample - loss: 7.0194e-05 - categorical_accuracy: 1.0000
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 51/100
# 23512/23512 [==============================] - 13s 546us/sample - loss: 7.3931e-05 - categorical_accuracy: 1.0000
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 52/100
# 23512/23512 [==============================] - 13s 548us/sample - loss: 6.6643e-05 - categorical_accuracy: 1.0000
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 53/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 6.4808e-05 - categorical_accuracy: 1.0000
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 54/100
# 23512/23512 [==============================] - 13s 546us/sample - loss: 6.4847e-05 - categorical_accuracy: 1.0000
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 55/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 6.2808e-05 - categorical_accuracy: 1.0000
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 56/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 6.1096e-05 - categorical_accuracy: 1.0000
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 57/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 7.3152e-05 - categorical_accuracy: 1.0000
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 58/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 6.0732e-05 - categorical_accuracy: 1.0000
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 59/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 1.1958e-04 - categorical_accuracy: 1.0000
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 60/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 6.0902e-05 - categorical_accuracy: 1.0000
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 61/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 5.9916e-05 - categorical_accuracy: 1.0000
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 62/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 6.5058e-05 - categorical_accuracy: 1.0000
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 63/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 6.2030e-05 - categorical_accuracy: 1.0000
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 64/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 5.7218e-05 - categorical_accuracy: 1.0000
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 65/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 5.7195e-05 - categorical_accuracy: 1.0000
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 66/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 6.3966e-05 - categorical_accuracy: 1.0000
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 67/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 5.8678e-05 - categorical_accuracy: 1.0000
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 68/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 5.8991e-05 - categorical_accuracy: 1.0000
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 69/100
# 23512/23512 [==============================] - 13s 546us/sample - loss: 6.0870e-05 - categorical_accuracy: 1.0000
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 70/100
# 23512/23512 [==============================] - 13s 546us/sample - loss: 5.4301e-05 - categorical_accuracy: 1.0000
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 71/100
# 23512/23512 [==============================] - 13s 548us/sample - loss: 5.3160e-05 - categorical_accuracy: 1.0000
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 72/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 5.3254e-05 - categorical_accuracy: 1.0000
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 73/100
# 23512/23512 [==============================] - 13s 546us/sample - loss: 5.3160e-05 - categorical_accuracy: 1.0000
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 74/100
# 23512/23512 [==============================] - 13s 546us/sample - loss: 5.2355e-05 - categorical_accuracy: 1.0000
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 75/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 5.4890e-05 - categorical_accuracy: 1.0000
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 76/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 5.1542e-05 - categorical_accuracy: 1.0000
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 77/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 5.8001e-05 - categorical_accuracy: 1.0000
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 78/100
# 23512/23512 [==============================] - 13s 546us/sample - loss: 5.0958e-05 - categorical_accuracy: 1.0000
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 79/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 5.2869e-05 - categorical_accuracy: 1.0000
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 80/100
# 23512/23512 [==============================] - 13s 546us/sample - loss: 5.2320e-05 - categorical_accuracy: 1.0000
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 81/100
# 23512/23512 [==============================] - 13s 548us/sample - loss: 5.2348e-05 - categorical_accuracy: 1.0000
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 82/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 5.2511e-05 - categorical_accuracy: 1.0000
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 83/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 5.3155e-05 - categorical_accuracy: 1.0000
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 84/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 5.3547e-05 - categorical_accuracy: 1.0000
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 85/100
# 23512/23512 [==============================] - 13s 548us/sample - loss: 5.1129e-05 - categorical_accuracy: 1.0000
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 86/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 5.1277e-05 - categorical_accuracy: 1.0000
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 87/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 5.1001e-05 - categorical_accuracy: 1.0000
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 88/100
# 23512/23512 [==============================] - 13s 548us/sample - loss: 5.1107e-05 - categorical_accuracy: 1.0000
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 89/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 4.9652e-05 - categorical_accuracy: 1.0000
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 90/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 4.9090e-05 - categorical_accuracy: 1.0000
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 91/100
# 23512/23512 [==============================] - 13s 546us/sample - loss: 4.9548e-05 - categorical_accuracy: 1.0000
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 92/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 5.0166e-05 - categorical_accuracy: 1.0000
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 93/100
# 23512/23512 [==============================] - 13s 548us/sample - loss: 5.1003e-05 - categorical_accuracy: 1.0000
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 94/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 5.0718e-05 - categorical_accuracy: 1.0000
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 95/100
# 23512/23512 [==============================] - 13s 548us/sample - loss: 4.9476e-05 - categorical_accuracy: 1.0000
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 96/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 4.9219e-05 - categorical_accuracy: 1.0000
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 97/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 4.9277e-05 - categorical_accuracy: 1.0000
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 98/100
# 23512/23512 [==============================] - 13s 547us/sample - loss: 4.8876e-05 - categorical_accuracy: 1.0000
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 99/100
# 23512/23512 [==============================] - 13s 548us/sample - loss: 4.9098e-05 - categorical_accuracy: 1.0000
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 1.0485760000000006e-07.
# Epoch 100/100
# 23512/23512 [==============================] - 13s 548us/sample - loss: 4.9660e-05 - categorical_accuracy: 1.0000
# 2613/2613 [==============================] - 1s 296us/sample
# (2613, 11)
# [[ 6  1  2  8  6  6  0  4  9  8  2  5  4  1  7  3 10  7  9  9  7  5  0  5
#    3  0  8  7  9  3  1  5  0  9  5  9  2  8  6  5  5  9  8  0  1  2  8  5
#    7  8 10  6  4  4  3 10  4  5  5  2  1  0  5  3  3  9  1  2 10 10  2  0
#    7  0 10  9  8  9  4  0  4  8  0  2  2  0  4 10  9  3  2  3  7 10  5  7
#    2  5  9  9]]
# (2613, 1)
# [[ 6  1  2  8  6  6  0  4  9  8  2  6  4  1  7  3 10  7  9  9  7  6  0  6
#    3  0  8  7  9  3  1  6  0  9  5  9  2  8  6  5  6  9  8  0  1  2  8  5
#    7  8 10  6  4  4  3 10  4  6  5  2  1  0  5  3  3  9  1  2 10 10  2  0
#    7  0 10  9  8  9  4  0  4  8  0  2  2  0  4 10  9  3  2  1  7 10  5  7
#    2  5  9  9]]
# 2613/2613 [==============================] - 1s 309us/sample - loss: 0.4095 - categorical_accuracy: 0.9480
# ##################################################################################################################################
# #####################################################  K-FOLD 2  ################################################################
# Train dataset:
# (23512, 1, 128, 40) (23512, 11)
# Test dataset:
# (2613, 1, 128, 40) (2613, 11)
# Activity:  20
# Activity:  11
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 40)]      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 128, 40)       1088
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 64, 64, 20)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64, 64, 20)        256
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 64, 64, 20)        65600
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 64, 16, 5)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64, 16, 5)         256
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 64, 16, 5)         65600
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 64, 4, 2)          0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 64, 4, 2)          256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64, 4, 2)          0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 8, 64)             0
# _________________________________________________________________
# gru_1 (GRU)                  (None, 64)                24768
# _________________________________________________________________
# activity_class (Dense)       (None, 11)                715
# =================================================================
# Total params: 158,539
# Trainable params: 158,155
# Non-trainable params: 384
# _________________________________________________________________
# None
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/100
# 23512/23512 [==============================] - 14s 575us/sample - loss: 0.5782 - categorical_accuracy: 0.8392
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 0.0240 - categorical_accuracy: 0.9977
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/100
# 23512/23512 [==============================] - 13s 540us/sample - loss: 0.0198 - categorical_accuracy: 0.9958
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/100
# 23512/23512 [==============================] - 13s 541us/sample - loss: 0.0102 - categorical_accuracy: 0.9977
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 0.0084 - categorical_accuracy: 0.9979
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 0.0083 - categorical_accuracy: 0.9982
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 0.0031 - categorical_accuracy: 0.9996
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 0.0069 - categorical_accuracy: 0.9980
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 0.0155 - categorical_accuracy: 0.9954
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 10/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 0.0011 - categorical_accuracy: 0.9999
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 11/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 7.6622e-04 - categorical_accuracy: 0.9999
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 12/100
# 23512/23512 [==============================] - 13s 543us/sample - loss: 5.9475e-04 - categorical_accuracy: 1.0000
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 13/100
# 23512/23512 [==============================] - 13s 543us/sample - loss: 5.3192e-04 - categorical_accuracy: 1.0000
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 14/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 3.4203e-04 - categorical_accuracy: 1.0000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 15/100
# 23512/23512 [==============================] - 13s 543us/sample - loss: 6.6425e-04 - categorical_accuracy: 0.9999
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 16/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 3.6121e-04 - categorical_accuracy: 1.0000
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 17/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 5.9348e-04 - categorical_accuracy: 0.9999
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 18/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 0.0011 - categorical_accuracy: 0.9998
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 19/100
# 23512/23512 [==============================] - 13s 544us/sample - loss: 3.0063e-04 - categorical_accuracy: 1.0000
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 20/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 2.7565e-04 - categorical_accuracy: 1.0000
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 21/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 2.4746e-04 - categorical_accuracy: 1.0000
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 22/100
# 23512/23512 [==============================] - 13s 543us/sample - loss: 3.1590e-04 - categorical_accuracy: 0.9999
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 23/100
# 23512/23512 [==============================] - 13s 543us/sample - loss: 2.2945e-04 - categorical_accuracy: 1.0000
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 24/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 1.8947e-04 - categorical_accuracy: 1.0000
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 25/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 1.7674e-04 - categorical_accuracy: 1.0000
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 26/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 1.5591e-04 - categorical_accuracy: 1.0000
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 27/100
# 23512/23512 [==============================] - 13s 544us/sample - loss: 1.4910e-04 - categorical_accuracy: 1.0000
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 28/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 1.3886e-04 - categorical_accuracy: 1.0000
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 29/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 1.3544e-04 - categorical_accuracy: 1.0000
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 30/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 1.7281e-04 - categorical_accuracy: 1.0000
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 31/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 1.2708e-04 - categorical_accuracy: 1.0000
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 32/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 1.2043e-04 - categorical_accuracy: 1.0000
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 33/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 1.2351e-04 - categorical_accuracy: 1.0000
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 34/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 1.1244e-04 - categorical_accuracy: 1.0000
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 35/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 1.1179e-04 - categorical_accuracy: 1.0000
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 36/100
# 23512/23512 [==============================] - 13s 545us/sample - loss: 1.0327e-04 - categorical_accuracy: 1.0000
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 37/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 1.0542e-04 - categorical_accuracy: 1.0000
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 38/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 1.0778e-04 - categorical_accuracy: 1.0000
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 39/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 9.7871e-05 - categorical_accuracy: 1.0000
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 40/100
# 23512/23512 [==============================] - 13s 544us/sample - loss: 9.3180e-05 - categorical_accuracy: 1.0000
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 41/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 9.2135e-05 - categorical_accuracy: 1.0000
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 42/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 8.8554e-05 - categorical_accuracy: 1.0000
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 43/100
# 23512/23512 [==============================] - 13s 543us/sample - loss: 9.6694e-05 - categorical_accuracy: 1.0000
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 44/100
# 23512/23512 [==============================] - 13s 544us/sample - loss: 8.6989e-05 - categorical_accuracy: 1.0000
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 45/100
# 23512/23512 [==============================] - 13s 543us/sample - loss: 8.4904e-05 - categorical_accuracy: 1.0000
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 46/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 8.3708e-05 - categorical_accuracy: 1.0000
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 47/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 8.1072e-05 - categorical_accuracy: 1.0000
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 48/100
# 23512/23512 [==============================] - 13s 544us/sample - loss: 7.9583e-05 - categorical_accuracy: 1.0000
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 49/100
# 23512/23512 [==============================] - 13s 543us/sample - loss: 7.5329e-05 - categorical_accuracy: 1.0000
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 50/100
# 23512/23512 [==============================] - 13s 543us/sample - loss: 7.6050e-05 - categorical_accuracy: 1.0000
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 51/100
# 23512/23512 [==============================] - 13s 543us/sample - loss: 7.5383e-05 - categorical_accuracy: 1.0000
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 52/100
# 23512/23512 [==============================] - 13s 544us/sample - loss: 6.9728e-05 - categorical_accuracy: 1.0000
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 53/100
# 23512/23512 [==============================] - 13s 543us/sample - loss: 7.2379e-05 - categorical_accuracy: 1.0000
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 54/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 8.2755e-05 - categorical_accuracy: 1.0000
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 55/100
# 23512/23512 [==============================] - 13s 544us/sample - loss: 1.0638e-04 - categorical_accuracy: 1.0000
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 56/100
# 23512/23512 [==============================] - 13s 544us/sample - loss: 8.2580e-05 - categorical_accuracy: 1.0000
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 57/100
# 23512/23512 [==============================] - 13s 543us/sample - loss: 8.2024e-05 - categorical_accuracy: 1.0000
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 58/100
# 23512/23512 [==============================] - 13s 544us/sample - loss: 7.2819e-05 - categorical_accuracy: 1.0000
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 59/100
# 23512/23512 [==============================] - 13s 543us/sample - loss: 6.6536e-05 - categorical_accuracy: 1.0000
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 60/100
# 23512/23512 [==============================] - 13s 543us/sample - loss: 6.6164e-05 - categorical_accuracy: 1.0000
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 61/100
# 23512/23512 [==============================] - 13s 543us/sample - loss: 1.8298e-04 - categorical_accuracy: 1.0000
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 62/100
# 23512/23512 [==============================] - 13s 544us/sample - loss: 6.7784e-05 - categorical_accuracy: 1.0000
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 63/100
# 23512/23512 [==============================] - 13s 543us/sample - loss: 7.8756e-05 - categorical_accuracy: 1.0000
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 64/100
# 23512/23512 [==============================] - 13s 544us/sample - loss: 6.8868e-05 - categorical_accuracy: 1.0000
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 65/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 6.4524e-05 - categorical_accuracy: 1.0000
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 66/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 6.4675e-05 - categorical_accuracy: 1.0000
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 67/100
# 23512/23512 [==============================] - 13s 543us/sample - loss: 6.1549e-05 - categorical_accuracy: 1.0000
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 68/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 6.3412e-05 - categorical_accuracy: 1.0000
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 69/100
# 23512/23512 [==============================] - 13s 544us/sample - loss: 6.6828e-05 - categorical_accuracy: 1.0000
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 70/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 6.1196e-05 - categorical_accuracy: 1.0000
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 71/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 6.0766e-05 - categorical_accuracy: 1.0000
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 72/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 6.4349e-05 - categorical_accuracy: 1.0000
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 73/100
# 23512/23512 [==============================] - 13s 544us/sample - loss: 6.1034e-05 - categorical_accuracy: 1.0000
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 74/100
# 23512/23512 [==============================] - 13s 543us/sample - loss: 5.9186e-05 - categorical_accuracy: 1.0000
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 75/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 6.0406e-05 - categorical_accuracy: 1.0000
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 76/100
# 23512/23512 [==============================] - 13s 544us/sample - loss: 6.0899e-05 - categorical_accuracy: 1.0000
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 77/100
# 23512/23512 [==============================] - 13s 543us/sample - loss: 5.8530e-05 - categorical_accuracy: 1.0000
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 78/100
# 23512/23512 [==============================] - 13s 545us/sample - loss: 6.2480e-05 - categorical_accuracy: 1.0000
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 79/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 6.1175e-05 - categorical_accuracy: 1.0000
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 80/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 5.9022e-05 - categorical_accuracy: 1.0000
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 81/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 5.7778e-05 - categorical_accuracy: 1.0000
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 82/100
# 23512/23512 [==============================] - 13s 543us/sample - loss: 5.9779e-05 - categorical_accuracy: 1.0000
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 83/100
# 23512/23512 [==============================] - 13s 543us/sample - loss: 6.0882e-05 - categorical_accuracy: 1.0000
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 84/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 6.2234e-05 - categorical_accuracy: 1.0000
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 85/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 5.6806e-05 - categorical_accuracy: 1.0000
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 86/100
# 23512/23512 [==============================] - 13s 544us/sample - loss: 5.7109e-05 - categorical_accuracy: 1.0000
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 87/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 5.9766e-05 - categorical_accuracy: 1.0000
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 88/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 5.6246e-05 - categorical_accuracy: 1.0000
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 89/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 5.9704e-05 - categorical_accuracy: 1.0000
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 90/100
# 23512/23512 [==============================] - 13s 544us/sample - loss: 6.1697e-05 - categorical_accuracy: 1.0000
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 91/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 5.6590e-05 - categorical_accuracy: 1.0000
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 92/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 5.8045e-05 - categorical_accuracy: 1.0000
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 93/100
# 23512/23512 [==============================] - 13s 543us/sample - loss: 5.7966e-05 - categorical_accuracy: 1.0000
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 94/100
# 23512/23512 [==============================] - 13s 544us/sample - loss: 6.2618e-05 - categorical_accuracy: 1.0000
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 95/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 6.9878e-05 - categorical_accuracy: 1.0000
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 96/100
# 23512/23512 [==============================] - 13s 542us/sample - loss: 5.7313e-05 - categorical_accuracy: 1.0000
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 97/100
# 23512/23512 [==============================] - 13s 543us/sample - loss: 5.7412e-05 - categorical_accuracy: 1.0000
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 98/100
# ...
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 68/100
# 23512/23512 [==============================] - 13s 552us/sample - loss: 6.2779e-05 - categorical_accuracy: 1.0000
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 69/100
# 23512/23512 [==============================] - 13s 551us/sample - loss: 5.9595e-05 - categorical_accuracy: 1.0000
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 70/100
# 23512/23512 [==============================] - 13s 552us/sample - loss: 5.7855e-05 - categorical_accuracy: 1.0000
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 71/100
# 23512/23512 [==============================] - 13s 551us/sample - loss: 6.0777e-05 - categorical_accuracy: 1.0000
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 72/100
# 23512/23512 [==============================] - 13s 553us/sample - loss: 5.6863e-05 - categorical_accuracy: 1.0000
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 73/100
# 23512/23512 [==============================] - 13s 553us/sample - loss: 6.1668e-05 - categorical_accuracy: 1.0000
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 74/100
# 23512/23512 [==============================] - 13s 552us/sample - loss: 5.7472e-05 - categorical_accuracy: 1.0000
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 75/100
# 23512/23512 [==============================] - 13s 553us/sample - loss: 1.3333e-04 - categorical_accuracy: 1.0000
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 76/100
# 11520/23512 [=============>................] - ETA: 6s - loss: 8.7324e-05 - categorical_accuracy: 1.0000
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 23512/23512 [==============================] - 13s 552us/sample - loss: 9.1395e-05 - categorical_accuracy: 1.0000
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 94/100
# 23512/23512 [==============================] - 13s 552us/sample - loss: 5.7618e-05 - categorical_accuracy: 1.0000
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 95/100
# 23512/23512 [==============================] - 13s 553us/sample - loss: 5.3375e-05 - categorical_accuracy: 1.0000
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 96/100
# 23512/23512 [==============================] - 13s 552us/sample - loss: 5.5895e-05 - categorical_accuracy: 1.0000
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 97/100
# 23512/23512 [==============================] - 13s 551us/sample - loss: 5.5529e-05 - categorical_accuracy: 1.0000
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 98/100
# 23512/23512 [==============================] - 13s 551us/sample - loss: 5.7139e-05 - categorical_accuracy: 1.0000
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 99/100
# 23512/23512 [==============================] - 13s 552us/sample - loss: 5.3587e-05 - categorical_accuracy: 1.0000
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 1.0485760000000006e-07.
# Epoch 100/100
# 23512/23512 [==============================] - 13s 552us/sample - loss: 5.8746e-05 - categorical_accuracy: 1.0000
# 2613/2613 [==============================] - 1s 307us/sample
# (2613, 11)
# [[ 5  2  7  8  8 10  7  8  5  3  3  2  4  4  1  0  2  4  6  4 10 10  8  3
#    0  8  0 10  4  5  6  7  6  8  8 10  6  1  0  6  0  0 10  3  6  7  2  0
#    0  7  4  5  7  8  0  0 10  7  6  1  0  1  2  2  8  7  7  5  8  3  6  3
#    0  1  5  5  7  3  5  2  3  5  0  6  2  8 10  3  7  8 10  2  1  8  2  2
#    4  0  4  4]]
# (2613, 1)
# [[ 5  2  7  8  8 10  7  8  5  3  3  2  4  4  1  0  2  4  6  4 10 10  8  3
#    0  8  0 10  4  5  6  7  6  8  8 10  6  1  0  6  0  0 10  3  6  7  2  0
#    0  7  4  5  7  8  0  0 10  7  6  1  0  1  2  2  8  7  7  5  8  3  6  3
#    0  1  5  5  7  3  5  2  3  5  0  6  2  8 10  3  7  8 10  2  1  8  2  2
#    4  0  4  4]]
# 2613/2613 [==============================] - 1s 313us/sample - loss: 2.1070e-05 - categorical_accuracy: 1.0000
# ##################################################################################################################################
# #####################################################  K-FOLD 6  ################################################################
# Train dataset:
# (23513, 1, 128, 40) (23513, 11)
# Test dataset:
# (2612, 1, 128, 40) (2612, 11)
# Activity:  20
# Activity:  11
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 40)]      0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 64, 128, 40)       1088
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 64, 64, 20)        0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 64, 64, 20)        256
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 64, 64, 20)        65600
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 64, 16, 5)         0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 64, 16, 5)         256
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 64, 16, 5)         65600
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 64, 4, 2)          0
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 64, 4, 2)          256
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64, 4, 2)          0
# _________________________________________________________________
# reshape_5 (Reshape)          (None, 8, 64)             0
# _________________________________________________________________
# gru_5 (GRU)                  (None, 64)                24768
# _________________________________________________________________
# activity_class (Dense)       (None, 11)                715
# =================================================================
# Total params: 158,539
# Trainable params: 158,155
# Non-trainable params: 384
# _________________________________________________________________
# None
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/100
# 23513/23513 [==============================] - 15s 623us/sample - loss: 0.5865 - categorical_accuracy: 0.8372
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/100
# 23513/23513 [==============================] - 13s 569us/sample - loss: 0.0296 - categorical_accuracy: 0.9949
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/100
# 23513/23513 [==============================] - 13s 551us/sample - loss: 0.0152 - categorical_accuracy: 0.9970
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/100
# 23513/23513 [==============================] - 13s 552us/sample - loss: 0.0108 - categorical_accuracy: 0.9974
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/100
# 23513/23513 [==============================] - 13s 552us/sample - loss: 0.0104 - categorical_accuracy: 0.9974
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/100
# 23513/23513 [==============================] - 13s 552us/sample - loss: 0.0049 - categorical_accuracy: 0.9990
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/100
# 23513/23513 [==============================] - 13s 551us/sample - loss: 0.0036 - categorical_accuracy: 0.9993
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/100
# 23513/23513 [==============================] - 13s 551us/sample - loss: 0.0102 - categorical_accuracy: 0.9971
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/100
# 10112/23513 [===========>..................] - ETA: 7s - loss: 0.0088 - categorical_accuracy: 0.9973
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 23513/23513 [==============================] - 13s 552us/sample - loss: 1.1924e-04 - categorical_accuracy: 1.0000
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 29/100
# 23513/23513 [==============================] - 13s 553us/sample - loss: 1.0662e-04 - categorical_accuracy: 1.0000
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 30/100
# 23513/23513 [==============================] - 13s 552us/sample - loss: 1.1300e-04 - categorical_accuracy: 1.0000
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 31/100
# 23513/23513 [==============================] - 13s 552us/sample - loss: 1.1713e-04 - categorical_accuracy: 1.0000
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 32/100
# 23513/23513 [==============================] - 13s 553us/sample - loss: 9.5705e-05 - categorical_accuracy: 1.0000
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 33/100
# 23513/23513 [==============================] - 13s 553us/sample - loss: 9.9519e-05 - categorical_accuracy: 1.0000
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 34/100
# 23513/23513 [==============================] - 13s 552us/sample - loss: 9.9968e-05 - categorical_accuracy: 1.0000
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 35/100
# 23513/23513 [==============================] - 13s 552us/sample - loss: 1.0141e-04 - categorical_accuracy: 1.0000
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 36/100
# 23513/23513 [==============================] - 13s 553us/sample - loss: 9.2881e-05 - categorical_accuracy: 1.0000
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 37/100
# 23513/23513 [==============================] - 13s 553us/sample - loss: 8.5316e-05 - categorical_accuracy: 1.0000
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 38/100
# 23513/23513 [==============================] - 13s 554us/sample - loss: 7.8995e-05 - categorical_accuracy: 1.0000
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 39/100
# 23513/23513 [==============================] - 13s 553us/sample - loss: 7.7758e-05 - categorical_accuracy: 1.0000
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 40/100
# 23513/23513 [==============================] - 13s 552us/sample - loss: 1.0808e-04 - categorical_accuracy: 1.0000
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 41/100
# 23513/23513 [==============================] - 13s 549us/sample - loss: 7.7337e-05 - categorical_accuracy: 1.0000
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 42/100
# 23513/23513 [==============================] - 13s 547us/sample - loss: 8.5395e-05 - categorical_accuracy: 1.0000
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 43/100
# 23513/23513 [==============================] - 13s 552us/sample - loss: 7.2609e-05 - categorical_accuracy: 1.0000
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 44/100
# 23513/23513 [==============================] - 13s 553us/sample - loss: 7.3187e-05 - categorical_accuracy: 1.0000
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 45/100
# 23513/23513 [==============================] - 13s 554us/sample - loss: 6.9540e-05 - categorical_accuracy: 1.0000
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 46/100
# 23513/23513 [==============================] - 13s 553us/sample - loss: 6.7410e-05 - categorical_accuracy: 1.0000
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 47/100
# 23513/23513 [==============================] - 13s 554us/sample - loss: 6.3471e-05 - categorical_accuracy: 1.0000
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 48/100
# 23513/23513 [==============================] - 13s 552us/sample - loss: 6.5179e-05 - categorical_accuracy: 1.0000
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 49/100
# 23513/23513 [==============================] - 13s 553us/sample - loss: 7.2827e-05 - categorical_accuracy: 1.0000
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 50/100
# 23513/23513 [==============================] - 13s 553us/sample - loss: 6.3217e-05 - categorical_accuracy: 1.0000
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 51/100
# 23513/23513 [==============================] - 13s 554us/sample - loss: 6.5389e-05 - categorical_accuracy: 1.0000
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 52/100
# 23513/23513 [==============================] - 13s 553us/sample - loss: 6.2893e-05 - categorical_accuracy: 1.0000
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 53/100
# 23513/23513 [==============================] - 13s 552us/sample - loss: 1.2177e-04 - categorical_accuracy: 1.0000
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 54/100
# 23513/23513 [==============================] - 13s 551us/sample - loss: 7.2474e-05 - categorical_accuracy: 1.0000
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 55/100
# 23513/23513 [==============================] - 13s 554us/sample - loss: 6.4334e-05 - categorical_accuracy: 1.0000
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 56/100
# 23513/23513 [==============================] - 13s 553us/sample - loss: 5.9893e-05 - categorical_accuracy: 1.0000
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 57/100
# 23513/23513 [==============================] - 13s 552us/sample - loss: 6.1345e-05 - categorical_accuracy: 1.0000
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 58/100
# 23513/23513 [==============================] - 13s 553us/sample - loss: 5.9407e-05 - categorical_accuracy: 1.0000
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 59/100
#  5504/23513 [======>.......................] - ETA: 9s - loss: 5.5929e-05 - categorical_accuracy: 1.0000

# %% [markdown]
# # Accuracy

# %%
sum = 0
for acc in accuracies:
    sum += acc
print('Accuracy of K-Fold: ' + str(sum/10))
# Out:
# Accuracy of K-Fold: 0.9947186887264252
