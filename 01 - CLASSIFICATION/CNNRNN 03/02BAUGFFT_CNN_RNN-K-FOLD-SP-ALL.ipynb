# %% [markdown]
# # CNN

# %%
import tensorflow.keras as keras

# %%
# Módulos necesarios. Asegurarse de poder importarlos.
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from pylab import rcParams
from scipy import stats
from sklearn import metrics
import seaborn as sns
from sklearn import preprocessing
import os as os
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
from time import time

# Config the matplotlib backend as plotting inline in IPython
# %matplotlib inline

# %%
import sys
print(sys.executable)
print(sys.version)
print(sys.version_info)
tf.__version__
# Out:
# /usr/bin/python
# 3.6.8 (default, Aug 20 2019, 17:12:48)
# [GCC 8.3.0]
# sys.version_info(major=3, minor=6, micro=8, releaselevel='final', serial=0)
# '1.14.0'

# %%
keras.__version__
# Out:
# '2.2.4-tf'

# %% [markdown]
# # 12-FOLD

# %%
subjects = ['01', '02', '03', '05', '08', '09', '10', '11', '13', '14', '16', '17']
global activities
activities = [9,10,11,12,13,19,20,21,24,25,31]

# %%
# Ajustado a los datos
n_time_steps = 128
n_classes = 11 # Nº de clases (el 0 está eliminado)
n_channels = 1 # Nº de canales
n_columns = 40

# Podríamos variarlo
batch_size = 128 # Tamaño del batch
learning_rate = 1e-3 # Learning rate (por defecto es 0.001)
epochs = 100 # Épocas

# %%
class LearningRateDecay:
    def plot(self, epochs, title="Learning Rate Schedule"):
        # compute the set of learning rates for each corresponding
        # epoch
        lrs = [self(i) for i in epochs]
 
        # the learning rate schedule
        plt.style.use("ggplot")
        plt.figure()
        plt.plot(epochs, lrs)
        plt.title(title)
        plt.xlabel("Epoch #")
        plt.ylabel("Learning Rate")
class StepDecay(LearningRateDecay):
    def __init__(self, initAlpha=0.01, factor=0.25, dropEvery=10):
        # store the base initial learning rate, drop factor, and
        # epochs to drop every
        self.initAlpha = initAlpha
        self.factor = factor
        self.dropEvery = dropEvery
 
    def __call__(self, epoch):
        # compute the learning rate for the current epoch
        exp = np.floor((1 + epoch) / self.dropEvery)
        alpha = self.initAlpha * (self.factor ** exp)
        if(alpha<1e-9):
            alpha=1e-9

        # return the learning rate
        return float(alpha) 

schedule = StepDecay(initAlpha=learning_rate, factor=0.4, dropEvery=10)

reduce_lr = keras.callbacks.LearningRateScheduler(schedule, verbose = 1)
callbacks_list = [reduce_lr]

# %%
#Visualize training evolution
def plot_curves(model, acc, loss, val_acc, val_loss, subject_test):
    #########################################################################################
    # LOSS plot
    plt.figure(figsize=(12,8))
    plt.plot(model.history.history[loss], label='Training loss')
    plt.xlabel('Epochs', fontsize=15)
    plt.ylabel('Loss', fontsize=15)
    plt.tick_params(labelsize=10)
    plt.legend(loc=1,prop={'size': 10})
    plt.title('Loss in trainnig', fontsize=20)
    fig = plt.gcf()
    plt.show()
    
    fig.savefig('./02BAUGFFT_SP_KFOLD_models/loss_train_02BAUGFFT_SP_KFOLD_'+subject_test+'.pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./02BAUGFFT_SP_KFOLD_models/loss_train_02BAUGFFT_SP_KFOLD_'+subject_test+'svg', bbox_inches='tight',format='svg')
    
    #########################################################################################
    # ACC plot
    plt.figure(figsize=(12,8))
    plt.plot(model.history.history[acc], label='Training accuracy')
    plt.xlabel('Epochs', fontsize=15)
    plt.ylabel('Accuracy', fontsize=15)
    plt.tick_params(labelsize=10)
    plt.legend(loc=1,prop={'size': 10})
    plt.title('Accuracy in training', fontsize=20)
    fig = plt.gcf()
    plt.show()

    fig.savefig('./02BAUGFFT_SP_KFOLD_models/acc_train_02BAUGFFT_SP_KFOLD_'+subject_test+'pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./02BAUGFFT_SP_KFOLD_models/acc_train_02BAUGFFT_SP_KFOLD_'+subject_test+'svg', bbox_inches='tight',format='svg')
    
    #########################################################################################
    # ACC+LOSS plot
    plt.figure(figsize=(14,10))
    plt_loss = host_subplot(111, axes_class=AA.Axes)
    plt.subplots_adjust(right=0.75)

    plt_acc = plt_loss.twinx()
    plt_acc.axis["right"].toggle(all=True)
    
    plt_loss.set_xlim(0, len(model.history.history[loss]))
    plt_loss.set_ylim(0, max(model.history.history[loss]))
    plt_loss.set_xlabel('Epochs')
    plt_loss.set_ylabel('Loss')
    plt_acc.set_ylabel('Accuracy')
                        
    plt_loss.axis['left'].label.set_fontsize(15)
    plt_loss.axis['bottom'].label.set_fontsize(15)
    plt_acc.axis['right'].label.set_fontsize(15)
    
    plt_loss.plot(model.history.history[loss], c='tab:blue', ls='--', label='Training loss')
    plt_acc.plot(model.history.history[acc], c='tab:orange',ls='--', label='Training accuracy')
    
    plt.tick_params(labelsize=10)
    plt.title('Training performance', fontsize=20)
    plt_acc.set_ylim(0, 1)
    plt_loss.legend(loc=1, prop={'size': 10})
    
    fig = plt.gcf()
    plt.show()

    fig.savefig('./02BAUGFFT_SP_KFOLD_models/all_train_02BAUGFFT_SP_KFOLD_'+subject_test+'pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./02BAUGFFT_SP_KFOLD_models/all_train_02BAUGFFT_SP_KFOLD_'+subject_test+'svg', bbox_inches='tight',format='svg')

# %%
def plot_confusion_matrix(y_true, y_pred, subject_test, classes,
                          cmap=plt.cm.Blues):

    # Compute confusion matrix
    cm = metrics.confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(20, 20))
    sns.heatmap(cm, xticklabels=classes, yticklabels=classes, square = True, robust = True, annot=True, cmap='YlOrBr')
    plt.title('CONFUSION MATRIX')
    plt.ylabel('TRUE ACTIVITY')
    plt.xlabel('PREDICTION')
    
    locs, labels = plt.xticks()
    plt.xticks(locs, labels, rotation='vertical')
    locs, labels = plt.yticks()
    plt.yticks(locs, labels, rotation='horizontal')

    # Guardamos la imagen en formato vectorial
    plt.draw()
    plt.savefig('./02BAUGFFT_SP_KFOLD_models/matriz_confusion_'+subject_test+'.svg', bbox_inches='tight',format='svg')
    plt.show()

# %%
accuracies = []
for i in range(12):
    print('##################################################################################################################################')
    print('#####################################################  K-FOLD %d  ################################################################'%(i+1))
    
    subject_test = subjects[i]
    subjects_train = [s for s in subjects if s not in subject_test]
    print('Training subjects: ' + str(subjects_train))
    print('Test subject: ' + str(subject_test))
    
    ##  GENERACIÓN DATASET
    tr_seg = np.concatenate((np.load('./augment_2/subject_'+subjects_train[0]+'_seg.npy'),np.load('./augment_2/subject_'+subjects_train[1]+'_seg.npy'),np.load('./augment_2/subject_'+subjects_train[2]+'_seg.npy'),np.load('./augment_2/subject_'+subjects_train[3]+'_seg.npy'),
                             np.load('./augment_2/subject_'+subjects_train[4]+'_seg.npy'),np.load('./augment_2/subject_'+subjects_train[5]+'_seg.npy'),np.load('./augment_2/subject_'+subjects_train[6]+'_seg.npy'),np.load('./augment_2/subject_'+subjects_train[7]+'_seg.npy'),
                             np.load('./augment_2/subject_'+subjects_train[8]+'_seg.npy'),np.load('./augment_2/subject_'+subjects_train[9]+'_seg.npy'),np.load('./augment_2/subject_'+subjects_train[10]+'_seg.npy')))
    
    tr_lab = np.concatenate((np.load('./augment_2/subject_'+subjects_train[0]+'_lab.npy'),np.load('./augment_2/subject_'+subjects_train[1]+'_lab.npy'),np.load('./augment_2/subject_'+subjects_train[2]+'_lab.npy'),np.load('./augment_2/subject_'+subjects_train[3]+'_lab.npy'),
                             np.load('./augment_2/subject_'+subjects_train[4]+'_lab.npy'),np.load('./augment_2/subject_'+subjects_train[5]+'_lab.npy'),np.load('./augment_2/subject_'+subjects_train[6]+'_lab.npy'),np.load('./augment_2/subject_'+subjects_train[7]+'_lab.npy'),
                             np.load('./augment_2/subject_'+subjects_train[8]+'_lab.npy'),np.load('./augment_2/subject_'+subjects_train[9]+'_lab.npy'),np.load('./augment_2/subject_'+subjects_train[10]+'_lab.npy')))

    ts_seg = np.load('./augment_2/subject_'+subject_test+'_seg.npy')
    ts_lab = np.load('./augment_2/subject_'+subject_test+'_lab.npy')
    
    limit = 40
    tr_seg = tr_seg[:,:,:,:limit]
    ts_seg = ts_seg[:,:,:,:limit]
    ####################################################################################################################
    ## SHUFFLE DE DATOS
    np.random.seed(235)
    tr_seg = np.reshape(tr_seg[np.random.shuffle(np.arange(0,tr_seg.shape[0]))], (11*2375,1,128,limit))
    tr_lab = np.reshape(tr_lab[np.random.shuffle(np.arange(0,tr_seg.shape[0]))], (11*2375,11))

    np.random.seed(235)
    ts_seg = np.reshape(ts_seg[np.random.shuffle(np.arange(0,ts_seg.shape[0]))], (2375,1,128,limit))
    ts_lab = np.reshape(ts_lab[np.random.shuffle(np.arange(0,ts_seg.shape[0]))], (2375,11))
    
    print('Train dataset: ')
    print(tr_seg.shape, tr_lab.shape)
    print('Test dataset: ')
    print(ts_seg.shape, ts_lab.shape)
    ####################################################################################################################
    ## VISTA DE DFT-2D
    plt.figure(figsize=(30,30))
    plt.imshow(np.log(np.abs(np.fft.fftshift(tr_seg[0,0,:,20:40].T))**2))
    plt.show()
    print('Activity: ',activities[np.argmax(tr_lab[0])])

    plt.figure(figsize=(30,30))
    plt.imshow(np.log(np.fft.fftshift(tr_seg[10,0,:,20:40].T)**2))
    plt.show()
    print('Activity: ',activities[np.argmax(tr_lab[10])])
    ####################################################################################################################
    ## RED
    quat_input = keras.Input(shape=(n_channels, n_time_steps, n_columns), name='input_layer')

    # Some convolutional layers
    conv_1 = keras.layers.Conv2D(64, kernel_size=4,padding='same',activation='relu', data_format = 'channels_first')(quat_input)
    max_1 = keras.layers.MaxPooling2D(pool_size=2, strides=2, padding='same', data_format = 'channels_first')(conv_1)
    bn_1 = keras.layers.BatchNormalization(axis=1)(max_1)
    conv_2 = keras.layers.Conv2D(64,kernel_size=4, padding='same',activation='relu', data_format = 'channels_first')(bn_1)
    max_2 = keras.layers.MaxPooling2D(pool_size=4, strides=4, padding='same', data_format = 'channels_first')(conv_2)
    bn_2 = keras.layers.BatchNormalization(axis=1)(max_2)
    conv_3 = keras.layers.Conv2D(64,kernel_size=4, padding='same',activation='relu', data_format = 'channels_first')(bn_2)
    max_3 = keras.layers.MaxPooling2D(pool_size=4, strides=4, padding='same', data_format = 'channels_first')(conv_3)
    bn_3 = keras.layers.BatchNormalization(axis=1)(max_3)

    # Flatten the output of the convolutional layers
    #conv_flat = keras.layers.Flatten()(max_3)
    dr_1 = keras.layers.Dropout(0.5)(bn_3)

    units = 64

    res_1 = keras.layers.Reshape((8,units))(dr_1)

    gru_1 = keras.layers.GRU(units, activation='tanh', return_sequences=False, reset_after = False)(res_1)
    
    # Output layers: separate outputs for the weather and the ground labels
    multiclass_output = keras.layers.Dense(n_classes, activation='softmax',name='activity_class')(gru_1)
    
    # Creamos la estrcutura que contendrá a nuestro modelo
    model = keras.Model(inputs=quat_input, outputs=[multiclass_output],name='cnn')

    # Compilamos el modelo
    model.compile(optimizer=keras.optimizers.Adam(lr=learning_rate),
                  loss='categorical_crossentropy', metrics=['categorical_accuracy'])
    
    print(model.summary())
    ####################################################################################################################
    ## TRAIN
    history = model.fit(tr_seg,
                        tr_lab,
                        epochs = epochs,
                        steps_per_epoch = None,
                        verbose = 1,
                        batch_size = batch_size,
                        callbacks = callbacks_list)
    model.save('./02BAUGFFT_SP_KFOLD_models/CNN_'+subject_test+'.h5')
    
    #Visualize training evolution
    plot_curves(model, 'categorical_accuracy', 'loss', 'val_categorical_accuracy', 'val_loss', subject_test)
    ####################################################################################################################
    ## TEST
    predictions = model.predict(ts_seg, batch_size = batch_size, verbose = 1)
    
    print(predictions.shape)
    
    y_pred = np.argmax(predictions,axis=-1)
    y_pred = np.expand_dims(y_pred,axis=-1)
    print(y_pred[:100].T)
    
    y_true = np.argmax(ts_lab,axis=-1)
    y_true = np.expand_dims(y_true,axis=-1)
    print(y_true.shape)
    print(y_true[:100].T)
    
    evaluation = model.evaluate(ts_seg, ts_lab, batch_size=batch_size, verbose=1)
    accuracies.append(evaluation[1])
    
    fo = open('./02BAUGFFT_SP_KFOLD_models/accuracy_'+subject_test+'.txt', "w")
    fo.seek(0,2)
    fo.write(str(evaluation))
    fo.close()
    
    ####################################################################################################################
    ## CONFUSION MATRIX
    y_true_flat = np.ndarray.flatten(y_true)
    y_pred_flat = np.ndarray.flatten(y_pred)
    
    plot_confusion_matrix(y_true_flat, y_pred_flat, subject_test, classes=activities)
    
    del subject_test, subjects_train, limit, tr_seg, tr_lab, ts_seg, ts_lab, model, history, y_pred, y_true, predictions, evaluation, y_true_flat, y_pred_flat
# Out:
# ##################################################################################################################################
# #####################################################  K-FOLD 1  ################################################################
# Training subjects: ['02', '03', '05', '08', '09', '10', '11', '13', '14', '16', '17']
# Test subject: 01
# Train dataset:
# (26125, 1, 128, 40) (26125, 11)
# Test dataset:
# (2375, 1, 128, 40) (2375, 11)
# Activity:  20
# Activity:  31
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 40)]      0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 128, 40)       1088
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 20)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 20)        256
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 20)        65600
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 16, 5)         0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 16, 5)         256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 16, 5)         65600
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 64, 4, 2)          0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64, 4, 2)          256
# _________________________________________________________________
# dropout (Dropout)            (None, 64, 4, 2)          0
# _________________________________________________________________
# reshape (Reshape)            (None, 8, 64)             0
# _________________________________________________________________
# gru (GRU)                    (None, 64)                24768
# _________________________________________________________________
# activity_class (Dense)       (None, 11)                715
# =================================================================
# Total params: 158,539
# Trainable params: 158,155
# Non-trainable params: 384
# _________________________________________________________________
# None
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/100
# 26125/26125 [==============================] - 22s 830us/sample - loss: 0.5792 - categorical_accuracy: 0.8384
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/100
# 26125/26125 [==============================] - 14s 544us/sample - loss: 0.0260 - categorical_accuracy: 0.9963
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/100
# 26125/26125 [==============================] - 14s 542us/sample - loss: 0.0213 - categorical_accuracy: 0.9954
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/100
# 26125/26125 [==============================] - 14s 541us/sample - loss: 0.0027 - categorical_accuracy: 0.9998
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/100
# 26125/26125 [==============================] - 14s 542us/sample - loss: 0.0295 - categorical_accuracy: 0.9913
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/100
# 26125/26125 [==============================] - 14s 542us/sample - loss: 0.0018 - categorical_accuracy: 0.9998
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/100
# 26125/26125 [==============================] - 14s 542us/sample - loss: 0.0041 - categorical_accuracy: 0.9990
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/100
# 26125/26125 [==============================] - 14s 542us/sample - loss: 0.0136 - categorical_accuracy: 0.9961
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/100
# 26125/26125 [==============================] - 14s 542us/sample - loss: 0.0052 - categorical_accuracy: 0.9988
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 10/100
# 26125/26125 [==============================] - 14s 542us/sample - loss: 9.0377e-04 - categorical_accuracy: 1.0000
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 11/100
# 26125/26125 [==============================] - 14s 542us/sample - loss: 8.6248e-04 - categorical_accuracy: 0.9999
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 12/100
# 26125/26125 [==============================] - 14s 542us/sample - loss: 4.4675e-04 - categorical_accuracy: 1.0000
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 13/100
# 26125/26125 [==============================] - 14s 542us/sample - loss: 0.0011 - categorical_accuracy: 0.9998
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 14/100
# 26125/26125 [==============================] - 14s 543us/sample - loss: 3.5271e-04 - categorical_accuracy: 1.0000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 15/100
# 26125/26125 [==============================] - 14s 542us/sample - loss: 3.2049e-04 - categorical_accuracy: 1.0000
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 16/100
# 26125/26125 [==============================] - 14s 542us/sample - loss: 2.4306e-04 - categorical_accuracy: 1.0000
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 17/100
# 26125/26125 [==============================] - 14s 542us/sample - loss: 2.1504e-04 - categorical_accuracy: 1.0000
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 18/100
# 26125/26125 [==============================] - 14s 542us/sample - loss: 1.8015e-04 - categorical_accuracy: 1.0000
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 19/100
# 26125/26125 [==============================] - 14s 542us/sample - loss: 2.2135e-04 - categorical_accuracy: 1.0000
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 20/100
# 26125/26125 [==============================] - 14s 542us/sample - loss: 1.7618e-04 - categorical_accuracy: 1.0000
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 21/100
# 26125/26125 [==============================] - 14s 542us/sample - loss: 1.6415e-04 - categorical_accuracy: 1.0000
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 22/100
# 26125/26125 [==============================] - 14s 542us/sample - loss: 1.4420e-04 - categorical_accuracy: 1.0000
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 23/100
# 26125/26125 [==============================] - 14s 542us/sample - loss: 1.3392e-04 - categorical_accuracy: 1.0000
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 24/100
# 26125/26125 [==============================] - 14s 543us/sample - loss: 1.8067e-04 - categorical_accuracy: 1.0000
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 25/100
# 26125/26125 [==============================] - 14s 542us/sample - loss: 1.3346e-04 - categorical_accuracy: 1.0000
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 26/100
# 26125/26125 [==============================] - 14s 541us/sample - loss: 1.2252e-04 - categorical_accuracy: 1.0000
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 27/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 1.1998e-04 - categorical_accuracy: 1.0000
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 28/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 1.0769e-04 - categorical_accuracy: 1.0000
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 29/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 9.7507e-05 - categorical_accuracy: 1.0000
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 30/100
# 26125/26125 [==============================] - 14s 541us/sample - loss: 9.4435e-05 - categorical_accuracy: 1.0000
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 31/100
# 26125/26125 [==============================] - 14s 541us/sample - loss: 1.3083e-04 - categorical_accuracy: 1.0000
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 32/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 1.0162e-04 - categorical_accuracy: 1.0000
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 33/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 9.6353e-05 - categorical_accuracy: 1.0000
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 34/100
# 26125/26125 [==============================] - 14s 541us/sample - loss: 8.8580e-05 - categorical_accuracy: 1.0000
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 35/100
# 26125/26125 [==============================] - 14s 541us/sample - loss: 8.2616e-05 - categorical_accuracy: 1.0000
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 36/100
# 26125/26125 [==============================] - 14s 541us/sample - loss: 8.0222e-05 - categorical_accuracy: 1.0000
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 37/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 8.3457e-05 - categorical_accuracy: 1.0000
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 38/100
# 26125/26125 [==============================] - 14s 541us/sample - loss: 7.7935e-05 - categorical_accuracy: 1.0000
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 39/100
# 26125/26125 [==============================] - 14s 541us/sample - loss: 2.3918e-04 - categorical_accuracy: 1.0000
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 40/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 1.2723e-04 - categorical_accuracy: 1.0000
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 41/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 1.4641e-04 - categorical_accuracy: 1.0000
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 42/100
# 26125/26125 [==============================] - 14s 541us/sample - loss: 1.0703e-04 - categorical_accuracy: 1.0000
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 43/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 3.8072e-04 - categorical_accuracy: 1.0000
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 44/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 1.0215e-04 - categorical_accuracy: 1.0000
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 45/100
# 26125/26125 [==============================] - 14s 541us/sample - loss: 8.7345e-05 - categorical_accuracy: 1.0000
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 46/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 7.1032e-05 - categorical_accuracy: 1.0000
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 47/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 8.8253e-05 - categorical_accuracy: 1.0000
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 48/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 9.2981e-05 - categorical_accuracy: 1.0000
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 49/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 9.9006e-05 - categorical_accuracy: 1.0000
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 50/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 6.9442e-05 - categorical_accuracy: 1.0000
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 51/100
# 26125/26125 [==============================] - 14s 542us/sample - loss: 6.9665e-05 - categorical_accuracy: 1.0000
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 52/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 9.2499e-05 - categorical_accuracy: 1.0000
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 53/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 6.0766e-05 - categorical_accuracy: 1.0000
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 54/100
# 26125/26125 [==============================] - 14s 541us/sample - loss: 5.8978e-05 - categorical_accuracy: 1.0000
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 55/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 6.0684e-05 - categorical_accuracy: 1.0000
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 56/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 5.7195e-05 - categorical_accuracy: 1.0000
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 57/100
# 26125/26125 [==============================] - 14s 541us/sample - loss: 5.6005e-05 - categorical_accuracy: 1.0000
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 58/100
# 26125/26125 [==============================] - 14s 542us/sample - loss: 5.4286e-05 - categorical_accuracy: 1.0000
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 59/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 5.3993e-05 - categorical_accuracy: 1.0000
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 60/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 5.4346e-05 - categorical_accuracy: 1.0000
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 61/100
# 26125/26125 [==============================] - 14s 539us/sample - loss: 5.5334e-05 - categorical_accuracy: 1.0000
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 62/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 5.9811e-05 - categorical_accuracy: 1.0000
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 63/100
# 26125/26125 [==============================] - 14s 539us/sample - loss: 5.3770e-05 - categorical_accuracy: 1.0000
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 64/100
# 26125/26125 [==============================] - 14s 541us/sample - loss: 5.2272e-05 - categorical_accuracy: 1.0000
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 65/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 5.1466e-05 - categorical_accuracy: 1.0000
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 66/100
# 26125/26125 [==============================] - 14s 542us/sample - loss: 5.0903e-05 - categorical_accuracy: 1.0000
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 67/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 4.9764e-05 - categorical_accuracy: 1.0000
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 68/100
# 26125/26125 [==============================] - 14s 541us/sample - loss: 5.0148e-05 - categorical_accuracy: 1.0000
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 69/100
# 26125/26125 [==============================] - 14s 541us/sample - loss: 4.7018e-05 - categorical_accuracy: 1.0000
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 70/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 4.8061e-05 - categorical_accuracy: 1.0000
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 71/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 4.8224e-05 - categorical_accuracy: 1.0000
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 72/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 4.7602e-05 - categorical_accuracy: 1.0000
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 73/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 5.1749e-05 - categorical_accuracy: 1.0000
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 74/100
# 26125/26125 [==============================] - 14s 541us/sample - loss: 4.5665e-05 - categorical_accuracy: 1.0000
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 75/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 4.6656e-05 - categorical_accuracy: 1.0000
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 76/100
# 26125/26125 [==============================] - 14s 541us/sample - loss: 1.2551e-04 - categorical_accuracy: 1.0000
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 77/100
# 26125/26125 [==============================] - 14s 541us/sample - loss: 4.4471e-05 - categorical_accuracy: 1.0000
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 78/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 4.7822e-05 - categorical_accuracy: 1.0000
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 79/100
# 26125/26125 [==============================] - 14s 541us/sample - loss: 6.9363e-05 - categorical_accuracy: 1.0000
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 80/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 4.6365e-05 - categorical_accuracy: 1.0000
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 81/100
# 26125/26125 [==============================] - 14s 541us/sample - loss: 4.5836e-05 - categorical_accuracy: 1.0000
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 82/100
# 26125/26125 [==============================] - 14s 541us/sample - loss: 4.5788e-05 - categorical_accuracy: 1.0000
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 83/100
# 26125/26125 [==============================] - 14s 541us/sample - loss: 4.5590e-05 - categorical_accuracy: 1.0000
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 84/100
# 26125/26125 [==============================] - 14s 541us/sample - loss: 4.6825e-05 - categorical_accuracy: 1.0000
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 85/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 4.8983e-05 - categorical_accuracy: 1.0000
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 86/100
# 26125/26125 [==============================] - 14s 541us/sample - loss: 4.7856e-05 - categorical_accuracy: 1.0000
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 87/100
# 26125/26125 [==============================] - 14s 541us/sample - loss: 6.4169e-05 - categorical_accuracy: 1.0000
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 88/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 4.3718e-05 - categorical_accuracy: 1.0000
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 89/100
# 26125/26125 [==============================] - 14s 539us/sample - loss: 4.6945e-05 - categorical_accuracy: 1.0000
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 90/100
# 26125/26125 [==============================] - 14s 541us/sample - loss: 4.8965e-05 - categorical_accuracy: 1.0000
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 91/100
# 26125/26125 [==============================] - 14s 541us/sample - loss: 4.5700e-05 - categorical_accuracy: 1.0000
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 92/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 4.3395e-05 - categorical_accuracy: 1.0000
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 93/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 4.7118e-05 - categorical_accuracy: 1.0000
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 94/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 5.3292e-05 - categorical_accuracy: 1.0000
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 95/100
# 26125/26125 [==============================] - 14s 541us/sample - loss: 6.5906e-05 - categorical_accuracy: 1.0000
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 96/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 4.3814e-05 - categorical_accuracy: 1.0000
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 97/100
# 26125/26125 [==============================] - 14s 541us/sample - loss: 5.6110e-05 - categorical_accuracy: 1.0000
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 98/100
# 26125/26125 [==============================] - 14s 541us/sample - loss: 4.7265e-05 - categorical_accuracy: 1.0000
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 99/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 4.3569e-05 - categorical_accuracy: 1.0000
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 1.0485760000000006e-07.
# Epoch 100/100
# 26125/26125 [==============================] - 14s 540us/sample - loss: 4.4170e-05 - categorical_accuracy: 1.0000
# 2375/2375 [==============================] - 1s 330us/sample
# (2375, 11)
# [[ 5  1  2  8  6  6  0  4  9  8  2  5  4  1  7  3 10  7  9  9  7  5  0  5
#    3  0  8  7  9  3  1  5  0  9  5  9  2  8  5  5  5  9  8  0  1  2  8  5
#    7  8 10  6  4  4  3 10  4  5  5  2  1  0  5  3  3  9  1  2 10 10  2  0
#    7  0 10  9  8  9  4  0  4  8  0  2  2  0  4 10  9  3  2  3  7 10  5  7
#    2  5  9  9]]
# (2375, 1)
# [[ 6  1  2  8  6  6  0  4  9  8  2  6  4  1  7  3 10  7  9  9  7  6  0  6
#    3  0  8  7  9  3  1  6  0  9  5  9  2  8  6  5  6  9  8  0  1  2  8  5
#    7  8 10  6  4  4  3 10  4  6  5  2  1  0  5  3  3  9  1  2 10 10  2  0
#    7  0 10  9  8  9  4  0  4  8  0  2  2  0  4 10  9  3  2  1  7 10  5  7
#    2  5  9  9]]
# 2375/2375 [==============================] - 1s 342us/sample - loss: 0.6112 - categorical_accuracy: 0.9360
# ##################################################################################################################################
# #####################################################  K-FOLD 2  ################################################################
# Training subjects: ['01', '03', '05', '08', '09', '10', '11', '13', '14', '16', '17']
# Test subject: 02
# Train dataset:
# (26125, 1, 128, 40) (26125, 11)
# Test dataset:
# (2375, 1, 128, 40) (2375, 11)
# Activity:  20
# Activity:  11
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 40)]      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 128, 40)       1088
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 64, 64, 20)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64, 64, 20)        256
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 64, 64, 20)        65600
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 64, 16, 5)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64, 16, 5)         256
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 64, 16, 5)         65600
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 64, 4, 2)          0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 64, 4, 2)          256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64, 4, 2)          0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 8, 64)             0
# _________________________________________________________________
# gru_1 (GRU)                  (None, 64)                24768
# _________________________________________________________________
# activity_class (Dense)       (None, 11)                715
# =================================================================
# Total params: 158,539
# Trainable params: 158,155
# Non-trainable params: 384
# _________________________________________________________________
# None
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/100
# 26125/26125 [==============================] - 15s 579us/sample - loss: 0.5690 - categorical_accuracy: 0.8397
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 0.0200 - categorical_accuracy: 0.9983
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 0.0147 - categorical_accuracy: 0.9974
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 0.0092 - categorical_accuracy: 0.9981
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 0.0146 - categorical_accuracy: 0.9958
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/100
# 26125/26125 [==============================] - 14s 548us/sample - loss: 0.0063 - categorical_accuracy: 0.9981
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 0.0068 - categorical_accuracy: 0.9982
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 7.9038e-04 - categorical_accuracy: 1.0000
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/100
# 26125/26125 [==============================] - 14s 548us/sample - loss: 5.1595e-04 - categorical_accuracy: 1.0000
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 10/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 4.0711e-04 - categorical_accuracy: 1.0000
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 11/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 5.6738e-04 - categorical_accuracy: 0.9999
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 12/100
# 26125/26125 [==============================] - 14s 549us/sample - loss: 3.4666e-04 - categorical_accuracy: 0.9999
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 13/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 2.5067e-04 - categorical_accuracy: 1.0000
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 14/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 2.3156e-04 - categorical_accuracy: 1.0000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 15/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 3.3579e-04 - categorical_accuracy: 0.9999
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 16/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 0.0088 - categorical_accuracy: 0.9976
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 17/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 5.0967e-04 - categorical_accuracy: 1.0000
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 18/100
# 26125/26125 [==============================] - 14s 548us/sample - loss: 4.2165e-04 - categorical_accuracy: 1.0000
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 19/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 2.7830e-04 - categorical_accuracy: 1.0000
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 20/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 2.2387e-04 - categorical_accuracy: 1.0000
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 21/100
# 26125/26125 [==============================] - 14s 548us/sample - loss: 2.1234e-04 - categorical_accuracy: 1.0000
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 22/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 1.8303e-04 - categorical_accuracy: 1.0000
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 23/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 1.6328e-04 - categorical_accuracy: 1.0000
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 24/100
# 26125/26125 [==============================] - 14s 548us/sample - loss: 1.4767e-04 - categorical_accuracy: 1.0000
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 25/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 1.5057e-04 - categorical_accuracy: 1.0000
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 26/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 1.5484e-04 - categorical_accuracy: 1.0000
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 27/100
# 26125/26125 [==============================] - 14s 548us/sample - loss: 1.2260e-04 - categorical_accuracy: 1.0000
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 28/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 1.2879e-04 - categorical_accuracy: 1.0000
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 29/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 1.0894e-04 - categorical_accuracy: 1.0000
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 30/100
# 26125/26125 [==============================] - 14s 548us/sample - loss: 1.0904e-04 - categorical_accuracy: 1.0000
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 31/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 1.2180e-04 - categorical_accuracy: 1.0000
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 32/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 9.7841e-05 - categorical_accuracy: 1.0000
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 33/100
# 26125/26125 [==============================] - 14s 548us/sample - loss: 1.0233e-04 - categorical_accuracy: 1.0000
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 34/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 9.1888e-05 - categorical_accuracy: 1.0000
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 35/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 1.3045e-04 - categorical_accuracy: 1.0000
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 36/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 2.1484e-04 - categorical_accuracy: 1.0000
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 37/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 1.0873e-04 - categorical_accuracy: 1.0000
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 38/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 1.0030e-04 - categorical_accuracy: 1.0000
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 39/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 1.1933e-04 - categorical_accuracy: 1.0000
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 40/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 8.5375e-05 - categorical_accuracy: 1.0000
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 41/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 8.0395e-05 - categorical_accuracy: 1.0000
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 42/100
# 26125/26125 [==============================] - 14s 548us/sample - loss: 7.8881e-05 - categorical_accuracy: 1.0000
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 43/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 7.9061e-05 - categorical_accuracy: 1.0000
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 44/100
# 26125/26125 [==============================] - 14s 548us/sample - loss: 7.6346e-05 - categorical_accuracy: 1.0000
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 45/100
# 26125/26125 [==============================] - 14s 548us/sample - loss: 1.0612e-04 - categorical_accuracy: 1.0000
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 46/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 8.4739e-05 - categorical_accuracy: 1.0000
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 47/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 7.2764e-05 - categorical_accuracy: 1.0000
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 48/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 6.7555e-05 - categorical_accuracy: 1.0000
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 49/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 6.3511e-05 - categorical_accuracy: 1.0000
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 50/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 5.8874e-05 - categorical_accuracy: 1.0000
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 51/100
# 26125/26125 [==============================] - 14s 549us/sample - loss: 5.9993e-05 - categorical_accuracy: 1.0000
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 52/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 6.3977e-05 - categorical_accuracy: 1.0000
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 53/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 6.0095e-05 - categorical_accuracy: 1.0000
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 54/100
# 26125/26125 [==============================] - 14s 548us/sample - loss: 6.0950e-05 - categorical_accuracy: 1.0000
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 55/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 7.4122e-05 - categorical_accuracy: 1.0000
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 56/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 5.4535e-05 - categorical_accuracy: 1.0000
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 57/100
# 26125/26125 [==============================] - 14s 548us/sample - loss: 5.6279e-05 - categorical_accuracy: 1.0000
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 58/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 5.5340e-05 - categorical_accuracy: 1.0000
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 59/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 6.5323e-05 - categorical_accuracy: 1.0000
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 60/100
# 26125/26125 [==============================] - 14s 548us/sample - loss: 6.4066e-05 - categorical_accuracy: 1.0000
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 61/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 5.0660e-05 - categorical_accuracy: 1.0000
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 62/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 5.1329e-05 - categorical_accuracy: 1.0000
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 63/100
# 26125/26125 [==============================] - 14s 548us/sample - loss: 5.1732e-05 - categorical_accuracy: 1.0000
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 64/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 5.2029e-05 - categorical_accuracy: 1.0000
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 65/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 5.7729e-05 - categorical_accuracy: 1.0000
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 66/100
# 26125/26125 [==============================] - 14s 549us/sample - loss: 4.8479e-05 - categorical_accuracy: 1.0000
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 67/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 4.6958e-05 - categorical_accuracy: 1.0000
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 68/100
# 26125/26125 [==============================] - 14s 548us/sample - loss: 5.2688e-05 - categorical_accuracy: 1.0000
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 69/100
# 26125/26125 [==============================] - 14s 548us/sample - loss: 5.3322e-05 - categorical_accuracy: 1.0000
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 70/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 4.4839e-05 - categorical_accuracy: 1.0000
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 71/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 4.8479e-05 - categorical_accuracy: 1.0000
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 72/100
# 26125/26125 [==============================] - 14s 548us/sample - loss: 4.5026e-05 - categorical_accuracy: 1.0000
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 73/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 4.5098e-05 - categorical_accuracy: 1.0000
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 74/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 4.7842e-05 - categorical_accuracy: 1.0000
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 75/100
# 26125/26125 [==============================] - 14s 548us/sample - loss: 4.8305e-05 - categorical_accuracy: 1.0000
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 76/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 4.6140e-05 - categorical_accuracy: 1.0000
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 77/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 5.3302e-05 - categorical_accuracy: 1.0000
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 78/100
# 26125/26125 [==============================] - 14s 548us/sample - loss: 4.4410e-05 - categorical_accuracy: 1.0000
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 79/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 4.5474e-05 - categorical_accuracy: 1.0000
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 80/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 4.3834e-05 - categorical_accuracy: 1.0000
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 81/100
# 26125/26125 [==============================] - 14s 548us/sample - loss: 7.1530e-05 - categorical_accuracy: 1.0000
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 82/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 4.6060e-05 - categorical_accuracy: 1.0000
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 83/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 4.5828e-05 - categorical_accuracy: 1.0000
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 84/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 4.6720e-05 - categorical_accuracy: 1.0000
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 85/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 4.1796e-05 - categorical_accuracy: 1.0000
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 86/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 4.4456e-05 - categorical_accuracy: 1.0000
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 87/100
# 26125/26125 [==============================] - 14s 548us/sample - loss: 4.4973e-05 - categorical_accuracy: 1.0000
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 88/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 4.4049e-05 - categorical_accuracy: 1.0000
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 89/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 4.0794e-05 - categorical_accuracy: 1.0000
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 90/100
# 26125/26125 [==============================] - 14s 549us/sample - loss: 5.7390e-05 - categorical_accuracy: 1.0000
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 91/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 4.1568e-05 - categorical_accuracy: 1.0000
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 92/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 4.6880e-05 - categorical_accuracy: 1.0000
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 93/100
# 26125/26125 [==============================] - 14s 548us/sample - loss: 4.2820e-05 - categorical_accuracy: 1.0000
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 94/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 4.3387e-05 - categorical_accuracy: 1.0000
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 95/100
# 26125/26125 [==============================] - 14s 546us/sample - loss: 5.2771e-05 - categorical_accuracy: 1.0000
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 96/100
# 26125/26125 [==============================] - 14s 547us/sample - loss: 5.0105e-05 - categorical_accuracy: 1.0000
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 97/100
# ...
#    2  3  8  2  1  2 10  7 10  8  6  6  5  6  1  0  6 10  6  2  1  8  9  2
#    4  6 10  1  6  4  3  5  6  1  8  3 10  7  8  2  2  0  0  8  5  0  7  6
#    8  0  3 10  8  7  2  3  9  0  6  1  1  3  5  8  0  8  8 10 10  6  7  6
#    2 10  2  5]]
# (2375, 1)
# [[ 6  2  6  9  1  7  8  9  7  5 10  2  9  6 10  3 10  6  5  5  1  4  9  3
#    2  3  8  2  1  2 10  7 10  8  6  6  5  6  1  0  6 10  6  2  1  8  9  2
#    4  6 10  1  6  4  3  5  6  1  9  3 10  7  9  2  2  0  0  8  5  0  7  6
#    9  0  3 10  8  7  2  3  9  0  6  1  1  3  5  8  0  8  8 10 10  6  7  6
#    2 10  2  5]]
# 2375/2375 [==============================] - 1s 295us/sample - loss: 0.3129 - categorical_accuracy: 0.9604
# ##################################################################################################################################
# #####################################################  K-FOLD 3  ################################################################
# Training subjects: ['01', '02', '05', '08', '09', '10', '11', '13', '14', '16', '17']
# Test subject: 03
# Train dataset:
# (26125, 1, 128, 40) (26125, 11)
# Test dataset:
# (2375, 1, 128, 40) (2375, 11)
# Activity:  20
# Activity:  11
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 40)]      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 64, 128, 40)       1088
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 64, 64, 20)        0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 64, 64, 20)        256
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 64, 64, 20)        65600
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 64, 16, 5)         0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 64, 16, 5)         256
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 64, 16, 5)         65600
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 64, 4, 2)          0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 64, 4, 2)          256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64, 4, 2)          0
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 8, 64)             0
# _________________________________________________________________
# gru_2 (GRU)                  (None, 64)                24768
# _________________________________________________________________
# activity_class (Dense)       (None, 11)                715
# =================================================================
# Total params: 158,539
# Trainable params: 158,155
# Non-trainable params: 384
# _________________________________________________________________
# None
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/100
# 26125/26125 [==============================] - 15s 589us/sample - loss: 0.5394 - categorical_accuracy: 0.8485
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/100
# 26125/26125 [==============================] - 15s 556us/sample - loss: 0.0277 - categorical_accuracy: 0.9959
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 0.0155 - categorical_accuracy: 0.9963
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 0.0147 - categorical_accuracy: 0.9963
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 0.0018 - categorical_accuracy: 0.9999
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/100
# 26125/26125 [==============================] - 14s 555us/sample - loss: 0.0023 - categorical_accuracy: 0.9997
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 0.0074 - categorical_accuracy: 0.9982
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 0.0113 - categorical_accuracy: 0.9968
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/100
# 26125/26125 [==============================] - 14s 554us/sample - loss: 0.0077 - categorical_accuracy: 0.9979
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 10/100
# 26125/26125 [==============================] - 14s 554us/sample - loss: 0.0016 - categorical_accuracy: 0.9995
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 11/100
# 26125/26125 [==============================] - 14s 555us/sample - loss: 9.5321e-04 - categorical_accuracy: 0.9998
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 12/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 6.7835e-04 - categorical_accuracy: 0.9999
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 13/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 7.4087e-04 - categorical_accuracy: 0.9998
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 14/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 0.0021 - categorical_accuracy: 0.9994
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 15/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 3.1984e-04 - categorical_accuracy: 1.0000
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 16/100
# 26125/26125 [==============================] - 14s 555us/sample - loss: 2.7923e-04 - categorical_accuracy: 1.0000
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 17/100
# 26125/26125 [==============================] - 14s 555us/sample - loss: 2.6055e-04 - categorical_accuracy: 1.0000
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 18/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 2.2777e-04 - categorical_accuracy: 1.0000
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 19/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 1.5634e-04 - categorical_accuracy: 1.0000
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 20/100
# 26125/26125 [==============================] - 15s 556us/sample - loss: 1.4707e-04 - categorical_accuracy: 1.0000
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 21/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 1.4087e-04 - categorical_accuracy: 1.0000
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 22/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 1.3349e-04 - categorical_accuracy: 1.0000
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 23/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 1.3628e-04 - categorical_accuracy: 1.0000
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 24/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 1.2668e-04 - categorical_accuracy: 1.0000
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 25/100
# 26125/26125 [==============================] - 14s 555us/sample - loss: 1.1660e-04 - categorical_accuracy: 1.0000
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 26/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 2.3543e-04 - categorical_accuracy: 1.0000
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 27/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 1.2781e-04 - categorical_accuracy: 1.0000
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 28/100
# 26125/26125 [==============================] - 15s 556us/sample - loss: 1.1526e-04 - categorical_accuracy: 1.0000
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 29/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 4.9530e-04 - categorical_accuracy: 0.9999
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 30/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 3.5661e-04 - categorical_accuracy: 0.9999
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 31/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 1.1967e-04 - categorical_accuracy: 1.0000
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 32/100
# 26125/26125 [==============================] - 15s 556us/sample - loss: 2.0006e-04 - categorical_accuracy: 1.0000
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 33/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 1.6984e-04 - categorical_accuracy: 1.0000
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 34/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 2.1977e-04 - categorical_accuracy: 1.0000
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 35/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 1.9091e-04 - categorical_accuracy: 1.0000
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 36/100
# 26125/26125 [==============================] - 15s 556us/sample - loss: 3.3585e-04 - categorical_accuracy: 0.9999
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 37/100
# 26125/26125 [==============================] - 15s 556us/sample - loss: 1.5391e-04 - categorical_accuracy: 1.0000
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 38/100
# 26125/26125 [==============================] - 14s 555us/sample - loss: 8.6468e-05 - categorical_accuracy: 1.0000
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 39/100
# 26125/26125 [==============================] - 14s 555us/sample - loss: 8.7329e-05 - categorical_accuracy: 1.0000
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 40/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 9.2630e-05 - categorical_accuracy: 1.0000
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 41/100
# 26125/26125 [==============================] - 15s 556us/sample - loss: 2.0046e-04 - categorical_accuracy: 1.0000
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 42/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 8.1790e-05 - categorical_accuracy: 1.0000
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 43/100
# 26125/26125 [==============================] - 14s 554us/sample - loss: 8.4263e-05 - categorical_accuracy: 1.0000
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 44/100
# 26125/26125 [==============================] - 15s 556us/sample - loss: 7.7350e-05 - categorical_accuracy: 1.0000
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 45/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 7.7612e-05 - categorical_accuracy: 1.0000
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 46/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 7.7421e-05 - categorical_accuracy: 1.0000
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 47/100
# 26125/26125 [==============================] - 15s 556us/sample - loss: 7.3898e-05 - categorical_accuracy: 1.0000
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 48/100
# 26125/26125 [==============================] - 15s 556us/sample - loss: 8.3110e-05 - categorical_accuracy: 1.0000
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 49/100
# 26125/26125 [==============================] - 15s 556us/sample - loss: 6.6222e-05 - categorical_accuracy: 1.0000
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 50/100
# 26125/26125 [==============================] - 15s 556us/sample - loss: 6.3058e-05 - categorical_accuracy: 1.0000
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 51/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 7.0156e-05 - categorical_accuracy: 1.0000
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 52/100
# 26125/26125 [==============================] - 15s 557us/sample - loss: 6.4939e-05 - categorical_accuracy: 1.0000
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 53/100
# 26125/26125 [==============================] - 15s 556us/sample - loss: 6.0439e-05 - categorical_accuracy: 1.0000
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 54/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 5.9052e-05 - categorical_accuracy: 1.0000
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 55/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 6.0661e-05 - categorical_accuracy: 1.0000
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 56/100
# 26125/26125 [==============================] - 14s 555us/sample - loss: 5.9150e-05 - categorical_accuracy: 1.0000
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 57/100
# 26125/26125 [==============================] - 14s 555us/sample - loss: 7.0085e-05 - categorical_accuracy: 1.0000
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 58/100
# 26125/26125 [==============================] - 15s 556us/sample - loss: 6.2299e-05 - categorical_accuracy: 1.0000
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 59/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 5.9430e-05 - categorical_accuracy: 1.0000
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 60/100
# 26125/26125 [==============================] - 15s 555us/sample - loss: 5.6522e-05 - categorical_accuracy: 1.0000
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 61/100
# 20608/26125 [======================>.......] - ETA: 3s - loss: 5.9250e-05 - categorical_accuracy: 1.0000

# %% [markdown]
# # Accuracy

# %%
sum = 0
for acc in accuracies:
    sum += acc
print('Accuracy of K-Fold: ' + str(sum/12))
# Out:
# Accuracy of K-Fold: 0.9627368350823721
