# %% [markdown]
# # CNN

# %%
import tensorflow.keras as keras

# %%
# Módulos necesarios. Asegurarse de poder importarlos.
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from pylab import rcParams
from scipy import stats
from sklearn import metrics
import seaborn as sns
from sklearn import preprocessing
import os as os
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
from time import time

# Config the matplotlib backend as plotting inline in IPython
# %matplotlib inline

# %%
import sys
print(sys.executable)
print(sys.version)
print(sys.version_info)
tf.__version__
# Out:
# /usr/bin/python
# 3.6.8 (default, Aug 20 2019, 17:12:48)
# [GCC 8.3.0]
# sys.version_info(major=3, minor=6, micro=8, releaselevel='final', serial=0)
# '1.14.0'

# %%
keras.__version__
# Out:
# '2.2.4-tf'

# %% [markdown]
# # 12-FOLD

# %%
subjects = ['01', '02', '03', '05', '08', '09', '10', '11', '13', '14', '16', '17']
global activities
activities = [9,10,11,12,13,19,20,21,24,25,31]

# %%
# Ajustado a los datos
n_time_steps = 128
n_classes = 11 # Nº de clases (el 0 está eliminado)
n_channels = 1 # Nº de canales
n_columns = 40

# Podríamos variarlo
batch_size = 128 # Tamaño del batch
learning_rate = 1e-3 # Learning rate (por defecto es 0.001)
epochs = 100 # Épocas

# %%
class LearningRateDecay:
    def plot(self, epochs, title="Learning Rate Schedule"):
        # compute the set of learning rates for each corresponding
        # epoch
        lrs = [self(i) for i in epochs]
 
        # the learning rate schedule
        plt.style.use("ggplot")
        plt.figure()
        plt.plot(epochs, lrs)
        plt.title(title)
        plt.xlabel("Epoch #")
        plt.ylabel("Learning Rate")
class StepDecay(LearningRateDecay):
    def __init__(self, initAlpha=0.01, factor=0.25, dropEvery=10):
        # store the base initial learning rate, drop factor, and
        # epochs to drop every
        self.initAlpha = initAlpha
        self.factor = factor
        self.dropEvery = dropEvery
 
    def __call__(self, epoch):
        # compute the learning rate for the current epoch
        exp = np.floor((1 + epoch) / self.dropEvery)
        alpha = self.initAlpha * (self.factor ** exp)
        if(alpha<1e-9):
            alpha=1e-9

        # return the learning rate
        return float(alpha) 

schedule = StepDecay(initAlpha=learning_rate, factor=0.4, dropEvery=10)

reduce_lr = keras.callbacks.LearningRateScheduler(schedule, verbose = 1)
callbacks_list = [reduce_lr]

# %%
#Visualize training evolution
def plot_curves(model, acc, loss, val_acc, val_loss, subject_test):
    #########################################################################################
    # LOSS plot
    plt.figure(figsize=(12,8))
    plt.plot(model.history.history[loss], label='Training loss')
    plt.xlabel('Epochs', fontsize=15)
    plt.ylabel('Loss', fontsize=15)
    plt.tick_params(labelsize=10)
    plt.legend(loc=1,prop={'size': 10})
    plt.title('Loss in trainnig', fontsize=20)
    fig = plt.gcf()
    plt.show()
    
    fig.savefig('./000_1_AUGNORMFFT_SP/loss_train_000_1_AUGNORMFFT_SP_KFOLD_'+subject_test+'.pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./000_1_AUGNORMFFT_SP/loss_train_000_1_AUGNORMFFT_SP_KFOLD_'+subject_test+'svg', bbox_inches='tight',format='svg')
    
    #########################################################################################
    # ACC plot
    plt.figure(figsize=(12,8))
    plt.plot(model.history.history[acc], label='Training accuracy')
    plt.xlabel('Epochs', fontsize=15)
    plt.ylabel('Accuracy', fontsize=15)
    plt.tick_params(labelsize=10)
    plt.legend(loc=1,prop={'size': 10})
    plt.title('Accuracy in training', fontsize=20)
    fig = plt.gcf()
    plt.show()

    fig.savefig('./000_1_AUGNORMFFT_SP/acc_train_000_1_AUGNORMFFT_SP_KFOLD_'+subject_test+'pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./000_1_AUGNORMFFT_SP/acc_train_000_1_AUGNORMFFT_SP_KFOLD_'+subject_test+'svg', bbox_inches='tight',format='svg')
    
    #########################################################################################
    # ACC+LOSS plot
    plt.figure(figsize=(14,10))
    plt_loss = host_subplot(111, axes_class=AA.Axes)
    plt.subplots_adjust(right=0.75)

    plt_acc = plt_loss.twinx()
    plt_acc.axis["right"].toggle(all=True)
    
    plt_loss.set_xlim(0, len(model.history.history[loss]))
    plt_loss.set_ylim(0, max(model.history.history[loss]))
    plt_loss.set_xlabel('Epochs')
    plt_loss.set_ylabel('Loss')
    plt_acc.set_ylabel('Accuracy')
                        
    plt_loss.axis['left'].label.set_fontsize(15)
    plt_loss.axis['bottom'].label.set_fontsize(15)
    plt_acc.axis['right'].label.set_fontsize(15)
    
    plt_loss.plot(model.history.history[loss], c='tab:blue', ls='--', label='Training loss')
    plt_acc.plot(model.history.history[acc], c='tab:orange',ls='--', label='Training accuracy')
    
    plt.tick_params(labelsize=10)
    plt.title('Training performance', fontsize=20)
    plt_acc.set_ylim(0, 1)
    plt_loss.legend(loc=1, prop={'size': 10})
    
    fig = plt.gcf()
    plt.show()

    fig.savefig('./000_1_AUGNORMFFT_SP/all_train_000_1_AUGNORMFFT_SP_KFOLD_'+subject_test+'pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./000_1_AUGNORMFFT_SP/all_train_000_1_AUGNORMFFT_SP_KFOLD_'+subject_test+'svg', bbox_inches='tight',format='svg')

# %%
def plot_confusion_matrix(y_true, y_pred, subject_test, classes,
                          cmap=plt.cm.Blues):

    # Compute confusion matrix
    cm = metrics.confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(20, 20))
    sns.heatmap(cm, xticklabels=classes, yticklabels=classes, square = True, robust = True, annot=True, cmap='YlOrBr')
    plt.title('CONFUSION MATRIX')
    plt.ylabel('TRUE ACTIVITY')
    plt.xlabel('PREDICTION')
    
    locs, labels = plt.xticks()
    plt.xticks(locs, labels, rotation='vertical')
    locs, labels = plt.yticks()
    plt.yticks(locs, labels, rotation='horizontal')

    # Guardamos la imagen en formato vectorial
    plt.draw()
    plt.savefig('./000_1_AUGNORMFFT_SP/matriz_confusion_'+subject_test+'.svg', bbox_inches='tight',format='svg')
    plt.show()

# %%
accuracies = []
for i in range(12):
    print('##################################################################################################################################')
    print('#####################################################  K-FOLD %d  ################################################################'%(i+1))
    
    subject_test = subjects[i]
    subjects_train = [s for s in subjects if s not in subject_test]
    print('Training subjects: ' + str(subjects_train))
    print('Test subject: ' + str(subject_test))
    
    ##  GENERACIÓN DATASET
    tr_seg = np.concatenate((np.load('./augment_norm/subject_'+subjects_train[0]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[1]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[2]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[3]+'_seg.npy'),
                             np.load('./augment_norm/subject_'+subjects_train[4]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[5]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[6]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[7]+'_seg.npy'),
                             np.load('./augment_norm/subject_'+subjects_train[8]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[9]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[10]+'_seg.npy')))
    
    tr_lab = np.concatenate((np.load('./augment_norm/subject_'+subjects_train[0]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[1]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[2]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[3]+'_lab.npy'),
                             np.load('./augment_norm/subject_'+subjects_train[4]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[5]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[6]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[7]+'_lab.npy'),
                             np.load('./augment_norm/subject_'+subjects_train[8]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[9]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[10]+'_lab.npy')))

    ts_seg = np.load('./augment_norm/subject_'+subject_test+'_seg.npy')
    ts_lab = np.load('./augment_norm/subject_'+subject_test+'_lab.npy')
    
    limit = 40
    tr_seg = tr_seg[:,:,:,:limit]
    ts_seg = ts_seg[:,:,:,:limit]
    ####################################################################################################################
    ## SHUFFLE DE DATOS
    np.random.seed(235)
    tr_seg = np.reshape(tr_seg[np.random.shuffle(np.arange(0,tr_seg.shape[0]))], (11*2375,1,128,limit))
    tr_lab = np.reshape(tr_lab[np.random.shuffle(np.arange(0,tr_seg.shape[0]))], (11*2375,11))

    np.random.seed(235)
    ts_seg = np.reshape(ts_seg[np.random.shuffle(np.arange(0,ts_seg.shape[0]))], (2375,1,128,limit))
    ts_lab = np.reshape(ts_lab[np.random.shuffle(np.arange(0,ts_seg.shape[0]))], (2375,11))
    
    print('Train dataset: ')
    print(tr_seg.shape, tr_lab.shape)
    print('Test dataset: ')
    print(ts_seg.shape, ts_lab.shape)
    ####################################################################################################################
    ## VISTA DE DFT-2D
    plt.figure(figsize=(30,30))
    plt.imshow(np.log(np.abs(np.fft.fftshift(tr_seg[0,0,:,20:40].T))**2))
    plt.show()
    print('Activity: ',activities[np.argmax(tr_lab[0])])

    plt.figure(figsize=(30,30))
    plt.imshow(np.log(np.fft.fftshift(tr_seg[10,0,:,20:40].T)**2))
    plt.show()
    print('Activity: ',activities[np.argmax(tr_lab[10])])
    ####################################################################################################################
    ## RED
    quat_input = keras.Input(shape=(n_channels, n_time_steps, n_columns), name='input_layer')

    # Some convolutional layers
    conv_1 = keras.layers.Conv2D(16, kernel_size=4,padding='same',activation='relu', data_format = 'channels_first')(quat_input)
    max_1 = keras.layers.MaxPooling2D(pool_size=2, strides=2, padding='same', data_format = 'channels_first')(conv_1)
    bn_1 = keras.layers.BatchNormalization(axis=1)(max_1)
    conv_2 = keras.layers.Conv2D(32,kernel_size=4, padding='same',activation='relu', data_format = 'channels_first')(bn_1)
    max_2 = keras.layers.MaxPooling2D(pool_size=2, strides=2, padding='same', data_format = 'channels_first')(conv_2)

    # Flatten the output of the convolutional layers
    conv_flat = keras.layers.Flatten()(max_2)

    # Output layers: separate outputs for the weather and the ground labels
    multiclass_output = keras.layers.Dense(n_classes, activation='softmax',name='activity_class')(conv_flat)
    
    # Creamos la estrcutura que contendrá a nuestro modelo
    model = keras.Model(inputs=quat_input, outputs=[multiclass_output],name='cnn')

    # Compilamos el modelo
    model.compile(optimizer=keras.optimizers.Adam(lr=learning_rate),
                  loss='categorical_crossentropy', metrics=['categorical_accuracy'])
    
    print(model.summary())
    ####################################################################################################################
    ## TRAIN
    history = model.fit(tr_seg,
                        tr_lab,
                        epochs = epochs,
                        steps_per_epoch = None,
                        verbose = 1,
                        batch_size = batch_size,
                        callbacks = callbacks_list)
    model.save('./000_1_AUGNORMFFT_SP/CNN_'+subject_test+'.h5')
    
    #Visualize training evolution
    plot_curves(model, 'categorical_accuracy', 'loss', 'val_categorical_accuracy', 'val_loss', subject_test)
    ####################################################################################################################
    ## TEST
    predictions = model.predict(ts_seg, batch_size = batch_size, verbose = 1)
    
    print(predictions.shape)
    
    y_pred = np.argmax(predictions,axis=-1)
    y_pred = np.expand_dims(y_pred,axis=-1)
    print(y_pred[:100].T)
    
    y_true = np.argmax(ts_lab,axis=-1)
    y_true = np.expand_dims(y_true,axis=-1)
    print(y_true.shape)
    print(y_true[:100].T)
    
    evaluation = model.evaluate(ts_seg, ts_lab, batch_size=batch_size, verbose=1)
    accuracies.append(evaluation[1])
    
    fo = open('./000_1_AUGNORMFFT_SP/accuracy_'+subject_test+'.txt', "w")
    fo.seek(0,2)
    fo.write(str(evaluation))
    fo.close()
    
    ####################################################################################################################
    ## CONFUSION MATRIX
    y_true_flat = np.ndarray.flatten(y_true)
    y_pred_flat = np.ndarray.flatten(y_pred)
    
    plot_confusion_matrix(y_true_flat, y_pred_flat, subject_test, classes=activities)
    
    del subject_test, subjects_train, limit, tr_seg, tr_lab, ts_seg, ts_lab, model, history, y_pred, y_true, predictions, evaluation, y_true_flat, y_pred_flat
# Out:
# ##################################################################################################################################
# #####################################################  K-FOLD 1  ################################################################
# Training subjects: ['02', '03', '05', '08', '09', '10', '11', '13', '14', '16', '17']
# Test subject: 01
# Train dataset:
# (26125, 1, 128, 40) (26125, 11)
# Test dataset:
# (2375, 1, 128, 40) (2375, 11)
# Activity:  20
# Activity:  25
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 40)]      0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 16, 128, 40)       272
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 64, 20)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 16, 64, 20)        64
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 64, 20)        8224
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 10)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 10240)             0
# _________________________________________________________________
# activity_class (Dense)       (None, 11)                112651
# =================================================================
# Total params: 121,211
# Trainable params: 121,179
# Non-trainable params: 32
# _________________________________________________________________
# None
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/100
# 26125/26125 [==============================] - 11s 402us/sample - loss: 0.4137 - categorical_accuracy: 0.8858
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/100
# 26125/26125 [==============================] - 4s 164us/sample - loss: 0.0062 - categorical_accuracy: 1.0000
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 0.0020 - categorical_accuracy: 1.0000
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 0.0010 - categorical_accuracy: 1.0000
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 6.2269e-04 - categorical_accuracy: 1.0000
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 4.1483e-04 - categorical_accuracy: 1.0000
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 2.9262e-04 - categorical_accuracy: 1.0000
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 2.1997e-04 - categorical_accuracy: 1.0000
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.6762e-04 - categorical_accuracy: 1.0000
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 10/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.3909e-04 - categorical_accuracy: 1.0000
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 11/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.2730e-04 - categorical_accuracy: 1.0000
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 12/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.1359e-04 - categorical_accuracy: 1.0000
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 13/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.0319e-04 - categorical_accuracy: 1.0000
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 14/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 9.2644e-05 - categorical_accuracy: 1.0000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 15/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 8.3330e-05 - categorical_accuracy: 1.0000
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 16/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 7.5461e-05 - categorical_accuracy: 1.0000
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 17/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 6.7038e-05 - categorical_accuracy: 1.0000
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 18/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 6.0072e-05 - categorical_accuracy: 1.0000
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 19/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 5.3819e-05 - categorical_accuracy: 1.0000
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 20/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 4.9241e-05 - categorical_accuracy: 1.0000
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 21/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 4.7033e-05 - categorical_accuracy: 1.0000
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 22/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 4.4563e-05 - categorical_accuracy: 1.0000
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 23/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 4.2511e-05 - categorical_accuracy: 1.0000
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 24/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 4.0124e-05 - categorical_accuracy: 1.0000
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 25/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 3.7982e-05 - categorical_accuracy: 1.0000
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 26/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 3.5619e-05 - categorical_accuracy: 1.0000
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 27/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 3.4022e-05 - categorical_accuracy: 1.0000
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 28/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 3.1337e-05 - categorical_accuracy: 1.0000
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 29/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 2.8995e-05 - categorical_accuracy: 1.0000
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 30/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 2.7459e-05 - categorical_accuracy: 1.0000
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 31/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 2.6658e-05 - categorical_accuracy: 1.0000
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 32/100
# 26125/26125 [==============================] - 4s 164us/sample - loss: 2.5743e-05 - categorical_accuracy: 1.0000
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 33/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 2.4673e-05 - categorical_accuracy: 1.0000
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 34/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 2.4297e-05 - categorical_accuracy: 1.0000
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 35/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 2.2538e-05 - categorical_accuracy: 1.0000
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 36/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 2.2194e-05 - categorical_accuracy: 1.0000
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 37/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 2.0870e-05 - categorical_accuracy: 1.0000
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 38/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 2.0102e-05 - categorical_accuracy: 1.0000
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 39/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.9005e-05 - categorical_accuracy: 1.0000
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 40/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.8206e-05 - categorical_accuracy: 1.0000
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 41/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.7957e-05 - categorical_accuracy: 1.0000
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 42/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.7455e-05 - categorical_accuracy: 1.0000
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 43/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.7143e-05 - categorical_accuracy: 1.0000
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 44/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.6504e-05 - categorical_accuracy: 1.0000
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 45/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.5990e-05 - categorical_accuracy: 1.0000
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 46/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.5474e-05 - categorical_accuracy: 1.0000
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 47/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.4823e-05 - categorical_accuracy: 1.0000
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 48/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.4522e-05 - categorical_accuracy: 1.0000
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 49/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.3721e-05 - categorical_accuracy: 1.0000
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 50/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.3156e-05 - categorical_accuracy: 1.0000
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 51/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.3093e-05 - categorical_accuracy: 1.0000
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 52/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.2835e-05 - categorical_accuracy: 1.0000
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 53/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.2603e-05 - categorical_accuracy: 1.0000
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 54/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.2279e-05 - categorical_accuracy: 1.0000
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 55/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.2107e-05 - categorical_accuracy: 1.0000
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 56/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.1841e-05 - categorical_accuracy: 1.0000
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 57/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.1375e-05 - categorical_accuracy: 1.0000
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 58/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.1025e-05 - categorical_accuracy: 1.0000
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 59/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.0687e-05 - categorical_accuracy: 1.0000
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 60/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.0502e-05 - categorical_accuracy: 1.0000
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 61/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.0290e-05 - categorical_accuracy: 1.0000
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 62/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.0104e-05 - categorical_accuracy: 1.0000
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 63/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.0030e-05 - categorical_accuracy: 1.0000
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 64/100
# 26125/26125 [==============================] - 4s 164us/sample - loss: 9.7424e-06 - categorical_accuracy: 1.0000
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 65/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 9.6078e-06 - categorical_accuracy: 1.0000
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 66/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 9.4952e-06 - categorical_accuracy: 1.0000
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 67/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 9.2538e-06 - categorical_accuracy: 1.0000
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 68/100
# 26125/26125 [==============================] - 4s 164us/sample - loss: 9.1701e-06 - categorical_accuracy: 1.0000
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 69/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 8.8292e-06 - categorical_accuracy: 1.0000
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 70/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 8.7944e-06 - categorical_accuracy: 1.0000
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 71/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 8.7200e-06 - categorical_accuracy: 1.0000
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 72/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 8.5902e-06 - categorical_accuracy: 1.0000
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 73/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 8.5385e-06 - categorical_accuracy: 1.0000
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 74/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 8.3966e-06 - categorical_accuracy: 1.0000
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 75/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 8.1742e-06 - categorical_accuracy: 1.0000
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 76/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 8.0557e-06 - categorical_accuracy: 1.0000
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 77/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 8.0172e-06 - categorical_accuracy: 1.0000
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 78/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 7.8864e-06 - categorical_accuracy: 1.0000
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 79/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 7.8859e-06 - categorical_accuracy: 1.0000
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 80/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 7.7356e-06 - categorical_accuracy: 1.0000
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 81/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 7.7085e-06 - categorical_accuracy: 1.0000
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 82/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 7.7231e-06 - categorical_accuracy: 1.0000
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 83/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 7.5592e-06 - categorical_accuracy: 1.0000
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 84/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 7.5388e-06 - categorical_accuracy: 1.0000
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 85/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 7.4816e-06 - categorical_accuracy: 1.0000
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 86/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 7.3837e-06 - categorical_accuracy: 1.0000
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 87/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 7.3622e-06 - categorical_accuracy: 1.0000
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 88/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 7.2438e-06 - categorical_accuracy: 1.0000
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 89/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 7.1770e-06 - categorical_accuracy: 1.0000
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 90/100
# 26125/26125 [==============================] - 4s 164us/sample - loss: 7.1882e-06 - categorical_accuracy: 1.0000
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 91/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 7.2820e-06 - categorical_accuracy: 1.0000
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 92/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 7.2452e-06 - categorical_accuracy: 1.0000
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 93/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 7.1391e-06 - categorical_accuracy: 1.0000
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 94/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 7.1307e-06 - categorical_accuracy: 1.0000
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 95/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 7.1194e-06 - categorical_accuracy: 1.0000
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 96/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 7.0659e-06 - categorical_accuracy: 1.0000
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 97/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 6.9784e-06 - categorical_accuracy: 1.0000
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 98/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 7.0626e-06 - categorical_accuracy: 1.0000
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 99/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 6.9505e-06 - categorical_accuracy: 1.0000
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 1.0485760000000006e-07.
# Epoch 100/100
# 26125/26125 [==============================] - 4s 164us/sample - loss: 7.2177e-06 - categorical_accuracy: 1.0000
# 2375/2375 [==============================] - 0s 106us/sample
# (2375, 11)
# [[ 4 10  3  4  5 10  4  8  4  7  9 10  8  4  8  5  1  5  5  1  9 10 10  4
#    3  9  2  4  0  0  9  4  0  5  5 10  4  5  5  9 10  8  9  1  1  7  6  7
#    1  1  4  6  2  4  2  8  2  5  4  8  2  3  0  9  0 10  5  9  7 10  6  1
#    6  7  5  2  2  8  1  9  7 10 10  1  1  6  3  3  1  1  9  4  0  0 10  1
#    8  0  4  2]]
# (2375, 1)
# [[ 4 10  3  4  5 10  4  8  4  7  9 10  8  4  8  5  1  5  5  1  9 10 10  4
#    3  9  2  4  0  0  9  4  0  5  5 10  4  5  6  9  8  8  9  1  1  7  6  7
#    1  1  4  6  2  4  2  8  2  6  4  8  2  3  0  9  0 10  5  9  7 10  6  1
#    6  7  5  2  2  8  1  9  7 10 10  1  1  6  3  3  1  1  9  4  0  0 10  1
#    9  0  4  2]]
# 2375/2375 [==============================] - 0s 120us/sample - loss: 0.1879 - categorical_accuracy: 0.9491
# ##################################################################################################################################
# #####################################################  K-FOLD 2  ################################################################
# Training subjects: ['01', '03', '05', '08', '09', '10', '11', '13', '14', '16', '17']
# Test subject: 02
# Train dataset:
# (26125, 1, 128, 40) (26125, 11)
# Test dataset:
# (2375, 1, 128, 40) (2375, 11)
# Activity:  13
# Activity:  25
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 40)]      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 128, 40)       272
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 64, 20)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 64, 20)        64
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 64, 20)        8224
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 32, 32, 10)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 10240)             0
# _________________________________________________________________
# activity_class (Dense)       (None, 11)                112651
# =================================================================
# Total params: 121,211
# Trainable params: 121,179
# Non-trainable params: 32
# _________________________________________________________________
# None
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/100
# 26125/26125 [==============================] - 4s 169us/sample - loss: 0.3835 - categorical_accuracy: 0.8983
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 0.0063 - categorical_accuracy: 0.9998
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 0.0018 - categorical_accuracy: 1.0000
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 9.7484e-04 - categorical_accuracy: 1.0000
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 5.8731e-04 - categorical_accuracy: 1.0000
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 3.9108e-04 - categorical_accuracy: 1.0000
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 2.8717e-04 - categorical_accuracy: 1.0000
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 2.0637e-04 - categorical_accuracy: 1.0000
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 1.5844e-04 - categorical_accuracy: 1.0000
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 10/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 1.3061e-04 - categorical_accuracy: 1.0000
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 11/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 1.1874e-04 - categorical_accuracy: 1.0000
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 12/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 1.0696e-04 - categorical_accuracy: 1.0000
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 13/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 9.7217e-05 - categorical_accuracy: 1.0000
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 14/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 8.7480e-05 - categorical_accuracy: 1.0000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 15/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 7.8467e-05 - categorical_accuracy: 1.0000
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 16/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 7.0535e-05 - categorical_accuracy: 1.0000
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 17/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 6.3278e-05 - categorical_accuracy: 1.0000
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 18/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 5.6792e-05 - categorical_accuracy: 1.0000
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 19/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 5.1000e-05 - categorical_accuracy: 1.0000
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 20/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 4.6600e-05 - categorical_accuracy: 1.0000
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 21/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 4.4379e-05 - categorical_accuracy: 1.0000
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 22/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 4.2288e-05 - categorical_accuracy: 1.0000
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 23/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 4.0137e-05 - categorical_accuracy: 1.0000
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 24/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 3.8129e-05 - categorical_accuracy: 1.0000
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 25/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 3.5725e-05 - categorical_accuracy: 1.0000
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 26/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 3.3988e-05 - categorical_accuracy: 1.0000
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 27/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 3.1536e-05 - categorical_accuracy: 1.0000
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 28/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 2.9665e-05 - categorical_accuracy: 1.0000
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 29/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 2.7624e-05 - categorical_accuracy: 1.0000
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 30/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 2.6120e-05 - categorical_accuracy: 1.0000
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 31/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 2.5227e-05 - categorical_accuracy: 1.0000
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 32/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 2.4388e-05 - categorical_accuracy: 1.0000
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 33/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 2.3582e-05 - categorical_accuracy: 1.0000
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 34/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 2.2740e-05 - categorical_accuracy: 1.0000
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 35/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 2.1649e-05 - categorical_accuracy: 1.0000
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 36/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 2.0972e-05 - categorical_accuracy: 1.0000
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 37/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 1.9966e-05 - categorical_accuracy: 1.0000
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 38/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 1.8872e-05 - categorical_accuracy: 1.0000
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 39/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 1.8076e-05 - categorical_accuracy: 1.0000
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 40/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 1.7230e-05 - categorical_accuracy: 1.0000
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 41/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 1.6873e-05 - categorical_accuracy: 1.0000
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 42/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.6573e-05 - categorical_accuracy: 1.0000
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 43/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 1.5990e-05 - categorical_accuracy: 1.0000
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 44/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 1.5503e-05 - categorical_accuracy: 1.0000
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 45/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 1.5140e-05 - categorical_accuracy: 1.0000
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 46/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 1.4682e-05 - categorical_accuracy: 1.0000
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 47/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 1.4098e-05 - categorical_accuracy: 1.0000
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 48/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 1.3640e-05 - categorical_accuracy: 1.0000
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 49/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 1.2956e-05 - categorical_accuracy: 1.0000
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 50/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 1.2460e-05 - categorical_accuracy: 1.0000
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 51/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.2327e-05 - categorical_accuracy: 1.0000
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 52/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.2065e-05 - categorical_accuracy: 1.0000
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 53/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 1.1828e-05 - categorical_accuracy: 1.0000
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 54/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 1.1606e-05 - categorical_accuracy: 1.0000
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 55/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 1.1247e-05 - categorical_accuracy: 1.0000
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 56/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 1.0962e-05 - categorical_accuracy: 1.0000
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 57/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 1.0805e-05 - categorical_accuracy: 1.0000
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 58/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 1.0405e-05 - categorical_accuracy: 1.0000
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 59/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 1.0044e-05 - categorical_accuracy: 1.0000
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 60/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 9.7923e-06 - categorical_accuracy: 1.0000
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 61/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 9.6366e-06 - categorical_accuracy: 1.0000
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 62/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 9.4869e-06 - categorical_accuracy: 1.0000
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 63/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 9.3689e-06 - categorical_accuracy: 1.0000
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 64/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 9.1681e-06 - categorical_accuracy: 1.0000
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 65/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 8.9463e-06 - categorical_accuracy: 1.0000
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 66/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 8.8095e-06 - categorical_accuracy: 1.0000
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 67/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 8.6916e-06 - categorical_accuracy: 1.0000
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 68/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 8.4500e-06 - categorical_accuracy: 1.0000
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 69/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 8.2484e-06 - categorical_accuracy: 1.0000
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 70/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 8.0686e-06 - categorical_accuracy: 1.0000
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 71/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 7.9635e-06 - categorical_accuracy: 1.0000
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 72/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 7.8683e-06 - categorical_accuracy: 1.0000
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 73/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 7.8354e-06 - categorical_accuracy: 1.0000
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 74/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 7.6539e-06 - categorical_accuracy: 1.0000
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 75/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 7.5528e-06 - categorical_accuracy: 1.0000
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 76/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 7.4957e-06 - categorical_accuracy: 1.0000
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 77/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 7.4003e-06 - categorical_accuracy: 1.0000
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 78/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 7.2468e-06 - categorical_accuracy: 1.0000
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 79/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 7.1568e-06 - categorical_accuracy: 1.0000
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 80/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 7.0711e-06 - categorical_accuracy: 1.0000
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 81/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 7.0368e-06 - categorical_accuracy: 1.0000
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 82/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 6.9769e-06 - categorical_accuracy: 1.0000
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 83/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 6.9325e-06 - categorical_accuracy: 1.0000
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 84/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 6.8288e-06 - categorical_accuracy: 1.0000
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 85/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 6.7729e-06 - categorical_accuracy: 1.0000
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 86/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 6.7283e-06 - categorical_accuracy: 1.0000
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 87/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 6.7365e-06 - categorical_accuracy: 1.0000
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 88/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 6.6315e-06 - categorical_accuracy: 1.0000
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 89/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 6.5945e-06 - categorical_accuracy: 1.0000
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 90/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 6.5369e-06 - categorical_accuracy: 1.0000
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 91/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 6.5740e-06 - categorical_accuracy: 1.0000
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 92/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 6.4782e-06 - categorical_accuracy: 1.0000
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 93/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 6.5162e-06 - categorical_accuracy: 1.0000
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 94/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 6.4711e-06 - categorical_accuracy: 1.0000
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 95/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 6.4402e-06 - categorical_accuracy: 1.0000
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 96/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 6.4371e-06 - categorical_accuracy: 1.0000
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 97/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 6.3458e-06 - categorical_accuracy: 1.0000
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 98/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 6.3174e-06 - categorical_accuracy: 1.0000
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 99/100
# 26125/26125 [==============================] - 4s 163us/sample - loss: 6.3382e-06 - categorical_accuracy: 1.0000
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 1.0485760000000006e-07.
# Epoch 100/100
# 26125/26125 [==============================] - 4s 162us/sample - loss: 6.3471e-06 - categorical_accuracy: 1.0000
# 2375/2375 [==============================] - 0s 88us/sample
# (2375, 11)
# [[ 6  9 10  7  0  4 10  8  3  7  8  6  5  6  8  7  9  4 10  0  7  7  8  0
#    5  5  0  0  0  6  2  9  8  4  7  8  6  1  0  1  4  0  3  3  7  6  0 10
#    4  0  1  8  2  4  8 10  1  5 10  3  7  0  3  4  8  1  1  6  6  6  8  0
#    3  2  2  5  5  3  7  6  1  1  6  3  1  5  4  1  8  7  1  7  7  8  6  3
#    4  3  5  7]]
# (2375, 1)
# [[ 6  9 10  7  0  4 10  8  3  7  9  6  5  6  8  7  9  4 10  0  7  7  8  0
#    5  5  0  0  0  6  2  9  9  4  7  9  6  1  0  1  4  0  3  3  7  6  0 10
#    4  0  1  8  2  4  9 10  1  5 10  3  7  0  3  4  9  1  1  6  6  6  9  0
#    3  2  2  5  5  3  7  6  1  1  6  3  1  5  4  1  9  7  1  7  7  9  6  3
#    4  3  5  7]]
# 2375/2375 [==============================] - 0s 104us/sample - loss: 0.3564 - categorical_accuracy: 0.9322
# ##################################################################################################################################
# #####################################################  K-FOLD 3  ################################################################
# Training subjects: ['01', '02', '05', '08', '09', '10', '11', '13', '14', '16', '17']
# Test subject: 03
# Train dataset:
# (26125, 1, 128, 40) (26125, 11)
# Test dataset:
# (2375, 1, 128, 40) (2375, 11)
# Activity:  13
# Activity:  25
# Model: "cnn"
# ...
# Epoch 29/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 2.8688e-05 - categorical_accuracy: 1.0000
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 30/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 2.7215e-05 - categorical_accuracy: 1.0000
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 31/100
# 26125/26125 [==============================] - 4s 164us/sample - loss: 2.6428e-05 - categorical_accuracy: 1.0000
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 32/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 2.5531e-05 - categorical_accuracy: 1.0000
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 33/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 2.4587e-05 - categorical_accuracy: 1.0000
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 34/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 2.3712e-05 - categorical_accuracy: 1.0000
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 35/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 2.2745e-05 - categorical_accuracy: 1.0000
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 36/100
# 26125/26125 [==============================] - 4s 164us/sample - loss: 2.2033e-05 - categorical_accuracy: 1.0000
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 37/100
# 26125/26125 [==============================] - 4s 164us/sample - loss: 2.1086e-05 - categorical_accuracy: 1.0000
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 38/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 1.9702e-05 - categorical_accuracy: 1.0000
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 39/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 1.8844e-05 - categorical_accuracy: 1.0000
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 40/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 1.8012e-05 - categorical_accuracy: 1.0000
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 41/100
# 26125/26125 [==============================] - 4s 164us/sample - loss: 1.7672e-05 - categorical_accuracy: 1.0000
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 42/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 1.7303e-05 - categorical_accuracy: 1.0000
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 43/100
# 26125/26125 [==============================] - 4s 164us/sample - loss: 1.6722e-05 - categorical_accuracy: 1.0000
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 44/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 1.6438e-05 - categorical_accuracy: 1.0000
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 45/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 1.6406e-05 - categorical_accuracy: 1.0000
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 46/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 1.5360e-05 - categorical_accuracy: 1.0000
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 47/100
# 26125/26125 [==============================] - 4s 164us/sample - loss: 1.4824e-05 - categorical_accuracy: 1.0000
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 48/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 1.4339e-05 - categorical_accuracy: 1.0000
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 49/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 1.3692e-05 - categorical_accuracy: 1.0000
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 50/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 1.3272e-05 - categorical_accuracy: 1.0000
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 51/100
# 26125/26125 [==============================] - 4s 164us/sample - loss: 1.3007e-05 - categorical_accuracy: 1.0000
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 52/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 1.2875e-05 - categorical_accuracy: 1.0000
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 53/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 1.2367e-05 - categorical_accuracy: 1.0000
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 54/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 1.2113e-05 - categorical_accuracy: 1.0000
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 55/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 1.1886e-05 - categorical_accuracy: 1.0000
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 56/100
# 26125/26125 [==============================] - 4s 164us/sample - loss: 1.1576e-05 - categorical_accuracy: 1.0000
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 57/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 1.1232e-05 - categorical_accuracy: 1.0000
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 58/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 1.1105e-05 - categorical_accuracy: 1.0000
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 59/100
# 26125/26125 [==============================] - 4s 164us/sample - loss: 1.0721e-05 - categorical_accuracy: 1.0000
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 60/100
# 26125/26125 [==============================] - 4s 164us/sample - loss: 1.0335e-05 - categorical_accuracy: 1.0000
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 61/100
# 26125/26125 [==============================] - 4s 164us/sample - loss: 1.0216e-05 - categorical_accuracy: 1.0000
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 62/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 9.9827e-06 - categorical_accuracy: 1.0000
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 63/100
# 26125/26125 [==============================] - 4s 164us/sample - loss: 9.9121e-06 - categorical_accuracy: 1.0000
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 64/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 9.7332e-06 - categorical_accuracy: 1.0000
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 65/100
# 26125/26125 [==============================] - 4s 164us/sample - loss: 9.6385e-06 - categorical_accuracy: 1.0000
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 66/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 9.3654e-06 - categorical_accuracy: 1.0000
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 67/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 9.1195e-06 - categorical_accuracy: 1.0000
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 68/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 8.9314e-06 - categorical_accuracy: 1.0000
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 69/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 8.7792e-06 - categorical_accuracy: 1.0000
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 70/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 8.6169e-06 - categorical_accuracy: 1.0000
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 71/100
# 26125/26125 [==============================] - 4s 164us/sample - loss: 8.5152e-06 - categorical_accuracy: 1.0000
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 72/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 8.3567e-06 - categorical_accuracy: 1.0000
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 73/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 8.2966e-06 - categorical_accuracy: 1.0000
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 74/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 8.2150e-06 - categorical_accuracy: 1.0000
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 75/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 8.1158e-06 - categorical_accuracy: 1.0000
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 76/100
# 26125/26125 [==============================] - 4s 164us/sample - loss: 7.8976e-06 - categorical_accuracy: 1.0000
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 77/100
# 26125/26125 [==============================] - 4s 164us/sample - loss: 7.8479e-06 - categorical_accuracy: 1.0000
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 78/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 7.8072e-06 - categorical_accuracy: 1.0000
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 79/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 7.6964e-06 - categorical_accuracy: 1.0000
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 80/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 7.4748e-06 - categorical_accuracy: 1.0000
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 81/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 7.4161e-06 - categorical_accuracy: 1.0000
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 82/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 7.4165e-06 - categorical_accuracy: 1.0000
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 83/100
# 26125/26125 [==============================] - 4s 164us/sample - loss: 7.4608e-06 - categorical_accuracy: 1.0000
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 84/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 7.2768e-06 - categorical_accuracy: 1.0000
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 85/100
# 26125/26125 [==============================] - 4s 164us/sample - loss: 7.2259e-06 - categorical_accuracy: 1.0000
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 86/100
# 26125/26125 [==============================] - 4s 164us/sample - loss: 7.2138e-06 - categorical_accuracy: 1.0000
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 87/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 7.3085e-06 - categorical_accuracy: 1.0000
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 88/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 7.0770e-06 - categorical_accuracy: 1.0000
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 89/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 7.0492e-06 - categorical_accuracy: 1.0000
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 90/100
# 26125/26125 [==============================] - 4s 164us/sample - loss: 7.0099e-06 - categorical_accuracy: 1.0000
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 91/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 6.9930e-06 - categorical_accuracy: 1.0000
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 92/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 6.9318e-06 - categorical_accuracy: 1.0000
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 93/100
# 26125/26125 [==============================] - 4s 164us/sample - loss: 6.9698e-06 - categorical_accuracy: 1.0000
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 94/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 6.9567e-06 - categorical_accuracy: 1.0000
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 95/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 6.8787e-06 - categorical_accuracy: 1.0000
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 96/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 6.8400e-06 - categorical_accuracy: 1.0000
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 97/100
# 26125/26125 [==============================] - 4s 164us/sample - loss: 6.7838e-06 - categorical_accuracy: 1.0000
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 98/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 6.8239e-06 - categorical_accuracy: 1.0000
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 99/100
# 26125/26125 [==============================] - 4s 164us/sample - loss: 6.8304e-06 - categorical_accuracy: 1.0000
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 1.0485760000000006e-07.
# Epoch 100/100
# 26125/26125 [==============================] - 4s 165us/sample - loss: 6.7808e-06 - categorical_accuracy: 1.0000
# 2375/2375 [==============================] - 0s 131us/sample
# (2375, 11)
# [[ 1  5  4  5  9  0  2 10  9  0  1  5  3  9  9  0  6  9  5  4  2 10  6  9
#    2  3  0  5  1  3 10  5  5  4  3  5  9  7  8  6  9  9  5 10 10  6  2 10
#    7  3  4  4  8  1  4  4  3  7  5  1  4  3  9  4  3  0  9  8  1  5  2  6
#    9 10  0  0  8  9  7  0  7  0  6  8  2  9  9  3  1  5  4  9  8  4  3 10
#    1  5  2  3]]
# (2375, 1)
# [[ 0  5  4  4  9  0  2 10  9  0  1  5  3  9  9  5  5  6  5  4  2 10  6  8
#    2  3  0  4  1  3 10  5  5  4  3  4  9  7  8 10  6  6  5 10 10  6  2 10
#    7  3  4  4  8  1  4  5  3  7  5  1  4  3  7  5  3  0  6  8  1  4  2  6
#    7 10  0  5  8  9  7  0  7  0  6  8  2  9  7  3  1  5  4  9  8  4  3 10
#    1  5  2  3]]
# 2375/2375 [==============================] - 0s 147us/sample - loss: 0.5604 - categorical_accuracy: 0.8636

# %% [markdown]
# # Accuracy

# %%
sum = 0
for acc in accuracies:
    sum += acc
print('Accuracy of K-Fold: ' + str(sum/12))
# Out:
# Accuracy of K-Fold: 0.8935438642899195
