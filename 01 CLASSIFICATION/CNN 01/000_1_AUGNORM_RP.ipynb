# %% [markdown]
# # CNN

# %%
import tensorflow.keras as keras

# %%
# Módulos necesarios. Asegurarse de poder importarlos.
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from pylab import rcParams
from scipy import stats
from sklearn import metrics
import seaborn as sns
from sklearn import preprocessing
import os as os
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
from time import time

# Config the matplotlib backend as plotting inline in IPython
# %matplotlib inline

# %%
import sys
print(sys.executable)
print(sys.version)
print(sys.version_info)
tf.__version__
# Out:
# /usr/bin/python
# 3.6.8 (default, Aug 20 2019, 17:12:48)
# [GCC 8.3.0]
# sys.version_info(major=3, minor=6, micro=8, releaselevel='final', serial=0)
# '1.14.0'

# %%
keras.__version__
# Out:
# '2.2.4-tf'

# %% [markdown]
# # 10-FOLD

# %%
subjects = ['01', '02', '03', '05', '08', '09', '10', '11', '13', '14', '16', '17']
global activities
activities = [9,10,11,12,13,19,20,21,24,25,31]

# %%
# Ajustado a los datos
n_time_steps = 128
n_classes = 11 # Nº de clases (el 0 está eliminado)
n_channels = 1 # Nº de canales
n_columns = 20

# Podríamos variarlo
batch_size = 128 # Tamaño del batch
learning_rate = 1e-3 # Learning rate (por defecto es 0.001)
epochs = 100 # Épocas

# %%
class LearningRateDecay:
    def plot(self, epochs, title="Learning Rate Schedule"):
        # compute the set of learning rates for each correRPonding
        # epoch
        lrs = [self(i) for i in epochs]
 
        # the learning rate schedule
        plt.style.use("ggplot")
        plt.figure()
        plt.plot(epochs, lrs)
        plt.title(title)
        plt.xlabel("Epoch #")
        plt.ylabel("Learning Rate")
class StepDecay(LearningRateDecay):
    def __init__(self, initAlpha=0.01, factor=0.25, dropEvery=10):
        # store the base initial learning rate, drop factor, and
        # epochs to drop every
        self.initAlpha = initAlpha
        self.factor = factor
        self.dropEvery = dropEvery
 
    def __call__(self, epoch):
        # compute the learning rate for the current epoch
        exp = np.floor((1 + epoch) / self.dropEvery)
        alpha = self.initAlpha * (self.factor ** exp)
        if(alpha<1e-9):
            alpha=1e-9

        # return the learning rate
        return float(alpha) 

schedule = StepDecay(initAlpha=learning_rate, factor=0.4, dropEvery=10)

reduce_lr = keras.callbacks.LearningRateScheduler(schedule, verbose = 1)
callbacks_list = [reduce_lr]

# %%
#Visualize training evolution
def plot_curves(model, acc, loss, val_acc, val_loss, kfold):
    #########################################################################################
    # LOSS plot
    plt.figure(figsize=(12,8))
    plt.plot(model.history.history[loss], label='Training loss')
    plt.xlabel('Epochs', fontsize=15)
    plt.ylabel('Loss', fontsize=15)
    plt.tick_params(labelsize=10)
    plt.legend(loc=1,prop={'size': 10})
    plt.title('Loss in trainnig', fontsize=20)
    fig = plt.gcf()
    plt.show()
    
    fig.savefig('./000_1_AUGNORM_RP/loss_train_000_1_AUGNORM_RP_KFOLD_'+kfold+'.pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./000_1_AUGNORM_RP/loss_train_000_1_AUGNORM_RP_KFOLD_'+kfold+'svg', bbox_inches='tight',format='svg')
    
    #########################################################################################
    # ACC plot
    plt.figure(figsize=(12,8))
    plt.plot(model.history.history[acc], label='Training accuracy')
    plt.xlabel('Epochs', fontsize=15)
    plt.ylabel('Accuracy', fontsize=15)
    plt.tick_params(labelsize=10)
    plt.legend(loc=1,prop={'size': 10})
    plt.title('Accuracy in training', fontsize=20)
    fig = plt.gcf()
    plt.show()

    fig.savefig('./000_1_AUGNORM_RP/acc_train_000_1_AUGNORM_RP_KFOLD_'+kfold+'pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./000_1_AUGNORM_RP/acc_train_000_1_AUGNORM_RP_KFOLD_'+kfold+'svg', bbox_inches='tight',format='svg')
    
    #########################################################################################
    # ACC+LOSS plot
    plt.figure(figsize=(14,10))
    plt_loss = host_subplot(111, axes_class=AA.Axes)
    plt.subplots_adjust(right=0.75)

    plt_acc = plt_loss.twinx()
    plt_acc.axis["right"].toggle(all=True)
    
    plt_loss.set_xlim(0, len(model.history.history[loss]))
    plt_loss.set_ylim(0, max(model.history.history[loss]))
    plt_loss.set_xlabel('Epochs')
    plt_loss.set_ylabel('Loss')
    plt_acc.set_ylabel('Accuracy')
                        
    plt_loss.axis['left'].label.set_fontsize(15)
    plt_loss.axis['bottom'].label.set_fontsize(15)
    plt_acc.axis['right'].label.set_fontsize(15)
    
    plt_loss.plot(model.history.history[loss], c='tab:blue', ls='--', label='Training loss')
    plt_acc.plot(model.history.history[acc], c='tab:orange',ls='--', label='Training accuracy')
    
    plt.tick_params(labelsize=10)
    plt.title('Training performance', fontsize=20)
    plt_acc.set_ylim(0, 1)
    plt_loss.legend(loc=1, prop={'size': 10})
    
    fig = plt.gcf()
    plt.show()

    fig.savefig('./000_1_AUGNORM_RP/all_train_000_1_AUGNORM_RP_KFOLD_'+kfold+'pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./000_1_AUGNORM_RP/all_train_000_1_AUGNORM_RP_KFOLD_'+kfold+'svg', bbox_inches='tight',format='svg')

# %%
def plot_confusion_matrix(y_true, y_pred, kfold, classes,
                          cmap=plt.cm.Blues):

    # Compute confusion matrix
    cm = metrics.confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(20, 20))
    sns.heatmap(cm, xticklabels=classes, yticklabels=classes, square = True, robust = True, annot=True, cmap='YlOrBr')
    plt.title('CONFUSION MATRIX')
    plt.ylabel('TRUE ACTIVITY')
    plt.xlabel('PREDICTION')
    
    locs, labels = plt.xticks()
    plt.xticks(locs, labels, rotation='vertical')
    locs, labels = plt.yticks()
    plt.yticks(locs, labels, rotation='horizontal')

    # Guardamos la imagen en formato vectorial
    plt.draw()
    plt.savefig('./000_1_AUGNORM_RP/matriz_confusion_'+kfold+'.svg', bbox_inches='tight',format='svg')
    plt.show()

# %%
global size
size = 26125

# %%
from sklearn.model_selection import KFold
S = np.arange(0,size)
kf = KFold(n_splits=10)
kf.get_n_splits(S)

print(kf)  

S_train = []
S_test = []

for train_index, test_index in kf.split(S):
    print("TRAIN:", train_index, "TEST:", test_index)
    print(S[train_index])
    print(S[test_index])
    S_train.append(S[train_index])
    S_test.append(S[test_index])
# Out:
# KFold(n_splits=10, random_state=None, shuffle=False)
# TRAIN: [ 2613  2614  2615 ... 26122 26123 26124] TEST: [   0    1    2 ... 2610 2611 2612]
# [ 2613  2614  2615 ... 26122 26123 26124]
# [   0    1    2 ... 2610 2611 2612]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [2613 2614 2615 ... 5223 5224 5225]
# [    0     1     2 ... 26122 26123 26124]
# [2613 2614 2615 ... 5223 5224 5225]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [5226 5227 5228 ... 7836 7837 7838]
# [    0     1     2 ... 26122 26123 26124]
# [5226 5227 5228 ... 7836 7837 7838]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [ 7839  7840  7841 ... 10449 10450 10451]
# [    0     1     2 ... 26122 26123 26124]
# [ 7839  7840  7841 ... 10449 10450 10451]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [10452 10453 10454 ... 13062 13063 13064]
# [    0     1     2 ... 26122 26123 26124]
# [10452 10453 10454 ... 13062 13063 13064]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [13065 13066 13067 ... 15674 15675 15676]
# [    0     1     2 ... 26122 26123 26124]
# [13065 13066 13067 ... 15674 15675 15676]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [15677 15678 15679 ... 18286 18287 18288]
# [    0     1     2 ... 26122 26123 26124]
# [15677 15678 15679 ... 18286 18287 18288]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [18289 18290 18291 ... 20898 20899 20900]
# [    0     1     2 ... 26122 26123 26124]
# [18289 18290 18291 ... 20898 20899 20900]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [20901 20902 20903 ... 23510 23511 23512]
# [    0     1     2 ... 26122 26123 26124]
# [20901 20902 20903 ... 23510 23511 23512]
# TRAIN: [    0     1     2 ... 23510 23511 23512] TEST: [23513 23514 23515 ... 26122 26123 26124]
# [    0     1     2 ... 23510 23511 23512]
# [23513 23514 23515 ... 26122 26123 26124]

# %%
accuracies = []
for i in range(10):
    if(i<10):
        kfold='0'+str(i)
    else:
        kfold=str(i)
    print('##################################################################################################################################')
    print('#####################################################  K-FOLD %d  ################################################################'%(i+1))
    
    subjects = ['01', '02', '03', '05', '08', '09', '10', '11', '13', '14', '16', '17']
    
    ##  GENERACIÓN DATASET
    tr_seg = np.concatenate((np.load('./augment_norm/subject_'+subjects[0]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects[1]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects[2]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects[3]+'_seg.npy'),
                             np.load('./augment_norm/subject_'+subjects[4]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects[5]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects[6]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects[7]+'_seg.npy'),
                             np.load('./augment_norm/subject_'+subjects[8]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects[9]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects[10]+'_seg.npy')))

    tr_lab = np.concatenate((np.load('./augment_norm/subject_'+subjects[0]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects[1]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects[2]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects[3]+'_lab.npy'),
                             np.load('./augment_norm/subject_'+subjects[4]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects[5]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects[6]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects[7]+'_lab.npy'),
                             np.load('./augment_norm/subject_'+subjects[8]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects[9]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects[10]+'_lab.npy')))
    
    limit = 20
    tr_seg = tr_seg[:,:,:,:limit]
    ####################################################################################################################
    ## SHUFFLE DE DATOS
    np.random.seed(235)
    tr_seg = np.reshape(tr_seg[np.random.shuffle(np.arange(0,tr_seg.shape[0]))], (size,1,128,limit))
    tr_lab = np.reshape(tr_lab[np.random.shuffle(np.arange(0,tr_seg.shape[0]))], (size,11))
    
    ts_seg = tr_seg[S_test[i]]
    ts_lab = tr_lab[S_test[i]]
    
    tr_seg = tr_seg[S_train[i]]
    tr_lab = tr_lab[S_train[i]]
    
    print('Train dataset: ')
    print(tr_seg.shape, tr_lab.shape)
    print('Test dataset: ')
    print(ts_seg.shape, ts_lab.shape)
    ####################################################################################################################
    ## VISTA DE DFT-2D
    plt.figure(figsize=(30,30))
    plt.imshow(np.log(np.abs(np.fft.fftshift(tr_seg[0,0,:,20:40].T))**2))
    plt.show()
    print('Activity: ',activities[np.argmax(tr_lab[0])])

    plt.figure(figsize=(30,30))
    plt.imshow(np.log(np.fft.fftshift(tr_seg[10,0,:,20:40].T)**2))
    plt.show()
    print('Activity: ',activities[np.argmax(tr_lab[10])])
    ####################################################################################################################
    ## RED
    quat_input = keras.Input(shape=(n_channels, n_time_steps, n_columns), name='input_layer')

    # Some convolutional layers
    conv_1 = keras.layers.Conv2D(16, kernel_size=4,padding='same',activation='relu', data_format = 'channels_first')(quat_input)
    max_1 = keras.layers.MaxPooling2D(pool_size=2, strides=2, padding='same', data_format = 'channels_first')(conv_1)
    bn_1 = keras.layers.BatchNormalization(axis=1)(max_1)
    conv_2 = keras.layers.Conv2D(32,kernel_size=4, padding='same',activation='relu', data_format = 'channels_first')(bn_1)
    max_2 = keras.layers.MaxPooling2D(pool_size=2, strides=2, padding='same', data_format = 'channels_first')(conv_2)

    # Flatten the output of the convolutional layers
    conv_flat = keras.layers.Flatten()(max_2)

    # Output layers: separate outputs for the weather and the ground labels
    multiclass_output = keras.layers.Dense(n_classes, activation='softmax',name='activity_class')(conv_flat)
    
    # Creamos la estrcutura que contendrá a nuestro modelo
    model = keras.Model(inputs=quat_input, outputs=[multiclass_output],name='cnn')

    # Compilamos el modelo
    model.compile(optimizer=keras.optimizers.Adam(lr=learning_rate),
                  loss='categorical_crossentropy', metrics=['categorical_accuracy'])
    
    print(model.summary())
    ####################################################################################################################
    ## TRAIN
    history = model.fit(tr_seg,
                        tr_lab,
                        epochs = epochs,
                        steps_per_epoch = None,
                        verbose = 1,
                        batch_size = batch_size,
                        callbacks = callbacks_list)
    model.save('./000_1_AUGNORM_RP/CNN_RNN_'+kfold+'.h5')
    
    #Visualize training evolution
    plot_curves(model, 'categorical_accuracy', 'loss', 'val_categorical_accuracy', 'val_loss', kfold)
    ####################################################################################################################
    ## TEST
    predictions = model.predict(ts_seg, batch_size = batch_size, verbose = 1)
    
    print(predictions.shape)
    
    y_pred = np.argmax(predictions,axis=-1)
    y_pred = np.expand_dims(y_pred,axis=-1)
    print(y_pred[:100].T)
    
    y_true = np.argmax(ts_lab,axis=-1)
    y_true = np.expand_dims(y_true,axis=-1)
    print(y_true.shape)
    print(y_true[:100].T)
    
    evaluation = model.evaluate(ts_seg, ts_lab, batch_size=batch_size, verbose=1)
    accuracies.append(evaluation[1])
    
    fo = open('./000_1_AUGNORM_RP/accuracy_'+kfold+'.txt', "w")
    fo.seek(0,2)
    fo.write(str(evaluation))
    fo.close()
    
    ####################################################################################################################
    ## CONFUSION MATRIX
    y_true_flat = np.ndarray.flatten(y_true)
    y_pred_flat = np.ndarray.flatten(y_pred)
    
    plot_confusion_matrix(y_true_flat, y_pred_flat, kfold, classes=activities)
    
    del kfold, limit, tr_seg, tr_lab, ts_seg, ts_lab, model, history, y_pred, y_true, predictions, evaluation, y_true_flat, y_pred_flat
# Out:
# ##################################################################################################################################
# #####################################################  K-FOLD 1  ################################################################
# Train dataset:
# (23512, 1, 128, 20) (23512, 11)
# Test dataset:
# (2613, 1, 128, 20) (2613, 11)
# /usr/local/lib/python3.6/dist-packages/matplotlib/image.py:857: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=-0.5, top=-0.5
#   self.axes.set_ylim((ymin, ymax), auto=None)
# Activity:  12
# Activity:  25
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 20)]      0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 16, 128, 20)       272
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 64, 10)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 16, 64, 10)        64
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 64, 10)        8224
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 5)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 5120)              0
# _________________________________________________________________
# activity_class (Dense)       (None, 11)                56331
# =================================================================
# Total params: 64,891
# Trainable params: 64,859
# Non-trainable params: 32
# _________________________________________________________________
# None
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/100
# 23512/23512 [==============================] - 8s 358us/sample - loss: 0.6662 - categorical_accuracy: 0.7776
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/100
# 23512/23512 [==============================] - 2s 96us/sample - loss: 0.0568 - categorical_accuracy: 0.9876
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 0.0145 - categorical_accuracy: 0.9988
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 0.0063 - categorical_accuracy: 0.9998
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 0.0028 - categorical_accuracy: 1.0000
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 0.0019 - categorical_accuracy: 1.0000
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 0.0012 - categorical_accuracy: 1.0000
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 9.1192e-04 - categorical_accuracy: 1.0000
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 7.3590e-04 - categorical_accuracy: 1.0000
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 10/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 5.3496e-04 - categorical_accuracy: 1.0000
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 11/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 4.8232e-04 - categorical_accuracy: 1.0000
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 12/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 4.3919e-04 - categorical_accuracy: 1.0000
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 13/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 4.0090e-04 - categorical_accuracy: 1.0000
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 14/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 3.6540e-04 - categorical_accuracy: 1.0000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 15/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 3.2835e-04 - categorical_accuracy: 1.0000
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 16/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 3.0189e-04 - categorical_accuracy: 1.0000
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 17/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 2.8181e-04 - categorical_accuracy: 1.0000
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 18/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 2.4985e-04 - categorical_accuracy: 1.0000
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 19/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 2.2288e-04 - categorical_accuracy: 1.0000
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 20/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 2.0041e-04 - categorical_accuracy: 1.0000
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 21/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 1.9225e-04 - categorical_accuracy: 1.0000
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 22/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 1.8622e-04 - categorical_accuracy: 1.0000
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 23/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 1.7764e-04 - categorical_accuracy: 1.0000
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 24/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 1.6838e-04 - categorical_accuracy: 1.0000
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 25/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 1.6312e-04 - categorical_accuracy: 1.0000
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 26/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 1.5441e-04 - categorical_accuracy: 1.0000
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 27/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 1.4622e-04 - categorical_accuracy: 1.0000
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 28/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 1.3453e-04 - categorical_accuracy: 1.0000
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 29/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 1.2619e-04 - categorical_accuracy: 1.0000
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 30/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 1.1781e-04 - categorical_accuracy: 1.0000
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 31/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 1.1640e-04 - categorical_accuracy: 1.0000
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 32/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 1.1289e-04 - categorical_accuracy: 1.0000
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 33/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 1.0598e-04 - categorical_accuracy: 1.0000
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 34/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 1.0575e-04 - categorical_accuracy: 1.0000
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 35/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 1.0106e-04 - categorical_accuracy: 1.0000
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 36/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 9.9327e-05 - categorical_accuracy: 1.0000
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 37/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 9.3804e-05 - categorical_accuracy: 1.0000
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 38/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 9.2472e-05 - categorical_accuracy: 1.0000
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 39/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 8.9767e-05 - categorical_accuracy: 1.0000
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 40/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 8.1927e-05 - categorical_accuracy: 1.0000
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 41/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 8.0443e-05 - categorical_accuracy: 1.0000
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 42/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 8.0317e-05 - categorical_accuracy: 1.0000
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 43/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 7.9404e-05 - categorical_accuracy: 1.0000
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 44/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 7.7523e-05 - categorical_accuracy: 1.0000
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 45/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 7.3144e-05 - categorical_accuracy: 1.0000
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 46/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 7.2633e-05 - categorical_accuracy: 1.0000
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 47/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 6.9189e-05 - categorical_accuracy: 1.0000
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 48/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 6.7190e-05 - categorical_accuracy: 1.0000
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 49/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 6.4713e-05 - categorical_accuracy: 1.0000
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 50/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 6.2948e-05 - categorical_accuracy: 1.0000
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 51/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 6.1552e-05 - categorical_accuracy: 1.0000
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 52/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 6.1636e-05 - categorical_accuracy: 1.0000
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 53/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 5.9490e-05 - categorical_accuracy: 1.0000
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 54/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 5.9385e-05 - categorical_accuracy: 1.0000
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 55/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 5.8994e-05 - categorical_accuracy: 1.0000
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 56/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 5.7670e-05 - categorical_accuracy: 1.0000
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 57/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 5.5546e-05 - categorical_accuracy: 1.0000
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 58/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 5.4884e-05 - categorical_accuracy: 1.0000
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 59/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 5.3006e-05 - categorical_accuracy: 1.0000
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 60/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 5.1258e-05 - categorical_accuracy: 1.0000
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 61/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 5.1023e-05 - categorical_accuracy: 1.0000
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 62/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 5.0512e-05 - categorical_accuracy: 1.0000
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 63/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 4.9231e-05 - categorical_accuracy: 1.0000
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 64/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 4.7545e-05 - categorical_accuracy: 1.0000
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 65/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 4.8612e-05 - categorical_accuracy: 1.0000
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 66/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 4.7905e-05 - categorical_accuracy: 1.0000
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 67/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 4.6471e-05 - categorical_accuracy: 1.0000
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 68/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 4.5657e-05 - categorical_accuracy: 1.0000
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 69/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 4.4290e-05 - categorical_accuracy: 1.0000
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 70/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 4.5252e-05 - categorical_accuracy: 1.0000
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 71/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 4.4467e-05 - categorical_accuracy: 1.0000
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 72/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 4.3678e-05 - categorical_accuracy: 1.0000
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 73/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 4.3676e-05 - categorical_accuracy: 1.0000
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 74/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 4.2576e-05 - categorical_accuracy: 1.0000
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 75/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 4.3028e-05 - categorical_accuracy: 1.0000
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 76/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 4.2423e-05 - categorical_accuracy: 1.0000
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 77/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 4.1964e-05 - categorical_accuracy: 1.0000
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 78/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 4.1904e-05 - categorical_accuracy: 1.0000
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 79/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 4.1197e-05 - categorical_accuracy: 1.0000
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 80/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 4.1033e-05 - categorical_accuracy: 1.0000
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 81/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 4.0395e-05 - categorical_accuracy: 1.0000
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 82/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 4.0829e-05 - categorical_accuracy: 1.0000
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 83/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 4.0445e-05 - categorical_accuracy: 1.0000
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 84/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 4.0264e-05 - categorical_accuracy: 1.0000
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 85/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 3.9293e-05 - categorical_accuracy: 1.0000
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 86/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 4.0649e-05 - categorical_accuracy: 1.0000
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 87/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 3.9266e-05 - categorical_accuracy: 1.0000
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 88/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 4.0122e-05 - categorical_accuracy: 1.0000
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 89/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 3.9563e-05 - categorical_accuracy: 1.0000
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 90/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 3.9052e-05 - categorical_accuracy: 1.0000
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 91/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 3.8281e-05 - categorical_accuracy: 1.0000
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 92/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 3.9470e-05 - categorical_accuracy: 1.0000
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 93/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 3.9220e-05 - categorical_accuracy: 1.0000
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 94/100
# 23512/23512 [==============================] - 2s 94us/sample - loss: 3.9130e-05 - categorical_accuracy: 1.0000
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 95/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 3.9006e-05 - categorical_accuracy: 1.0000
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 96/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 3.8644e-05 - categorical_accuracy: 1.0000
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 97/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 3.8250e-05 - categorical_accuracy: 1.0000
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 98/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 3.8647e-05 - categorical_accuracy: 1.0000
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 99/100
# 23512/23512 [==============================] - 2s 93us/sample - loss: 3.7817e-05 - categorical_accuracy: 1.0000
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 1.0485760000000006e-07.
# Epoch 100/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 3.8696e-05 - categorical_accuracy: 1.0000
# 2613/2613 [==============================] - 0s 62us/sample
# (2613, 11)
# [[ 4 10  3  3  5  0  4 10  4  7  5 10 10  2 10 10  1  5  6  1 10 10 10  3
#    3 10  2  4 10 10 10  4 10  5  5 10  4  9  5  8 10 10  8  1  1  7  6  7
#    1  1  3  6  2  3  2 10  2  5  4 10  2  3 10  5 10 10  5  6  7 10 10  1
#    6  5  5  2  2  8  1 10  7 10 10  1  1  6  3  3  1  1  8  4 10 10 10  1
#   10 10  3  2]]
# (2613, 1)
# [[ 4 10  3  4  5 10  4  8  4  7  9 10  8  4  8  5  1  5  5  1  9 10 10  4
#    3  9  2  4  0  0  9  4  0  5  5 10  4  5  6  9  8  8  9  1  1  7  6  7
#    1  1  4  6  2  4  2  8  2  6  4  8  2  3  0  9  0 10  5  9  7 10  6  1
#    6  7  5  2  2  8  1  9  7 10 10  1  1  6  3  3  1  1  9  4  0  0 10  1
#    9  0  4  2]]
# 2613/2613 [==============================] - 0s 77us/sample - loss: 3.7973 - categorical_accuracy: 0.6288
# ##################################################################################################################################
# #####################################################  K-FOLD 2  ################################################################
# Train dataset:
# (23512, 1, 128, 20) (23512, 11)
# Test dataset:
# (2613, 1, 128, 20) (2613, 11)
# /usr/local/lib/python3.6/dist-packages/matplotlib/image.py:857: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=-0.5, top=-0.5
#   self.axes.set_ylim((ymin, ymax), auto=None)
# Activity:  13
# Activity:  25
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 20)]      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 128, 20)       272
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 64, 10)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 64, 10)        64
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 64, 10)        8224
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 32, 32, 5)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 5120)              0
# _________________________________________________________________
# activity_class (Dense)       (None, 11)                56331
# =================================================================
# Total params: 64,891
# Trainable params: 64,859
# Non-trainable params: 32
# _________________________________________________________________
# None
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/100
# 23512/23512 [==============================] - 3s 128us/sample - loss: 0.6931 - categorical_accuracy: 0.7671
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 0.0607 - categorical_accuracy: 0.9879
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 0.0225 - categorical_accuracy: 0.9962
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 0.0135 - categorical_accuracy: 0.9977
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 0.0156 - categorical_accuracy: 0.9959
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 0.0752 - categorical_accuracy: 0.9761
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 0.0068 - categorical_accuracy: 0.9986
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 0.0156 - categorical_accuracy: 0.9957
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 0.0016 - categorical_accuracy: 0.9997
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 10/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 4.3230e-04 - categorical_accuracy: 1.0000
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 11/100
# 23512/23512 [==============================] - 2s 92us/sample - loss: 3.1737e-04 - categorical_accuracy: 1.0000
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 12/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 2.7312e-04 - categorical_accuracy: 1.0000
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 13/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 2.5646e-04 - categorical_accuracy: 1.0000
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 14/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 2.2422e-04 - categorical_accuracy: 1.0000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 15/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 2.1248e-04 - categorical_accuracy: 1.0000
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 16/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 2.0125e-04 - categorical_accuracy: 1.0000
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 17/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 1.9208e-04 - categorical_accuracy: 1.0000
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 18/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 1.7674e-04 - categorical_accuracy: 1.0000
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 19/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 1.7089e-04 - categorical_accuracy: 1.0000
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 20/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 1.4520e-04 - categorical_accuracy: 1.0000
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 21/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 1.5287e-04 - categorical_accuracy: 1.0000
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 22/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 1.4316e-04 - categorical_accuracy: 1.0000
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 23/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 1.3931e-04 - categorical_accuracy: 1.0000
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 24/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 1.2946e-04 - categorical_accuracy: 1.0000
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 25/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 1.3766e-04 - categorical_accuracy: 1.0000
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 26/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 1.3077e-04 - categorical_accuracy: 1.0000
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 27/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 1.2060e-04 - categorical_accuracy: 1.0000
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 28/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 1.2068e-04 - categorical_accuracy: 1.0000
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 29/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 1.1336e-04 - categorical_accuracy: 1.0000
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 30/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 1.0930e-04 - categorical_accuracy: 1.0000
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 31/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 1.0808e-04 - categorical_accuracy: 1.0000
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 32/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 1.0100e-04 - categorical_accuracy: 1.0000
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 33/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 1.0362e-04 - categorical_accuracy: 1.0000
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 34/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 9.6455e-05 - categorical_accuracy: 1.0000
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 35/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 9.8185e-05 - categorical_accuracy: 1.0000
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 36/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 9.5303e-05 - categorical_accuracy: 1.0000
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 37/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 9.1987e-05 - categorical_accuracy: 1.0000
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 38/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 9.4777e-05 - categorical_accuracy: 1.0000
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 39/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 9.0719e-05 - categorical_accuracy: 1.0000
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 40/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 8.5015e-05 - categorical_accuracy: 1.0000
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 41/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 8.2888e-05 - categorical_accuracy: 1.0000
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 42/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 9.0466e-05 - categorical_accuracy: 1.0000
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 43/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 8.4333e-05 - categorical_accuracy: 1.0000
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 44/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 8.0218e-05 - categorical_accuracy: 1.0000
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 45/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 8.2170e-05 - categorical_accuracy: 1.0000
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 46/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 7.8477e-05 - categorical_accuracy: 1.0000
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 47/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 7.8135e-05 - categorical_accuracy: 1.0000
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 48/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 7.4355e-05 - categorical_accuracy: 1.0000
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 49/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 7.1112e-05 - categorical_accuracy: 1.0000
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 50/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 7.1251e-05 - categorical_accuracy: 1.0000
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 51/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 7.0669e-05 - categorical_accuracy: 1.0000
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 52/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 7.1084e-05 - categorical_accuracy: 1.0000
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 53/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 6.9070e-05 - categorical_accuracy: 1.0000
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 54/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 6.8438e-05 - categorical_accuracy: 1.0000
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 55/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 6.9096e-05 - categorical_accuracy: 1.0000
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 56/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 6.6145e-05 - categorical_accuracy: 1.0000
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 57/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 6.7527e-05 - categorical_accuracy: 1.0000
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 58/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 6.2622e-05 - categorical_accuracy: 1.0000
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 59/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 6.3069e-05 - categorical_accuracy: 1.0000
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 60/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 6.2002e-05 - categorical_accuracy: 1.0000
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 61/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 5.9461e-05 - categorical_accuracy: 1.0000
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 62/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 5.9582e-05 - categorical_accuracy: 1.0000
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 63/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 6.0013e-05 - categorical_accuracy: 1.0000
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 64/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 6.1816e-05 - categorical_accuracy: 1.0000
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 65/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 6.0247e-05 - categorical_accuracy: 1.0000
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 66/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 5.6776e-05 - categorical_accuracy: 1.0000
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 67/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 5.9482e-05 - categorical_accuracy: 1.0000
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 68/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 5.8265e-05 - categorical_accuracy: 1.0000
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 69/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 5.4327e-05 - categorical_accuracy: 1.0000
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 70/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 5.4740e-05 - categorical_accuracy: 1.0000
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 71/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 5.4188e-05 - categorical_accuracy: 1.0000
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 72/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 5.4777e-05 - categorical_accuracy: 1.0000
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 73/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 5.6097e-05 - categorical_accuracy: 1.0000
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 74/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 5.4003e-05 - categorical_accuracy: 1.0000
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 75/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 5.4799e-05 - categorical_accuracy: 1.0000
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 76/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 5.3002e-05 - categorical_accuracy: 1.0000
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 77/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 5.5081e-05 - categorical_accuracy: 1.0000
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 78/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 5.2610e-05 - categorical_accuracy: 1.0000
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 79/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 5.0668e-05 - categorical_accuracy: 1.0000
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 80/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 5.3264e-05 - categorical_accuracy: 1.0000
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 81/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 5.0789e-05 - categorical_accuracy: 1.0000
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 82/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 5.2421e-05 - categorical_accuracy: 1.0000
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 83/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 5.2997e-05 - categorical_accuracy: 1.0000
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 84/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 5.0486e-05 - categorical_accuracy: 1.0000
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 85/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 5.0191e-05 - categorical_accuracy: 1.0000
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 86/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 5.2573e-05 - categorical_accuracy: 1.0000
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 87/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 5.1035e-05 - categorical_accuracy: 1.0000
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 88/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 4.9945e-05 - categorical_accuracy: 1.0000
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 89/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 5.0144e-05 - categorical_accuracy: 1.0000
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 90/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 4.8964e-05 - categorical_accuracy: 1.0000
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 91/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 4.8455e-05 - categorical_accuracy: 1.0000
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 92/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 5.3538e-05 - categorical_accuracy: 1.0000
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 93/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 4.9508e-05 - categorical_accuracy: 1.0000
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 94/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 5.0486e-05 - categorical_accuracy: 1.0000
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 95/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 5.1057e-05 - categorical_accuracy: 1.0000
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 96/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 4.8790e-05 - categorical_accuracy: 1.0000
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 97/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 4.9576e-05 - categorical_accuracy: 1.0000
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 98/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 5.1436e-05 - categorical_accuracy: 1.0000
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 99/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 4.9116e-05 - categorical_accuracy: 1.0000
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 1.0485760000000006e-07.
# Epoch 100/100
# 23512/23512 [==============================] - 2s 91us/sample - loss: 5.0507e-05 - categorical_accuracy: 1.0000
# 2613/2613 [==============================] - 0s 108us/sample
# (2613, 11)
# [[ 3  1  7 10  7  3 10  8  4  1  9  6  0  3  4  1 10  9 10  9  9  8  8  7
#    8 10  5  5  9  8  4  4  7  5 10  9  0  7 10  5  9  1  4  1  0 10  9  7
#    0  2  6  0  2  3  5  1  7  6  7  9  7  3  8  2  2  0  3  4  0  4  8  1
#    8  6  4  5  3  5  0  3  9  2  7  4 10  6  6  8 10  6  2  6  8  2  9  6
#    9  4  6 10]]
# (2613, 1)
# [[ 3  1  7 10  7  3 10  8  4  1  9  6  0  3  4  1 10  9 10  9  9  8  8  7
#    8 10  5  5  9  8  4  4  7  5 10  9  0  7 10  5  9  1  4  1  0 10  9  7
#    0  2  6  0  2  3  5  1  7  6  7  9  7  3  8  2  2  0  3  4  0  4  8  1
#    8  6  4  5  3  5  0  3  9  2  7  4 10  6  6  8 10  6  2  6  8  2  9  6
#    9  4  6 10]]
# 2613/2613 [==============================] - 0s 70us/sample - loss: 0.0182 - categorical_accuracy: 0.9950
# ##################################################################################################################################
# #####################################################  K-FOLD 3  ################################################################
# Train dataset:
# (23512, 1, 128, 20) (23512, 11)
# Test dataset:
# (2613, 1, 128, 20) (2613, 11)
# /usr/local/lib/python3.6/dist-packages/matplotlib/image.py:857: UserWarning: Attempting to set identical bottom==top results
# ...
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 93/100
# 23513/23513 [==============================] - 2s 94us/sample - loss: 6.4738e-05 - categorical_accuracy: 1.0000
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 94/100
# 23513/23513 [==============================] - 2s 94us/sample - loss: 6.6671e-05 - categorical_accuracy: 1.0000
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 95/100
# 23513/23513 [==============================] - 2s 94us/sample - loss: 6.4961e-05 - categorical_accuracy: 1.0000
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 96/100
# 23513/23513 [==============================] - 2s 94us/sample - loss: 6.5661e-05 - categorical_accuracy: 1.0000
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 97/100
# 23513/23513 [==============================] - 2s 94us/sample - loss: 6.5440e-05 - categorical_accuracy: 1.0000
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 98/100
# 23513/23513 [==============================] - 2s 94us/sample - loss: 6.3659e-05 - categorical_accuracy: 1.0000
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 99/100
# 23513/23513 [==============================] - 2s 94us/sample - loss: 6.5187e-05 - categorical_accuracy: 1.0000
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 1.0485760000000006e-07.
# Epoch 100/100
# 23513/23513 [==============================] - 2s 94us/sample - loss: 6.6494e-05 - categorical_accuracy: 1.0000
# 2612/2612 [==============================] - 0s 76us/sample
# (2612, 11)
# [[ 9  8  4 10  0  6  4  4 10  9  4 10 10  5  8  4  5  4  4  0  8  8  0  7
#    9  7  3 10  0  3  0  2  9  1  0  5  8  4  8 10  5  0  0  2  2  6  3  5
#    2  2  1  0  3  6  2  1  5  1  5  6  0  4  9  9  7  9  2  8  9  8  5  3
#    0  3  1  2  6  8  2  4 10 10  7  7  8  2  3  6  2  8  0  8  3  3  9  8
#    6  1  4 10]]
# (2612, 1)
# [[ 9  8  4 10  0  6  4  4 10  9  4 10 10  5  8  4  5  4  4  0  8  8  0  7
#    9  7  3 10  0  3  0  2  9  1  0  5  8  4  8 10  5  0  0  2  2  6  3  5
#    2  2  1  0  3  6  2  1  5  1  5  6  0  4  9  9  7  9  2  8  9  8  5  3
#    0  3  1  2  6  8  2  4 10 10  7  7  8  2  3  6  2  8  0  8  3  3  9  8
#    6  1  4 10]]
# 2612/2612 [==============================] - 0s 96us/sample - loss: 0.0229 - categorical_accuracy: 0.9927
# ##################################################################################################################################
# #####################################################  K-FOLD 10  ################################################################
# Train dataset:
# (23513, 1, 128, 20) (23513, 11)
# Test dataset:
# (2612, 1, 128, 20) (2612, 11)
# /usr/local/lib/python3.6/dist-packages/matplotlib/image.py:857: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=-0.5, top=-0.5
#   self.axes.set_ylim((ymin, ymax), auto=None)
# Activity:  13
# Activity:  25
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 20)]      0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 16, 128, 20)       272
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 16, 64, 10)        0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 16, 64, 10)        64
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 32, 64, 10)        8224
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 32, 32, 5)         0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 5120)              0
# _________________________________________________________________
# activity_class (Dense)       (None, 11)                56331
# =================================================================
# Total params: 64,891
# Trainable params: 64,859
# Non-trainable params: 32
# _________________________________________________________________
# None
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/100
# 23513/23513 [==============================] - 3s 106us/sample - loss: 0.6857 - categorical_accuracy: 0.7663
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 0.0616 - categorical_accuracy: 0.9863
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 0.0158 - categorical_accuracy: 0.9986
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/100
# 23513/23513 [==============================] - 2s 96us/sample - loss: 0.0260 - categorical_accuracy: 0.9940
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 0.0129 - categorical_accuracy: 0.9970
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/100
# 23513/23513 [==============================] - 2s 95us/sample - loss: 0.0031 - categorical_accuracy: 0.9996
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/100
# 23513/23513 [==============================] - 2s 96us/sample - loss: 0.0013 - categorical_accuracy: 1.0000
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 6.8876e-04 - categorical_accuracy: 1.0000
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 5.6865e-04 - categorical_accuracy: 1.0000
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 10/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 4.7350e-04 - categorical_accuracy: 1.0000
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 11/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 4.3074e-04 - categorical_accuracy: 1.0000
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 12/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 4.1120e-04 - categorical_accuracy: 1.0000
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 13/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 3.8171e-04 - categorical_accuracy: 1.0000
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 14/100
# 23513/23513 [==============================] - 2s 96us/sample - loss: 3.4516e-04 - categorical_accuracy: 1.0000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 15/100
# 23513/23513 [==============================] - 2s 96us/sample - loss: 3.2565e-04 - categorical_accuracy: 1.0000
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 16/100
# 23513/23513 [==============================] - 2s 96us/sample - loss: 2.9978e-04 - categorical_accuracy: 1.0000
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 17/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 2.7948e-04 - categorical_accuracy: 1.0000
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 18/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 2.5573e-04 - categorical_accuracy: 1.0000
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 19/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 2.3603e-04 - categorical_accuracy: 1.0000
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 20/100
# 23513/23513 [==============================] - 2s 96us/sample - loss: 2.1409e-04 - categorical_accuracy: 1.0000
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 21/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 2.0657e-04 - categorical_accuracy: 1.0000
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 22/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 2.0245e-04 - categorical_accuracy: 1.0000
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 23/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 1.9508e-04 - categorical_accuracy: 1.0000
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 24/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 1.8617e-04 - categorical_accuracy: 1.0000
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 25/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 1.7867e-04 - categorical_accuracy: 1.0000
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 26/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 1.7113e-04 - categorical_accuracy: 1.0000
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 27/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 1.6274e-04 - categorical_accuracy: 1.0000
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 28/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 1.5621e-04 - categorical_accuracy: 1.0000
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 29/100
# 23513/23513 [==============================] - 2s 98us/sample - loss: 1.4844e-04 - categorical_accuracy: 1.0000
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 30/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 1.3904e-04 - categorical_accuracy: 1.0000
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 31/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 1.3381e-04 - categorical_accuracy: 1.0000
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 32/100
# 23513/23513 [==============================] - 2s 96us/sample - loss: 1.2969e-04 - categorical_accuracy: 1.0000
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 33/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 1.2779e-04 - categorical_accuracy: 1.0000
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 34/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 1.2340e-04 - categorical_accuracy: 1.0000
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 35/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 1.1867e-04 - categorical_accuracy: 1.0000
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 36/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 1.1507e-04 - categorical_accuracy: 1.0000
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 37/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 1.1166e-04 - categorical_accuracy: 1.0000
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 38/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 1.0803e-04 - categorical_accuracy: 1.0000
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 39/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 1.0358e-04 - categorical_accuracy: 1.0000
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 40/100
# 23513/23513 [==============================] - 2s 96us/sample - loss: 1.0125e-04 - categorical_accuracy: 1.0000
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 41/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 9.9830e-05 - categorical_accuracy: 1.0000
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 42/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 9.7090e-05 - categorical_accuracy: 1.0000
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 43/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 9.4784e-05 - categorical_accuracy: 1.0000
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 44/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 9.1255e-05 - categorical_accuracy: 1.0000
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 45/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 9.1393e-05 - categorical_accuracy: 1.0000
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 46/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 8.8681e-05 - categorical_accuracy: 1.0000
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 47/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 8.6631e-05 - categorical_accuracy: 1.0000
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 48/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 8.3557e-05 - categorical_accuracy: 1.0000
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 49/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 8.3489e-05 - categorical_accuracy: 1.0000
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 50/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 7.9343e-05 - categorical_accuracy: 1.0000
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 51/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 7.7826e-05 - categorical_accuracy: 1.0000
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 52/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 7.6541e-05 - categorical_accuracy: 1.0000
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 53/100
# 23513/23513 [==============================] - 2s 97us/sample - loss: 7.5060e-05 - categorical_accuracy: 1.0000
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 54/100
#  4352/23513 [====>.........................] - ETA: 1s - loss: 7.3349e-05 - categorical_accuracy: 1.0000
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# # Accuracy

# %%
sum = 0
for acc in accuracies:
    sum += acc
print('Accuracy of K-Fold: ' + str(sum/10))
# Out:
# Accuracy of K-Fold: 0.9439654111862182
