# %% [markdown]
# # CNN

# %%
import tensorflow.keras as keras

# %%
# Módulos necesarios. Asegurarse de poder importarlos.
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from pylab import rcParams
from scipy import stats
from sklearn import metrics
import seaborn as sns
from sklearn import preprocessing
import os as os
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
from time import time

# Config the matplotlib backend as plotting inline in IPython
# %matplotlib inline

# %%
import sys
print(sys.executable)
print(sys.version)
print(sys.version_info)
tf.__version__
# Out:
# /usr/bin/python
# 3.6.8 (default, Aug 20 2019, 17:12:48)
# [GCC 8.3.0]
# sys.version_info(major=3, minor=6, micro=8, releaselevel='final', serial=0)
# '1.14.0'

# %%
keras.__version__
# Out:
# '2.2.4-tf'

# %% [markdown]
# # 12-FOLD

# %%
subjects = ['01', '02', '03', '05', '08', '09', '10', '11', '13', '14', '16', '17']
global activities
activities = [9,10,11,12,13,19,20,21,24,25,31]

# %%
# Ajustado a los datos
n_time_steps = 128
n_classes = 11 # Nº de clases (el 0 está eliminado)
n_channels = 1 # Nº de canales
n_columns = 20

# Podríamos variarlo
batch_size = 128 # Tamaño del batch
learning_rate = 1e-3 # Learning rate (por defecto es 0.001)
epochs = 100 # Épocas

# %%
class LearningRateDecay:
    def plot(self, epochs, title="Learning Rate Schedule"):
        # compute the set of learning rates for each corresponding
        # epoch
        lrs = [self(i) for i in epochs]
 
        # the learning rate schedule
        plt.style.use("ggplot")
        plt.figure()
        plt.plot(epochs, lrs)
        plt.title(title)
        plt.xlabel("Epoch #")
        plt.ylabel("Learning Rate")
class StepDecay(LearningRateDecay):
    def __init__(self, initAlpha=0.01, factor=0.25, dropEvery=10):
        # store the base initial learning rate, drop factor, and
        # epochs to drop every
        self.initAlpha = initAlpha
        self.factor = factor
        self.dropEvery = dropEvery
 
    def __call__(self, epoch):
        # compute the learning rate for the current epoch
        exp = np.floor((1 + epoch) / self.dropEvery)
        alpha = self.initAlpha * (self.factor ** exp)
        if(alpha<1e-9):
            alpha=1e-9

        # return the learning rate
        return float(alpha) 

schedule = StepDecay(initAlpha=learning_rate, factor=0.4, dropEvery=10)

reduce_lr = keras.callbacks.LearningRateScheduler(schedule, verbose = 1)
callbacks_list = [reduce_lr]

# %%
#Visualize training evolution
def plot_curves(model, acc, loss, val_acc, val_loss, subject_test):
    #########################################################################################
    # LOSS plot
    plt.figure(figsize=(12,8))
    plt.plot(model.history.history[loss], label='Training loss')
    plt.xlabel('Epochs', fontsize=15)
    plt.ylabel('Loss', fontsize=15)
    plt.tick_params(labelsize=10)
    plt.legend(loc=1,prop={'size': 10})
    plt.title('Loss in trainnig', fontsize=20)
    fig = plt.gcf()
    plt.show()
    
    fig.savefig('./000_1_FFT_SP/loss_train_000_1_FFT_SP_KFOLD_'+subject_test+'.pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./000_1_FFT_SP/loss_train_000_1_FFT_SP_KFOLD_'+subject_test+'svg', bbox_inches='tight',format='svg')
    
    #########################################################################################
    # ACC plot
    plt.figure(figsize=(12,8))
    plt.plot(model.history.history[acc], label='Training accuracy')
    plt.xlabel('Epochs', fontsize=15)
    plt.ylabel('Accuracy', fontsize=15)
    plt.tick_params(labelsize=10)
    plt.legend(loc=1,prop={'size': 10})
    plt.title('Accuracy in training', fontsize=20)
    fig = plt.gcf()
    plt.show()

    fig.savefig('./000_1_FFT_SP/acc_train_000_1_FFT_SP_KFOLD_'+subject_test+'pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./000_1_FFT_SP/acc_train_000_1_FFT_SP_KFOLD_'+subject_test+'svg', bbox_inches='tight',format='svg')
    
    #########################################################################################
    # ACC+LOSS plot
    plt.figure(figsize=(14,10))
    plt_loss = host_subplot(111, axes_class=AA.Axes)
    plt.subplots_adjust(right=0.75)

    plt_acc = plt_loss.twinx()
    plt_acc.axis["right"].toggle(all=True)
    
    plt_loss.set_xlim(0, len(model.history.history[loss]))
    plt_loss.set_ylim(0, max(model.history.history[loss]))
    plt_loss.set_xlabel('Epochs')
    plt_loss.set_ylabel('Loss')
    plt_acc.set_ylabel('Accuracy')
                        
    plt_loss.axis['left'].label.set_fontsize(15)
    plt_loss.axis['bottom'].label.set_fontsize(15)
    plt_acc.axis['right'].label.set_fontsize(15)
    
    plt_loss.plot(model.history.history[loss], c='tab:blue', ls='--', label='Training loss')
    plt_acc.plot(model.history.history[acc], c='tab:orange',ls='--', label='Training accuracy')
    
    plt.tick_params(labelsize=10)
    plt.title('Training performance', fontsize=20)
    plt_acc.set_ylim(0, 1)
    plt_loss.legend(loc=1, prop={'size': 10})
    
    fig = plt.gcf()
    plt.show()

    fig.savefig('./000_1_FFT_SP/all_train_000_1_FFT_SP_KFOLD_'+subject_test+'pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./000_1_FFT_SP/all_train_000_1_FFT_SP_KFOLD_'+subject_test+'svg', bbox_inches='tight',format='svg')

# %%
def plot_confusion_matrix(y_true, y_pred, subject_test, classes,
                          cmap=plt.cm.Blues):

    # Compute confusion matrix
    cm = metrics.confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(20, 20))
    sns.heatmap(cm, xticklabels=classes, yticklabels=classes, square = True, robust = True, annot=True, cmap='YlOrBr')
    plt.title('CONFUSION MATRIX')
    plt.ylabel('TRUE ACTIVITY')
    plt.xlabel('PREDICTION')
    
    locs, labels = plt.xticks()
    plt.xticks(locs, labels, rotation='vertical')
    locs, labels = plt.yticks()
    plt.yticks(locs, labels, rotation='horizontal')

    # Guardamos la imagen en formato vectorial
    plt.draw()
    plt.savefig('./000_1_FFT_SP/matriz_confusion_'+subject_test+'.svg', bbox_inches='tight',format='svg')
    plt.show()

# %%
accuracies = []
for i in range(1,12):
    print('##################################################################################################################################')
    print('#####################################################  K-FOLD %d  ################################################################'%(i+1))
    
    subject_test = subjects[i]
    subjects_train = [s for s in subjects if s not in subject_test]
    print('Training subjects: ' + str(subjects_train))
    print('Test subject: ' + str(subject_test))
    
    ##  GENERACIÓN DATASET
    tr_seg = np.concatenate((np.load('./augment_norm/subject_'+subjects_train[0]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[1]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[2]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[3]+'_seg.npy'),
                             np.load('./augment_norm/subject_'+subjects_train[4]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[5]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[6]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[7]+'_seg.npy'),
                             np.load('./augment_norm/subject_'+subjects_train[8]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[9]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[10]+'_seg.npy')))
    
    tr_lab = np.concatenate((np.load('./augment_norm/subject_'+subjects_train[0]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[1]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[2]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[3]+'_lab.npy'),
                             np.load('./augment_norm/subject_'+subjects_train[4]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[5]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[6]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[7]+'_lab.npy'),
                             np.load('./augment_norm/subject_'+subjects_train[8]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[9]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[10]+'_lab.npy')))

    ts_seg = np.load('./augment_norm/subject_'+subject_test+'_seg.npy')
    ts_lab = np.load('./augment_norm/subject_'+subject_test+'_lab.npy')
    
    limit = 40
    tr_seg = tr_seg[:,:,:,20:limit]
    ts_seg = ts_seg[:,:,:,20:limit]
    ####################################################################################################################
    ## SHUFFLE DE DATOS
    np.random.seed(235)
    tr_seg = np.reshape(tr_seg[np.random.shuffle(np.arange(0,tr_seg.shape[0]))], (11*2375,1,128,20))
    tr_lab = np.reshape(tr_lab[np.random.shuffle(np.arange(0,tr_seg.shape[0]))], (11*2375,11))

    np.random.seed(235)
    ts_seg = np.reshape(ts_seg[np.random.shuffle(np.arange(0,ts_seg.shape[0]))], (2375,1,128,20))
    ts_lab = np.reshape(ts_lab[np.random.shuffle(np.arange(0,ts_seg.shape[0]))], (2375,11))
    
    print('Train dataset: ')
    print(tr_seg.shape, tr_lab.shape)
    print('Test dataset: ')
    print(ts_seg.shape, ts_lab.shape)
    ####################################################################################################################
    ## VISTA DE DFT-2D
    plt.figure(figsize=(30,30))
    plt.imshow(np.log(np.abs(np.fft.fftshift(tr_seg[0,0,:,:].T))**2))
    plt.show()
    print('Activity: ',activities[np.argmax(tr_lab[0])])

    plt.figure(figsize=(30,30))
    plt.imshow(np.log(np.fft.fftshift(tr_seg[10,0,:,:].T)**2))
    plt.show()
    print('Activity: ',activities[np.argmax(tr_lab[10])])
    ####################################################################################################################
    ## RED
    quat_input = keras.Input(shape=(n_channels, n_time_steps, n_columns), name='input_layer')

    # Some convolutional layers
    conv_1 = keras.layers.Conv2D(16, kernel_size=4,padding='same',activation='relu', data_format = 'channels_first')(quat_input)
    max_1 = keras.layers.MaxPooling2D(pool_size=2, strides=2, padding='same', data_format = 'channels_first')(conv_1)
    bn_1 = keras.layers.BatchNormalization(axis=1)(max_1)
    conv_2 = keras.layers.Conv2D(32,kernel_size=4, padding='same',activation='relu', data_format = 'channels_first')(bn_1)
    max_2 = keras.layers.MaxPooling2D(pool_size=2, strides=2, padding='same', data_format = 'channels_first')(conv_2)

    # Flatten the output of the convolutional layers
    conv_flat = keras.layers.Flatten()(max_2)

    # Output layers: separate outputs for the weather and the ground labels
    multiclass_output = keras.layers.Dense(n_classes, activation='softmax',name='activity_class')(conv_flat)
    
    # Creamos la estrcutura que contendrá a nuestro modelo
    model = keras.Model(inputs=quat_input, outputs=[multiclass_output],name='cnn')

    # Compilamos el modelo
    model.compile(optimizer=keras.optimizers.Adam(lr=learning_rate),
                  loss='categorical_crossentropy', metrics=['categorical_accuracy'])
    
    print(model.summary())
    ####################################################################################################################
    ## TRAIN
    history = model.fit(tr_seg,
                        tr_lab,
                        epochs = epochs,
                        steps_per_epoch = None,
                        verbose = 1,
                        batch_size = batch_size,
                        callbacks = callbacks_list)
    model.save('./000_1_FFT_SP/CNN_RNN_'+subject_test+'.h5')
    
    #Visualize training evolution
    plot_curves(model, 'categorical_accuracy', 'loss', 'val_categorical_accuracy', 'val_loss', subject_test)
    ####################################################################################################################
    ## TEST
    predictions = model.predict(ts_seg, batch_size = batch_size, verbose = 1)
    
    print(predictions.shape)
    
    y_pred = np.argmax(predictions,axis=-1)
    y_pred = np.expand_dims(y_pred,axis=-1)
    print(y_pred[:100].T)
    
    y_true = np.argmax(ts_lab,axis=-1)
    y_true = np.expand_dims(y_true,axis=-1)
    print(y_true.shape)
    print(y_true[:100].T)
    
    evaluation = model.evaluate(ts_seg, ts_lab, batch_size=batch_size, verbose=1)
    accuracies.append(evaluation[1])
    
    fo = open('./000_1_FFT_SP/accuracy_'+subject_test+'.txt', "w")
    fo.seek(0,2)
    fo.write(str(evaluation))
    fo.close()
    
    ####################################################################################################################
    ## CONFUSION MATRIX
    y_true_flat = np.ndarray.flatten(y_true)
    y_pred_flat = np.ndarray.flatten(y_pred)
    
    plot_confusion_matrix(y_true_flat, y_pred_flat, subject_test, classes=activities)
    
    del subject_test, subjects_train, limit, tr_seg, tr_lab, ts_seg, ts_lab, model, history, y_pred, y_true, predictions, evaluation, y_true_flat, y_pred_flat
# Out:
# ##################################################################################################################################
# #####################################################  K-FOLD 2  ################################################################
# Training subjects: ['01', '03', '05', '08', '09', '10', '11', '13', '14', '16', '17']
# Test subject: 02
# Train dataset:
# (26125, 1, 128, 20) (26125, 11)
# Test dataset:
# (2375, 1, 128, 20) (2375, 11)
# Activity:  13
# Activity:  25
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 20)]      0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 16, 128, 20)       272
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 64, 10)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 16, 64, 10)        64
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 64, 10)        8224
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 5)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 5120)              0
# _________________________________________________________________
# activity_class (Dense)       (None, 11)                56331
# =================================================================
# Total params: 64,891
# Trainable params: 64,859
# Non-trainable params: 32
# _________________________________________________________________
# None
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/100
# 26125/26125 [==============================] - 9s 328us/sample - loss: 0.5919 - categorical_accuracy: 0.8165
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 0.0690 - categorical_accuracy: 0.9905
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 0.0188 - categorical_accuracy: 0.9991
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/100
# 26125/26125 [==============================] - 3s 97us/sample - loss: 0.0078 - categorical_accuracy: 0.9998
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 0.0041 - categorical_accuracy: 1.0000
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 0.0025 - categorical_accuracy: 1.0000
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/100
# 26125/26125 [==============================] - 3s 97us/sample - loss: 0.0016 - categorical_accuracy: 1.0000
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 0.0012 - categorical_accuracy: 1.0000
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 8.6231e-04 - categorical_accuracy: 1.0000
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 10/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 7.1360e-04 - categorical_accuracy: 1.0000
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 11/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 0.0012 - categorical_accuracy: 0.9998
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 12/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 5.7140e-04 - categorical_accuracy: 1.0000
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 13/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 5.1020e-04 - categorical_accuracy: 1.0000
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 14/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 4.5573e-04 - categorical_accuracy: 1.0000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 15/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 4.1050e-04 - categorical_accuracy: 1.0000
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 16/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 3.6254e-04 - categorical_accuracy: 1.0000
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 17/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 3.2207e-04 - categorical_accuracy: 1.0000
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 18/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 2.8430e-04 - categorical_accuracy: 1.0000
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 19/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 2.6071e-04 - categorical_accuracy: 1.0000
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 20/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 2.3537e-04 - categorical_accuracy: 1.0000
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 21/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 2.2291e-04 - categorical_accuracy: 1.0000
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 22/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 2.0940e-04 - categorical_accuracy: 1.0000
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 23/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 1.9909e-04 - categorical_accuracy: 1.0000
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 24/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 1.9130e-04 - categorical_accuracy: 1.0000
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 25/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 1.7607e-04 - categorical_accuracy: 1.0000
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 26/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 1.7062e-04 - categorical_accuracy: 1.0000
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 27/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 1.5677e-04 - categorical_accuracy: 1.0000
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 28/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 1.4608e-04 - categorical_accuracy: 1.0000
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 29/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 1.3671e-04 - categorical_accuracy: 1.0000
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 30/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 1.2800e-04 - categorical_accuracy: 1.0000
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 31/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 1.2312e-04 - categorical_accuracy: 1.0000
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 32/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 1.2002e-04 - categorical_accuracy: 1.0000
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 33/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 1.1901e-04 - categorical_accuracy: 1.0000
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 34/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 1.1116e-04 - categorical_accuracy: 1.0000
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 35/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 1.0662e-04 - categorical_accuracy: 1.0000
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 36/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 1.0321e-04 - categorical_accuracy: 1.0000
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 37/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 9.8860e-05 - categorical_accuracy: 1.0000
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 38/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 9.3485e-05 - categorical_accuracy: 1.0000
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 39/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 8.9034e-05 - categorical_accuracy: 1.0000
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 40/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 8.3992e-05 - categorical_accuracy: 1.0000
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 41/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 8.2196e-05 - categorical_accuracy: 1.0000
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 42/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 7.7734e-05 - categorical_accuracy: 1.0000
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 43/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 7.9735e-05 - categorical_accuracy: 1.0000
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 44/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 7.6530e-05 - categorical_accuracy: 1.0000
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 45/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 7.2414e-05 - categorical_accuracy: 1.0000
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 46/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 7.0243e-05 - categorical_accuracy: 1.0000
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 47/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 6.9083e-05 - categorical_accuracy: 1.0000
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 48/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 6.6184e-05 - categorical_accuracy: 1.0000
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 49/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 6.2853e-05 - categorical_accuracy: 1.0000
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 50/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 6.0930e-05 - categorical_accuracy: 1.0000
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 51/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 6.0100e-05 - categorical_accuracy: 1.0000
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 52/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 5.8633e-05 - categorical_accuracy: 1.0000
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 53/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 5.8026e-05 - categorical_accuracy: 1.0000
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 54/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 5.5933e-05 - categorical_accuracy: 1.0000
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 55/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 5.4554e-05 - categorical_accuracy: 1.0000
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 56/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 5.4910e-05 - categorical_accuracy: 1.0000
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 57/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 5.2635e-05 - categorical_accuracy: 1.0000
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 58/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 5.0945e-05 - categorical_accuracy: 1.0000
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 59/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 4.8996e-05 - categorical_accuracy: 1.0000
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 60/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.8544e-05 - categorical_accuracy: 1.0000
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 61/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 4.6937e-05 - categorical_accuracy: 1.0000
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 62/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 4.7765e-05 - categorical_accuracy: 1.0000
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 63/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.6382e-05 - categorical_accuracy: 1.0000
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 64/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 4.5579e-05 - categorical_accuracy: 1.0000
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 65/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 4.7042e-05 - categorical_accuracy: 1.0000
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 66/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 4.5087e-05 - categorical_accuracy: 1.0000
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 67/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 4.3392e-05 - categorical_accuracy: 1.0000
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 68/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.3122e-05 - categorical_accuracy: 1.0000
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 69/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 4.4562e-05 - categorical_accuracy: 1.0000
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 70/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 4.2668e-05 - categorical_accuracy: 1.0000
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 71/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 4.2976e-05 - categorical_accuracy: 1.0000
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 72/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 4.1785e-05 - categorical_accuracy: 1.0000
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 73/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 4.1965e-05 - categorical_accuracy: 1.0000
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 74/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 4.1586e-05 - categorical_accuracy: 1.0000
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 75/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.0845e-05 - categorical_accuracy: 1.0000
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 76/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 4.0634e-05 - categorical_accuracy: 1.0000
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 77/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 4.0692e-05 - categorical_accuracy: 1.0000
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 78/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 4.0559e-05 - categorical_accuracy: 1.0000
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 79/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 3.9947e-05 - categorical_accuracy: 1.0000
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 80/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 3.9812e-05 - categorical_accuracy: 1.0000
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 81/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 4.0015e-05 - categorical_accuracy: 1.0000
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 82/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 3.9183e-05 - categorical_accuracy: 1.0000
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 83/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 3.9593e-05 - categorical_accuracy: 1.0000
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 84/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 3.9538e-05 - categorical_accuracy: 1.0000
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 85/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 3.9697e-05 - categorical_accuracy: 1.0000
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 86/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 3.9015e-05 - categorical_accuracy: 1.0000
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 87/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 3.8848e-05 - categorical_accuracy: 1.0000
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 88/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 3.8544e-05 - categorical_accuracy: 1.0000
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 89/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 3.8582e-05 - categorical_accuracy: 1.0000
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 90/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 3.9930e-05 - categorical_accuracy: 1.0000
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 91/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 3.9870e-05 - categorical_accuracy: 1.0000
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 92/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 3.9706e-05 - categorical_accuracy: 1.0000
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 93/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 3.8828e-05 - categorical_accuracy: 1.0000
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 94/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 3.8587e-05 - categorical_accuracy: 1.0000
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 95/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 3.7506e-05 - categorical_accuracy: 1.0000
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 96/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 3.8368e-05 - categorical_accuracy: 1.0000
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 97/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 3.8044e-05 - categorical_accuracy: 1.0000
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 98/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 3.8271e-05 - categorical_accuracy: 1.0000
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 99/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 3.8180e-05 - categorical_accuracy: 1.0000
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 1.0485760000000006e-07.
# Epoch 100/100
# 26125/26125 [==============================] - 3s 98us/sample - loss: 3.8717e-05 - categorical_accuracy: 1.0000
# 2375/2375 [==============================] - 0s 73us/sample
# (2375, 11)
# [[ 6  9 10  7  0  4 10  8  2  7  8  6  5  6  8  5  9  4 10  0  7  7  8  0
#    5  5  0  0  0  6  2  8  8  4  7  8  6  1  0  1  4  0  2  2  7  6  0 10
#    4  0  1  8  2  4  8 10  1  5 10  2  7  0  2  4  8  1  1  6  6  6  8  0
#    3  2  2  5  5  2  7  6  1  1  6  2  1  5  4  1  9  7  1  7  5  8  6  2
#    4  2  5  7]]
# (2375, 1)
# [[ 6  9 10  7  0  4 10  8  3  7  9  6  5  6  8  7  9  4 10  0  7  7  8  0
#    5  5  0  0  0  6  2  9  9  4  7  9  6  1  0  1  4  0  3  3  7  6  0 10
#    4  0  1  8  2  4  9 10  1  5 10  3  7  0  3  4  9  1  1  6  6  6  9  0
#    3  2  2  5  5  3  7  6  1  1  6  3  1  5  4  1  9  7  1  7  7  9  6  3
#    4  3  5  7]]
# 2375/2375 [==============================] - 0s 88us/sample - loss: 0.9766 - categorical_accuracy: 0.8480
# ##################################################################################################################################
# #####################################################  K-FOLD 3  ################################################################
# Training subjects: ['01', '02', '05', '08', '09', '10', '11', '13', '14', '16', '17']
# Test subject: 03
# Train dataset:
# (26125, 1, 128, 20) (26125, 11)
# Test dataset:
# (2375, 1, 128, 20) (2375, 11)
# Activity:  13
# Activity:  25
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 20)]      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 128, 20)       272
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 64, 10)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 64, 10)        64
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 64, 10)        8224
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 32, 32, 5)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 5120)              0
# _________________________________________________________________
# activity_class (Dense)       (None, 11)                56331
# =================================================================
# Total params: 64,891
# Trainable params: 64,859
# Non-trainable params: 32
# _________________________________________________________________
# None
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/100
# 26125/26125 [==============================] - 3s 105us/sample - loss: 0.5913 - categorical_accuracy: 0.8162
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 0.0834 - categorical_accuracy: 0.9848
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 0.0240 - categorical_accuracy: 0.9980
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 0.0107 - categorical_accuracy: 0.9997
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 0.0049 - categorical_accuracy: 1.0000
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 0.0031 - categorical_accuracy: 1.0000
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 0.0019 - categorical_accuracy: 1.0000
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 0.0013 - categorical_accuracy: 1.0000
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 0.0010 - categorical_accuracy: 1.0000
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 10/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 8.0720e-04 - categorical_accuracy: 1.0000
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 11/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 0.0011 - categorical_accuracy: 1.0000
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 12/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 6.4213e-04 - categorical_accuracy: 1.0000
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 13/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 5.6961e-04 - categorical_accuracy: 1.0000
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 14/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 5.1682e-04 - categorical_accuracy: 1.0000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 15/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.6403e-04 - categorical_accuracy: 1.0000
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 16/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.0736e-04 - categorical_accuracy: 1.0000
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 17/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 3.6634e-04 - categorical_accuracy: 1.0000
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 18/100
# 26125/26125 [==============================] - 3s 100us/sample - loss: 3.1934e-04 - categorical_accuracy: 1.0000
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 19/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 2.9766e-04 - categorical_accuracy: 1.0000
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 20/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 2.6388e-04 - categorical_accuracy: 1.0000
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 21/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 2.5046e-04 - categorical_accuracy: 1.0000
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 22/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 2.3386e-04 - categorical_accuracy: 1.0000
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 23/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 2.2704e-04 - categorical_accuracy: 1.0000
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 24/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 2.1245e-04 - categorical_accuracy: 1.0000
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 25/100
# 26125/26125 [==============================] - 3s 100us/sample - loss: 1.9699e-04 - categorical_accuracy: 1.0000
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 26/100
# 26125/26125 [==============================] - 3s 100us/sample - loss: 1.8739e-04 - categorical_accuracy: 1.0000
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 27/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 1.7030e-04 - categorical_accuracy: 1.0000
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 28/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 1.6268e-04 - categorical_accuracy: 1.0000
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 29/100
# 26125/26125 [==============================] - 3s 100us/sample - loss: 1.5111e-04 - categorical_accuracy: 1.0000
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 30/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 1.4030e-04 - categorical_accuracy: 1.0000
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 31/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 1.3613e-04 - categorical_accuracy: 1.0000
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 32/100
# 26125/26125 [==============================] - 3s 100us/sample - loss: 1.3298e-04 - categorical_accuracy: 1.0000
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 33/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 1.3154e-04 - categorical_accuracy: 1.0000
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 34/100
# 26125/26125 [==============================] - 3s 100us/sample - loss: 1.2245e-04 - categorical_accuracy: 1.0000
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 35/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 1.1780e-04 - categorical_accuracy: 1.0000
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 36/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 1.1429e-04 - categorical_accuracy: 1.0000
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 37/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 1.0854e-04 - categorical_accuracy: 1.0000
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 38/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 1.0439e-04 - categorical_accuracy: 1.0000
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 39/100
# 26125/26125 [==============================] - 3s 100us/sample - loss: 9.7840e-05 - categorical_accuracy: 1.0000
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 40/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 9.2386e-05 - categorical_accuracy: 1.0000
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 41/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 8.9511e-05 - categorical_accuracy: 1.0000
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 42/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 8.6352e-05 - categorical_accuracy: 1.0000
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 43/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 8.6869e-05 - categorical_accuracy: 1.0000
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 44/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 8.2596e-05 - categorical_accuracy: 1.0000
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 45/100
# 26125/26125 [==============================] - 3s 100us/sample - loss: 8.1482e-05 - categorical_accuracy: 1.0000
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 46/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 7.7015e-05 - categorical_accuracy: 1.0000
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 47/100
# 26125/26125 [==============================] - 3s 100us/sample - loss: 7.5487e-05 - categorical_accuracy: 1.0000
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 48/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 7.2770e-05 - categorical_accuracy: 1.0000
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 49/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 7.1470e-05 - categorical_accuracy: 1.0000
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 50/100
# 26125/26125 [==============================] - 3s 100us/sample - loss: 6.6200e-05 - categorical_accuracy: 1.0000
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 51/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 6.5277e-05 - categorical_accuracy: 1.0000
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 52/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 6.3745e-05 - categorical_accuracy: 1.0000
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 53/100
# 26125/26125 [==============================] - 3s 100us/sample - loss: 6.2268e-05 - categorical_accuracy: 1.0000
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 54/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 6.1218e-05 - categorical_accuracy: 1.0000
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 55/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 6.0776e-05 - categorical_accuracy: 1.0000
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 56/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 5.9815e-05 - categorical_accuracy: 1.0000
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 57/100
# 26125/26125 [==============================] - 3s 100us/sample - loss: 5.7994e-05 - categorical_accuracy: 1.0000
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 58/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 5.5945e-05 - categorical_accuracy: 1.0000
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 59/100
# 26125/26125 [==============================] - 3s 100us/sample - loss: 5.3290e-05 - categorical_accuracy: 1.0000
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 60/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 5.3437e-05 - categorical_accuracy: 1.0000
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 61/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 5.2374e-05 - categorical_accuracy: 1.0000
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 62/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 5.3507e-05 - categorical_accuracy: 1.0000
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 63/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 5.0695e-05 - categorical_accuracy: 1.0000
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 64/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.9566e-05 - categorical_accuracy: 1.0000
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 65/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 5.0744e-05 - categorical_accuracy: 1.0000
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 66/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 5.0349e-05 - categorical_accuracy: 1.0000
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 67/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.8083e-05 - categorical_accuracy: 1.0000
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 68/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.7219e-05 - categorical_accuracy: 1.0000
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 69/100
# 26125/26125 [==============================] - 3s 100us/sample - loss: 4.8690e-05 - categorical_accuracy: 1.0000
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 70/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.6143e-05 - categorical_accuracy: 1.0000
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 71/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.6864e-05 - categorical_accuracy: 1.0000
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 72/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.5145e-05 - categorical_accuracy: 1.0000
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 73/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.5367e-05 - categorical_accuracy: 1.0000
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 74/100
# 26125/26125 [==============================] - 3s 100us/sample - loss: 4.5472e-05 - categorical_accuracy: 1.0000
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 75/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.5339e-05 - categorical_accuracy: 1.0000
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 76/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.5021e-05 - categorical_accuracy: 1.0000
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 77/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.3982e-05 - categorical_accuracy: 1.0000
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 78/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.7674e-05 - categorical_accuracy: 1.0000
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 79/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.4559e-05 - categorical_accuracy: 1.0000
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 80/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.4292e-05 - categorical_accuracy: 1.0000
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 81/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.4695e-05 - categorical_accuracy: 1.0000
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 82/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.3892e-05 - categorical_accuracy: 1.0000
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 83/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.4930e-05 - categorical_accuracy: 1.0000
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 84/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.3634e-05 - categorical_accuracy: 1.0000
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 85/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.4275e-05 - categorical_accuracy: 1.0000
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 86/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.2852e-05 - categorical_accuracy: 1.0000
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 87/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.3035e-05 - categorical_accuracy: 1.0000
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 88/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.2712e-05 - categorical_accuracy: 1.0000
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 89/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.3129e-05 - categorical_accuracy: 1.0000
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 90/100
# 26125/26125 [==============================] - 3s 100us/sample - loss: 4.3259e-05 - categorical_accuracy: 1.0000
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 91/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.3435e-05 - categorical_accuracy: 1.0000
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 92/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.3399e-05 - categorical_accuracy: 1.0000
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 93/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.3473e-05 - categorical_accuracy: 1.0000
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 94/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.3059e-05 - categorical_accuracy: 1.0000
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 95/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.1720e-05 - categorical_accuracy: 1.0000
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 96/100
# 26125/26125 [==============================] - 3s 100us/sample - loss: 4.3021e-05 - categorical_accuracy: 1.0000
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 97/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.2699e-05 - categorical_accuracy: 1.0000
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 98/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.2450e-05 - categorical_accuracy: 1.0000
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 99/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.2156e-05 - categorical_accuracy: 1.0000
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 1.0485760000000006e-07.
# Epoch 100/100
# 26125/26125 [==============================] - 3s 99us/sample - loss: 4.3544e-05 - categorical_accuracy: 1.0000
# 2375/2375 [==============================] - 0s 61us/sample
# (2375, 11)
# [[ 1  5  5  1  3  4  3  9  8  5  8  4  8 10  8  8  9  4  9  2  3  2  4  8
#    4  6  4  4  6  4  5  8  0  2  1  5  8  6  5  2  6  5  8  4 10  0  4  4
#   10  6  4  8  2  8  4  6  1  4  5  3  2  6  8  4  4  1  4  4  4  8  0  4
#    8  8 10  4  9  3  5  4  8  0  8  4  9  4  4  9  3  4  0 10  6  4  3  9
#    3  3  1  4]]
# (2375, 1)
# [[ 1  5  6  1  3  0  3  9 10  6 10  4  8 10  8  8  9  5  9  2  3  2  4  8
#    4  7  4  5  7  0  7  8  0  2  1  6 10  7  7  2  6  7  8  0 10  0  5  4
#   10  7  5  8  2  8  4  7  1  4  5  3  2  7  8  0  4  1  5  4  0  8  0  4
#    8  8 10  4  9  3  7  5  8  0  8  5  9  5  5  9  3  0  0 10  7  5  3  9
#    3  3  1  4]]
# 2375/2375 [==============================] - 0s 76us/sample - loss: 2.3270 - categorical_accuracy: 0.7074
# ##################################################################################################################################
# #####################################################  K-FOLD 4  ################################################################
# Training subjects: ['01', '02', '03', '08', '09', '10', '11', '13', '14', '16', '17']
# Test subject: 05
# Train dataset:
# (26125, 1, 128, 20) (26125, 11)
# Test dataset:
# (2375, 1, 128, 20) (2375, 11)
# Activity:  13
# Activity:  25
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 20)]      0
# ...
# Epoch 29/100
# 26125/26125 [==============================] - 3s 102us/sample - loss: 1.4549e-04 - categorical_accuracy: 1.0000
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 30/100
# 26125/26125 [==============================] - 3s 102us/sample - loss: 1.3436e-04 - categorical_accuracy: 1.0000
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 31/100
# 26125/26125 [==============================] - 3s 102us/sample - loss: 1.3287e-04 - categorical_accuracy: 1.0000
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 32/100
# 26125/26125 [==============================] - 3s 102us/sample - loss: 1.2625e-04 - categorical_accuracy: 1.0000
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 33/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 1.2552e-04 - categorical_accuracy: 1.0000
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 34/100
# 26125/26125 [==============================] - 3s 102us/sample - loss: 1.1763e-04 - categorical_accuracy: 1.0000
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 35/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 1.1137e-04 - categorical_accuracy: 1.0000
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 36/100
# 26125/26125 [==============================] - 3s 102us/sample - loss: 1.1022e-04 - categorical_accuracy: 1.0000
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 37/100
# 26125/26125 [==============================] - 3s 102us/sample - loss: 1.1318e-04 - categorical_accuracy: 1.0000
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 38/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 9.7943e-05 - categorical_accuracy: 1.0000
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 39/100
# 26125/26125 [==============================] - 3s 102us/sample - loss: 9.2804e-05 - categorical_accuracy: 1.0000
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 40/100
# 26125/26125 [==============================] - 3s 102us/sample - loss: 8.7316e-05 - categorical_accuracy: 1.0000
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 41/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 8.6652e-05 - categorical_accuracy: 1.0000
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 42/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 8.9202e-05 - categorical_accuracy: 1.0000
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 43/100
# 26125/26125 [==============================] - 3s 102us/sample - loss: 8.2385e-05 - categorical_accuracy: 1.0000
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 44/100
# 26125/26125 [==============================] - 3s 102us/sample - loss: 7.8711e-05 - categorical_accuracy: 1.0000
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 45/100
# 26125/26125 [==============================] - 3s 102us/sample - loss: 7.8744e-05 - categorical_accuracy: 1.0000
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 46/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 7.5267e-05 - categorical_accuracy: 1.0000
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 47/100
# 26125/26125 [==============================] - 3s 102us/sample - loss: 7.2043e-05 - categorical_accuracy: 1.0000
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 48/100
# 26125/26125 [==============================] - 3s 102us/sample - loss: 7.2060e-05 - categorical_accuracy: 1.0000
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 49/100
# 26125/26125 [==============================] - 3s 102us/sample - loss: 6.5818e-05 - categorical_accuracy: 1.0000
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 50/100
# 26125/26125 [==============================] - 3s 102us/sample - loss: 6.4621e-05 - categorical_accuracy: 1.0000
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 51/100
# 26125/26125 [==============================] - 3s 102us/sample - loss: 6.3075e-05 - categorical_accuracy: 1.0000
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 52/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 6.4915e-05 - categorical_accuracy: 1.0000
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 53/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 6.1964e-05 - categorical_accuracy: 1.0000
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 54/100
# 26125/26125 [==============================] - 3s 102us/sample - loss: 5.8717e-05 - categorical_accuracy: 1.0000
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 55/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 5.8134e-05 - categorical_accuracy: 1.0000
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 56/100
# 26125/26125 [==============================] - 3s 102us/sample - loss: 5.7383e-05 - categorical_accuracy: 1.0000
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 57/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 5.5424e-05 - categorical_accuracy: 1.0000
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 58/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 5.5070e-05 - categorical_accuracy: 1.0000
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 59/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 5.1631e-05 - categorical_accuracy: 1.0000
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 60/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 5.0905e-05 - categorical_accuracy: 1.0000
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 61/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 5.1684e-05 - categorical_accuracy: 1.0000
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 62/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 5.0229e-05 - categorical_accuracy: 1.0000
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 63/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 5.0292e-05 - categorical_accuracy: 1.0000
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 64/100
# 26125/26125 [==============================] - 3s 102us/sample - loss: 5.0170e-05 - categorical_accuracy: 1.0000
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 65/100
# 26125/26125 [==============================] - 3s 102us/sample - loss: 5.0970e-05 - categorical_accuracy: 1.0000
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 66/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 4.9325e-05 - categorical_accuracy: 1.0000
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 67/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 4.6879e-05 - categorical_accuracy: 1.0000
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 68/100
# 26125/26125 [==============================] - 3s 102us/sample - loss: 4.6892e-05 - categorical_accuracy: 1.0000
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 69/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 4.5955e-05 - categorical_accuracy: 1.0000
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 70/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 4.6560e-05 - categorical_accuracy: 1.0000
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 71/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 4.5633e-05 - categorical_accuracy: 1.0000
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 72/100
# 26125/26125 [==============================] - 3s 102us/sample - loss: 4.5839e-05 - categorical_accuracy: 1.0000
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 73/100
# 26125/26125 [==============================] - 3s 102us/sample - loss: 4.3940e-05 - categorical_accuracy: 1.0000
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 74/100
# 26125/26125 [==============================] - 3s 102us/sample - loss: 4.4008e-05 - categorical_accuracy: 1.0000
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 75/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 4.4139e-05 - categorical_accuracy: 1.0000
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 76/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 4.4553e-05 - categorical_accuracy: 1.0000
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 77/100
# 26125/26125 [==============================] - 3s 102us/sample - loss: 4.3496e-05 - categorical_accuracy: 1.0000
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 78/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 4.3541e-05 - categorical_accuracy: 1.0000
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 79/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 4.3545e-05 - categorical_accuracy: 1.0000
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 80/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 4.3275e-05 - categorical_accuracy: 1.0000
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 81/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 4.2855e-05 - categorical_accuracy: 1.0000
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 82/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 4.1768e-05 - categorical_accuracy: 1.0000
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 83/100
# 26125/26125 [==============================] - 3s 102us/sample - loss: 4.3338e-05 - categorical_accuracy: 1.0000
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 84/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 4.2673e-05 - categorical_accuracy: 1.0000
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 85/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 4.1331e-05 - categorical_accuracy: 1.0000
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 86/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 4.1394e-05 - categorical_accuracy: 1.0000
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 87/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 4.2999e-05 - categorical_accuracy: 1.0000
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 88/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 4.2558e-05 - categorical_accuracy: 1.0000
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 89/100
# 26125/26125 [==============================] - 3s 102us/sample - loss: 4.1086e-05 - categorical_accuracy: 1.0000
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 90/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 4.2850e-05 - categorical_accuracy: 1.0000
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 91/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 4.1528e-05 - categorical_accuracy: 1.0000
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 92/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 4.2025e-05 - categorical_accuracy: 1.0000
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 93/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 4.0735e-05 - categorical_accuracy: 1.0000
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 94/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 4.1965e-05 - categorical_accuracy: 1.0000
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 95/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 4.1419e-05 - categorical_accuracy: 1.0000
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 96/100
# 26125/26125 [==============================] - 3s 102us/sample - loss: 4.2077e-05 - categorical_accuracy: 1.0000
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 97/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 4.0929e-05 - categorical_accuracy: 1.0000
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 98/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 4.0529e-05 - categorical_accuracy: 1.0000
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 99/100
# 26125/26125 [==============================] - 3s 103us/sample - loss: 4.0835e-05 - categorical_accuracy: 1.0000
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 1.0485760000000006e-07.
# Epoch 100/100
# 26125/26125 [==============================] - 3s 102us/sample - loss: 4.0294e-05 - categorical_accuracy: 1.0000
# 2375/2375 [==============================] - 0s 91us/sample
# (2375, 11)
# [[ 0  5  4  4  9  0  2 10  9  0  1  5  8  9  9  6  5  3  5  5  2 10  5  8
#    2  8  0  5  0  8 10  5  5  5  8  5  9  5  8 10  3  5  5 10 10  3  2 10
#    7  8  5  5  8  0  4  5  8  5  5  1  4  8  5  5  8  0  3  8  0  1  2  5
#    7 10  0  5  8  9  5  0  7  0  5  8  2  9  7  8  0  5  4  9  8  4  8 10
#    0  5  2  8]]
# (2375, 1)
# [[ 0  5  4  4  9  0  2 10  9  0  1  5  3  9  9  5  5  6  5  4  2 10  6  8
#    2  3  0  4  1  3 10  5  5  4  3  4  9  7  8 10  6  6  5 10 10  6  2 10
#    7  3  4  4  8  1  4  5  3  7  5  1  4  3  7  5  3  0  6  8  1  4  2  6
#    7 10  0  5  8  9  7  0  7  0  6  8  2  9  7  3  1  5  4  9  8  4  3 10
#    1  5  2  3]]
# 2375/2375 [==============================] - 0s 111us/sample - loss: 2.5201 - categorical_accuracy: 0.6518

# %% [markdown]
# # Accuracy

# %%
sum = 0

for acc in accuracies:
    sum += acc

print('Accuracy of K-Fold: ' + str(sum/12))
# Out:
# Accuracy of K-Fold: 0.7110526363054911
