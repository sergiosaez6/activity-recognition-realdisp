# %% [markdown]
# # CNN

# %%
import tensorflow.keras as keras

# %%
# Módulos necesarios. Asegurarse de poder importarlos.
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from pylab import rcParams
from scipy import stats
from sklearn import metrics
import seaborn as sns
from sklearn import preprocessing
import os as os
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
from time import time

# Config the matplotlib backend as plotting inline in IPython
# %matplotlib inline

# %%
import sys
print(sys.executable)
print(sys.version)
print(sys.version_info)
tf.__version__
# Out:
# /usr/bin/python
# 3.6.8 (default, Aug 20 2019, 17:12:48)
# [GCC 8.3.0]
# sys.version_info(major=3, minor=6, micro=8, releaselevel='final', serial=0)
# '1.14.0'

# %%
keras.__version__
# Out:
# '2.2.4-tf'

# %% [markdown]
# # 12-FOLD

# %%
subjects = ['01', '02', '03', '05', '08', '09', '10', '11', '13', '14', '16', '17']
global activities
activities = [9,10,11,12,13,19,20,21,24,25,31]

# %%
# Ajustado a los datos
n_time_steps = 128
n_classes = 11 # Nº de clases (el 0 está eliminado)
n_channels = 1 # Nº de canales
n_columns = 40

# Podríamos variarlo
batch_size = 128 # Tamaño del batch
learning_rate = 9e-4 # Learning rate (por defecto es 0.001)
epochs = 100 # Épocas

# %%
class LearningRateDecay:
    def plot(self, epochs, title="Learning Rate Schedule"):
        # compute the set of learning rates for each corresponding
        # epoch
        lrs = [self(i) for i in epochs]
 
        # the learning rate schedule
        plt.style.use("ggplot")
        plt.figure()
        plt.plot(epochs, lrs)
        plt.title(title)
        plt.xlabel("Epoch #")
        plt.ylabel("Learning Rate")
class StepDecay(LearningRateDecay):
    def __init__(self, initAlpha=0.01, factor=0.25, dropEvery=10):
        # store the base initial learning rate, drop factor, and
        # epochs to drop every
        self.initAlpha = initAlpha
        self.factor = factor
        self.dropEvery = dropEvery
 
    def __call__(self, epoch):
        # compute the learning rate for the current epoch
        exp = np.floor((1 + epoch) / self.dropEvery)
        alpha = self.initAlpha * (self.factor ** exp)
        if(alpha<1e-9):
            alpha=1e-9

        # return the learning rate
        return float(alpha) 

schedule = StepDecay(initAlpha=learning_rate, factor=0.8, dropEvery=10)

reduce_lr = keras.callbacks.LearningRateScheduler(schedule, verbose = 1)
callbacks_list = [reduce_lr]

# %%
#Visualize training evolution
def plot_curves(model, acc, loss, val_acc, val_loss, subject_test):
    #########################################################################################
    # LOSS plot
    plt.figure(figsize=(12,8))
    plt.plot(model.history.history[loss], label='Training loss')
    plt.xlabel('Epochs', fontsize=15)
    plt.ylabel('Loss', fontsize=15)
    plt.tick_params(labelsize=10)
    plt.legend(loc=1,prop={'size': 10})
    plt.title('Loss in trainnig', fontsize=20)
    fig = plt.gcf()
    plt.show()
    
    fig.savefig('./01AUGNORMFFT_SP_KFOLD_models/loss_train_01AUGNORMFFT_SP_KFOLD_'+subject_test+'.pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./01AUGNORMFFT_SP_KFOLD_models/loss_train_01AUGNORMFFT_SP_KFOLD_'+subject_test+'svg', bbox_inches='tight',format='svg')
    
    #########################################################################################
    # ACC plot
    plt.figure(figsize=(12,8))
    plt.plot(model.history.history[acc], label='Training accuracy')
    plt.xlabel('Epochs', fontsize=15)
    plt.ylabel('Accuracy', fontsize=15)
    plt.tick_params(labelsize=10)
    plt.legend(loc=1,prop={'size': 10})
    plt.title('Accuracy in training', fontsize=20)
    fig = plt.gcf()
    plt.show()

    fig.savefig('./01AUGNORMFFT_SP_KFOLD_models/acc_train_01AUGNORMFFT_SP_KFOLD_'+subject_test+'pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./01AUGNORMFFT_SP_KFOLD_models/acc_train_01AUGNORMFFT_SP_KFOLD_'+subject_test+'svg', bbox_inches='tight',format='svg')
    
    #########################################################################################
    # ACC+LOSS plot
    plt.figure(figsize=(14,10))
    plt_loss = host_subplot(111, axes_class=AA.Axes)
    plt.subplots_adjust(right=0.75)

    plt_acc = plt_loss.twinx()
    plt_acc.axis["right"].toggle(all=True)
    
    plt_loss.set_xlim(0, len(model.history.history[loss]))
    plt_loss.set_ylim(0, max(model.history.history[loss]))
    plt_loss.set_xlabel('Epochs')
    plt_loss.set_ylabel('Loss')
    plt_acc.set_ylabel('Accuracy')
                        
    plt_loss.axis['left'].label.set_fontsize(15)
    plt_loss.axis['bottom'].label.set_fontsize(15)
    plt_acc.axis['right'].label.set_fontsize(15)
    
    plt_loss.plot(model.history.history[loss], c='tab:blue', ls='--', label='Training loss')
    plt_acc.plot(model.history.history[acc], c='tab:orange',ls='--', label='Training accuracy')
    
    plt.tick_params(labelsize=10)
    plt.title('Training performance', fontsize=20)
    plt_acc.set_ylim(0, 1)
    plt_loss.legend(loc=1, prop={'size': 10})
    
    fig = plt.gcf()
    plt.show()

    fig.savefig('./01AUGNORMFFT_SP_KFOLD_models/all_train_01AUGNORMFFT_SP_KFOLD_'+subject_test+'pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./01AUGNORMFFT_SP_KFOLD_models/all_train_01AUGNORMFFT_SP_KFOLD_'+subject_test+'svg', bbox_inches='tight',format='svg')

# %%
def plot_confusion_matrix(y_true, y_pred, subject_test, classes,
                          cmap=plt.cm.Blues):

    # Compute confusion matrix
    cm = metrics.confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(20, 20))
    sns.heatmap(cm, xticklabels=classes, yticklabels=classes, square = True, robust = True, annot=True, cmap='YlOrBr')
    plt.title('CONFUSION MATRIX')
    plt.ylabel('TRUE ACTIVITY')
    plt.xlabel('PREDICTION')
    
    locs, labels = plt.xticks()
    plt.xticks(locs, labels, rotation='vertical')
    locs, labels = plt.yticks()
    plt.yticks(locs, labels, rotation='horizontal')

    # Guardamos la imagen en formato vectorial
    plt.draw()
    plt.savefig('./01AUGNORMFFT_SP_KFOLD_models/matriz_confusion_'+subject_test+'.svg', bbox_inches='tight',format='svg')
    plt.show()

# %%
accuracies = []
for i in range(12):
    print('##################################################################################################################################')
    print('#####################################################  K-FOLD %d  ################################################################'%(i+1))
    
    subject_test = subjects[i]
    subjects_train = [s for s in subjects if s not in subject_test]
    print('Training subjects: ' + str(subjects_train))
    print('Test subject: ' + str(subject_test))
    
    ##  GENERACIÓN DATASET
    tr_seg = np.concatenate((np.load('./augment_norm/subject_'+subjects_train[0]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[1]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[2]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[3]+'_seg.npy'),
                             np.load('./augment_norm/subject_'+subjects_train[4]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[5]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[6]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[7]+'_seg.npy'),
                             np.load('./augment_norm/subject_'+subjects_train[8]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[9]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[10]+'_seg.npy')))
    
    tr_lab = np.concatenate((np.load('./augment_norm/subject_'+subjects_train[0]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[1]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[2]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[3]+'_lab.npy'),
                             np.load('./augment_norm/subject_'+subjects_train[4]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[5]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[6]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[7]+'_lab.npy'),
                             np.load('./augment_norm/subject_'+subjects_train[8]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[9]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[10]+'_lab.npy')))

    ts_seg = np.load('./augment_norm/subject_'+subject_test+'_seg.npy')
    ts_lab = np.load('./augment_norm/subject_'+subject_test+'_lab.npy')
    
    limit = 40
    tr_seg = tr_seg[:,:,:,:limit]
    ts_seg = ts_seg[:,:,:,:limit]
    ####################################################################################################################
    ## SHUFFLE DE DATOS
    np.random.seed(235)
    tr_seg = np.reshape(tr_seg[np.random.shuffle(np.arange(0,tr_seg.shape[0]))], (11*2375,1,128,limit))
    tr_lab = np.reshape(tr_lab[np.random.shuffle(np.arange(0,tr_seg.shape[0]))], (11*2375,11))

    np.random.seed(235)
    ts_seg = np.reshape(ts_seg[np.random.shuffle(np.arange(0,ts_seg.shape[0]))], (2375,1,128,limit))
    ts_lab = np.reshape(ts_lab[np.random.shuffle(np.arange(0,ts_seg.shape[0]))], (2375,11))
    
    print('Train dataset: ')
    print(tr_seg.shape, tr_lab.shape)
    print('Test dataset: ')
    print(ts_seg.shape, ts_lab.shape)
    ####################################################################################################################
    ## VISTA DE DFT-2D
    plt.figure(figsize=(30,30))
    plt.imshow(np.log(np.abs(np.fft.fftshift(tr_seg[0,0,:,20:40].T))**2))
    plt.show()
    print('Activity: ',activities[np.argmax(tr_lab[0])])

    plt.figure(figsize=(30,30))
    plt.imshow(np.log(np.fft.fftshift(tr_seg[10,0,:,20:40].T)**2))
    plt.show()
    print('Activity: ',activities[np.argmax(tr_lab[10])])
    ####################################################################################################################
    ## RED
    quat_input = keras.Input(shape=(n_channels, n_time_steps, n_columns), name='input_layer')

    # Initializer
    #initializer = RandomNormal(mean=0.0, stddev=0.02)

    # Some convolutional layers
    conv_1 = keras.layers.Conv2D(16, activation='relu', kernel_size=4,padding='same',strides=1,data_format='channels_first')(quat_input)#, kernel_initializer=initializer)(quat_input)
    max_1 = keras.layers.MaxPooling2D(pool_size=2, strides=2, padding='same', data_format = 'channels_first')(conv_1)
    bn_1 = keras.layers.BatchNormalization(axis=1)(max_1)

    conv_2 = keras.layers.Conv2D(32, activation='relu', kernel_size=4,padding='same',strides=1,data_format='channels_first')(bn_1)#, kernel_initializer=initializer)(max_1)
    max_2 = keras.layers.MaxPooling2D(pool_size=2, strides=2, padding='same', data_format = 'channels_first')(conv_2)
    bn_2 = keras.layers.BatchNormalization(axis=1)(max_2)

    conv_3 = keras.layers.Conv2D(64, activation='relu', kernel_size=4,padding='same',strides=1,data_format='channels_first')(bn_2)#, kernel_initializer=initializer)(re_2)
    max_3 = keras.layers.MaxPooling2D(pool_size=2, strides=2, padding='same', data_format = 'channels_first')(conv_3)
    bn_3 = keras.layers.BatchNormalization(axis=1)(max_3)

    conv_4 = keras.layers.Conv2D(128, activation='relu', kernel_size=4,padding='same',strides=1,data_format='channels_first')(bn_3)#, kernel_initializer=initializer)(re_2)
    max_4 = keras.layers.MaxPooling2D(pool_size=2, strides=2, padding='same', data_format = 'channels_first')(conv_4)
    bn_4 = keras.layers.BatchNormalization(axis=1)(max_4)

    # Flatten the output of the convolutional layers
    conv_flat = keras.layers.Flatten()(bn_4)

    dr_2 = keras.layers.Dropout(0.5)(conv_flat)

    # Output layers: separate outputs for the weather and the ground labels
    multiclass_output = keras.layers.Dense(n_classes, activation='softmax',name='activity_class')(dr_2)

    # Creamos la estrcutura que contendrá a nuestro modelo
    model = keras.Model(inputs=quat_input, outputs=[multiclass_output],name='cnn')

    # Compilamos el modelo
    model.compile(optimizer=keras.optimizers.Adam(lr=learning_rate),
                  loss='categorical_crossentropy', metrics=['categorical_accuracy'])
    
    print(model.summary())
    ####################################################################################################################
    ## TRAIN
    history = model.fit(tr_seg,
                        tr_lab,
                        epochs = epochs,
                        steps_per_epoch = None,
                        verbose = 1,
                        batch_size = batch_size,
                        callbacks = callbacks_list)
    model.save('./01AUGNORMFFT_SP_KFOLD_models/CNN_'+subject_test+'.h5')
    
    #Visualize training evolution
    plot_curves(model, 'categorical_accuracy', 'loss', 'val_categorical_accuracy', 'val_loss', subject_test)
    ####################################################################################################################
    ## TEST
    predictions = model.predict(ts_seg, batch_size = batch_size, verbose = 1)
    
    print(predictions.shape)
    
    y_pred = np.argmax(predictions,axis=-1)
    y_pred = np.expand_dims(y_pred,axis=-1)
    print(y_pred[:100].T)
    
    y_true = np.argmax(ts_lab,axis=-1)
    y_true = np.expand_dims(y_true,axis=-1)
    print(y_true.shape)
    print(y_true[:100].T)
    
    evaluation = model.evaluate(ts_seg, ts_lab, batch_size=batch_size, verbose=1)
    accuracies.append(evaluation[1])
    
    fo = open('./01AUGNORMFFT_SP_KFOLD_models/accuracy_'+subject_test+'.txt', "w")
    fo.seek(0,2)
    fo.write(str(evaluation))
    fo.close()
    
    ####################################################################################################################
    ## CONFUSION MATRIX
    y_true_flat = np.ndarray.flatten(y_true)
    y_pred_flat = np.ndarray.flatten(y_pred)
    
    plot_confusion_matrix(y_true_flat, y_pred_flat, subject_test, classes=activities)
    
    del subject_test, subjects_train, limit, tr_seg, tr_lab, ts_seg, ts_lab, model, history, y_pred, y_true, predictions, evaluation, y_true_flat, y_pred_flat
# Out:
# ##################################################################################################################################
# #####################################################  K-FOLD 1  ################################################################
# Training subjects: ['02', '03', '05', '08', '09', '10', '11', '13', '14', '16', '17']
# Test subject: 01
# Train dataset:
# (26125, 1, 128, 40) (26125, 11)
# Test dataset:
# (2375, 1, 128, 40) (2375, 11)
# Activity:  20
# Activity:  25
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 40)]      0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 16, 128, 40)       272
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 64, 20)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 16, 64, 20)        64
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 64, 20)        8224
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 10)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 10)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 32, 10)        32832
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 64, 16, 5)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64, 16, 5)         256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 128, 16, 5)        131200
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 128,
100
# 26125/26125 [==============================] - 6s 232us/sample - loss: 4.3712e-06 - categorical_accuracy: 1.0000
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 0.00015099494400000007.
# Epoch 81/100
# 26125/26125 [==============================] - 6s 232us/sample - loss: 4.1642e-06 - categorical_accuracy: 1.0000
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 0.00015099494400000007.
# Epoch 82/100
# 26125/26125 [==============================] - 6s 232us/sample - loss: 3.0951e-06 - categorical_accuracy: 1.0000
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 0.00015099494400000007.
# Epoch 83/100
# 26125/26125 [==============================] - 6s 232us/sample - loss: 2.6517e-06 - categorical_accuracy: 1.0000
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 0.00015099494400000007.
# Epoch 84/100
# 26125/26125 [==============================] - 6s 232us/sample - loss: 1.1299e-05 - categorical_accuracy: 1.0000
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 0.00015099494400000007.
# Epoch 85/100
# 26125/26125 [==============================] - 6s 232us/sample - loss: 4.8761e-06 - categorical_accuracy: 1.0000
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 0.00015099494400000007.
# Epoch 86/100
# 26125/26125 [==============================] - 6s 232us/sample - loss: 5.5814e-06 - categorical_accuracy: 1.0000
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 0.00015099494400000007.
# Epoch 87/100
# 26125/26125 [==============================] - 6s 232us/sample - loss: 4.7891e-06 - categorical_accuracy: 1.0000
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 0.00015099494400000007.
# Epoch 88/100
# 26125/26125 [==============================] - 6s 232us/sample - loss: 2.9836e-06 - categorical_accuracy: 1.0000
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 0.00015099494400000007.
# Epoch 89/100
# 26125/26125 [==============================] - 6s 231us/sample - loss: 1.8710e-06 - categorical_accuracy: 1.0000
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 0.00012079595520000005.
# Epoch 90/100
# 26125/26125 [==============================] - 6s 232us/sample - loss: 3.8190e-06 - categorical_accuracy: 1.0000
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 0.00012079595520000005.
# Epoch 91/100
# 26125/26125 [==============================] - 6s 232us/sample - loss: 1.8825e-06 - categorical_accuracy: 1.0000
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 0.00012079595520000005.
# Epoch 92/100
# 26125/26125 [==============================] - 6s 232us/sample - loss: 3.0778e-06 - categorical_accuracy: 1.0000
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 0.00012079595520000005.
# Epoch 93/100
# 26125/26125 [==============================] - 6s 232us/sample - loss: 4.2313e-06 - categorical_accuracy: 1.0000
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 0.00012079595520000005.
# Epoch 94/100
# 26125/26125 [==============================] - 6s 232us/sample - loss: 4.2965e-04 - categorical_accuracy: 0.9999
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 0.00012079595520000005.
# Epoch 95/100
# 26125/26125 [==============================] - 6s 232us/sample - loss: 9.6689e-06 - categorical_accuracy: 1.0000
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 0.00012079595520000005.
# Epoch 96/100
# 26125/26125 [==============================] - 6s 232us/sample - loss: 6.7926e-06 - categorical_accuracy: 1.0000
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 0.00012079595520000005.
# Epoch 97/100
# 26125/26125 [==============================] - 6s 232us/sample - loss: 5.8533e-06 - categorical_accuracy: 1.0000
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 0.00012079595520000005.
# Epoch 98/100
# 26125/26125 [==============================] - 6s 231us/sample - loss: 3.6727e-06 - categorical_accuracy: 1.0000
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 0.00012079595520000005.
# Epoch 99/100
# 26125/26125 [==============================] - 6s 232us/sample - loss: 3.1340e-06 - categorical_accuracy: 1.0000
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 9.663676416000005e-05.
# Epoch 100/100
# 26125/26125 [==============================] - 6s 232us/sample - loss: 3.3619e-06 - categorical_accuracy: 1.0000
# 2375/2375 [==============================] - 0s 154us/sample
# (2375, 11)
# [[ 4 10  3  4  5 10  4  8  4  7  9 10  8  4  8  5  1  5  5  1  9 10 10  4
#    3  9  2  4  0  0  9  4  0  5  5 10  4  5  5  9  8  8  9  1  1  7  6  7
#    1  1  4  5  2  4  2  8  2  5  4  8  2  3  0  9  0 10  5  9  7 10  5  1
#    5  7  5  2  2  8  1  9  7 10 10  1  1  6  3  3  1  1  9  4  0  0 10  3
#    9  0  4  2]]
# (2375, 1)
# [[ 4 10  3  4  5 10  4  8  4  7  9 10  8  4  8  5  1  5  5  1  9 10 10  4
#    3  9  2  4  0  0  9  4  0  5  5 10  4  5  6  9  8  8  9  1  1  7  6  7
#    1  1  4  6  2  4  2  8  2  6  4  8  2  3  0  9  0 10  5  9  7 10  6  1
#    6  7  5  2  2  8  1  9  7 10 10  1  1  6  3  3  1  1  9  4  0  0 10  1
#    9  0  4  2]]
# 2375/2375 [==============================] - 0s 166us/sample - loss: 0.7602 - categorical_accuracy: 0.9335
# ##################################################################################################################################
# #####################################################  K-FOLD 2  ################################################################
# Training subjects: ['01', '03', '05', '08', '09', '10', '11', '13', '14', '16', '17']
# Test subject: 02
# Train dataset:
# (26125, 1, 128, 40) (26125, 11)
# Test dataset:
# (2375, 1, 128, 40) (2375, 11)
# Activity:  13
# Activity:  25
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 40)]      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 128, 40)       272
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 64, 20)        0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 64, 20)        64
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 64, 20)        8224
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 32, 32, 10)        0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32, 32, 10)        128
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 64, 32, 10)        32832
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 64, 16, 5)         0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 64, 16, 5)         256
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 128, 16, 5)        131200
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 128, 8, 3)         0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 128, 8, 3)         512
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3072)              0
# _________________________________________________________________
# activity_class (Dense)       (None, 11)                33803
# =================================================================
# Total params: 207,291
# Trainable params: 206,811
# Non-trainable params: 480
# _________________________________________________________________
# None
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 1/100
# 26125/26125 [==============================] - 7s 263us/sample - loss: 0.3158 - categorical_accuracy: 0.9038
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 2/100
# 26125/26125 [==============================] - 6s 235us/sample - loss: 0.0040 - categorical_accuracy: 0.9997
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 3/100
# 26125/26125 [==============================] - 6s 235us/sample - loss: 0.0012 - categorical_accuracy: 1.0000
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 4/100
# 26125/26125 [==============================] - 6s 236us/sample - loss: 5.1768e-04 - categorical_accuracy: 1.0000
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 5/100
# 26125/26125 [==============================] - 6s 235us/sample - loss: 4.8033e-04 - categorical_accuracy: 1.0000
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 6/100
# 26125/26125 [==============================] - 6s 235us/sample - loss: 2.5392e-04 - categorical_accuracy: 1.0000
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 7/100
# 26125/26125 [==============================] - 6s 236us/sample - loss: 1.2115e-04 - categorical_accuracy: 1.0000
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 8/100
# 26125/26125 [==============================] - 6s 236us/sample - loss: 1.2321e-04 - categorical_accuracy: 1.0000
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 9/100
# 26125/26125 [==============================] - 6s 236us/sample - loss: 0.0469 - categorical_accuracy: 0.9841
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 10/100
# 26125/26125 [==============================] - 6s 236us/sample - loss: 0.0030 - categorical_accuracy: 0.9993
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 11/100
# 26125/26125 [==============================] - 6s 236us/sample - loss: 1.7397e-04 - categorical_accuracy: 1.0000
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 12/100
# 26125/26125 [==============================] - 6s 237us/sample - loss: 1.3159e-04 - categorical_accuracy: 1.0000
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 13/100
# 26125/26125 [==============================] - 6s 236us/sample - loss: 8.4564e-05 - categorical_accuracy: 1.0000
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 14/100
# 26125/26125 [==============================] - 6s 236us/sample - loss: 5.3160e-05 - categorical_accuracy: 1.0000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 15/100
# 26125/26125 [==============================] - 6s 237us/sample - loss: 5.1955e-05 - categorical_accuracy: 1.0000
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 16/100
# 26125/26125 [==============================] - 6s 236us/sample - loss: 6.4977e-05 - categorical_accuracy: 1.0000
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 17/100
# 26125/26125 [==============================] - 6s 237us/sample - loss: 3.9073e-05 - categorical_accuracy: 1.0000
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 18/100
# 26125/26125 [==============================] - 6s 236us/sample - loss: 5.8171e-05 - categorical_accuracy: 1.0000
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 19/100
# 26125/26125 [==============================] - 6s 236us/sample - loss: 4.9874e-05 - categorical_accuracy: 1.0000
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 20/100
# 26125/26125 [==============================] - 6s 236us/sample - loss: 2.4249e-05 - categorical_accuracy: 1.0000
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 21/100
# 26125/26125 [==============================] - 6s 236us/sample - loss: 2.5972e-05 - categorical_accuracy: 1.0000
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 22/100
# 26125/26125 [==============================] - 6s 236us/sample - loss: 1.0669e-04 - categorical_accuracy: 1.0000
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 23/100
# 26125/26125 [==============================] - 6s 237us/sample - loss: 2.5138e-05 - categorical_accuracy: 1.0000
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 24/100
# 26125/26125 [==============================] - 6s 236us/sample - loss: 1.9827e-05 - categorical_accuracy: 1.0000
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 25/100
# 26125/26125 [==============================] - 6s 237us/sample - loss: 0.0194 - categorical_accuracy: 0.9940
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 26/100
# 26125/26125 [==============================] - 6s 237us/sample - loss:
- categorical_accuracy: 1.0000
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 9.663676416000005e-05.
# Epoch 100/100
# 26125/26125 [==============================] - 6s 235us/sample - loss: 1.1102e-06 - categorical_accuracy: 1.0000
# 2375/2375 [==============================] - 0s 145us/sample
# (2375, 11)
# [[ 1  5  7  1  3  1  3  8 10  6 10  4  8 10  8  8  9  5  9  2  3  2  4  8
#    4  7  4  5  7  0  7  8  0  2  1  7 10  7  7  2  7  7  8  0 10  0  5  4
#   10  7  5  8  2  8  4  7  1  4  5  3  2  7  8  1  4  1  5  4  0  8  0  4
#    8  8 10  4  8  3  7  5  8  0  8  5  9  5  5  8  3  1  1 10  7  5  3  9
#    3  3  1  4]]
# (2375, 1)
# [[ 1  5  6  1  3  0  3  9 10  6 10  4  8 10  8  8  9  5  9  2  3  2  4  8
#    4  7  4  5  7  0  7  8  0  2  1  6 10  7  7  2  6  7  8  0 10  0  5  4
#   10  7  5  8  2  8  4  7  1  4  5  3  2  7  8  0  4  1  5  4  0  8  0  4
#    8  8 10  4  9  3  7  5  8  0  8  5  9  5  5  9  3  0  0 10  7  5  3  9
#    3  3  1  4]]
# 2375/2375 [==============================] - 0s 158us/sample - loss: 0.4821 - categorical_accuracy: 0.8863
# ##################################################################################################################################
# #####################################################  K-FOLD 4  ################################################################
# Training subjects: ['01', '02', '03', '08', '09', '10', '11', '13', '14', '16', '17']
# Test subject: 05
# Train dataset:
# (26125, 1, 128, 40) (26125, 11)
# Test dataset:
# (2375, 1, 128, 40) (2375, 11)
# Activity:  13
# Activity:  25
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 40)]      0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 16, 128, 40)       272
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 16, 64, 20)        0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 16, 64, 20)        64
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 32, 64, 20)        8224
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 32, 32, 10)        0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 32, 32, 10)        128
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 64, 32, 10)        32832
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 64, 16, 5)         0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 64, 16, 5)         256
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 128, 16, 5)        131200
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 128, 8, 3)         0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 128, 8, 3)         512
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 3072)              0
# _________________________________________________________________
# activity_class (Dense)       (None, 11)                33803
# =================================================================
# Total params: 207,291
# Trainable params: 206,811
# Non-trainable params: 480
# _________________________________________________________________
# None
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 1/100
# 26125/26125 [==============================] - 7s 252us/sample - loss: 0.3117 - categorical_accuracy: 0.9022
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 2/100
# 26125/26125 [==============================] - 6s 234us/sample - loss: 0.0033 - categorical_accuracy: 0.9997
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 3/100
# 26125/26125 [==============================] - 6s 233us/sample - loss: 0.0017 - categorical_accuracy: 0.9998
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 4/100
# 26125/26125 [==============================] - 6s 234us/sample - loss: 6.3900e-04 - categorical_accuracy: 1.0000
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 5/100
# 26125/26125 [==============================] - 6s 234us/sample - loss: 0.0253 - categorical_accuracy: 0.9918
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 6/100
# 26125/26125 [==============================] - 6s 234us/sample - loss: 0.0033 - categorical_accuracy: 0.9991
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 7/100
# 26125/26125 [==============================] - 6s 235us/sample - loss: 2.5847e-04 - categorical_accuracy: 1.0000
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 8/100
# 26125/26125 [==============================] - 6s 235us/sample - loss: 7.5804e-05 - categorical_accuracy: 1.0000
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 9/100
# 26125/26125 [==============================] - 6s 235us/sample - loss: 5.5761e-05 - categorical_accuracy: 1.0000
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 10/100
# 26125/26125 [==============================] - 6s 235us/sample - loss: 4.9266e-05 - categorical_accuracy: 1.0000
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 11/100
# 26125/26125 [==============================] - 6s 235us/sample - loss: 3.3784e-05 - categorical_accuracy: 1.0000
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 12/100
# 26125/26125 [==============================] - 6s 235us/sample - loss: 4.1208e-05 - categorical_accuracy: 1.0000
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 13/100
# 26125/26125 [==============================] - 6s 235us/sample - loss: 3.4011e-05 - categorical_accuracy: 1.0000
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 14/100
# 26125/26125 [==============================] - 6s 236us/sample - loss: 2.1804e-05 - categorical_accuracy: 1.0000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 15/100
# 26125/26125 [==============================] - 6s 235us/sample - loss: 2.0403e-05 - categorical_accuracy: 1.0000
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 16/100
# 26125/26125 [==============================] - 6s 236us/sample - loss: 0.0049 - categorical_accuracy: 0.9985
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 17/100
# 26125/26125 [==============================] - 6s 235us/sample - loss: 0.0330 - categorical_accuracy: 0.9891
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 18/100
# 26125/26125 [==============================] - 6s 235us/sample - loss: 7.6096e-04 - categorical_accuracy: 0.9997
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 19/100
# 22400/26125 [========================>.....] - ETA: 0s - loss: 5.4935e-04 - categorical_accuracy: 0.9999

# %% [markdown]
# # Accuracy

# %%
sum = 0
for acc in accuracies:
    sum += acc
print('Accuracy of K-Fold: ' + str(sum/12))
# Out:
# Accuracy of K-Fold: 0.9394736886024475
