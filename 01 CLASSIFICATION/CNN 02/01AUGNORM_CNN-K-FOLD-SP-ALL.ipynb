# %% [markdown]
# # CNN

# %%
import tensorflow.keras as keras

# %%
# Módulos necesarios. Asegurarse de poder importarlos.
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from pylab import rcParams
from scipy import stats
from sklearn import metrics
import seaborn as sns
from sklearn import preprocessing
import os as os
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
from time import time

# Config the matplotlib backend as plotting inline in IPython
# %matplotlib inline

# %%
import sys
print(sys.executable)
print(sys.version)
print(sys.version_info)
tf.__version__
# Out:
# /usr/bin/python
# 3.6.8 (default, Aug 20 2019, 17:12:48)
# [GCC 8.3.0]
# sys.version_info(major=3, minor=6, micro=8, releaselevel='final', serial=0)
# '1.14.0'

# %%
keras.__version__
# Out:
# '2.2.4-tf'

# %% [markdown]
# # 12-FOLD

# %%
subjects = ['01', '02', '03', '05', '08', '09', '10', '11', '13', '14', '16', '17']
global activities
activities = [9,10,11,12,13,19,20,21,24,25,31]

# %%
# Ajustado a los datos
n_time_steps = 128
n_classes = 11 # Nº de clases (el 0 está eliminado)
n_channels = 1 # Nº de canales
n_columns = 20

# Podríamos variarlo
batch_size = 128 # Tamaño del batch
learning_rate = 9e-4 # Learning rate (por defecto es 0.001)
epochs = 100 # Épocas

# %%
class LearningRateDecay:
    def plot(self, epochs, title="Learning Rate Schedule"):
        # compute the set of learning rates for each corresponding
        # epoch
        lrs = [self(i) for i in epochs]
 
        # the learning rate schedule
        plt.style.use("ggplot")
        plt.figure()
        plt.plot(epochs, lrs)
        plt.title(title)
        plt.xlabel("Epoch #")
        plt.ylabel("Learning Rate")
class StepDecay(LearningRateDecay):
    def __init__(self, initAlpha=0.01, factor=0.25, dropEvery=10):
        # store the base initial learning rate, drop factor, and
        # epochs to drop every
        self.initAlpha = initAlpha
        self.factor = factor
        self.dropEvery = dropEvery
 
    def __call__(self, epoch):
        # compute the learning rate for the current epoch
        exp = np.floor((1 + epoch) / self.dropEvery)
        alpha = self.initAlpha * (self.factor ** exp)
        if(alpha<1e-9):
            alpha=1e-9

        # return the learning rate
        return float(alpha) 

schedule = StepDecay(initAlpha=learning_rate, factor=0.8, dropEvery=10)

reduce_lr = keras.callbacks.LearningRateScheduler(schedule, verbose = 1)
callbacks_list = [reduce_lr]

# %%
#Visualize training evolution
def plot_curves(model, acc, loss, val_acc, val_loss, subject_test):
    #########################################################################################
    # LOSS plot
    plt.figure(figsize=(12,8))
    plt.plot(model.history.history[loss], label='Training loss')
    plt.xlabel('Epochs', fontsize=15)
    plt.ylabel('Loss', fontsize=15)
    plt.tick_params(labelsize=10)
    plt.legend(loc=1,prop={'size': 10})
    plt.title('Loss in trainnig', fontsize=20)
    fig = plt.gcf()
    plt.show()
    
    fig.savefig('./01AUGNORM_SP_KFOLD_models/loss_train_01AUGNORM_SP_KFOLD_'+subject_test+'.pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./01AUGNORM_SP_KFOLD_models/loss_train_01AUGNORM_SP_KFOLD_'+subject_test+'svg', bbox_inches='tight',format='svg')
    
    #########################################################################################
    # ACC plot
    plt.figure(figsize=(12,8))
    plt.plot(model.history.history[acc], label='Training accuracy')
    plt.xlabel('Epochs', fontsize=15)
    plt.ylabel('Accuracy', fontsize=15)
    plt.tick_params(labelsize=10)
    plt.legend(loc=1,prop={'size': 10})
    plt.title('Accuracy in training', fontsize=20)
    fig = plt.gcf()
    plt.show()

    fig.savefig('./01AUGNORM_SP_KFOLD_models/acc_train_01AUGNORM_SP_KFOLD_'+subject_test+'pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./01AUGNORM_SP_KFOLD_models/acc_train_01AUGNORM_SP_KFOLD_'+subject_test+'svg', bbox_inches='tight',format='svg')
    
    #########################################################################################
    # ACC+LOSS plot
    plt.figure(figsize=(14,10))
    plt_loss = host_subplot(111, axes_class=AA.Axes)
    plt.subplots_adjust(right=0.75)

    plt_acc = plt_loss.twinx()
    plt_acc.axis["right"].toggle(all=True)
    
    plt_loss.set_xlim(0, len(model.history.history[loss]))
    plt_loss.set_ylim(0, max(model.history.history[loss]))
    plt_loss.set_xlabel('Epochs')
    plt_loss.set_ylabel('Loss')
    plt_acc.set_ylabel('Accuracy')
                        
    plt_loss.axis['left'].label.set_fontsize(15)
    plt_loss.axis['bottom'].label.set_fontsize(15)
    plt_acc.axis['right'].label.set_fontsize(15)
    
    plt_loss.plot(model.history.history[loss], c='tab:blue', ls='--', label='Training loss')
    plt_acc.plot(model.history.history[acc], c='tab:orange',ls='--', label='Training accuracy')
    
    plt.tick_params(labelsize=10)
    plt.title('Training performance', fontsize=20)
    plt_acc.set_ylim(0, 1)
    plt_loss.legend(loc=1, prop={'size': 10})
    
    fig = plt.gcf()
    plt.show()

    fig.savefig('./01AUGNORM_SP_KFOLD_models/all_train_01AUGNORM_SP_KFOLD_'+subject_test+'pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./01AUGNORM_SP_KFOLD_models/all_train_01AUGNORM_SP_KFOLD_'+subject_test+'svg', bbox_inches='tight',format='svg')

# %%
def plot_confusion_matrix(y_true, y_pred, subject_test, classes,
                          cmap=plt.cm.Blues):

    # Compute confusion matrix
    cm = metrics.confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(20, 20))
    sns.heatmap(cm, xticklabels=classes, yticklabels=classes, square = True, robust = True, annot=True, cmap='YlOrBr')
    plt.title('CONFUSION MATRIX')
    plt.ylabel('TRUE ACTIVITY')
    plt.xlabel('PREDICTION')
    
    locs, labels = plt.xticks()
    plt.xticks(locs, labels, rotation='vertical')
    locs, labels = plt.yticks()
    plt.yticks(locs, labels, rotation='horizontal')

    # Guardamos la imagen en formato vectorial
    plt.draw()
    plt.savefig('./01AUGNORM_SP_KFOLD_models/matriz_confusion_'+subject_test+'.svg', bbox_inches='tight',format='svg')
    plt.show()

# %%
accuracies = []
for i in range(12):
    print('##################################################################################################################################')
    print('#####################################################  K-FOLD %d  ################################################################'%(i+1))
    
    subject_test = subjects[i]
    subjects_train = [s for s in subjects if s not in subject_test]
    print('Training subjects: ' + str(subjects_train))
    print('Test subject: ' + str(subject_test))
    
    ##  GENERACIÓN DATASET
    tr_seg = np.concatenate((np.load('./augment_norm/subject_'+subjects_train[0]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[1]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[2]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[3]+'_seg.npy'),
                             np.load('./augment_norm/subject_'+subjects_train[4]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[5]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[6]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[7]+'_seg.npy'),
                             np.load('./augment_norm/subject_'+subjects_train[8]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[9]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects_train[10]+'_seg.npy')))
    
    tr_lab = np.concatenate((np.load('./augment_norm/subject_'+subjects_train[0]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[1]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[2]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[3]+'_lab.npy'),
                             np.load('./augment_norm/subject_'+subjects_train[4]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[5]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[6]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[7]+'_lab.npy'),
                             np.load('./augment_norm/subject_'+subjects_train[8]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[9]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects_train[10]+'_lab.npy')))

    ts_seg = np.load('./augment_norm/subject_'+subject_test+'_seg.npy')
    ts_lab = np.load('./augment_norm/subject_'+subject_test+'_lab.npy')
    
    limit = 20
    tr_seg = tr_seg[:,:,:,:limit]
    ts_seg = ts_seg[:,:,:,:limit]
    ####################################################################################################################
    ## SHUFFLE DE DATOS
    np.random.seed(235)
    tr_seg = np.reshape(tr_seg[np.random.shuffle(np.arange(0,tr_seg.shape[0]))], (11*2375,1,128,limit))
    tr_lab = np.reshape(tr_lab[np.random.shuffle(np.arange(0,tr_seg.shape[0]))], (11*2375,11))

    np.random.seed(235)
    ts_seg = np.reshape(ts_seg[np.random.shuffle(np.arange(0,ts_seg.shape[0]))], (2375,1,128,limit))
    ts_lab = np.reshape(ts_lab[np.random.shuffle(np.arange(0,ts_seg.shape[0]))], (2375,11))
    
    print('Train dataset: ')
    print(tr_seg.shape, tr_lab.shape)
    print('Test dataset: ')
    print(ts_seg.shape, ts_lab.shape)
    ####################################################################################################################
    ## VISTA DE DFT-2D
    plt.figure(figsize=(30,30))
    plt.imshow(np.log(np.abs(np.fft.fftshift(tr_seg[0,0,:,20:40].T))**2))
    plt.show()
    print('Activity: ',activities[np.argmax(tr_lab[0])])

    plt.figure(figsize=(30,30))
    plt.imshow(np.log(np.fft.fftshift(tr_seg[10,0,:,20:40].T)**2))
    plt.show()
    print('Activity: ',activities[np.argmax(tr_lab[10])])
    ####################################################################################################################
    ## RED
    quat_input = keras.Input(shape=(n_channels, n_time_steps, n_columns), name='input_layer')

    # Initializer
    #initializer = RandomNormal(mean=0.0, stddev=0.02)

    # Some convolutional layers
    conv_1 = keras.layers.Conv2D(16, activation='relu', kernel_size=4,padding='same',strides=1,data_format='channels_first')(quat_input)#, kernel_initializer=initializer)(quat_input)
    max_1 = keras.layers.MaxPooling2D(pool_size=2, strides=2, padding='same', data_format = 'channels_first')(conv_1)
    bn_1 = keras.layers.BatchNormalization(axis=1)(max_1)

    conv_2 = keras.layers.Conv2D(32, activation='relu', kernel_size=4,padding='same',strides=1,data_format='channels_first')(bn_1)#, kernel_initializer=initializer)(max_1)
    max_2 = keras.layers.MaxPooling2D(pool_size=2, strides=2, padding='same', data_format = 'channels_first')(conv_2)
    bn_2 = keras.layers.BatchNormalization(axis=1)(max_2)

    conv_3 = keras.layers.Conv2D(64, activation='relu', kernel_size=4,padding='same',strides=1,data_format='channels_first')(bn_2)#, kernel_initializer=initializer)(re_2)
    max_3 = keras.layers.MaxPooling2D(pool_size=2, strides=2, padding='same', data_format = 'channels_first')(conv_3)
    bn_3 = keras.layers.BatchNormalization(axis=1)(max_3)

    conv_4 = keras.layers.Conv2D(128, activation='relu', kernel_size=4,padding='same',strides=1,data_format='channels_first')(bn_3)#, kernel_initializer=initializer)(re_2)
    max_4 = keras.layers.MaxPooling2D(pool_size=2, strides=2, padding='same', data_format = 'channels_first')(conv_4)
    bn_4 = keras.layers.BatchNormalization(axis=1)(max_4)

    # Flatten the output of the convolutional layers
    conv_flat = keras.layers.Flatten()(bn_4)

    dr_2 = keras.layers.Dropout(0.5)(conv_flat)

    # Output layers: separate outputs for the weather and the ground labels
    multiclass_output = keras.layers.Dense(n_classes, activation='softmax',name='activity_class')(dr_2)

    # Creamos la estrcutura que contendrá a nuestro modelo
    model = keras.Model(inputs=quat_input, outputs=[multiclass_output],name='cnn')

    # Compilamos el modelo
    model.compile(optimizer=keras.optimizers.Adam(lr=learning_rate),
                  loss='categorical_crossentropy', metrics=['categorical_accuracy'])
    
    print(model.summary())
    ####################################################################################################################
    ## TRAIN
    history = model.fit(tr_seg,
                        tr_lab,
                        epochs = epochs,
                        steps_per_epoch = None,
                        verbose = 1,
                        batch_size = batch_size,
                        callbacks = callbacks_list)
    model.save('./01AUGNORM_SP_KFOLD_models/CNN_'+subject_test+'.h5')
    
    #Visualize training evolution
    plot_curves(model, 'categorical_accuracy', 'loss', 'val_categorical_accuracy', 'val_loss', subject_test)
    ####################################################################################################################
    ## TEST
    predictions = model.predict(ts_seg, batch_size = batch_size, verbose = 1)
    
    print(predictions.shape)
    
    y_pred = np.argmax(predictions,axis=-1)
    y_pred = np.expand_dims(y_pred,axis=-1)
    print(y_pred[:100].T)
    
    y_true = np.argmax(ts_lab,axis=-1)
    y_true = np.expand_dims(y_true,axis=-1)
    print(y_true.shape)
    print(y_true[:100].T)
    
    evaluation = model.evaluate(ts_seg, ts_lab, batch_size=batch_size, verbose=1)
    accuracies.append(evaluation[1])
    
    fo = open('./01AUGNORM_SP_KFOLD_models/accuracy_'+subject_test+'.txt', "w")
    fo.seek(0,2)
    fo.write(str(evaluation))
    fo.close()
    
    ####################################################################################################################
    ## CONFUSION MATRIX
    y_true_flat = np.ndarray.flatten(y_true)
    y_pred_flat = np.ndarray.flatten(y_pred)
    
    plot_confusion_matrix(y_true_flat, y_pred_flat, subject_test, classes=activities)
    
    del subject_test, subjects_train, limit, tr_seg, tr_lab, ts_seg, ts_lab, model, history, y_pred, y_true, predictions, evaluation, y_true_flat, y_pred_flat
# Out:
# ##################################################################################################################################
# #####################################################  K-FOLD 1  ################################################################
# Training subjects: ['02', '03', '05', '08', '09', '10', '11', '13', '14', '16', '17']
# Test subject: 01
# Train dataset:
# (26125, 1, 128, 20) (26125, 11)
# Test dataset:
# (2375, 1, 128, 20) (2375, 11)
# /usr/local/lib/python3.6/dist-packages/matplotlib/image.py:857: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=-0.5, top=-0.5
#   self.axes.set_ylim((ymin, ymax), auto=None)
# Activity:  20
# Activity:  25
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 20)]      0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 16, 128, 20)       272
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 64, 10)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 16, 64, 10)        64
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 64, 10)        8224
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 5)         0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 5)         128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 32, 5)         32832
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 64, 16, 3)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64, 16, 3)         256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 128, 16, 3)        131200
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 128, 8, 2)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128, 8, 2)         512
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# activity_class (Dense)       (None, 11)                22539
# =================================================================
# Total params: 196,027
# Trainable params: 195,547
# Non-trainable params: 480
# _________________________________________________________________
# None
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 1/100
# 26125/26125 [==============================] - 10s 401us/sample - loss: 0.3805 - categorical_accuracy: 0.8789
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 2/100
# 26125/26125 [==============================] - 4s 146us/sample - loss: 0.0125 - categorical_accuracy: 0.9969
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 3/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 0.0033 - categorical_accuracy: 0.9995
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 4/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 0.0019 - categorical_accuracy: 0.9996
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 5/100
# 26125/26125 [==============================] - 4s 144us/sample - loss: 0.0439 - categorical_accuracy: 0.9870
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 6/100
# 26125/26125 [==============================] - 4s 144us/sample - loss: 8.1841e-04 - categorical_accuracy: 0.9999
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 7/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 2.3607e-04 - categorical_accuracy: 1.0000
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 8/100
# 26125/26125 [==============================] - 4s 144us/sample - loss: 1.5540e-04 - categorical_accuracy: 1.0000
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 9/100
# 26125/26125 [==============================] - 4s 144us/sample - loss: 1.2199e-04 - categorical_accuracy: 1.0000
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 10/100
# 26125/26125 [==============================] - 4s 144us/sample - loss: 8.4985e-05 - categorical_accuracy: 1.0000
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 11/100
# 26125/26125 [==============================] - 4s 144us/sample - loss: 6.5492e-05 - categorical_accuracy: 1.0000
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 12/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 4.7636e-05 - categorical_accuracy: 1.0000
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 13/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 4.5774e-05 - categorical_accuracy: 1.0000
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 14/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 6.0252e-05 - categorical_accuracy: 1.0000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 15/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 4.4765e-05 - categorical_accuracy: 1.0000
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 16/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 3.7030e-05 - categorical_accuracy: 1.0000
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 17/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 3.5379e-05 - categorical_accuracy: 1.0000
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 18/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 2.1856e-05 - categorical_accuracy: 1.0000
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 19/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 2.1354e-05 - categorical_accuracy: 1.0000
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 20/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 0.0458 - categorical_accuracy: 0.9862
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 21/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 0.0016 - categorical_accuracy: 0.9995
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 22/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 1.4156e-04 - categorical_accuracy: 1.0000
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 23/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 6.0819e-05 - categorical_accuracy: 1.0000
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 24/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 7.0667e-05 - categorical_accuracy: 1.0000
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 25/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 4.4321e-05 - categorical_accuracy: 1.0000
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 26/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 0.0025 - categorical_accuracy: 0.9995
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 27/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 1.4807e-04 - categorical_accuracy: 1.0000
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 28/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 7.1208e-05 - categorical_accuracy: 1.0000
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 29/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 0.0136 - categorical_accuracy: 0.9963
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0004608000000000001.
# Epoch 30/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 4.2148e-04 - categorical_accuracy: 0.9998
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0004608000000000001.
# Epoch 31/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 7.2299e-05 - categorical_accuracy: 1.0000
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0004608000000000001.
# Epoch 32/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 4.3676e-05 - categorical_accuracy: 1.0000
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0004608000000000001.
# Epoch 33/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 7.8226e-05 - categorical_accuracy: 1.0000
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0004608000000000001.
# Epoch 34/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 2.8900e-05 - categorical_accuracy: 1.0000
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0004608000000000001.
# Epoch 35/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 2.7817e-05 - categorical_accuracy: 1.0000
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0004608000000000001.
# Epoch 36/100
# 26125/26125 [==============================] - 4s 146us/sample - loss: 2.9954e-05 - categorical_accuracy: 1.0000
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0004608000000000001.
# Epoch 37/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 1.4720e-05 - categorical_accuracy: 1.0000
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0004608000000000001.
# Epoch 38/100
# 26125/26125 [==============================] - 4s 146us/sample - loss: 2.1359e-05 - categorical_accuracy: 1.0000
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0004608000000000001.
# Epoch 39/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 1.5230e-05 - categorical_accuracy: 1.0000
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.00036864000000000005.
# Epoch 40/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 8.4258e-06 - categorical_accuracy: 1.0000
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.00036864000000000005.
# Epoch 41/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 1.1085e-05 - categorical_accuracy: 1.0000
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.00036864000000000005.
# Epoch 42/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 7.7450e-06 - categorical_accuracy: 1.0000
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.00036864000000000005.
# Epoch 43/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 6.7539e-06 - categorical_accuracy: 1.0000
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.00036864000000000005.
# Epoch 44/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 6.3927e-06 - categorical_accuracy: 1.0000
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.00036864000000000005.
# Epoch 45/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 6.4593e-06 - categorical_accuracy: 1.0000
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.00036864000000000005.
# Epoch 46/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 5.6572e-06 - categorical_accuracy: 1.0000
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.00036864000000000005.
# Epoch 47/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 6.6157e-06 - categorical_accuracy: 1.0000
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.00036864000000000005.
# Epoch 48/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 1.2076e-05 - categorical_accuracy: 1.0000
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.00036864000000000005.
# Epoch 49/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 6.2346e-06 - categorical_accuracy: 1.0000
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0002949120000000001.
# Epoch 50/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 1.2602e-05 - categorical_accuracy: 1.0000
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0002949120000000001.
# Epoch 51/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 5.6683e-06 - categorical_accuracy: 1.0000
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0002949120000000001.
# Epoch 52/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 3.9687e-06 - categorical_accuracy: 1.0000
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0002949120000000001.
# Epoch 53/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 0.0087 - categorical_accuracy: 0.9976
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0002949120000000001.
# Epoch 54/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 4.8757e-04 - categorical_accuracy: 0.9998
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0002949120000000001.
# Epoch 55/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 3.0433e-04 - categorical_accuracy: 0.9999
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0002949120000000001.
# Epoch 56/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 3.8112e-05 - categorical_accuracy: 1.0000
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0002949120000000001.
# Epoch 57/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 2.1856e-05 - categorical_accuracy: 1.0000
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0002949120000000001.
# Epoch 58/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 8.5645e-05 - categorical_accuracy: 1.0000
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0002949120000000001.
# Epoch 59/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 1.9335e-05 - categorical_accuracy: 1.0000
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.00023592960000000008.
# Epoch 60/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 1.7618e-05 - categorical_accuracy: 1.0000
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.00023592960000000008.
# Epoch 61/100
# 26125/26125 [==============================] - 4s 146us/sample - loss: 1.2932e-05 - categorical_accuracy: 1.0000
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.00023592960000000008.
# Epoch 62/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 6.8007e-06 - categorical_accuracy: 1.0000
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.00023592960000000008.
# Epoch 63/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 2.7874e-05 - categorical_accuracy: 1.0000
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.00023592960000000008.
# Epoch 64/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 6.0124e-06 - categorical_accuracy: 1.0000
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.00023592960000000008.
# Epoch 65/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 1.1046e-05 - categorical_accuracy: 1.0000
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.00023592960000000008.
# Epoch 66/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 5.6018e-06 - categorical_accuracy: 1.0000
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.00023592960000000008.
# Epoch 67/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 7.9431e-06 - categorical_accuracy: 1.0000
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 0.00023592960000000008.
# Epoch 68/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 5.0452e-06 - categorical_accuracy: 1.0000
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 0.00023592960000000008.
# Epoch 69/100
# 26125/26125 [==============================] - 4s 146us/sample - loss: 5.4372e-06 - categorical_accuracy: 1.0000
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 0.00018874368000000005.
# Epoch 70/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 8.5284e-06 - categorical_accuracy: 1.0000
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 0.00018874368000000005.
# Epoch 71/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 3.4305e-06 - categorical_accuracy: 1.0000
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 0.00018874368000000005.
# Epoch 72/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 4.4396e-06 - categorical_accuracy: 1.0000
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 0.00018874368000000005.
# Epoch 73/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 3.2062e-06 - categorical_accuracy: 1.0000
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 0.00018874368000000005.
# Epoch 74/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 2.6775e-06 - categorical_accuracy: 1.0000
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 0.00018874368000000005.
# Epoch 75/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 2.9773e-06 - categorical_accuracy: 1.0000
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 0.00018874368000000005.
# Epoch 76/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 5.4015e-06 - categorical_accuracy: 1.0000
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 0.00018874368000000005.
# Epoch 77/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 3.8966e-06 - categorical_accuracy: 1.0000
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 0.00018874368000000005.
# Epoch 78/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 2.5491e-06 - categorical_accuracy: 1.0000
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 0.00018874368000000005.
# Epoch 79/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 4.0274e-06 - categorical_accuracy: 1.0000
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 0.00015099494400000007.
# Epoch 80/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 2.2065e-06 - categorical_accuracy: 1.0000
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 0.00015099494400000007.
# Epoch 81/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 1.5514e-06 - categorical_accuracy: 1.0000
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 0.00015099494400000007.
# Epoch 82/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 2.6956e-06 - categorical_accuracy: 1.0000
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 0.00015099494400000007.
# Epoch 83/100
# 26125/26125 [==============================] - 4s 146us/sample - loss: 1.1092e-06 - categorical_accuracy: 1.0000
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 0.00015099494400000007.
# Epoch 84/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 3.3043e-06 - categorical_accuracy: 1.0000
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 0.00015099494400000007.
# Epoch 85/100
# 26125/26125 [==============================] - 4s 146us/sample - loss: 2.6250e-06 - categorical_accuracy: 1.0000
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 0.00015099494400000007.
# Epoch 86/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 1.3607e-06 - categorical_accuracy: 1.0000
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 0.00015099494400000007.
# Epoch 87/100
# 26125/26125 [==============================] - 4s 146us/sample - loss: 1.4991e-06 - categorical_accuracy: 1.0000
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 0.00015099494400000007.
# Epoch 88/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 6.1293e-04 - categorical_accuracy: 0.9998
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 0.00015099494400000007.
# Epoch 89/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 0.0014 - categorical_accuracy: 0.9996
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 0.00012079595520000005.
# Epoch 90/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 7.3203e-05 - categorical_accuracy: 1.0000
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 0.00012079595520000005.
# Epoch 91/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 4.3471e-04 - categorical_accuracy: 0.9998
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 0.00012079595520000005.
# Epoch 92/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 2.9521e-05 - categorical_accuracy: 1.0000
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 0.00012079595520000005.
# Epoch 93/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 2.0999e-05 - categorical_accuracy: 1.0000
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 0.00012079595520000005.
# Epoch 94/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 2.4341e-05 - categorical_accuracy: 1.0000
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 0.00012079595520000005.
# Epoch 95/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 6.0159e-06 - categorical_accuracy: 1.0000
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 0.00012079595520000005.
# Epoch 96/100
# 26125/26125 [==============================] - 4s 146us/sample - loss: 7.3934e-06 - categorical_accuracy: 1.0000
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 0.00012079595520000005.
# Epoch 97/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 9.7342e-05 - categorical_accuracy: 0.9999
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 0.00012079595520000005.
# Epoch 98/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 1.9242e-05 - categorical_accuracy: 1.0000
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 0.00012079595520000005.
# Epoch 99/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 5.4434e-05 - categorical_accuracy: 1.0000
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 9.663676416000005e-05.
# Epoch 100/100
# 26125/26125 [==============================] - 4s 145us/sample - loss: 3.7902e-05 - categorical_accuracy: 1.0000
# 2375/2375 [==============================] - 0s 112us/sample
# (2375, 11)
# [[ 4 10  3  4  5 10  4  8  4  7  8 10  8  4  0  5  1  5  5  1  8 10 10  4
#    3  9  2  4  0  0  8  4  0  5  5 10  4  9  5  9 10  0  9  3  1  7  6  7
#    1  1  4  6  2  4  2  0  2  5  4  8  2  3  0 10  0 10  5  9  7 10  6  1
#    6  7  5  2  2  8  1  0  7 10 10  1  1  6  3  3  1  1  9  4  0  0 10  1
#    0  0  4  2]]
# (2375, 1)
# [[ 4 10  3  4  5 10  4  8  4  7  9 10  8  4  8  5  1  5  5  1  9 10 10  4
#    3  9  2  4  0  0  9  4  0  5  5 10  4  5  6  9  8  8  9  1  1  7  6  7
#    1  1  4  6  2  4  2  8  2  6  4  8  2  3  0  9  0 10  5  9  7 10  6  1
#    6  7  5  2  2  8  1  9  7 10 10  1  1  6  3  3  1  1  9  4  0  0 10  1
#    9  0  4  2]]
# 2375/2375 [==============================] - 0s 127us/sample - loss: 0.9559 - categorical_accuracy: 0.8669
# ##################################################################################################################################
# #####################################################  K-FOLD 2  ################################################################
# Training subjects: ['01', '03', '05', '08', '09', '10', '11', '13', '14', '16', '17']
# Test subject: 02
# Train dataset:
# (26125, 1, 128, 20) (26125, 11)
# Test dataset:
# (2375, 1, 128, 20) (2375, 11)
# /usr/local/lib/python3.6/dist-packages/matplotlib/image.py:857: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=-0.5, top=-0.5
#   self.axes.set_ylim((ymin, ymax), auto=None)
# Activity:  13
# Activity:  25
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 20)]      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 128, 20)       272
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 64, 10)        0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 64, 10)        64
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 64, 10)        8224
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 32, 32, 5)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32, 32, 5)         128
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 64, 32, 5)         32832
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 64, 16, 3)         0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 64, 16, 3)         256
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 128, 16, 3)        131200
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 128, 8, 2)         0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 128, 8, 2)         512
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# activity_class (Dense)       (None, 11)                22539
# =================================================================
# Total params: 196,027
# Trainable params: 195,547
# Non-trainable params: 480
# _________________________________________________________________
# None
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 1/100
# 26125/26125 [==============================] - 5s 190us/sample - loss: 0.4274 - categorical_accuracy: 0.8614
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 2/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 0.0099 - categorical_accuracy: 0.9979
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 3/100
# 26125/26125 [==============================] - 4s 146us/sample - loss: 0.0191 - categorical_accuracy: 0.9950
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 4/100
# 26125/26125 [==============================] - 4s 146us/sample - loss: 0.0014 - categorical_accuracy: 0.9998
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 5/100
# 26125/26125 [==============================] - 4s 146us/sample - loss: 0.0168 - categorical_accuracy: 0.9943
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 6/100
# 26125/26125 [==============================] - 4s 146us/sample - loss: 0.0327 - categorical_accuracy: 0.9911
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 7/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 5.3332e-04 - categorical_accuracy: 1.0000
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 8/100
# 26125/26125 [==============================] - 4s 146us/sample - loss: 2.1351e-04 - categorical_accuracy: 1.0000
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 9/100
# 26125/26125 [==============================] - 4s 146us/sample - loss: 2.0040e-04 - categorical_accuracy: 1.0000
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 10/100
# 26125/26125 [==============================] - 4s 146us/sample - loss: 2.0595e-04 - categorical_accuracy: 1.0000
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 11/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 1.1104e-04 - categorical_accuracy: 1.0000
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 12/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 2.9611e-04 - categorical_accuracy: 1.0000
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 13/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 9.1850e-05 - categorical_accuracy: 1.0000
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 14/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 7.5455e-05 - categorical_accuracy: 1.0000
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 15/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 4.8251e-05 - categorical_accuracy: 1.0000
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 16/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 5.5183e-05 - categorical_accuracy: 1.0000
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 17/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 3.7836e-05 - categorical_accuracy: 1.0000
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 18/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 3.1016e-05 - categorical_accuracy: 1.0000
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 19/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 2.5955e-05 - categorical_accuracy: 1.0000
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 20/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 2.3502e-05 - categorical_accuracy: 1.0000
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 21/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 2.2228e-05 - categorical_accuracy: 1.0000
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 22/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 1.8655e-05 - categorical_accuracy: 1.0000
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 23/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 1.8610e-05 - categorical_accuracy: 1.0000
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 24/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 0.0475 - categorical_accuracy: 0.9857
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 25/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 0.0052 - categorical_accuracy: 0.9984
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 26/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 0.0045 - categorical_accuracy: 0.9988
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 27/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 3.5989e-04 - categorical_accuracy: 0.9999
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 28/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 1.9129e-04 - categorical_accuracy: 1.0000
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 29/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 5.8654e-05 - categorical_accuracy: 1.0000
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0004608000000000001.
# Epoch 30/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 5.5870e-05 - categorical_accuracy: 1.0000
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0004608000000000001.
# Epoch 31/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 5.0988e-05 - categorical_accuracy: 1.0000
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0004608000000000001.
# Epoch 32/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 1.5577e-04 - categorical_accuracy: 1.0000
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0004608000000000001.
# Epoch 33/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 4.3859e-05 - categorical_accuracy: 1.0000
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0004608000000000001.
# Epoch 34/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 2.2145e-05 - categorical_accuracy: 1.0000
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0004608000000000001.
# Epoch 35/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 2.6381e-05 - categorical_accuracy: 1.0000
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0004608000000000001.
# Epoch 36/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 1.6133e-05 - categorical_accuracy: 1.0000
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0004608000000000001.
# Epoch 37/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 1.6666e-05 - categorical_accuracy: 1.0000
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0004608000000000001.
# Epoch 38/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 1.7290e-05 - categorical_accuracy: 1.0000
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0004608000000000001.
# Epoch 39/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 1.2827e-05 - categorical_accuracy: 1.0000
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.00036864000000000005.
# Epoch 40/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 1.1357e-05 - categorical_accuracy: 1.0000
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.00036864000000000005.
# Epoch 41/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 0.0032 - categorical_accuracy: 0.9988
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.00036864000000000005.
# Epoch 42/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 0.0035 - categorical_accuracy: 0.9989
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.00036864000000000005.
# Epoch 43/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 0.0015 - categorical_accuracy: 0.9997
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.00036864000000000005.
# Epoch 44/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 9.2309e-04 - categorical_accuracy: 0.9997
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.00036864000000000005.
# Epoch 45/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 7.4269e-05 - categorical_accuracy: 1.0000
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.00036864000000000005.
# Epoch 46/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 0.0036 - categorical_accuracy: 0.9992
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.00036864000000000005.
# Epoch 47/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 4.5906e-05 - categorical_accuracy: 1.0000
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.00036864000000000005.
# Epoch 48/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 7.4980e-05 - categorical_accuracy: 1.0000
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.00036864000000000005.
# Epoch 49/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 3.1548e-05 - categorical_accuracy: 1.0000
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0002949120000000001.
# Epoch 50/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 2.6256e-05 - categorical_accuracy: 1.0000
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0002949120000000001.
# Epoch 51/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 2.4122e-05 - categorical_accuracy: 1.0000
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0002949120000000001.
# Epoch 52/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 6.4053e-05 - categorical_accuracy: 1.0000
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0002949120000000001.
# Epoch 53/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 1.2675e-05 - categorical_accuracy: 1.0000
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0002949120000000001.
# Epoch 54/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 1.1897e-05 - categorical_accuracy: 1.0000
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0002949120000000001.
# Epoch 55/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 2.1291e-05 - categorical_accuracy: 1.0000
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0002949120000000001.
# Epoch 56/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 1.3490e-05 - categorical_accuracy: 1.0000
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0002949120000000001.
# Epoch 57/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 6.8813e-06 - categorical_accuracy: 1.0000
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0002949120000000001.
# Epoch 58/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 5.9910e-06 - categorical_accuracy: 1.0000
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0002949120000000001.
# Epoch 59/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 4.6434e-06 - categorical_accuracy: 1.0000
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.00023592960000000008.
# Epoch 60/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 3.2784e-06 - categorical_accuracy: 1.0000
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.00023592960000000008.
# Epoch 61/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 6.2070e-06 - categorical_accuracy: 1.0000
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.00023592960000000008.
# Epoch 62/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 3.3311e-06 - categorical_accuracy: 1.0000
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.00023592960000000008.
# Epoch 63/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 6.2484e-06 - categorical_accuracy: 1.0000
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.00023592960000000008.
# Epoch 64/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 7.6702e-06 - categorical_accuracy: 1.0000
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.00023592960000000008.
# Epoch 65/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 0.0049 - categorical_accuracy: 0.9991
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.00023592960000000008.
# Epoch 66/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 4.2840e-04 - categorical_accuracy: 0.9998
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.00023592960000000008.
# Epoch 67/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 9.1823e-05 - categorical_accuracy: 1.0000
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 0.00023592960000000008.
# Epoch 68/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 3.2595e-05 - categorical_accuracy: 1.0000
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 0.00023592960000000008.
# Epoch 69/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 1.8380e-05 - categorical_accuracy: 1.0000
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 0.00018874368000000005.
# Epoch 70/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 2.2977e-05 - categorical_accuracy: 1.0000
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 0.00018874368000000005.
# Epoch 71/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 1.1045e-05 - categorical_accuracy: 1.0000
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 0.00018874368000000005.
# Epoch 72/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 9.5336e-06 - categorical_accuracy: 1.0000
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 0.00018874368000000005.
# Epoch 73/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 1.4581e-05 - categorical_accuracy: 1.0000
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 0.00018874368000000005.
# Epoch 74/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 1.4431e-05 - categorical_accuracy: 1.0000
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 0.00018874368000000005.
# Epoch 75/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 1.0717e-05 - categorical_accuracy: 1.0000
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 0.00018874368000000005.
# Epoch 76/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 7.7652e-06 - categorical_accuracy: 1.0000
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 0.00018874368000000005.
# Epoch 77/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 4.4048e-06 - categorical_accuracy: 1.0000
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 0.00018874368000000005.
# Epoch 78/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 8.1529e-06 - categorical_accuracy: 1.0000
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 0.00018874368000000005.
# Epoch 79/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 3.5205e-06 - categorical_accuracy: 1.0000
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 0.00015099494400000007.
# Epoch 80/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 3.9528e-06 - categorical_accuracy: 1.0000
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 0.00015099494400000007.
# Epoch 81/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 6.0933e-06 - categorical_accuracy: 1.0000
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 0.00015099494400000007.
# Epoch 82/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 3.4537e-06 - categorical_accuracy: 1.0000
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 0.00015099494400000007.
# Epoch 83/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 4.6499e-06 - categorical_accuracy: 1.0000
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 0.00015099494400000007.
# Epoch 84/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 3.3487e-06 - categorical_accuracy: 1.0000
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 0.00015099494400000007.
# Epoch 85/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 2.4087e-06 - categorical_accuracy: 1.0000
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 0.00015099494400000007.
# Epoch 86/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 1.4373e-05 - categorical_accuracy: 1.0000
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 0.00015099494400000007.
# Epoch 87/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 4.2717e-06 - categorical_accuracy: 1.0000
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 0.00015099494400000007.
# Epoch 88/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 3.5232e-06 - categorical_accuracy: 1.0000
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 0.00015099494400000007.
# Epoch 89/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 5.7621e-06 - categorical_accuracy: 1.0000
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 0.00012079595520000005.
# Epoch 90/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 8.0878e-06 - categorical_accuracy: 1.0000
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 0.00012079595520000005.
# Epoch 91/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 1.1560e-05 - categorical_accuracy: 1.0000
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 0.00012079595520000005.
# Epoch 92/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 1.8848e-04 - categorical_accuracy: 0.9999
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 0.00012079595520000005.
# Epoch 93/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 7.2395e-04 - categorical_accuracy: 0.9998
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 0.00012079595520000005.
# Epoch 94/100
# 26125/26125 [==============================] - 4s 147us/sample - loss: 8.0304e-05 - categorical_accuracy: 1.0000
#
# ...
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 0.00012079595520000005.
# Epoch 94/100
# 26125/26125 [==============================] - 4s 150us/sample - loss: 4.4891e-06 - categorical_accuracy: 1.0000
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 0.00012079595520000005.
# Epoch 95/100
# 26125/26125 [==============================] - 4s 149us/sample - loss: 8.5616e-06 - categorical_accuracy: 1.0000
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 0.00012079595520000005.
# Epoch 96/100
# 26125/26125 [==============================] - 4s 149us/sample - loss: 3.3493e-06 - categorical_accuracy: 1.0000
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 0.00012079595520000005.
# Epoch 97/100
# 26125/26125 [==============================] - 4s 149us/sample - loss: 2.5456e-06 - categorical_accuracy: 1.0000
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 0.00012079595520000005.
# Epoch 98/100
# 26125/26125 [==============================] - 4s 149us/sample - loss: 1.9243e-06 - categorical_accuracy: 1.0000
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 0.00012079595520000005.
# Epoch 99/100
# 26125/26125 [==============================] - 4s 149us/sample - loss: 2.1658e-06 - categorical_accuracy: 1.0000
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 9.663676416000005e-05.
# Epoch 100/100
# 26125/26125 [==============================] - 4s 149us/sample - loss: 1.7566e-06 - categorical_accuracy: 1.0000
# 2375/2375 [==============================] - 0s 126us/sample
# (2375, 11)
# [[ 9 10  0  8  4  8  9  7  4  8 10  4  2  2  4  6  0  4  9  4  2  6  6 10
#    2  4 10  2  7  2  1 10  5  7  1  7 10  1  4  8 10  9  4  4  4  2  6  0
#    6  2  2  7  2  7  5  5  4  5  2 10 10  2  7  2  1  2  1  4  1 10  3  9
#    9  2  1  2  8  5  0 10  4  5  4 10  9  8  1  6 10  0  8 10  8  2 10  4
#    7  4  9  1]]
# (2375, 1)
# [[ 9 10  0  8  4  8  9  7  4  8 10  4  2  3  4  6  0  4  9  4  2  6  6 10
#    2  3 10  2  7  2  1 10  5  7  1  7 10  1  4  8 10  9  4  4  4  3  6  0
#    6  2  2  7  2  7  5  5  4  5  2 10 10  3  7  2  1  2  1  4  1 10  3  9
#    9  2  3  2  8  5  0 10  4  5  4 10  9  8  1  6 10  0  8 10  8  3 10  4
#    7  4  9  1]]
# 2375/2375 [==============================] - 0s 157us/sample - loss: 0.1598 - categorical_accuracy: 0.9566
# ##################################################################################################################################
# #####################################################  K-FOLD 7  ################################################################
# Training subjects: ['01', '02', '03', '05', '08', '09', '11', '13', '14', '16', '17']
# Test subject: 10
# Train dataset:
# (26125, 1, 128, 20) (26125, 11)
# Test dataset:
# (2375, 1, 128, 20) (2375, 11)
# /usr/local/lib/python3.6/dist-packages/matplotlib/image.py:857: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=-0.5, top=-0.5
#   self.axes.set_ylim((ymin, ymax), auto=None)
# Activity:  13
# Activity:  25
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 20)]      0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 16, 128, 20)       272
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 16, 64, 10)        0
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 16, 64, 10)        64
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 32, 64, 10)        8224
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 32, 32, 5)         0
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 32, 32, 5)         128
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 64, 32, 5)         32832
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 64, 16, 3)         0
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 64, 16, 3)         256
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 128, 16, 3)        131200
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 128, 8, 2)         0
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 128, 8, 2)         512
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# activity_class (Dense)       (None, 11)                22539
# =================================================================
# Total params: 196,027
# Trainable params: 195,547
# Non-trainable params: 480
# _________________________________________________________________
# None
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 1/100
# 26125/26125 [==============================] - 4s 170us/sample - loss: 0.4738 - categorical_accuracy: 0.8477
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 2/100
# 26125/26125 [==============================] - 4s 150us/sample - loss: 0.0336 - categorical_accuracy: 0.9909
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 3/100
# 26125/26125 [==============================] - 4s 150us/sample - loss: 0.0045 - categorical_accuracy: 0.9989
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 4/100
# 26125/26125 [==============================] - 4s 150us/sample - loss: 0.0111 - categorical_accuracy: 0.9967
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 5/100
# 26125/26125 [==============================] - 4s 150us/sample - loss: 0.0015 - categorical_accuracy: 0.9997
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 6/100
# 26125/26125 [==============================] - 4s 150us/sample - loss: 6.7124e-04 - categorical_accuracy: 0.9999
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 7/100
# 26125/26125 [==============================] - 4s 150us/sample - loss: 0.0285 - categorical_accuracy: 0.9910
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 8/100
# 26125/26125 [==============================] - 4s 150us/sample - loss: 0.0251 - categorical_accuracy: 0.9926
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0009.
# Epoch 9/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 0.0012 - categorical_accuracy: 0.9996
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 10/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 2.5180e-04 - categorical_accuracy: 0.9999
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 11/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 1.2448e-04 - categorical_accuracy: 1.0000
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 12/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 8.3427e-05 - categorical_accuracy: 1.0000
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 13/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 7.0918e-05 - categorical_accuracy: 1.0000
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 14/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 0.0030 - categorical_accuracy: 0.9990
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 15/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 1.2923e-04 - categorical_accuracy: 1.0000
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 16/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 0.0054 - categorical_accuracy: 0.9984
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 17/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 0.0099 - categorical_accuracy: 0.9972
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 18/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 0.0013 - categorical_accuracy: 0.9998
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.00072.
# Epoch 19/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 6.9333e-05 - categorical_accuracy: 1.0000
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 20/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 4.5525e-05 - categorical_accuracy: 1.0000
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 21/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 2.2161e-04 - categorical_accuracy: 0.9999
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 22/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 5.5421e-05 - categorical_accuracy: 1.0000
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 23/100
# 26125/26125 [==============================] - 4s 150us/sample - loss: 6.4358e-05 - categorical_accuracy: 1.0000
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 24/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 1.9358e-05 - categorical_accuracy: 1.0000
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 25/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 2.2923e-05 - categorical_accuracy: 1.0000
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 26/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 1.9624e-05 - categorical_accuracy: 1.0000
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 27/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 2.2765e-05 - categorical_accuracy: 1.0000
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 28/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 1.5924e-05 - categorical_accuracy: 1.0000
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0005760000000000001.
# Epoch 29/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 2.7121e-05 - categorical_accuracy: 1.0000
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0004608000000000001.
# Epoch 30/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 1.4638e-05 - categorical_accuracy: 1.0000
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0004608000000000001.
# Epoch 31/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 6.9488e-06 - categorical_accuracy: 1.0000
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0004608000000000001.
# Epoch 32/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 8.2322e-06 - categorical_accuracy: 1.0000
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0004608000000000001.
# Epoch 33/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 8.5296e-06 - categorical_accuracy: 1.0000
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0004608000000000001.
# Epoch 34/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 5.9629e-06 - categorical_accuracy: 1.0000
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0004608000000000001.
# Epoch 35/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 6.8949e-06 - categorical_accuracy: 1.0000
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0004608000000000001.
# Epoch 36/100
# 26125/26125 [==============================] - 4s 152us/sample - loss: 9.5948e-06 - categorical_accuracy: 1.0000
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0004608000000000001.
# Epoch 37/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 1.2404e-05 - categorical_accuracy: 1.0000
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0004608000000000001.
# Epoch 38/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 3.9458e-06 - categorical_accuracy: 1.0000
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0004608000000000001.
# Epoch 39/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 4.4438e-06 - categorical_accuracy: 1.0000
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.00036864000000000005.
# Epoch 40/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 0.0151 - categorical_accuracy: 0.9953
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.00036864000000000005.
# Epoch 41/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 0.0030 - categorical_accuracy: 0.9990
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.00036864000000000005.
# Epoch 42/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 9.4089e-05 - categorical_accuracy: 1.0000
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.00036864000000000005.
# Epoch 43/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 7.1908e-05 - categorical_accuracy: 1.0000
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.00036864000000000005.
# Epoch 44/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 4.6561e-05 - categorical_accuracy: 1.0000
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.00036864000000000005.
# Epoch 45/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 5.7454e-05 - categorical_accuracy: 1.0000
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.00036864000000000005.
# Epoch 46/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 1.8541e-05 - categorical_accuracy: 1.0000
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.00036864000000000005.
# Epoch 47/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 1.9198e-04 - categorical_accuracy: 0.9999
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.00036864000000000005.
# Epoch 48/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 2.6779e-05 - categorical_accuracy: 1.0000
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.00036864000000000005.
# Epoch 49/100
# 26125/26125 [==============================] - 4s 150us/sample - loss: 1.3017e-05 - categorical_accuracy: 1.0000
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0002949120000000001.
# Epoch 50/100
# 26125/26125 [==============================] - 4s 151us/sample - loss: 2.2623e-05 - categorical_accuracy: 1.0000
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0002949120000000001.
# Epoch 51/100
#  2816/26125 [==>...........................] - ETA: 3s - loss: 1.0909e-05 - categorical_accuracy: 1.0000

# %% [markdown]
# # Accuracy

# %%
sum = 0
for acc in accuracies:
    sum += acc
print('Accuracy of K-Fold: ' + str(sum/12))
# Out:
# Accuracy of K-Fold: 0.9268771906693777
