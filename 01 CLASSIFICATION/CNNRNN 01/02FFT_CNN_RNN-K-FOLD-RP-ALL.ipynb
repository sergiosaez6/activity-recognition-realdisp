# %% [markdown]
# # CNN

# %%
import tensorflow.keras as keras

# %%
# Módulos necesarios. Asegurarse de poder importarlos.
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from pylab import rcParams
from scipy import stats
from sklearn import metrics
import seaborn as sns
from sklearn import preprocessing
import os as os
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
from time import time

# Config the matplotlib backend as plotting inline in IPython
# %matplotlib inline

# %%
import sys
print(sys.executable)
print(sys.version)
print(sys.version_info)
tf.__version__
# Out:
# /usr/bin/python
# 3.6.8 (default, Aug 20 2019, 17:12:48)
# [GCC 8.3.0]
# sys.version_info(major=3, minor=6, micro=8, releaselevel='final', serial=0)
# '1.14.0'

# %%
keras.__version__
# Out:
# '2.2.4-tf'

# %% [markdown]
# # 10-FOLD

# %%
subjects = ['01', '02', '03', '05', '08', '09', '10', '11', '13', '14', '16', '17']
global activities
activities = [9,10,11,12,13,19,20,21,24,25,31]

# %%
# Ajustado a los datos
n_time_steps = 128
n_classes = 11 # Nº de clases (el 0 está eliminado)
n_channels = 1 # Nº de canales
n_columns = 20

# Podríamos variarlo
batch_size = 128 # Tamaño del batch
learning_rate = 1e-3 # Learning rate (por defecto es 0.001)
epochs = 100 # Épocas

# %%
class LearningRateDecay:
    def plot(self, epochs, title="Learning Rate Schedule"):
        # compute the set of learning rates for each correRPonding
        # epoch
        lrs = [self(i) for i in epochs]
 
        # the learning rate schedule
        plt.style.use("ggplot")
        plt.figure()
        plt.plot(epochs, lrs)
        plt.title(title)
        plt.xlabel("Epoch #")
        plt.ylabel("Learning Rate")
class StepDecay(LearningRateDecay):
    def __init__(self, initAlpha=0.01, factor=0.25, dropEvery=10):
        # store the base initial learning rate, drop factor, and
        # epochs to drop every
        self.initAlpha = initAlpha
        self.factor = factor
        self.dropEvery = dropEvery
 
    def __call__(self, epoch):
        # compute the learning rate for the current epoch
        exp = np.floor((1 + epoch) / self.dropEvery)
        alpha = self.initAlpha * (self.factor ** exp)
        if(alpha<1e-9):
            alpha=1e-9

        # return the learning rate
        return float(alpha) 

schedule = StepDecay(initAlpha=learning_rate, factor=0.4, dropEvery=10)

reduce_lr = keras.callbacks.LearningRateScheduler(schedule, verbose = 1)
callbacks_list = [reduce_lr]

# %%
#Visualize training evolution
def plot_curves(model, acc, loss, val_acc, val_loss, kfold):
    #########################################################################################
    # LOSS plot
    plt.figure(figsize=(12,8))
    plt.plot(model.history.history[loss], label='Training loss')
    plt.xlabel('Epochs', fontsize=15)
    plt.ylabel('Loss', fontsize=15)
    plt.tick_params(labelsize=10)
    plt.legend(loc=1,prop={'size': 10})
    plt.title('Loss in trainnig', fontsize=20)
    fig = plt.gcf()
    plt.show()
    
    fig.savefig('./02FFT_RP_KFOLD_models/loss_train_02FFT_RP_KFOLD_'+kfold+'.pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./02FFT_RP_KFOLD_models/loss_train_02FFT_RP_KFOLD_'+kfold+'svg', bbox_inches='tight',format='svg')
    
    #########################################################################################
    # ACC plot
    plt.figure(figsize=(12,8))
    plt.plot(model.history.history[acc], label='Training accuracy')
    plt.xlabel('Epochs', fontsize=15)
    plt.ylabel('Accuracy', fontsize=15)
    plt.tick_params(labelsize=10)
    plt.legend(loc=1,prop={'size': 10})
    plt.title('Accuracy in training', fontsize=20)
    fig = plt.gcf()
    plt.show()

    fig.savefig('./02FFT_RP_KFOLD_models/acc_train_02FFT_RP_KFOLD_'+kfold+'pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./02FFT_RP_KFOLD_models/acc_train_02FFT_RP_KFOLD_'+kfold+'svg', bbox_inches='tight',format='svg')
    
    #########################################################################################
    # ACC+LOSS plot
    plt.figure(figsize=(14,10))
    plt_loss = host_subplot(111, axes_class=AA.Axes)
    plt.subplots_adjust(right=0.75)

    plt_acc = plt_loss.twinx()
    plt_acc.axis["right"].toggle(all=True)
    
    plt_loss.set_xlim(0, len(model.history.history[loss]))
    plt_loss.set_ylim(0, max(model.history.history[loss]))
    plt_loss.set_xlabel('Epochs')
    plt_loss.set_ylabel('Loss')
    plt_acc.set_ylabel('Accuracy')
                        
    plt_loss.axis['left'].label.set_fontsize(15)
    plt_loss.axis['bottom'].label.set_fontsize(15)
    plt_acc.axis['right'].label.set_fontsize(15)
    
    plt_loss.plot(model.history.history[loss], c='tab:blue', ls='--', label='Training loss')
    plt_acc.plot(model.history.history[acc], c='tab:orange',ls='--', label='Training accuracy')
    
    plt.tick_params(labelsize=10)
    plt.title('Training performance', fontsize=20)
    plt_acc.set_ylim(0, 1)
    plt_loss.legend(loc=1, prop={'size': 10})
    
    fig = plt.gcf()
    plt.show()

    fig.savefig('./02FFT_RP_KFOLD_models/all_train_02FFT_RP_KFOLD_'+kfold+'pdf', bbox_inches='tight',format='pdf')
    fig.savefig('./02FFT_RP_KFOLD_models/all_train_02FFT_RP_KFOLD_'+kfold+'svg', bbox_inches='tight',format='svg')

# %%
def plot_confusion_matrix(y_true, y_pred, kfold, classes,
                          cmap=plt.cm.Blues):

    # Compute confusion matrix
    cm = metrics.confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(20, 20))
    sns.heatmap(cm, xticklabels=classes, yticklabels=classes, square = True, robust = True, annot=True, cmap='YlOrBr')
    plt.title('CONFUSION MATRIX')
    plt.ylabel('TRUE ACTIVITY')
    plt.xlabel('PREDICTION')
    
    locs, labels = plt.xticks()
    plt.xticks(locs, labels, rotation='vertical')
    locs, labels = plt.yticks()
    plt.yticks(locs, labels, rotation='horizontal')

    # Guardamos la imagen en formato vectorial
    plt.draw()
    plt.savefig('./02FFT_RP_KFOLD_models/matriz_confusion_'+kfold+'.svg', bbox_inches='tight',format='svg')
    plt.show()

# %%
global size
size = 26125

# %%
from sklearn.model_selection import KFold
S = np.arange(0,size)
kf = KFold(n_splits=10)
kf.get_n_splits(S)

print(kf)  

S_train = []
S_test = []

for train_index, test_index in kf.split(S):
    print("TRAIN:", train_index, "TEST:", test_index)
    print(S[train_index])
    print(S[test_index])
    S_train.append(S[train_index])
    S_test.append(S[test_index])
# Out:
# KFold(n_splits=10, random_state=None, shuffle=False)
# TRAIN: [ 2613  2614  2615 ... 26122 26123 26124] TEST: [   0    1    2 ... 2610 2611 2612]
# [ 2613  2614  2615 ... 26122 26123 26124]
# [   0    1    2 ... 2610 2611 2612]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [2613 2614 2615 ... 5223 5224 5225]
# [    0     1     2 ... 26122 26123 26124]
# [2613 2614 2615 ... 5223 5224 5225]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [5226 5227 5228 ... 7836 7837 7838]
# [    0     1     2 ... 26122 26123 26124]
# [5226 5227 5228 ... 7836 7837 7838]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [ 7839  7840  7841 ... 10449 10450 10451]
# [    0     1     2 ... 26122 26123 26124]
# [ 7839  7840  7841 ... 10449 10450 10451]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [10452 10453 10454 ... 13062 13063 13064]
# [    0     1     2 ... 26122 26123 26124]
# [10452 10453 10454 ... 13062 13063 13064]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [13065 13066 13067 ... 15674 15675 15676]
# [    0     1     2 ... 26122 26123 26124]
# [13065 13066 13067 ... 15674 15675 15676]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [15677 15678 15679 ... 18286 18287 18288]
# [    0     1     2 ... 26122 26123 26124]
# [15677 15678 15679 ... 18286 18287 18288]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [18289 18290 18291 ... 20898 20899 20900]
# [    0     1     2 ... 26122 26123 26124]
# [18289 18290 18291 ... 20898 20899 20900]
# TRAIN: [    0     1     2 ... 26122 26123 26124] TEST: [20901 20902 20903 ... 23510 23511 23512]
# [    0     1     2 ... 26122 26123 26124]
# [20901 20902 20903 ... 23510 23511 23512]
# TRAIN: [    0     1     2 ... 23510 23511 23512] TEST: [23513 23514 23515 ... 26122 26123 26124]
# [    0     1     2 ... 23510 23511 23512]
# [23513 23514 23515 ... 26122 26123 26124]

# %%
accuracies = []
for i in range(10):
    if(i<10):
        kfold='0'+str(i)
    else:
        kfold=str(i)
    print('##################################################################################################################################')
    print('#####################################################  K-FOLD %d  ################################################################'%(i+1))
    
    subjects = ['01', '02', '03', '05', '08', '09', '10', '11', '13', '14', '16', '17']
    
    ##  GENERACIÓN DATASET
    tr_seg = np.concatenate((np.load('./augment_norm/subject_'+subjects[0]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects[1]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects[2]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects[3]+'_seg.npy'),
                             np.load('./augment_norm/subject_'+subjects[4]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects[5]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects[6]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects[7]+'_seg.npy'),
                             np.load('./augment_norm/subject_'+subjects[8]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects[9]+'_seg.npy'),np.load('./augment_norm/subject_'+subjects[10]+'_seg.npy')))

    tr_lab = np.concatenate((np.load('./augment_norm/subject_'+subjects[0]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects[1]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects[2]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects[3]+'_lab.npy'),
                             np.load('./augment_norm/subject_'+subjects[4]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects[5]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects[6]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects[7]+'_lab.npy'),
                             np.load('./augment_norm/subject_'+subjects[8]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects[9]+'_lab.npy'),np.load('./augment_norm/subject_'+subjects[10]+'_lab.npy')))
    
    limit = 40
    tr_seg = tr_seg[:,:,:,20:limit]
    ####################################################################################################################
    ## SHUFFLE DE DATOS
    np.random.seed(235)
    tr_seg = np.reshape(tr_seg[np.random.shuffle(np.arange(0,tr_seg.shape[0]))], (size,1,128,20))
    tr_lab = np.reshape(tr_lab[np.random.shuffle(np.arange(0,tr_seg.shape[0]))], (size,11))
    
    ts_seg = tr_seg[S_test[i]]
    ts_lab = tr_lab[S_test[i]]
    
    tr_seg = tr_seg[S_train[i]]
    tr_lab = tr_lab[S_train[i]]
    
    print('Train dataset: ')
    print(tr_seg.shape, tr_lab.shape)
    print('Test dataset: ')
    print(ts_seg.shape, ts_lab.shape)
    ####################################################################################################################
    ## VISTA DE DFT-2D
    plt.figure(figsize=(30,30))
    plt.imshow(np.log(np.abs(np.fft.fftshift(tr_seg[0,0,:,:].T))**2))
    plt.show()
    print('Activity: ',activities[np.argmax(tr_lab[0])])

    plt.figure(figsize=(30,30))
    plt.imshow(np.log(np.fft.fftshift(tr_seg[10,0,:,:].T)**2))
    plt.show()
    print('Activity: ',activities[np.argmax(tr_lab[10])])
    ####################################################################################################################
    ## RED
    quat_input = keras.Input(shape=(n_channels, n_time_steps, n_columns), name='input_layer')
    
    # Some convolutional layers
    conv_1 = keras.layers.Conv2D(32, kernel_size=4,padding='same',activation='relu', data_format = 'channels_first')(quat_input)
    max_1 = keras.layers.MaxPooling2D(pool_size=2, strides=2, padding='same', data_format = 'channels_first')(conv_1)
    bn_1 = keras.layers.BatchNormalization(axis=1)(max_1)
    conv_2 = keras.layers.Conv2D(64,kernel_size=4, padding='same',activation='relu', data_format = 'channels_first')(bn_1)
    max_2 = keras.layers.MaxPooling2D(pool_size=4, strides=4, padding='same', data_format = 'channels_first')(conv_2)
    bn_2 = keras.layers.BatchNormalization(axis=1)(max_2)
    conv_3 = keras.layers.Conv2D(32,kernel_size=4, padding='same',activation='relu', data_format = 'channels_first')(bn_2)
    max_3 = keras.layers.MaxPooling2D(pool_size=2, strides=2, padding='same', data_format = 'channels_first')(conv_3)
    bn_3 = keras.layers.BatchNormalization(axis=1)(max_3)

    # Flatten the output of the convolutional layers
    dr_2 = keras.layers.Dropout(0.5)(bn_3)

    units = 64

    res_1 = keras.layers.Reshape((8,units))(dr_2)

    gru_1 = keras.layers.GRU(units, activation='tanh', return_sequences=False, reset_after = False)(res_1)

    # Output layers: separate outputs for the weather and the ground labels
    multiclass_output = keras.layers.Dense(n_classes, activation='softmax',name='activity_class')(gru_1)

    # Creamos la estrcutura que contendrá a nuestro modelo
    model = keras.Model(inputs=quat_input, outputs=[multiclass_output],name='cnn')

    # Compilamos el modelo
    model.compile(optimizer=keras.optimizers.Adam(lr=learning_rate),
                  loss='categorical_crossentropy', metrics=['categorical_accuracy'])
    
    print(model.summary())
    ####################################################################################################################
    ## TRAIN
    history = model.fit(tr_seg,
                        tr_lab,
                        epochs = epochs,
                        steps_per_epoch = None,
                        verbose = 1,
                        batch_size = batch_size,
                        callbacks = callbacks_list)
    model.save('./02FFT_RP_KFOLD_models/CNN_RNN_'+kfold+'.h5')
    
    #Visualize training evolution
    plot_curves(model, 'categorical_accuracy', 'loss', 'val_categorical_accuracy', 'val_loss', kfold)
    ####################################################################################################################
    ## TEST
    predictions = model.predict(ts_seg, batch_size = batch_size, verbose = 1)
    
    print(predictions.shape)
    
    y_pred = np.argmax(predictions,axis=-1)
    y_pred = np.expand_dims(y_pred,axis=-1)
    print(y_pred[:100].T)
    
    y_true = np.argmax(ts_lab,axis=-1)
    y_true = np.expand_dims(y_true,axis=-1)
    print(y_true.shape)
    print(y_true[:100].T)
    
    evaluation = model.evaluate(ts_seg, ts_lab, batch_size=batch_size, verbose=1)
    accuracies.append(evaluation[1])
    
    fo = open('./02FFT_RP_KFOLD_models/accuracy_'+kfold+'.txt', "w")
    fo.seek(0,2)
    fo.write(str(evaluation))
    fo.close()
    
    ####################################################################################################################
    ## CONFUSION MATRIX
    y_true_flat = np.ndarray.flatten(y_true)
    y_pred_flat = np.ndarray.flatten(y_pred)
    
    plot_confusion_matrix(y_true_flat, y_pred_flat, kfold, classes=activities)
    
    del kfold, limit, tr_seg, tr_lab, ts_seg, ts_lab, model, history, y_pred, y_true, predictions, evaluation, y_true_flat, y_pred_flat
# Out:
# ##################################################################################################################################
# #####################################################  K-FOLD 7  ################################################################
# Train dataset:
# (23513, 1, 128, 20) (23513, 11)
# Test dataset:
# (2612, 1, 128, 20) (2612, 11)
# Activity:  13
# Activity:  25
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 20)]      0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 32, 128, 20)       544
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 64, 10)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 64, 10)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 10)        32832
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 16, 3)         0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 16, 3)         256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 16, 3)         32800
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 8, 2)          0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32, 8, 2)          128
# _________________________________________________________________
# dropout (Dropout)            (None, 32, 8, 2)          0
# _________________________________________________________________
# reshape (Reshape)            (None, 8, 64)             0
# _________________________________________________________________
# gru (GRU)                    (None, 64)                24768
# _________________________________________________________________
# activity_class (Dense)       (None, 11)                715
# =================================================================
# Total params: 92,171
# Trainable params: 91,915
# Non-trainable params: 256
# _________________________________________________________________
# None
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/100
# 23513/23513 [==============================] - 15s 628us/sample - loss: 0.8444 - categorical_accuracy: 0.7285
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/100
# 23513/23513 [==============================] - 6s 274us/sample - loss: 0.1045 - categorical_accuracy: 0.9727
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 0.0462 - categorical_accuracy: 0.9868
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 0.0280 - categorical_accuracy: 0.9920
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/100
# 23513/23513 [==============================] - 6s 265us/sample - loss: 0.0320 - categorical_accuracy: 0.9903
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 0.0147 - categorical_accuracy: 0.9960
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 0.0127 - categorical_accuracy: 0.9965
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 0.0200 - categorical_accuracy: 0.9938
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 0.0109 - categorical_accuracy: 0.9967
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 10/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 0.0033 - categorical_accuracy: 0.9992
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 11/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 0.0015 - categorical_accuracy: 0.9998
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 12/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 0.0017 - categorical_accuracy: 0.9996
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 13/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 0.0012 - categorical_accuracy: 0.9998
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 14/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 8.6792e-04 - categorical_accuracy: 0.9998
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 15/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 0.0012 - categorical_accuracy: 0.9997
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 16/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 0.0012 - categorical_accuracy: 0.9999
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 17/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 5.8757e-04 - categorical_accuracy: 1.0000
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 18/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 0.0015 - categorical_accuracy: 0.9996
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 19/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 6.7129e-04 - categorical_accuracy: 0.9999
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 20/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 9.6414e-04 - categorical_accuracy: 0.9997
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 21/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 5.3255e-04 - categorical_accuracy: 0.9999
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 22/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 4.0882e-04 - categorical_accuracy: 1.0000
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 23/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 3.9531e-04 - categorical_accuracy: 1.0000
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 24/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 4.5511e-04 - categorical_accuracy: 1.0000
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 25/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 8.8448e-04 - categorical_accuracy: 0.9998
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 26/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 5.4332e-04 - categorical_accuracy: 1.0000
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 27/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 3.8165e-04 - categorical_accuracy: 1.0000
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 28/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 3.2869e-04 - categorical_accuracy: 1.0000
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 29/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 2.7441e-04 - categorical_accuracy: 1.0000
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 30/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 5.9644e-04 - categorical_accuracy: 0.9998
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 31/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 5.7557e-04 - categorical_accuracy: 0.9999
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 32/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 3.4389e-04 - categorical_accuracy: 1.0000
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 33/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 2.5240e-04 - categorical_accuracy: 1.0000
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 34/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 2.1622e-04 - categorical_accuracy: 1.0000
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 35/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 3.3000e-04 - categorical_accuracy: 1.0000
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 36/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 2.0970e-04 - categorical_accuracy: 1.0000
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 37/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 2.3849e-04 - categorical_accuracy: 1.0000
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 38/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 1.9361e-04 - categorical_accuracy: 1.0000
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 39/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 3.7914e-04 - categorical_accuracy: 1.0000
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 40/100
# 23513/23513 [==============================] - 6s 265us/sample - loss: 1.9431e-04 - categorical_accuracy: 1.0000
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 41/100
# 23513/23513 [==============================] - 6s 265us/sample - loss: 2.3120e-04 - categorical_accuracy: 1.0000
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 42/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 3.1045e-04 - categorical_accuracy: 1.0000
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 43/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 2.5604e-04 - categorical_accuracy: 1.0000
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 44/100
# 23513/23513 [==============================] - 6s 265us/sample - loss: 2.4959e-04 - categorical_accuracy: 1.0000
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 45/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 2.9381e-04 - categorical_accuracy: 0.9999
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 46/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.4176e-04 - categorical_accuracy: 1.0000
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 47/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.6533e-04 - categorical_accuracy: 1.0000
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 48/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.3828e-04 - categorical_accuracy: 1.0000
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 49/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.6138e-04 - categorical_accuracy: 1.0000
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 50/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 3.2363e-04 - categorical_accuracy: 1.0000
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 51/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.6959e-04 - categorical_accuracy: 1.0000
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 52/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.3023e-04 - categorical_accuracy: 1.0000
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 53/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.5178e-04 - categorical_accuracy: 1.0000
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 54/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.6387e-04 - categorical_accuracy: 1.0000
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 55/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.3718e-04 - categorical_accuracy: 1.0000
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 56/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.2343e-04 - categorical_accuracy: 1.0000
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 57/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.5466e-04 - categorical_accuracy: 1.0000
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 58/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.3758e-04 - categorical_accuracy: 1.0000
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 59/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.5824e-04 - categorical_accuracy: 1.0000
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 60/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 2.2904e-04 - categorical_accuracy: 1.0000
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 61/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.4309e-04 - categorical_accuracy: 1.0000
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 62/100
# 23513/23513 [==============================] - 6s 265us/sample - loss: 1.2950e-04 - categorical_accuracy: 1.0000
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 63/100
# 23513/23513 [==============================] - 6s 265us/sample - loss: 1.2286e-04 - categorical_accuracy: 1.0000
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 64/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.3354e-04 - categorical_accuracy: 1.0000
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 65/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.2441e-04 - categorical_accuracy: 1.0000
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 66/100
# 23513/23513 [==============================] - 6s 265us/sample - loss: 1.0743e-04 - categorical_accuracy: 1.0000
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 67/100
# 23513/23513 [==============================] - 6s 265us/sample - loss: 1.4204e-04 - categorical_accuracy: 1.0000
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 68/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 1.6561e-04 - categorical_accuracy: 1.0000
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 69/100
# 23513/23513 [==============================] - 6s 265us/sample - loss: 1.1463e-04 - categorical_accuracy: 1.0000
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 70/100
# 23513/23513 [==============================] - 6s 265us/sample - loss: 1.4258e-04 - categorical_accuracy: 1.0000
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 71/100
# 19072/23513 [=======================>......] - ETA: 1s - loss: 1.2438e-04 - categorical_accuracy: 1.0000
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 23513/23513 [==============================] - 6s 265us/sample - loss: 0.0521 - categorical_accuracy: 0.9870
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/100
# 23513/23513 [==============================] - 6s 265us/sample - loss: 0.0289 - categorical_accuracy: 0.9922
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 0.0219 - categorical_accuracy: 0.9937
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 0.0212 - categorical_accuracy: 0.9938
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 0.0214 - categorical_accuracy: 0.9936
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 0.0082 - categorical_accuracy: 0.9977
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 0.0118 - categorical_accuracy: 0.9964
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 10/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 0.0030 - categorical_accuracy: 0.9994
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 11/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 0.0026 - categorical_accuracy: 0.9993
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 12/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 0.0025 - categorical_accuracy: 0.9993
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 13/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 0.0018 - categorical_accuracy: 0.9997
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 14/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 0.0025 - categorical_accuracy: 0.9994
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 15/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 9.6886e-04 - categorical_accuracy: 0.9998
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 16/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 9.9835e-04 - categorical_accuracy: 0.9998
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 17/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 0.0015 - categorical_accuracy: 0.9997
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 18/100
# 23513/23513 [==============================] - 6s 265us/sample - loss: 0.0033 - categorical_accuracy: 0.9991
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 19/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 0.0025 - categorical_accuracy: 0.9992
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 20/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 0.0012 - categorical_accuracy: 0.9998
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 21/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 0.0011 - categorical_accuracy: 0.9997
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 22/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 5.0677e-04 - categorical_accuracy: 1.0000
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 23/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 4.2091e-04 - categorical_accuracy: 1.0000
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 24/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 8.6064e-04 - categorical_accuracy: 0.9997
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 25/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 6.6256e-04 - categorical_accuracy: 0.9999
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 26/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 6.0728e-04 - categorical_accuracy: 0.9999
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 27/100
# 23513/23513 [==============================] - 6s 265us/sample - loss: 5.1002e-04 - categorical_accuracy: 1.0000
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 28/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 3.8611e-04 - categorical_accuracy: 1.0000
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 29/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 0.0010 - categorical_accuracy: 0.9997
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 30/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 4.6642e-04 - categorical_accuracy: 0.9999
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 31/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 4.2013e-04 - categorical_accuracy: 0.9999
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 32/100
# 23513/23513 [==============================] - 6s 265us/sample - loss: 2.2745e-04 - categorical_accuracy: 1.0000
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 33/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 2.4245e-04 - categorical_accuracy: 1.0000
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 34/100
# 21632/23513 [==========================>...] - ETA: 0s - loss: 3.2422e-04 - categorical_accuracy: 1.0000
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.2810e-04 - categorical_accuracy: 1.0000
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 71/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.3056e-04 - categorical_accuracy: 1.0000
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 72/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.1949e-04 - categorical_accuracy: 1.0000
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 73/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.0708e-04 - categorical_accuracy: 1.0000
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 74/100
# 23513/23513 [==============================] - 6s 265us/sample - loss: 2.0310e-04 - categorical_accuracy: 0.9999
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 75/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.4019e-04 - categorical_accuracy: 1.0000
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 76/100
# 23513/23513 [==============================] - 6s 265us/sample - loss: 1.0238e-04 - categorical_accuracy: 1.0000
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 77/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.0806e-04 - categorical_accuracy: 1.0000
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 78/100
# 23513/23513 [==============================] - 6s 265us/sample - loss: 1.2178e-04 - categorical_accuracy: 1.0000
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 79/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.0375e-04 - categorical_accuracy: 1.0000
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 80/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.4778e-04 - categorical_accuracy: 1.0000
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 81/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.0053e-04 - categorical_accuracy: 1.0000
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 82/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.7916e-04 - categorical_accuracy: 1.0000
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 83/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 1.3884e-04 - categorical_accuracy: 1.0000
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 84/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.6466e-04 - categorical_accuracy: 1.0000
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 85/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.2252e-04 - categorical_accuracy: 1.0000
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 86/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.3278e-04 - categorical_accuracy: 1.0000
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 87/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.0399e-04 - categorical_accuracy: 1.0000
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 88/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.6146e-04 - categorical_accuracy: 1.0000
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 89/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.2998e-04 - categorical_accuracy: 1.0000
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 90/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.1520e-04 - categorical_accuracy: 1.0000
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 91/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.0650e-04 - categorical_accuracy: 1.0000
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 92/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.5470e-04 - categorical_accuracy: 1.0000
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 93/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 2.1125e-04 - categorical_accuracy: 1.0000
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 94/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.1261e-04 - categorical_accuracy: 1.0000
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 95/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.0262e-04 - categorical_accuracy: 1.0000
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 96/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.1221e-04 - categorical_accuracy: 1.0000
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 97/100
# 23513/23513 [==============================] - 6s 265us/sample - loss: 1.3436e-04 - categorical_accuracy: 1.0000
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 98/100
# 23513/23513 [==============================] - 6s 265us/sample - loss: 9.9150e-05 - categorical_accuracy: 1.0000
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 99/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.9080e-04 - categorical_accuracy: 1.0000
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 1.0485760000000006e-07.
# Epoch 100/100
# 23513/23513 [==============================] - 6s 265us/sample - loss: 1.0777e-04 - categorical_accuracy: 1.0000
# 2612/2612 [==============================] - 0s 174us/sample
# (2612, 11)
# [[ 7  2  4  5  8  4  4  9 10  7  4  4  3  0  8  9  2  7  8  1  2  5  0  5
#    0  1  5  6  5  3  6  1  2  7 10  1  5  0  7  9  6  6  8  5  6  7  6  4
#    4  2  1  3  5  0  8  2  9 10  9  5  5  1 10  7  2  7  7  9  0  1  4  6
#    8  6  4  3  4  2  6  8  2  4 10  4 10 10 10  0  4  1  5 10  4  0 10  5
#    3  6 10  2]]
# (2612, 1)
# [[ 7  2  4  5  8  4  4  9 10  7  4  4  3  0  8  9  2  7  8  1  2  5  0  5
#    0  1  5  6  5  3  6  1  2  7 10  1  5  0  7  9  6  6  8  5  6  7  6  4
#    4  2  1  3  5  0  8  2  9 10  9  5  5  1 10  7  2  7  7  9  0  1  4  6
#    8  6  4  3  4  2  6  8  2  4 10  4 10 10 10  0  4  1  5 10  4  0 10  5
#    3  6 10  2]]
# 2612/2612 [==============================] - 1s 193us/sample - loss: 4.1998e-04 - categorical_accuracy: 0.9996
# ##################################################################################################################################
# #####################################################  K-FOLD 9  ################################################################
# Train dataset:
# (23513, 1, 128, 20) (23513, 11)
# Test dataset:
# (2612, 1, 128, 20) (2612, 11)
# Activity:  13
# Activity:  25
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 20)]      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 128, 20)       544
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 32, 64, 10)        0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 32, 64, 10)        128
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 64, 64, 10)        32832
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 64, 16, 3)         0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 64, 16, 3)         256
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 32, 16, 3)         32800
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 32, 8, 2)          0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32, 8, 2)          128
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32, 8, 2)          0
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 8, 64)             0
# _________________________________________________________________
# gru_2 (GRU)                  (None, 64)                24768
# _________________________________________________________________
# activity_class (Dense)       (None, 11)                715
# =================================================================
# Total params: 92,171
# Trainable params: 91,915
# Non-trainable params: 256
# _________________________________________________________________
# None
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/100
# 21120/23513 [=========================>....] - ETA: 0s - loss: 0.9017 - categorical_accuracy: 0.7053
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.7912e-04 - categorical_accuracy: 1.0000
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 38/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 1.8747e-04 - categorical_accuracy: 1.0000
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 39/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 2.8081e-04 - categorical_accuracy: 0.9999
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 40/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 1.5352e-04 - categorical_accuracy: 1.0000
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 41/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 2.8263e-04 - categorical_accuracy: 1.0000
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 42/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 1.9736e-04 - categorical_accuracy: 1.0000
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 43/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.7433e-04 - categorical_accuracy: 1.0000
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 44/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.9430e-04 - categorical_accuracy: 1.0000
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 45/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 1.8878e-04 - categorical_accuracy: 1.0000
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 46/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 1.5075e-04 - categorical_accuracy: 1.0000
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 47/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 1.3900e-04 - categorical_accuracy: 1.0000
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 48/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 1.4047e-04 - categorical_accuracy: 1.0000
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 49/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 1.8151e-04 - categorical_accuracy: 1.0000
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 50/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 2.8635e-04 - categorical_accuracy: 0.9999
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 51/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 2.7155e-04 - categorical_accuracy: 1.0000
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 52/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 3.0850e-04 - categorical_accuracy: 1.0000
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 53/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 2.2613e-04 - categorical_accuracy: 0.9999
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 54/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.4032e-04 - categorical_accuracy: 1.0000
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 55/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.5273e-04 - categorical_accuracy: 1.0000
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 56/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 1.4043e-04 - categorical_accuracy: 1.0000
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 57/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 1.2168e-04 - categorical_accuracy: 1.0000
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 58/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 2.2655e-04 - categorical_accuracy: 0.9999
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 59/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.6261e-04 - categorical_accuracy: 1.0000
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 60/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 1.4349e-04 - categorical_accuracy: 1.0000
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 61/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 1.2768e-04 - categorical_accuracy: 1.0000
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 62/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 1.3695e-04 - categorical_accuracy: 1.0000
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 63/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 1.4154e-04 - categorical_accuracy: 1.0000
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 64/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.2213e-04 - categorical_accuracy: 1.0000
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 65/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 1.2947e-04 - categorical_accuracy: 1.0000
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 66/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 1.0581e-04 - categorical_accuracy: 1.0000
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 67/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.0536e-04 - categorical_accuracy: 1.0000
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 68/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 1.2744e-04 - categorical_accuracy: 1.0000
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 69/100
# 18560/23513 [======================>.......] - ETA: 1s - loss: 1.2604e-04 - categorical_accuracy: 1.0000
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 23513/23513 [==============================] - 6s 267us/sample - loss: 1.6467e-04 - categorical_accuracy: 1.0000
# 2612/2612 [==============================] - 0s 186us/sample
# (2612, 11)
# [[ 9  8  4 10  0  6  4  4 10  9  4 10 10  5  8  4  5  4  4  0  8  8  0  7
#    9  7  3 10  0  3  0  2  9  1  0  5  8  4  8 10  5  0  0  2  2  6  3  5
#    2  2  1  0  3  6  2  1  5  1  5  6  0  4  9  9  7  9  2  8  9  8  5  3
#    0  3  1  2  6  8  2  4 10 10  7  7  8  2  3  6  2  8  0  8  3  3  9  8
#    6  1  4 10]]
# (2612, 1)
# [[ 9  8  4 10  0  6  4  4 10  9  4 10 10  5  8  4  5  4  4  0  8  8  0  7
#    9  7  3 10  0  3  0  2  9  1  0  5  8  4  8 10  5  0  0  2  2  6  3  5
#    2  2  1  0  3  6  2  1  5  1  5  6  0  4  9  9  7  9  2  8  9  8  5  3
#    0  3  1  2  6  8  2  4 10 10  7  7  8  2  3  6  2  8  0  8  3  3  9  8
#    6  1  4 10]]
# 2612/2612 [==============================] - 1s 206us/sample - loss: 0.0228 - categorical_accuracy: 0.9912
# ##################################################################################################################################
# #####################################################  K-FOLD 10  ################################################################
# Train dataset:
# (23513, 1, 128, 20) (23513, 11)
# Test dataset:
# (2612, 1, 128, 20) (2612, 11)
# Activity:  13
# Activity:  25
# Model: "cnn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 1, 128, 20)]      0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 32, 128, 20)       544
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 32, 64, 10)        0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 32, 64, 10)        128
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 64, 64, 10)        32832
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 64, 16, 3)         0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 64, 16, 3)         256
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 32, 16, 3)         32800
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 32, 8, 2)          0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 32, 8, 2)          128
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32, 8, 2)          0
# _________________________________________________________________
# reshape_3 (Reshape)          (None, 8, 64)             0
# _________________________________________________________________
# gru_3 (GRU)                  (None, 64)                24768
# _________________________________________________________________
# activity_class (Dense)       (None, 11)                715
# =================================================================
# Total params: 92,171
# Trainable params: 91,915
# Non-trainable params: 256
# _________________________________________________________________
# None
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 1/100
# 23513/23513 [==============================] - 7s 303us/sample - loss: 0.8039 - categorical_accuracy: 0.7506
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 2/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 0.0972 - categorical_accuracy: 0.9754
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 3/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 0.0432 - categorical_accuracy: 0.9879
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 4/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 0.0292 - categorical_accuracy: 0.9920
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 5/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 0.0260 - categorical_accuracy: 0.9925
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 6/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 0.0167 - categorical_accuracy: 0.9957
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 7/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 0.0097 - categorical_accuracy: 0.9974
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 8/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 0.0194 - categorical_accuracy: 0.9940
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.001.
# Epoch 9/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 0.0154 - categorical_accuracy: 0.9951
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 10/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 0.0030 - categorical_accuracy: 0.9994
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 11/100
# ...
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 17/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 0.0020 - categorical_accuracy: 0.9995
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 18/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 0.0013 - categorical_accuracy: 0.9997
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0004.
# Epoch 19/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 0.0041 - categorical_accuracy: 0.9987
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 20/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 0.0013 - categorical_accuracy: 0.9997
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 21/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 7.5423e-04 - categorical_accuracy: 0.9999
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 22/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 5.1875e-04 - categorical_accuracy: 1.0000
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 23/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 9.4677e-04 - categorical_accuracy: 0.9998
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 24/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 6.2632e-04 - categorical_accuracy: 1.0000
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 25/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 5.3543e-04 - categorical_accuracy: 0.9999
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 26/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 4.0419e-04 - categorical_accuracy: 0.9999
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 27/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 7.9836e-04 - categorical_accuracy: 0.9999
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 28/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 5.5595e-04 - categorical_accuracy: 0.9999
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00016000000000000004.
# Epoch 29/100
# 23513/23513 [==============================] - 6s 266us/sample - loss: 6.1741e-04 - categorical_accuracy: 0.9999
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 30/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 3.7698e-04 - categorical_accuracy: 0.9999
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 31/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 2.7437e-04 - categorical_accuracy: 1.0000
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 6.400000000000001e-05.
# Epoch 32/100
# 12672/23513 [===============>..............] - ETA: 2s - loss: 2.4550e-04 - categorical_accuracy: 1.0000
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 23513/23513 [==============================] - 6s 269us/sample - loss: 2.4914e-04 - categorical_accuracy: 1.0000
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 47/100
# 23513/23513 [==============================] - 6s 270us/sample - loss: 1.7393e-04 - categorical_accuracy: 1.0000
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 48/100
# 23513/23513 [==============================] - 6s 270us/sample - loss: 3.2643e-04 - categorical_accuracy: 0.9999
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 2.5600000000000006e-05.
# Epoch 49/100
# 23513/23513 [==============================] - 6s 270us/sample - loss: 1.9361e-04 - categorical_accuracy: 1.0000
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 50/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.5551e-04 - categorical_accuracy: 1.0000
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 51/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 2.0278e-04 - categorical_accuracy: 1.0000
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 52/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.5680e-04 - categorical_accuracy: 1.0000
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 53/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.7767e-04 - categorical_accuracy: 1.0000
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 54/100
# 23513/23513 [==============================] - 6s 270us/sample - loss: 1.3399e-04 - categorical_accuracy: 1.0000
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 55/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.4581e-04 - categorical_accuracy: 1.0000
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 56/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 1.3861e-04 - categorical_accuracy: 1.0000
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 57/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.3704e-04 - categorical_accuracy: 1.0000
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 58/100
# 23513/23513 [==============================] - 6s 269us/sample - loss: 2.3604e-04 - categorical_accuracy: 1.0000
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 1.0240000000000004e-05.
# Epoch 59/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.2239e-04 - categorical_accuracy: 1.0000
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 60/100
# 23513/23513 [==============================] - 6s 269us/sample - loss: 1.8621e-04 - categorical_accuracy: 1.0000
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 61/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 2.1362e-04 - categorical_accuracy: 0.9999
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 62/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.3807e-04 - categorical_accuracy: 1.0000
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 63/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.7944e-04 - categorical_accuracy: 1.0000
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 64/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.2122e-04 - categorical_accuracy: 1.0000
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 65/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.6438e-04 - categorical_accuracy: 1.0000
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 66/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.9944e-04 - categorical_accuracy: 1.0000
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 67/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.6970e-04 - categorical_accuracy: 1.0000
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 68/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 1.0672e-04 - categorical_accuracy: 1.0000
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 4.096000000000002e-06.
# Epoch 69/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 1.0886e-04 - categorical_accuracy: 1.0000
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 70/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.0466e-04 - categorical_accuracy: 1.0000
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 71/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 1.7802e-04 - categorical_accuracy: 1.0000
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 72/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 1.6576e-04 - categorical_accuracy: 1.0000
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 73/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.6795e-04 - categorical_accuracy: 1.0000
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 74/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 4.3365e-04 - categorical_accuracy: 0.9999
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 75/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.1140e-04 - categorical_accuracy: 1.0000
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 76/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 3.5428e-04 - categorical_accuracy: 0.9999
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 77/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 2.6855e-04 - categorical_accuracy: 1.0000
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 78/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.1531e-04 - categorical_accuracy: 1.0000
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 1.6384000000000007e-06.
# Epoch 79/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.1260e-04 - categorical_accuracy: 1.0000
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 80/100
# 23513/23513 [==============================] - 6s 269us/sample - loss: 1.2490e-04 - categorical_accuracy: 1.0000
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 81/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.3204e-04 - categorical_accuracy: 1.0000
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 82/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.9322e-04 - categorical_accuracy: 1.0000
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 83/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.1541e-04 - categorical_accuracy: 1.0000
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 84/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.4640e-04 - categorical_accuracy: 1.0000
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 85/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 3.5245e-04 - categorical_accuracy: 0.9999
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 86/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 2.9726e-04 - categorical_accuracy: 1.0000
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 87/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.6676e-04 - categorical_accuracy: 1.0000
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 88/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 1.2780e-04 - categorical_accuracy: 1.0000
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 6.553600000000004e-07.
# Epoch 89/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.2370e-04 - categorical_accuracy: 1.0000
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 90/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.3405e-04 - categorical_accuracy: 1.0000
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 91/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.1473e-04 - categorical_accuracy: 1.0000
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 92/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 1.1394e-04 - categorical_accuracy: 1.0000
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 93/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.3814e-04 - categorical_accuracy: 1.0000
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 94/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.2524e-04 - categorical_accuracy: 1.0000
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 95/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 1.5266e-04 - categorical_accuracy: 1.0000
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 96/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.2523e-04 - categorical_accuracy: 1.0000
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 97/100
# 23513/23513 [==============================] - 6s 267us/sample - loss: 1.1232e-04 - categorical_accuracy: 1.0000
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 98/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.1049e-04 - categorical_accuracy: 1.0000
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 2.6214400000000015e-07.
# Epoch 99/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.4470e-04 - categorical_accuracy: 1.0000
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 1.0485760000000006e-07.
# Epoch 100/100
# 23513/23513 [==============================] - 6s 268us/sample - loss: 1.3285e-04 - categorical_accuracy: 1.0000
# 2612/2612 [==============================] - 1s 194us/sample
# (2612, 11)
# [[ 6  1  3  9  4 10  5  1  4  1  1  8  0 10  3  9  1  8  9  6  1  2  8  1
#    6  0  8  2  2 10  1  4  1  4  2  8  5  4  9  5  1 10  5  8  4  7  4  3
#    6  8  2  4  7  8  1  5  1 10  7  7  0  8  7  9  7  3  4  6  4  4  3  7
#    3  9  0  9  5  8  2  1  2 10 10  1  3  6  9 10 10  1  0  9  8 10 10  2
#   10  2  8  6]]
# (2612, 1)
# [[ 6  1  3  9  4 10  5  1  4  1  1  8  0 10  3  9  1  8  9  6  1  2  8  1
#    6  0  8  2  2 10  1  4  1  4  2  8  5  4  9  5  1 10  5  8  4  7  4  3
#    6  8  2  4  7  8  1  5  1 10  7  7  0  8  7  9  7  3  4  6  4  4  3  7
#    3  9  0  9  5  8  2  1  2 10 10  1  3  6  9 10 10  1  0  9  8 10 10  2
#   10  2  8  6]]
# 2612/2612 [==============================] - 1s 213us/sample - loss: 0.2869 - categorical_accuracy: 0.9445

# %% [markdown]
# # Accuracy

# %%
sum = 0

for acc in accuracies:
    sum += acc

print('Accuracy of K-Fold: ' + str(sum/10))
# Out:
# Accuracy of K-Fold: 0.39352986216545105
